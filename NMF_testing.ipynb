# %%
import pandas as pd
from sklearn.decomposition import NMF
import numpy as np
import time
from sklearn.preprocessing import MinMaxScaler

# %%
ratings= pd.read_csv('./data/ratings.csv')
movies = pd.read_csv('./data/movies.csv')
movie_id_to_title = dict(zip(movies['movieId'], movies['title']))

# %%
def filter_by_average_rating(movies_df, ratings_df, min_rating=0):
    print(f"Filtering movies with average rating >= {min_rating}...")
    
    movies_with_ratings = pd.merge(movies_df, ratings_df, on='movieId', how='inner')
    
    average_ratings = movies_with_ratings.groupby('movieId')['rating'].mean()
    
    popular_movies = average_ratings[average_ratings >= min_rating].index
    
    filtered_movies_with_ratings = movies_with_ratings[movies_with_ratings['movieId'].isin(popular_movies)]
    
    print(f"Kept {len(popular_movies)} movies with average rating >= {min_rating}")
    
    return filtered_movies_with_ratings

# %%
def filter_users_by_activity(ratings_df, min_percentile, max_percentile):

    print(f"Filtering users with activity between {min_percentile*100:.0f}th and {max_percentile*100:.0f}th percentiles...")
    
    # Count ratings per user
    user_rating_counts = ratings_df.groupby('userId')['rating'].count()
    print(f"Before filtering: {len(user_rating_counts)} users with rating statistics:")
    print(user_rating_counts.describe())
    
    # Get percentile thresholds
    min_threshold = user_rating_counts.quantile(min_percentile)
    max_threshold = user_rating_counts.quantile(max_percentile)
    
    # Filter users
    filtered_users = user_rating_counts[(user_rating_counts >= min_threshold) & 
                                       (user_rating_counts <= max_threshold)].index
    
    filtered_ratings = ratings_df[ratings_df['userId'].isin(filtered_users)]
    
    # Get statistics after filtering
    user_rating_counts_after = filtered_ratings.groupby('userId')['rating'].count()
    print(f"After filtering: {len(user_rating_counts_after)} users with rating statistics:")
    print(user_rating_counts_after.describe())
    
    return filtered_ratings

# %%
def filter_movies_by_popularity(ratings_df, min_ratings):

    print(f"Filtering movies with at least {min_ratings} ratings...")
    
    # Count ratings per movie
    movie_rating_counts = ratings_df.groupby('movieId').size()
    
    print(f"Before filtering: {len(movie_rating_counts)} movies")
    print(f"Movies with <{min_ratings} ratings: {(movie_rating_counts < min_ratings).sum()}")
    
    # Filter movies with sufficient ratings
    popular_movies = movie_rating_counts[movie_rating_counts >= min_ratings].index
    
    filtered_ratings = ratings_df[ratings_df['movieId'].isin(popular_movies)]
    
    print(f"After filtering: {len(popular_movies)} movies kept")
    
    return filtered_ratings

# %%
def select_diverse_users(ratings_df, max_users_per_movie=1000, similarity_threshold=0.3):
    """
    Select a diverse set of users, prioritizing users with more ratings.
    
    Parameters:
    -----------
    ratings_df : pandas.DataFrame
        DataFrame containing user ratings
    max_users_per_movie : int
        Maximum number of users allowed per movie
    similarity_threshold : float
        Maximum allowed Jaccard similarity between users
        
    Returns:
    --------
    pandas.DataFrame
        Filtered ratings DataFrame with selected users
    """
    print(f"Selecting diverse users with max {max_users_per_movie} users per movie...")
    
    # Get initial statistics
    total_users = ratings_df['userId'].nunique()
    total_movies = ratings_df['movieId'].nunique()
    total_ratings = len(ratings_df)
    
    print(f"Initial dataset: {total_ratings} ratings from {total_users} users on {total_movies} movies")
    
    # Create a movie-to-users dictionary to track how many users rated each movie
    movie_to_users = {}
    for movie_id, group in ratings_df.groupby('movieId'):
        movie_to_users[movie_id] = set(group['userId'])
    
    # Create a user-to-movies dictionary
    user_to_movies = {}
    for user_id, group in ratings_df.groupby('userId'):
        user_to_movies[user_id] = set(group['movieId'])
    
    # Sort users by the number of ratings (CHANGED: now in descending order)
    user_rating_counts = ratings_df.groupby('userId').size()
    sorted_users = user_rating_counts.sort_values(ascending=False).index.tolist()
    
    # Add some randomness within rating count groups to prevent bias
    # Group users by rating count
    rating_count_groups = {}
    for user_id, count in user_rating_counts.items():
        if count not in rating_count_groups:
            rating_count_groups[count] = []
        rating_count_groups[count].append(user_id)
    
    # Shuffle each group and rebuild the sorted users list
    shuffled_sorted_users = []
    for count in sorted(rating_count_groups.keys(), reverse=True):
        group = rating_count_groups[count]
        np.random.shuffle(group)
        shuffled_sorted_users.extend(group)
    
    selected_users = set()
    movie_user_counts = {movie_id: 0 for movie_id in movie_to_users.keys()}
    
    # Process users in the sorted order (now more ratings first)
    for user_id in shuffled_sorted_users:
        user_movies = user_to_movies[user_id]
        
        # Skip users with too few ratings (optional)
        if len(user_movies) < 0:  # Minimum threshold
            continue
            
        # Check if this user would exceed the max users for any movie
        exceeds_limit = False
        for movie_id in user_movies:
            if movie_user_counts[movie_id] >= max_users_per_movie:
                exceeds_limit = True
                break
        
        # Check similarity with already selected users
        too_similar = False
        if not exceeds_limit and len(selected_users) > 0:
            # Only check similarity with a sample of existing users for efficiency
            # This optimization is crucial when you have many users
            sample_size = min(100, len(selected_users))
            sample_users = np.random.choice(list(selected_users), sample_size, replace=False)
            
            for selected_user in sample_users:
                selected_user_movies = user_to_movies[selected_user]
                
                # Only calculate similarity if there's a minimum overlap
                if len(user_movies) > 0 and len(selected_user_movies) > 0:
                    # Calculate Jaccard similarity between users
                    intersection = len(user_movies.intersection(selected_user_movies))
                    union = len(user_movies.union(selected_user_movies))
                    
                    similarity = intersection / union
                    if similarity > similarity_threshold:
                        too_similar = True
                        break
        
        # Add user if they don't exceed limits and aren't too similar
        if not exceeds_limit and not too_similar:
            selected_users.add(user_id)
            
            # Update movie user counts
            for movie_id in user_movies:
                movie_user_counts[movie_id] += 1
    
    # Filter the ratings DataFrame to only include selected users
    filtered_ratings = ratings_df[ratings_df['userId'].isin(selected_users)]
    
    # Calculate and print statistics
    avg_ratings_per_user = filtered_ratings.groupby('userId').size().mean()
    
    print(f"After filtering: {len(filtered_ratings)} ratings from {len(selected_users)} users")
    print(f"Retained {len(filtered_ratings)/total_ratings:.1%} of original ratings")
    print(f"Average ratings per selected user: {avg_ratings_per_user:.1f}")
    
    return filtered_ratings

# %%
def remove_columns(filtered_df):
    if 'timestamp' in filtered_df.columns:
        filtered_df.drop(columns=["timestamp"], inplace=True)
    if 'genres' in filtered_df.columns:
        filtered_df.drop(columns=["genres"], inplace=True)
    if 'title' in filtered_df.columns:
        filtered_df.drop(columns=["title"], inplace=True)
    
    print(f"Final dataset: {len(filtered_df)} ratings across {filtered_df['movieId'].nunique()} movies from {filtered_df['userId'].nunique()} users")

    return filtered_df

# %%
ratings = remove_columns(ratings)
# Out:
# Final dataset: 33832162 ratings across 83239 movies from 330975 users

# %%
min_avg_rating=0
user_min_percentile=0.10
user_max_percentile=0.997
min_ratings_per_movie=3
max_users_per_movie=120 # 250
user_similarity_threshold=0.15 # 0.15

# %%
# Step 3: Filter users by activity level
filtered_df = filter_users_by_activity(
    ratings,
    min_percentile=user_min_percentile,
    max_percentile=user_max_percentile
)
# Out:
# Filtering users with activity between 10th and 100th percentiles...
# Before filtering: 330975 users with rating statistics:
# count    330975.00000
# mean        102.21969
# std         232.15453
# min           1.00000
# 25%          15.00000
# 50%          31.00000
# 75%          98.00000
# max       33332.00000
# Name: rating, dtype: float64
# After filtering: 297732 users with rating statistics:
# count    297732.000000
# mean        104.751767
# std         178.859589
# min           6.000000
# 25%          16.000000
# 50%          38.000000
# 75%         109.000000
# max        1686.000000
# Name: rating, dtype: float64

# %%
ratings_df = select_diverse_users(
    filtered_df, 
    max_users_per_movie=max_users_per_movie,
    similarity_threshold=user_similarity_threshold,
)
# Out:
# Selecting diverse users with max 120 users per movie...
# Initial dataset: 31187953 ratings from 297732 users on 67240 movies
# After filtering: 351755 ratings from 6244 users
# Retained 1.1% of original ratings
# Average ratings per selected user: 56.3

# %%
ratings_df["userId"].nunique(),ratings_df["movieId"].nunique()
# Out:
# (6244, 35923)

# %%
filtered_df = remove_columns(ratings_df)
# Out:
# Final dataset: 351755 ratings across 35923 movies from 6244 users

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (6244, 35923)

# %%
# Step 2: Filter by average rating
filtered_df = filter_by_average_rating(
    movies, 
    ratings_df, 
    min_rating=min_avg_rating
)
# Out:
# Filtering movies with average rating >= 0...
# Kept 35923 movies with average rating >= 0

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (6244, 35923)

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (6244, 35923)

# %%
filtered_df = filter_movies_by_popularity(
    filtered_df,
    min_ratings=min_ratings_per_movie
)
# Out:
# Filtering movies with at least 3 ratings...
# Before filtering: 35923 movies
# Movies with <3 ratings: 19634
# After filtering: 16289 movies kept

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (6242, 16289)

# %%
def scale_ratings(matrix):

    data = matrix.copy().values
    rows = data.shape[0]
    
    # Scale each user's ratings (each row)
    for i in range(rows):
        # Find rated movies for this user
        nonzero_mask = data[i, :] > 0
        rated_indices = np.where(nonzero_mask)[0]
        
        # Get user's ratings and reshape for scaler
        user_ratings = data[i, rated_indices].reshape(-1, 1)
        
        # Apply MinMaxScaler
        scaler = MinMaxScaler()
        scaled_ratings = scaler.fit_transform(user_ratings).flatten()
        
        # Update the matrix with scaled ratings
        data[i, rated_indices] = scaled_ratings
    
    # Convert back to DataFrame
    scaled_matrix = pd.DataFrame(data, index=matrix.index, columns=matrix.columns)
    return scaled_matrix

# %%
def prepare_user_ratings(ratings_file_path, user_movie_matrix_columns):

    user_data = pd.read_csv(ratings_file_path)
    user_data = user_data.dropna(subset=['movieId'])
    
    # Create user-movie ratings matrix with zero values - using float dtype
    user_ratings = pd.DataFrame(0.0, index=[0], columns=user_movie_matrix_columns, dtype=np.float64)
    
    # Fill with original ratings
    for _, row in user_data.iterrows():
        movie_id = row['movieId']
        if movie_id in user_ratings.columns:
            user_ratings.loc[0, movie_id] = float(row['Rating'])
    
    # Get indices of rated movies
    nonzero_mask = user_ratings.values > 0
    rated_indices = np.where(nonzero_mask[0])[0]
    
    # Get this user's ratings
    user_rating_values = user_ratings.iloc[0, rated_indices].values.reshape(-1, 1)
    
    # Apply MinMaxScaler
    scaler = MinMaxScaler()
    scaled_ratings = scaler.fit_transform(user_rating_values).flatten()
    
    # Update the user ratings with scaled values
    user_ratings.iloc[0, rated_indices] = scaled_ratings
    
    return user_data, user_ratings

# %%
def get_niche_recommendations(
    ratings_df,
    movies_df,
    user_ratings=None,
    n_recommendations=20,
    movie_id_to_title_map=None,
    popularity_percentile=70,  # Exclude movies above this percentile
    min_ratings=5              # Still need some ratings for quality assurance
):
    """
    Recommends niche movies by excluding popular ones.
    
    Parameters:
    -----------
    ratings_df : pandas.DataFrame
        DataFrame containing all ratings
    movies_df : pandas.DataFrame
        DataFrame containing movie information
    user_ratings : pandas.DataFrame, optional
        User's ratings data to calculate similarity or use as input to model
    n_recommendations : int, optional
        Number of recommendations to return
    movie_id_to_title_map : dict, optional
        Dictionary mapping movie IDs to titles
    popularity_percentile : float, optional
        Percentile threshold - movies above this percentile of popularity are excluded
    min_ratings : int, optional
        Minimum number of ratings a movie must have for consideration
        
    Returns:
    --------
    list
        List of tuples (movie_id, score) of recommended niche movies
    """
    # Count ratings per movie to determine popularity
    movie_ratings_count = ratings_df.groupby('movieId').size().reset_index(name='count')
    
    # Calculate the threshold for "popular" movies (e.g., top 30% by default)
    popularity_threshold = movie_ratings_count['count'].quantile(popularity_percentile/100)
    print(f"Popularity threshold: {popularity_threshold} ratings (top {popularity_percentile}%)")
    
    # Identify movies that are not overly popular but have some minimum ratings
    niche_movie_ids = movie_ratings_count[
        (movie_ratings_count['count'] < popularity_threshold) & 
        (movie_ratings_count['count'] >= min_ratings)
    ]['movieId'].values
    
    print(f"Found {len(niche_movie_ids)} niche movies out of {len(movie_ratings_count)} total movies")
    
    # Get already rated movies to exclude from recommendations
    rated_movie_ids = set()
    if user_ratings is not None and 'movieId' in user_ratings.columns:
        rated_movie_ids = set(user_ratings['movieId'].values)
        print(f"User has rated {len(rated_movie_ids)} movies")
    
    # Filter out already rated movies from niche candidates
    niche_candidates = [mid for mid in niche_movie_ids if mid not in rated_movie_ids]
    print(f"After removing rated movies: {len(niche_candidates)} niche candidates remain")
    
    # Calculate average ratings for the niche candidates
    niche_avg_ratings = ratings_df[ratings_df['movieId'].isin(niche_candidates)].groupby('movieId')['rating'].mean()
    
    # Sort by average rating to find the best niche movies
    sorted_niche_movies = niche_avg_ratings.sort_values(ascending=False)
    
    # Get personalized recommendations if user ratings are provided
    if user_ratings is not None and len(user_ratings) > 0:
        print("Using user ratings to personalize niche recommendations...")
        
        # Create a user profile based on genres they like
        # First, get genres for each movie the user has rated highly
        high_rated_movies = user_ratings[user_ratings['rating'] >= 4.0]['movieId'].values
        user_liked_genres = set()
        
        for movie_id in high_rated_movies:
            if movie_id in movies_df['movieId'].values:
                genres = movies_df[movies_df['movieId'] == movie_id]['genres'].values[0]
                user_liked_genres.update(genres.split('|'))
        
        print(f"User seems to like these genres: {', '.join(user_liked_genres)}")
        
        # Score niche movies based on genre match with user preferences
        niche_scores = {}
        for movie_id in niche_candidates:
            if movie_id in movies_df['movieId'].values:
                genres = movies_df[movies_df['movieId'] == movie_id]['genres'].values[0]
                movie_genres = set(genres.split('|'))
                
                # Calculate genre overlap score
                genre_match = len(user_liked_genres.intersection(movie_genres)) / max(1, len(movie_genres))
                
                # Combine with average rating
                avg_rating = niche_avg_ratings.get(movie_id, 0)
                final_score = (0.7 * avg_rating) + (0.3 * genre_match * 5)  # Weight by both factors
                
                niche_scores[movie_id] = final_score
        
        # Sort by final score
        recommendations = sorted(niche_scores.items(), key=lambda x: x[1], reverse=True)[:n_recommendations]
    else:
        # If no user ratings, just recommend the highest-rated niche movies
        recommendations = [(movie_id, score) for movie_id, score in 
                          sorted_niche_movies.head(n_recommendations).items()]
    
    if movie_id_to_title_map:
        print("\nTop Niche Recommendations:")
        for movie_id, score in recommendations:
            movie_title = movie_id_to_title_map.get(movie_id, f"Unknown Movie (ID: {movie_id})")
            count = movie_ratings_count[movie_ratings_count['movieId'] == movie_id]['count'].values[0]
            print(f"Movie: {movie_title}, Score: {score:.2f}, Ratings Count: {count}")
    
    return recommendations

# %%
def fit_model(
    user_movie_matrix,
    n_components=50,
    max_iter=200,
    init='random',
    solver='cd',
    tol=0.0001,

    sample_size=1.0
):

    print(f"\n--- Fitting model with {sample_size*100:.0f}% of users ---")
    
    # Sample users 
    if sample_size < 1.0:
        n_users = int(user_movie_matrix.shape[0] * sample_size)
        sampled_users = np.random.choice(user_movie_matrix.index, size=n_users, replace=False)
        training_matrix = user_movie_matrix.loc[sampled_users, :]
    else:
        training_matrix = user_movie_matrix
    
    print(f"Training matrix shape: {training_matrix.shape}")
    
    # Train the model
    start_time = time.time()
    nmf = NMF(
        n_components=n_components,
        max_iter=max_iter,
        verbose=0,
        init="nndsvd",
        solver=solver,
        tol=tol,
    )
    
    user_factors = nmf.fit_transform(training_matrix)
    item_factors = nmf.components_
    training_time = time.time() - start_time
    
    print(f"Training time: {training_time:.2f} seconds")
    print(f"Iterations completed: {nmf.n_iter_}")
    print(f"Final error: {nmf.reconstruction_err_}")
    
    return nmf, training_matrix, training_time

# %%
def get_recommendations(
    nmf_model,
    training_matrix,
    my_ratings,
    my_data,
    n_recommendations=20,
    movie_id_to_title_map=None
):
    # Transform personal ratings into factor space
    my_user_factors = nmf_model.transform(my_ratings)
    
    # Generate predictions
    predicted_ratings = np.dot(my_user_factors, nmf_model.components_)
    predicted_ratings_df = pd.DataFrame(predicted_ratings, columns=training_matrix.columns)
    
    # Get movies already rated
    rated_movies = set(int(movie_id) for movie_id in my_data['movieId'].values)
    print(f"You've rated {len(rated_movies)} movies")
    
    # Filter for unrated movies
    unrated_movies = [m for m in training_matrix.columns if int(m) not in rated_movies]
    print(f"Found {len(unrated_movies)} movies you haven't rated")
    
    # Get recommendations
    recommendations = []
    for movie_id in unrated_movies:
        pred_rating = predicted_ratings_df.loc[0, movie_id]
        recommendations.append((movie_id, pred_rating))
    
    recommendations.sort(key=lambda x: x[1], reverse=True)
    
    top_recommendations = recommendations[:n_recommendations]
    
    if movie_id_to_title_map:
        print("\nTop Recommendations:")
        for movie_id, predicted_rating in top_recommendations:
            # Convert from 0-1 scale back to 1-5 scale
            original_scale_rating = predicted_rating * 4 + 1 # this didnt work that well tbh
            
            movie_title = movie_id_to_title_map.get(movie_id, f"Unknown Movie (ID: {movie_id})")
            print(f"Movie: {movie_title}, Similarity Rating: {predicted_rating:.2f}/1.00")
    
    return top_recommendations

# %%
user_movie_matrix = filtered_df.pivot(index='userId', columns='movieId', values='rating')
user_movie_matrix = user_movie_matrix.fillna(0)
user_movie_matrix_scaled = scale_ratings(user_movie_matrix)

# %%
nmf_model, training_matrix, _ = fit_model(
    user_movie_matrix_scaled,
    n_components=400,
    sample_size=1,
    max_iter=800,
)
# Out:
# --- Fitting model with 100% of users ---
# Training matrix shape: (6242, 16289)
# Training time: 453.36 seconds
# Iterations completed: 82
# Final error: 218.1725877474704

# %%
import joblib
from joblib import load
from joblib import dump

# %%
# Save the model
dump(nmf_model, 'nmf_model_100comp.joblib')

# Save the training matrix
dump(training_matrix, 'training_matrix_100comp.joblib')

# Alternatively, save everything in one file
model_data = {
    'model': nmf_model,
    'training_matrix': training_matrix,
    'n_components': 100,
    'timestamp': pd.Timestamp.now().strftime('%Y-%m-%d %H:%M')
}
dump(model_data, 'recommender_data_100comp.joblib')

print("Model and training matrix saved successfully!")
# Out:
# Model and training matrix saved successfully!

# %%
# nmf_model = load('nmf_model800.pkl')

# %%
elliott_data, elliott_ratings = prepare_user_ratings(
    "data/loelliot_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
ludde_data, ludde_ratings = prepare_user_ratings(
    "data/ludde_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
charlie_data, charlie_ratings = prepare_user_ratings(
    "data/chaarll_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
tilda_data, tilda_ratings = prepare_user_ratings(
    "data/tilda_h_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
zorrodor_data, zorrodor_ratings = prepare_user_ratings(
    "data/zorrodor_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
lukas_data, lukas_ratings = prepare_user_ratings(
    "data/lukas_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
clara_data, clara_ratings = prepare_user_ratings(
    "data/clar_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
voided_data, voided_ratings = prepare_user_ratings(
    "data/voided_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
skellic_data, skellic_ratings = prepare_user_ratings(
    "data/skellic_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
liv_data, liv_ratings = prepare_user_ratings(
    "data/liv_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)

# %%
# Out:
# User has rated 415 movies
# Total movies available before filtering: 16289
# After removing rated movies: 15874 remain
# After applying min_ratings=1: 15874 remain
# Excluding top 11111 out of 15874 movies (70%)
# After popularity exclusion: 4763 candidates remain
#
# Sample of excluded popular movies:
# 1. Craft, The (1996) (120 ratings)
# 2. Miracle on 34th Street (1994) (120 ratings)
# 3. One Flew Over the Cuckoo's Nest (1975) (120 ratings)
# 4. Lethal Weapon 2 (1989) (120 ratings)
# 5. Departed, The (2006) (120 ratings)

# %%
niche_recommendations = get_niche_recommendations(
    ratings_df=ludde_ratings,
    movies_df=movies,
    n_recommendations=20,
    movie_id_to_title_map=movie_id_to_title,
    popularity_percentile=70,  # Exclude the top 70% most popular movies
    min_ratings=10             # Ensure some minimum quality threshold
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 niche_recommendations = get_niche_recommendations(
#       2     ratings_df=ludde_ratings,
#       3     movies_df=movies,
#       4     n_recommendations=20,
#       5     movie_id_to_title_map=movie_id_to_title,
#       6     popularity_percentile=70,  # Exclude the top 70% most popular movies
#       7     min_ratings=10             # Ensure some minimum quality threshold
#       8 )
#
# Cell In[116], line 36, in get_niche_recommendations(ratings_df, movies_df, user_ratings, n_recommendations, movie_id_to_title_map, popularity_percentile, min_ratings)
#      10 """
#      11 Recommends niche movies by excluding popular ones.
#      12
#    (...)     33     List of tuples (movie_id, score) of recommended niche movies
#      34 """
#      35 # Count ratings per movie to determine popularity
# ---> 36 movie_ratings_count = ratings_df.groupby('movieId').size().reset_index(name='count')
#      38 # Calculate the threshold for "popular" movies (e.g., top 30% by default)
#      39 popularity_threshold = movie_ratings_count['count'].quantile(popularity_percentile/100)
#
# File ~/Desktop/SKOLARBETE-ITHS/repos/ML-Movie-recommendation/.venv/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~/Desktop/SKOLARBETE-ITHS/repos/ML-Movie-recommendation/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/Desktop/SKOLARBETE-ITHS/repos/ML-Movie-recommendation/.venv/lib/python3.12/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'movieId'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=tilda_ratings,
    my_data=tilda_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 285 movies
# Found 16011 movies you haven't rated
#
# Top Recommendations:
# Movie: The Martian (2015), Similarity Rating: 0.41/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.36/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.35/1.00
# Movie: Room (2015), Similarity Rating: 0.34/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.34/1.00
# Movie: Little Women (2019), Similarity Rating: 0.31/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.30/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.30/1.00
# Movie: Moana (2016), Similarity Rating: 0.29/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.29/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 2 (2011), Similarity Rating: 0.29/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.28/1.00
# Movie: Kingsman: The Secret Service (2015), Similarity Rating: 0.28/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.28/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.28/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.27/1.00
# Movie: P.S. I Love You (2007), Similarity Rating: 0.27/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.27/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.27/1.00
# Movie: Avengers, The (2012), Similarity Rating: 0.27/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.27/1.00
# Movie: Django Unchained (2012), Similarity Rating: 0.26/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.26/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.26/1.00
# Movie: Crazy Rich Asians (2018), Similarity Rating: 0.26/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.25/1.00
# Movie: Incredibles, The (2004), Similarity Rating: 0.25/1.00
# Movie: Toy Story 3 (2010), Similarity Rating: 0.25/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.25/1.00
# Movie: Nocturnal Animals, Similarity Rating: 0.25/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.25/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.24/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.24/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 1 (2010), Similarity Rating: 0.24/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.24/1.00
# Movie: Harry Potter and the Half-Blood Prince (2009), Similarity Rating: 0.24/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.24/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.24/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.24/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.24/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.24/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.23/1.00
# Movie: Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005), Similarity Rating: 0.23/1.00
# Movie: The Age of Adaline (2015), Similarity Rating: 0.23/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.23/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.22/1.00
# Movie: Proposal, The (2009), Similarity Rating: 0.22/1.00
# Movie: 50 First Dates (2004), Similarity Rating: 0.22/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.22/1.00
# Movie: Cast Away (2000), Similarity Rating: 0.22/1.00
# Movie: Frozen (2013), Similarity Rating: 0.21/1.00
# Movie: Kick-Ass (2010), Similarity Rating: 0.21/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.21/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.21/1.00
# Movie: We're the Millers (2013), Similarity Rating: 0.21/1.00
# Movie: Me Before You (2016), Similarity Rating: 0.21/1.00
# Movie: How to Train Your Dragon (2010), Similarity Rating: 0.21/1.00
# Movie: Lake House, The (2006), Similarity Rating: 0.20/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.20/1.00
# Movie: Secret Life of Walter Mitty, The (2013), Similarity Rating: 0.20/1.00
# Movie: Encanto (2021), Similarity Rating: 0.20/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.20/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.20/1.00
# Movie: Brave (2012), Similarity Rating: 0.20/1.00
# Movie: Intouchables (2011), Similarity Rating: 0.20/1.00
# Movie: Tangled (2010), Similarity Rating: 0.20/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.20/1.00
# Movie: Aladdin (1992), Similarity Rating: 0.20/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.20/1.00
# Movie: Ice Age (2002), Similarity Rating: 0.20/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.20/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.20/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.19/1.00
# Movie: Kingsman: The Golden Circle (2017), Similarity Rating: 0.19/1.00
# Movie: Set It Up (2018), Similarity Rating: 0.19/1.00
# Movie: Sound of Metal (2019), Similarity Rating: 0.19/1.00
# Movie: The Intern (2015), Similarity Rating: 0.19/1.00
# Movie: Meet the Parents (2000), Similarity Rating: 0.19/1.00
# Movie: Help, The (2011), Similarity Rating: 0.19/1.00
# Movie: Beauty and the Beast (1991), Similarity Rating: 0.19/1.00
# Movie: Ready Player One, Similarity Rating: 0.19/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.19/1.00
# Movie: Edge of Tomorrow (2014), Similarity Rating: 0.18/1.00
# Movie: Bridget Jones's Diary (2001), Similarity Rating: 0.18/1.00
# Movie: One Day (2011), Similarity Rating: 0.18/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.18/1.00
# Movie: Beautiful Mind, A (2001), Similarity Rating: 0.18/1.00
# Movie: When Harry Met Sally... (1989), Similarity Rating: 0.18/1.00
# Movie: Love, Rosie (2014), Similarity Rating: 0.18/1.00
# Movie: Shrek 2 (2004), Similarity Rating: 0.18/1.00
# Movie: American Hustle (2013), Similarity Rating: 0.18/1.00
# Movie: Limitless (2011), Similarity Rating: 0.18/1.00
# Movie: Kung Fu Panda (2008), Similarity Rating: 0.18/1.00
# Movie: Bruce Almighty (2003), Similarity Rating: 0.18/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.18/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.18/1.00
# Movie: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), Similarity Rating: 0.18/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.18/1.00
# Movie: Wizard of Oz, The (1939), Similarity Rating: 0.18/1.00
# Movie: A Simple Favor (2018), Similarity Rating: 0.18/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.18/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.18/1.00
# Movie: Us (2019), Similarity Rating: 0.18/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.17/1.00
# Movie: Passengers (2016), Similarity Rating: 0.17/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.17/1.00
# Movie: Curious Case of Benjamin Button, The (2008), Similarity Rating: 0.17/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.17/1.00
# Movie: Incredibles 2 (2018), Similarity Rating: 0.17/1.00
# Movie: Game Night (2018), Similarity Rating: 0.17/1.00
# Movie: Good Time (2017), Similarity Rating: 0.17/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.17/1.00
# Movie: Thor (2011), Similarity Rating: 0.17/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.17/1.00
# Movie: Seven (a.k.a. Se7en) (1995), Similarity Rating: 0.17/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.17/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.17/1.00
# Movie: The Butterfly Effect (2004), Similarity Rating: 0.17/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.17/1.00
# Movie: Spider-Man (2002), Similarity Rating: 0.17/1.00
# Movie: The Lego Batman Movie (2017), Similarity Rating: 0.17/1.00
# Movie: Mulan (1998), Similarity Rating: 0.17/1.00
# Movie: About a Boy (2002), Similarity Rating: 0.17/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.16/1.00
# Movie: Great Gatsby, The (2013), Similarity Rating: 0.16/1.00
# Movie: Moonlight, Similarity Rating: 0.16/1.00
# Movie: 50/50 (2011), Similarity Rating: 0.16/1.00
# Movie: Captain America: The First Avenger (2011), Similarity Rating: 0.16/1.00
# Movie: Wonder Woman (2017), Similarity Rating: 0.16/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.16/1.00
# Movie: Moon (2009), Similarity Rating: 0.16/1.00
# Movie: Who Framed Roger Rabbit? (1988), Similarity Rating: 0.16/1.00
# Movie: Spider-Man: No Way Home (2021), Similarity Rating: 0.16/1.00
# Movie: Searching (2018), Similarity Rating: 0.16/1.00
# Movie: Batman Begins (2005), Similarity Rating: 0.16/1.00
# Movie: I'm Thinking of Ending Things, Similarity Rating: 0.16/1.00
# Movie: Time Traveler's Wife, The (2009), Similarity Rating: 0.16/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.16/1.00
# Movie: X-Men: First Class (2011), Similarity Rating: 0.16/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.16/1.00
# Movie: Zoolander (2001), Similarity Rating: 0.16/1.00
# Movie: Promising Young Woman (2020), Similarity Rating: 0.16/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.16/1.00
# Movie: Hotel Transylvania (2012), Similarity Rating: 0.16/1.00
# Movie: Garden State (2004), Similarity Rating: 0.16/1.00
# Movie: Blue Valentine (2010), Similarity Rating: 0.16/1.00
# Movie: Charlie and the Chocolate Factory (2005), Similarity Rating: 0.16/1.00
# Movie: Avatar (2009), Similarity Rating: 0.16/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.16/1.00
# Movie: Solo: A Star Wars Story (2018), Similarity Rating: 0.16/1.00
# Movie: Shang-Chi and the Legend of the Ten Rings (2021), Similarity Rating: 0.16/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.16/1.00
# Movie: How to Train Your Dragon: The Hidden World (2019), Similarity Rating: 0.16/1.00
# Movie: X-Men: Days of Future Past (2014), Similarity Rating: 0.16/1.00
# Movie: Safe Haven (2013), Similarity Rating: 0.16/1.00
# Movie: Memento (2000), Similarity Rating: 0.16/1.00
# Movie: Office Space (1999), Similarity Rating: 0.16/1.00
# Movie: Ant-Man and the Wasp (2018), Similarity Rating: 0.16/1.00
# Movie: Rogue One: A Star Wars Story (2016), Similarity Rating: 0.15/1.00
# Movie: You've Got Mail (1998), Similarity Rating: 0.15/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.15/1.00
# Movie: Shaun of the Dead (2004), Similarity Rating: 0.15/1.00
# Movie: Before Sunset (2004), Similarity Rating: 0.15/1.00
# Movie: Willy Wonka & the Chocolate Factory (1971), Similarity Rating: 0.15/1.00
# Movie: Fargo (1996), Similarity Rating: 0.15/1.00
# Movie: Rain Man (1988), Similarity Rating: 0.15/1.00
# Movie: American History X (1998), Similarity Rating: 0.15/1.00
# Movie: Adventures of Tintin, The (2011), Similarity Rating: 0.15/1.00
# Movie: Illusionist, The (2006), Similarity Rating: 0.15/1.00
# Movie: Lord of the Rings: The Two Towers, The (2002), Similarity Rating: 0.15/1.00
# Movie: Raw (2017), Similarity Rating: 0.15/1.00
# Movie: Fantastic Beasts and Where to Find Them (2016), Similarity Rating: 0.15/1.00
# Movie: Perfect Blue (1997), Similarity Rating: 0.15/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.15/1.00
# Movie: Hitch (2005), Similarity Rating: 0.15/1.00
# Movie: Hercules (1997), Similarity Rating: 0.15/1.00
# Movie: Life as We Know It (2010), Similarity Rating: 0.15/1.00
# Movie: The Spectacular Now (2013), Similarity Rating: 0.15/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.15/1.00
# Movie: The Hunger Games: Catching Fire (2013), Similarity Rating: 0.15/1.00
# Movie: The Greatest Showman (2017), Similarity Rating: 0.15/1.00
# Movie: The Longest Ride (2015), Similarity Rating: 0.15/1.00
# Movie: The Witch (2015), Similarity Rating: 0.15/1.00
# Movie: The Gentlemen (2020), Similarity Rating: 0.15/1.00
# Movie: Captain Fantastic (2016), Similarity Rating: 0.15/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.15/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.15/1.00
# Movie: Just Like Heaven (2005), Similarity Rating: 0.15/1.00
# Movie: Atonement (2007), Similarity Rating: 0.15/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.15/1.00
# Movie: It Follows (2014), Similarity Rating: 0.15/1.00
# Movie: In Bruges (2008), Similarity Rating: 0.15/1.00
# Movie: Lord of the Rings: The Fellowship of the Ring, The (2001), Similarity Rating: 0.15/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.15/1.00
# Movie: Wind River (2017), Similarity Rating: 0.15/1.00
# Movie: Star Wars: Episode VII - The Force Awakens (2015), Similarity Rating: 0.15/1.00
# Movie: Dunkirk (2017), Similarity Rating: 0.15/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.15/1.00
# Movie: Terminal, The (2004), Similarity Rating: 0.15/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.14/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=elliott_ratings,
    my_data=elliott_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
# response "Jag har sett typ en tredjedel av dessa filmer kanske, men inte sen jag började med letterboxd"
# Out:
# You've rated 177 movies
# Found 16142 movies you haven't rated
#
# Top Recommendations:
# Movie: Gone Girl (2014), Similarity Rating: 0.24/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.22/1.00
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.22/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.21/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.21/1.00
# Movie: Ready Player One, Similarity Rating: 0.20/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.20/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.19/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.19/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.19/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.18/1.00
# Movie: Nocturnal Animals, Similarity Rating: 0.18/1.00
# Movie: The Martian (2015), Similarity Rating: 0.18/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.18/1.00
# Movie: It Follows (2014), Similarity Rating: 0.17/1.00
# Movie: Ready or Not (2019), Similarity Rating: 0.17/1.00
# Movie: Spider-Man: No Way Home (2021), Similarity Rating: 0.17/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.17/1.00
# Movie: Deadpool (2016), Similarity Rating: 0.17/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.16/1.00
# Movie: The Favourite, Similarity Rating: 0.16/1.00
# Movie: Little Miss Sunshine (2006), Similarity Rating: 0.16/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.16/1.00
# Movie: Mandy (2018), Similarity Rating: 0.16/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.15/1.00
# Movie: Zombieland (2009), Similarity Rating: 0.15/1.00
# Movie: Top Gun: Maverick (2022), Similarity Rating: 0.15/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.15/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.15/1.00
# Movie: Upgrade (2018), Similarity Rating: 0.15/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.15/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.15/1.00
# Movie: Kingsman: The Secret Service (2015), Similarity Rating: 0.15/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.14/1.00
# Movie: The Ritual (2017), Similarity Rating: 0.14/1.00
# Movie: Host (2020), Similarity Rating: 0.14/1.00
# Movie: John Wick (2014), Similarity Rating: 0.14/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.14/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.14/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.14/1.00
# Movie: Grave Encounters (2011), Similarity Rating: 0.14/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.14/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.14/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.14/1.00
# Movie: 50/50 (2011), Similarity Rating: 0.14/1.00
# Movie: American Hustle (2013), Similarity Rating: 0.14/1.00
# Movie: 127 Hours (2010), Similarity Rating: 0.14/1.00
# Movie: Blade Runner 2049 (2017), Similarity Rating: 0.14/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.14/1.00
# Movie: Sinister (2012), Similarity Rating: 0.14/1.00
# Movie: Clueless (1995), Similarity Rating: 0.14/1.00
# Movie: The Fault in Our Stars (2014), Similarity Rating: 0.13/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.13/1.00
# Movie: The Witch (2015), Similarity Rating: 0.13/1.00
# Movie: Pitch Perfect (2012), Similarity Rating: 0.13/1.00
# Movie: A Simple Favor (2018), Similarity Rating: 0.13/1.00
# Movie: Once Upon a Time in Hollywood (2019), Similarity Rating: 0.13/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.13/1.00
# Movie: The Night House (2020), Similarity Rating: 0.13/1.00
# Movie: A Quiet Place Part II (2020), Similarity Rating: 0.13/1.00
# Movie: Arrival (2016), Similarity Rating: 0.13/1.00
# Movie: Mission: Impossible - Fallout (2018), Similarity Rating: 0.13/1.00
# Movie: Triangle (2009), Similarity Rating: 0.13/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.13/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.13/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.13/1.00
# Movie: Coco (2017), Similarity Rating: 0.13/1.00
# Movie: Southbound (2016), Similarity Rating: 0.13/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.13/1.00
# Movie: Kingsman: The Golden Circle (2017), Similarity Rating: 0.13/1.00
# Movie: Raw (2017), Similarity Rating: 0.13/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.12/1.00
# Movie: Limitless (2011), Similarity Rating: 0.12/1.00
# Movie: (500) Days of Summer (2009), Similarity Rating: 0.12/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.12/1.00
# Movie: Avengers, The (2012), Similarity Rating: 0.12/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.12/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.12/1.00
# Movie: John Wick: Chapter Two (2017), Similarity Rating: 0.12/1.00
# Movie: Escape Room (2019), Similarity Rating: 0.12/1.00
# Movie: The Endless (2017), Similarity Rating: 0.12/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.12/1.00
# Movie: Kill Your Darlings (2013), Similarity Rating: 0.12/1.00
# Movie: Ocean's 8 (2018), Similarity Rating: 0.12/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.12/1.00
# Movie: Hush (2016), Similarity Rating: 0.12/1.00
# Movie: Searching (2018), Similarity Rating: 0.12/1.00
# Movie: Up (2009), Similarity Rating: 0.11/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.11/1.00
# Movie: The Way He Looks (2014), Similarity Rating: 0.11/1.00
# Movie: The Suicide Squad (2021), Similarity Rating: 0.11/1.00
# Movie: Mommy (2014), Similarity Rating: 0.11/1.00
# Movie: Ford v. Ferrari (2019), Similarity Rating: 0.11/1.00
# Movie: Spider-Man (2002), Similarity Rating: 0.11/1.00
# Movie: John Wick: Chapter 3 – Parabellum (2019), Similarity Rating: 0.11/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.11/1.00
# Movie: Love and Monsters (2020), Similarity Rating: 0.11/1.00
# Movie: Hell House LLC (2015), Similarity Rating: 0.11/1.00
# Movie: Don't Breathe (2016), Similarity Rating: 0.11/1.00
# Movie: Soul (2020), Similarity Rating: 0.11/1.00
# Movie: Mother! (2017), Similarity Rating: 0.11/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.11/1.00
# Movie: Moana (2016), Similarity Rating: 0.10/1.00
# Movie: Battle Royale (Batoru rowaiaru) (2000), Similarity Rating: 0.10/1.00
# Movie: Demolition (2016), Similarity Rating: 0.10/1.00
# Movie: She's the Man (2006), Similarity Rating: 0.10/1.00
# Movie: Wrath of Man (2021), Similarity Rating: 0.10/1.00
# Movie: Juno (2007), Similarity Rating: 0.10/1.00
# Movie: The Gentlemen (2020), Similarity Rating: 0.10/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.10/1.00
# Movie: Halloween (2018), Similarity Rating: 0.10/1.00
# Movie: Barbarian (2022), Similarity Rating: 0.10/1.00
# Movie: Green Book (2018), Similarity Rating: 0.10/1.00
# Movie: Smile (2022), Similarity Rating: 0.10/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.10/1.00
# Movie: The Accountant (2016), Similarity Rating: 0.10/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.10/1.00
# Movie: You Were Never Really Here (2017), Similarity Rating: 0.10/1.00
# Movie: Intouchables (2011), Similarity Rating: 0.10/1.00
# Movie: Maze Runner, The (2014), Similarity Rating: 0.10/1.00
# Movie: Annabelle: Creation (2017), Similarity Rating: 0.10/1.00
# Movie: Wild Tales (2014), Similarity Rating: 0.10/1.00
# Movie: Run (2020), Similarity Rating: 0.10/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.10/1.00
# Movie: Molly's Game (2017), Similarity Rating: 0.10/1.00
# Movie: The Irishman (2019), Similarity Rating: 0.10/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.10/1.00
# Movie: Creep (2014), Similarity Rating: 0.10/1.00
# Movie: Laurence Anyways (2012), Similarity Rating: 0.10/1.00
# Movie: Shang-Chi and the Legend of the Ten Rings (2021), Similarity Rating: 0.10/1.00
# Movie: Moonlight, Similarity Rating: 0.10/1.00
# Movie: The Belko Experiment (2017), Similarity Rating: 0.09/1.00
# Movie: Pet Sematary (1989), Similarity Rating: 0.09/1.00
# Movie: Hot Fuzz (2007), Similarity Rating: 0.09/1.00
# Movie: Green Room (2015), Similarity Rating: 0.09/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.09/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.09/1.00
# Movie: 10 Cloverfield Lane (2016), Similarity Rating: 0.09/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.09/1.00
# Movie: Proposal, The (2009), Similarity Rating: 0.09/1.00
# Movie: Final Destination (2000), Similarity Rating: 0.09/1.00
# Movie: Minari (2020), Similarity Rating: 0.09/1.00
# Movie: Ant-Man and the Wasp (2018), Similarity Rating: 0.09/1.00
# Movie: The Vast of Night (2019), Similarity Rating: 0.09/1.00
# Movie: Willy's Wonderland (2021), Similarity Rating: 0.09/1.00
# Movie: Freaky (2020), Similarity Rating: 0.09/1.00
# Movie: Thoroughbreds (2018), Similarity Rating: 0.09/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.09/1.00
# Movie: Final Destination 3 (2006), Similarity Rating: 0.09/1.00
# Movie: Me and Earl and the Dying Girl (2015), Similarity Rating: 0.09/1.00
# Movie: Overlord (2018), Similarity Rating: 0.09/1.00
# Movie: Children of Men (2006), Similarity Rating: 0.09/1.00
# Movie: It's Kind of a Funny Story (2010), Similarity Rating: 0.09/1.00
# Movie: Good Time (2017), Similarity Rating: 0.09/1.00
# Movie: Sound of Metal (2019), Similarity Rating: 0.09/1.00
# Movie: The Big Sick (2017), Similarity Rating: 0.09/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.09/1.00
# Movie: Dark Knight, The (2008), Similarity Rating: 0.09/1.00
# Movie: Darkest Hour (2017), Similarity Rating: 0.09/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.09/1.00
# Movie: Solo: A Star Wars Story (2018), Similarity Rating: 0.09/1.00
# Movie: The Hunger Games (2012), Similarity Rating: 0.09/1.00
# Movie: Seeking a Friend for the End of the World (2012), Similarity Rating: 0.09/1.00
# Movie: Lars and the Real Girl (2007), Similarity Rating: 0.09/1.00
# Movie: #Alive (2020), Similarity Rating: 0.09/1.00
# Movie: The Banshees of Inisherin (2022), Similarity Rating: 0.09/1.00
# Movie: Underwater (2020), Similarity Rating: 0.09/1.00
# Movie: Honey Boy (2019), Similarity Rating: 0.09/1.00
# Movie: Step Up (2006), Similarity Rating: 0.09/1.00
# Movie: Boys (2014), Similarity Rating: 0.09/1.00
# Movie: Captain America: The First Avenger (2011), Similarity Rating: 0.09/1.00
# Movie: Conjuring, The (2013), Similarity Rating: 0.09/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.09/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.09/1.00
# Movie: American Made (2017), Similarity Rating: 0.09/1.00
# Movie: Haunt (2019), Similarity Rating: 0.09/1.00
# Movie: Hacksaw Ridge (2016), Similarity Rating: 0.09/1.00
# Movie: Zombieland: Double Tap (2019), Similarity Rating: 0.09/1.00
# Movie: Summer of 84 (2018), Similarity Rating: 0.09/1.00
# Movie: Captain America: The Winter Soldier (2014), Similarity Rating: 0.09/1.00
# Movie: Rocketman (2019), Similarity Rating: 0.09/1.00
# Movie: Warm Bodies (2013), Similarity Rating: 0.09/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.09/1.00
# Movie: Unfriended (2014), Similarity Rating: 0.09/1.00
# Movie: Holes (2003), Similarity Rating: 0.08/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.08/1.00
# Movie: Doctor Strange in the Multiverse of Madness (2022), Similarity Rating: 0.08/1.00
# Movie: Star Wars: The Last Jedi (2017), Similarity Rating: 0.08/1.00
# Movie: Help, The (2011), Similarity Rating: 0.08/1.00
# Movie: The Green Knight, Similarity Rating: 0.08/1.00
# Movie: The Autopsy of Jane Doe (2016), Similarity Rating: 0.08/1.00
# Movie: Closet Monster (2016), Similarity Rating: 0.08/1.00
# Movie: The Trial of the Chicago 7 (2020), Similarity Rating: 0.08/1.00
# Movie: The Taking of Deborah Logan (2014), Similarity Rating: 0.08/1.00
# Movie: First Reformed (2017), Similarity Rating: 0.08/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.08/1.00
# Movie: There Will Be Blood (2007), Similarity Rating: 0.08/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.08/1.00
# Movie: Final Destination 2 (2003), Similarity Rating: 0.08/1.00
# Movie: Love Actually (2003), Similarity Rating: 0.08/1.00
# '\nmin_avg_rating=2.5\nuser_min_percentile=0.25\nuser_max_percentile=0.999\nmin_ratings_per_movie=3\nmax_users_per_movie=250\nuser_similarity_threshold=0.15\nfit: \nn_components=200,\nsample_size=1,\nmax_iter=800\n'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=charlie_ratings,
    my_data=charlie_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 81 movies
# Found 16210 movies you haven't rated
#
# Top Recommendations:
# Movie: Get Out (2017), Similarity Rating: 0.19/1.00
# Movie: The Martian (2015), Similarity Rating: 0.19/1.00
# Movie: Children of Men (2006), Similarity Rating: 0.18/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.17/1.00
# Movie: Her (2013), Similarity Rating: 0.17/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.16/1.00
# Movie: No Country for Old Men (2007), Similarity Rating: 0.16/1.00
# Movie: Moon (2009), Similarity Rating: 0.16/1.00
# Movie: Avatar (2009), Similarity Rating: 0.16/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.16/1.00
# Movie: Baby Driver (2017), Similarity Rating: 0.16/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.15/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.15/1.00
# Movie: Lord of the Rings: The Return of the King, The (2003), Similarity Rating: 0.15/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.15/1.00
# Movie: Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001), Similarity Rating: 0.14/1.00
# Movie: Lord of the Rings: The Two Towers, The (2002), Similarity Rating: 0.14/1.00
# Movie: The Hateful Eight (2015), Similarity Rating: 0.14/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.14/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.14/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.14/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 2 (2011), Similarity Rating: 0.14/1.00
# Movie: Shrek (2001), Similarity Rating: 0.14/1.00
# Movie: Forrest Gump (1994), Similarity Rating: 0.14/1.00
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.14/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.14/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.13/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.13/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.13/1.00
# Movie: Rear Window (1954), Similarity Rating: 0.13/1.00
# Movie: Back to the Future (1985), Similarity Rating: 0.13/1.00
# Movie: Avengers, The (2012), Similarity Rating: 0.13/1.00
# Movie: 12 Angry Men (1957), Similarity Rating: 0.13/1.00
# Movie: Hobbit: An Unexpected Journey, The (2012), Similarity Rating: 0.13/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.13/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.13/1.00
# Movie: Scarface (1983), Similarity Rating: 0.13/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.13/1.00
# Movie: Kill Bill: Vol. 2 (2004), Similarity Rating: 0.13/1.00
# Movie: Toy Story 3 (2010), Similarity Rating: 0.13/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.13/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.13/1.00
# Movie: Howl's Moving Castle (Hauru no ugoku shiro) (2004), Similarity Rating: 0.12/1.00
# Movie: Drive (2011), Similarity Rating: 0.12/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.12/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.12/1.00
# Movie: Terminator 2: Judgment Day (1991), Similarity Rating: 0.12/1.00
# Movie: Aliens (1986), Similarity Rating: 0.12/1.00
# Movie: Kill Bill: Vol. 1 (2003), Similarity Rating: 0.12/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.12/1.00
# Movie: Bohemian Rhapsody (2018), Similarity Rating: 0.12/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.12/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.12/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.12/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.12/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.12/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.12/1.00
# Movie: North by Northwest (1959), Similarity Rating: 0.12/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.12/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.12/1.00
# Movie: Monsters, Inc. (2001), Similarity Rating: 0.12/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.12/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.12/1.00
# Movie: Trainspotting (1996), Similarity Rating: 0.12/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.11/1.00
# Movie: Green Book (2018), Similarity Rating: 0.11/1.00
# Movie: American History X (1998), Similarity Rating: 0.11/1.00
# Movie: Hobbit: The Desolation of Smaug, The (2013), Similarity Rating: 0.11/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.11/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.11/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.11/1.00
# Movie: Harry Potter and the Goblet of Fire (2005), Similarity Rating: 0.11/1.00
# Movie: Sin City (2005), Similarity Rating: 0.11/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.11/1.00
# Movie: Silence of the Lambs, The (1991), Similarity Rating: 0.11/1.00
# Movie: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), Similarity Rating: 0.11/1.00
# Movie: Lives of Others, The (Das leben der Anderen) (2006), Similarity Rating: 0.11/1.00
# Movie: Up (2009), Similarity Rating: 0.11/1.00
# Movie: Ready Player One, Similarity Rating: 0.11/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.11/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.11/1.00
# Movie: The Gentlemen (2020), Similarity Rating: 0.11/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.11/1.00
# Movie: Sunshine (2007), Similarity Rating: 0.11/1.00
# Movie: Cast Away (2000), Similarity Rating: 0.11/1.00
# Movie: Harry Potter and the Prisoner of Azkaban (2004), Similarity Rating: 0.11/1.00
# Movie: Snatch (2000), Similarity Rating: 0.11/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.11/1.00
# Movie: Logan (2017), Similarity Rating: 0.11/1.00
# Movie: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981), Similarity Rating: 0.11/1.00
# Movie: Road, The (2009), Similarity Rating: 0.11/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.11/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.11/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.11/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.11/1.00
# Movie: Lion King, The (1994), Similarity Rating: 0.11/1.00
# Movie: Taxi Driver (1976), Similarity Rating: 0.11/1.00
# Movie: Memento (2000), Similarity Rating: 0.11/1.00
# Movie: Encanto (2021), Similarity Rating: 0.11/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.10/1.00
# Movie: Game, The (1997), Similarity Rating: 0.10/1.00
# Movie: Ice Age (2002), Similarity Rating: 0.10/1.00
# Movie: Goodfellas (1990), Similarity Rating: 0.10/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.10/1.00
# Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Similarity Rating: 0.10/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.10/1.00
# Movie: Matrix Reloaded, The (2003), Similarity Rating: 0.10/1.00
# Movie: Die Hard (1988), Similarity Rating: 0.10/1.00
# Movie: Harry Potter and the Chamber of Secrets (2002), Similarity Rating: 0.10/1.00
# Movie: Moonlight, Similarity Rating: 0.10/1.00
# Movie: Kingsman: The Secret Service (2015), Similarity Rating: 0.10/1.00
# Movie: Psycho (1960), Similarity Rating: 0.10/1.00
# Movie: Moana (2016), Similarity Rating: 0.10/1.00
# Movie: Monty Python's Life of Brian (1979), Similarity Rating: 0.10/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.10/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.10/1.00
# Movie: Bourne Identity, The (2002), Similarity Rating: 0.10/1.00
# Movie: A Star Is Born (2018), Similarity Rating: 0.10/1.00
# Movie: Gladiator (2000), Similarity Rating: 0.10/1.00
# Movie: Fargo (1996), Similarity Rating: 0.10/1.00
# Movie: Dead Poets Society (1989), Similarity Rating: 0.10/1.00
# Movie: Saving Private Ryan (1998), Similarity Rating: 0.10/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.10/1.00
# Movie: Prisoners (2013), Similarity Rating: 0.10/1.00
# Movie: Room (2015), Similarity Rating: 0.10/1.00
# Movie: The Hunger Games (2012), Similarity Rating: 0.10/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.10/1.00
# Movie: The Irishman (2019), Similarity Rating: 0.10/1.00
# Movie: Boot, Das (Boat, The) (1981), Similarity Rating: 0.10/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.10/1.00
# Movie: Tangled (2010), Similarity Rating: 0.10/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.10/1.00
# Movie: Interview with the Vampire: The Vampire Chronicles (1994), Similarity Rating: 0.10/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.10/1.00
# Movie: Zombieland (2009), Similarity Rating: 0.10/1.00
# Movie: Girl with the Dragon Tattoo, The (2011), Similarity Rating: 0.10/1.00
# Movie: Deadpool (2016), Similarity Rating: 0.10/1.00
# Movie: You Were Never Really Here (2017), Similarity Rating: 0.10/1.00
# Movie: X-Men (2000), Similarity Rating: 0.10/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.10/1.00
# Movie: Men in Black (a.k.a. MIB) (1997), Similarity Rating: 0.10/1.00
# Movie: Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005), Similarity Rating: 0.09/1.00
# Movie: 50/50 (2011), Similarity Rating: 0.09/1.00
# Movie: How to Train Your Dragon (2010), Similarity Rating: 0.09/1.00
# Movie: Kung Fu Panda (2008), Similarity Rating: 0.09/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 1 (2010), Similarity Rating: 0.09/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.09/1.00
# Movie: Kick-Ass (2010), Similarity Rating: 0.09/1.00
# Movie: Planet Earth (2006), Similarity Rating: 0.09/1.00
# Movie: Harry Potter and the Half-Blood Prince (2009), Similarity Rating: 0.09/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.09/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.09/1.00
# Movie: American Hustle (2013), Similarity Rating: 0.09/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.09/1.00
# Movie: Stand by Me (1986), Similarity Rating: 0.09/1.00
# Movie: Secret Life of Walter Mitty, The (2013), Similarity Rating: 0.09/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.09/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.09/1.00
# Movie: Mission: Impossible - Fallout (2018), Similarity Rating: 0.09/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.09/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.09/1.00
# Movie: Incendies (2010), Similarity Rating: 0.09/1.00
# Movie: Bullet Train (2022), Similarity Rating: 0.09/1.00
# Movie: Cloud Atlas (2012), Similarity Rating: 0.09/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.09/1.00
# Movie: Oblivion (2013), Similarity Rating: 0.09/1.00
# Movie: Darkest Hour (2017), Similarity Rating: 0.09/1.00
# Movie: Vertigo (1958), Similarity Rating: 0.09/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.09/1.00
# Movie: The Machinist (2004), Similarity Rating: 0.09/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.09/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.09/1.00
# Movie: Source Code (2011), Similarity Rating: 0.09/1.00
# Movie: There Will Be Blood (2007), Similarity Rating: 0.09/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.09/1.00
# Movie: Harry Potter and the Order of the Phoenix (2007), Similarity Rating: 0.09/1.00
# Movie: Juno (2007), Similarity Rating: 0.09/1.00
# Movie: District 9 (2009), Similarity Rating: 0.09/1.00
# Movie: Jurassic World (2015), Similarity Rating: 0.09/1.00
# Movie: Kingsman: The Golden Circle (2017), Similarity Rating: 0.09/1.00
# Movie: Moneyball (2011), Similarity Rating: 0.09/1.00
# Movie: Old Boy (2003), Similarity Rating: 0.09/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.08/1.00
# Movie: Fantastic Beasts and Where to Find Them (2016), Similarity Rating: 0.08/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.08/1.00
# Movie: Beautiful Mind, A (2001), Similarity Rating: 0.08/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.08/1.00
# Movie: The Edge of Seventeen (2016), Similarity Rating: 0.08/1.00
# Movie: Curious Case of Benjamin Button, The (2008), Similarity Rating: 0.08/1.00
# Movie: Secret in Their Eyes, The (El secreto de sus ojos) (2009), Similarity Rating: 0.08/1.00
# Movie: In Bruges (2008), Similarity Rating: 0.08/1.00
# Movie: John Wick (2014), Similarity Rating: 0.08/1.00
# Movie: World War Z (2013), Similarity Rating: 0.08/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.08/1.00
# Movie: Hitchhiker's Guide to the Galaxy, The (2005), Similarity Rating: 0.08/1.00
# Movie: Charlie and the Chocolate Factory (2005), Similarity Rating: 0.08/1.00
# Movie: Coco (2017), Similarity Rating: 0.08/1.00
# Movie: Exit Through the Gift Shop (2010), Similarity Rating: 0.08/1.00
# Movie: Little Miss Sunshine (2006), Similarity Rating: 0.08/1.00
# Movie: Midsommar (2019), Similarity Rating: 0.08/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=voided_ratings,
    my_data=voided_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
"""jo men det gör dom, har typ alla förrutom guardians of the galaxy på min watchlist haha
och det stämmer att de jag redan hade sett som totoro hade jag inte rateat"""
# Out:
# You've rated 271 movies
# Found 16026 movies you haven't rated
#
# Top Recommendations:
# Movie: Godfather, The (1972), Similarity Rating: 0.39/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.38/1.00
# Movie: Moana (2016), Similarity Rating: 0.33/1.00
# Movie: WALL·E (2008), Similarity Rating: 0.33/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.32/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.32/1.00
# Movie: The Martian (2015), Similarity Rating: 0.32/1.00
# Movie: Coco (2017), Similarity Rating: 0.31/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.30/1.00
# Movie: Inception (2010), Similarity Rating: 0.30/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.30/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.30/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.29/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.29/1.00
# Movie: 2001: A Space Odyssey (1968), Similarity Rating: 0.29/1.00
# Movie: Seven Samurai (Shichinin no samurai) (1954), Similarity Rating: 0.28/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.28/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.28/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.28/1.00
# Movie: Moon (2009), Similarity Rating: 0.28/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.28/1.00
# Movie: Fargo (1996), Similarity Rating: 0.28/1.00
# Movie: It Follows (2014), Similarity Rating: 0.26/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.26/1.00
# Movie: Lives of Others, The (Das leben der Anderen) (2006), Similarity Rating: 0.26/1.00
# Movie: Dark Knight, The (2008), Similarity Rating: 0.26/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.25/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.25/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.25/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.25/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.25/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.24/1.00
# Movie: Perfect Blue (1997), Similarity Rating: 0.24/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.24/1.00
# Movie: Raging Bull (1980), Similarity Rating: 0.24/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.24/1.00
# Movie: My Neighbor Totoro (Tonari no Totoro) (1988), Similarity Rating: 0.24/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.24/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.24/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.23/1.00
# Movie: Monsters, Inc. (2001), Similarity Rating: 0.23/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.23/1.00
# Movie: Citizen Kane (1941), Similarity Rating: 0.23/1.00
# Movie: Us (2019), Similarity Rating: 0.23/1.00
# Movie: Barton Fink (1991), Similarity Rating: 0.23/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.22/1.00
# Movie: Rosemary's Baby (1968), Similarity Rating: 0.22/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.22/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.22/1.00
# Movie: Game Night (2018), Similarity Rating: 0.22/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.22/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.22/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.22/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.21/1.00
# Movie: Ghost Dog: The Way of the Samurai (1999), Similarity Rating: 0.21/1.00
# Movie: Frozen (2013), Similarity Rating: 0.21/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.21/1.00
# Movie: The Hateful Eight (2015), Similarity Rating: 0.21/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.21/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.21/1.00
# Movie: Sicario (2015), Similarity Rating: 0.20/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.20/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.20/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.20/1.00
# Movie: Slumdog Millionaire (2008), Similarity Rating: 0.20/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.20/1.00
# Movie: Don't Breathe (2016), Similarity Rating: 0.20/1.00
# Movie: Charlie and the Chocolate Factory (2005), Similarity Rating: 0.20/1.00
# Movie: Paprika (Papurika) (2006), Similarity Rating: 0.20/1.00
# Movie: Act of Killing, The (2012), Similarity Rating: 0.20/1.00
# Movie: Soul (2020), Similarity Rating: 0.19/1.00
# Movie: Sin City (2005), Similarity Rating: 0.19/1.00
# Movie: Hate (Haine, La) (1995), Similarity Rating: 0.19/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.19/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.19/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.19/1.00
# Movie: Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001), Similarity Rating: 0.19/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.19/1.00
# Movie: Moonlight, Similarity Rating: 0.19/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.19/1.00
# Movie: True Grit (2010), Similarity Rating: 0.19/1.00
# Movie: Seventh Seal, The (Sjunde inseglet, Det) (1957), Similarity Rating: 0.19/1.00
# Movie: Sunshine (2007), Similarity Rating: 0.19/1.00
# Movie: Burn After Reading (2008), Similarity Rating: 0.19/1.00
# Movie: Hangover, The (2009), Similarity Rating: 0.19/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.18/1.00
# Movie: Aguirre: The Wrath of God (Aguirre, der Zorn Gottes) (1972), Similarity Rating: 0.18/1.00
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.18/1.00
# Movie: Ran (1985), Similarity Rating: 0.18/1.00
# Movie: The Machinist (2004), Similarity Rating: 0.18/1.00
# Movie: Suspiria (1977), Similarity Rating: 0.18/1.00
# Movie: [REC] (2007), Similarity Rating: 0.18/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.18/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.18/1.00
# Movie: Avatar (2009), Similarity Rating: 0.18/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.18/1.00
# Movie: District 9 (2009), Similarity Rating: 0.18/1.00
# Movie: World's End, The (2013), Similarity Rating: 0.18/1.00
# Movie: Prophet, A (Un Prophète) (2009), Similarity Rating: 0.18/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.18/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.18/1.00
# Movie: Cube (1997), Similarity Rating: 0.18/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.18/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.18/1.00
# Movie: Psycho (1960), Similarity Rating: 0.18/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.18/1.00
# Movie: Green Room (2015), Similarity Rating: 0.18/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.18/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.18/1.00
# Movie: Battle Royale (Batoru rowaiaru) (2000), Similarity Rating: 0.18/1.00
# Movie: Punch-Drunk Love (2002), Similarity Rating: 0.18/1.00
# Movie: Toy Story 3 (2010), Similarity Rating: 0.18/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.17/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.17/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.17/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.17/1.00
# Movie: Irreversible (Irréversible) (2002), Similarity Rating: 0.17/1.00
# Movie: Band of Brothers (2001), Similarity Rating: 0.17/1.00
# Movie: Man on the Moon (1999), Similarity Rating: 0.17/1.00
# Movie: Alice in Wonderland (2010), Similarity Rating: 0.17/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.17/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.17/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.17/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.17/1.00
# Movie: Grave of the Fireflies (Hotaru no haka) (1988), Similarity Rating: 0.16/1.00
# Movie: Third Man, The (1949), Similarity Rating: 0.16/1.00
# Movie: Blade Runner 2049 (2017), Similarity Rating: 0.16/1.00
# Movie: Night of the Living Dead (1968), Similarity Rating: 0.16/1.00
# Movie: Logan (2017), Similarity Rating: 0.16/1.00
# Movie: Split (2017), Similarity Rating: 0.16/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.16/1.00
# Movie: Incredibles, The (2004), Similarity Rating: 0.16/1.00
# Movie: Little Women (2019), Similarity Rating: 0.16/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.16/1.00
# Movie: Orphanage, The (Orfanato, El) (2007), Similarity Rating: 0.16/1.00
# Movie: Yojimbo (1961), Similarity Rating: 0.16/1.00
# Movie: Gravity (2013), Similarity Rating: 0.16/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.16/1.00
# Movie: Napoleon Dynamite (2004), Similarity Rating: 0.16/1.00
# Movie: Mother! (2017), Similarity Rating: 0.16/1.00
# Movie: Star Wars: Episode VII - The Force Awakens (2015), Similarity Rating: 0.16/1.00
# Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Similarity Rating: 0.16/1.00
# Movie: Terminal, The (2004), Similarity Rating: 0.16/1.00
# Movie: Scream (1996), Similarity Rating: 0.16/1.00
# Movie: Synecdoche, New York (2008), Similarity Rating: 0.16/1.00
# Movie: Shrek (2001), Similarity Rating: 0.16/1.00
# Movie: Maze Runner, The (2014), Similarity Rating: 0.16/1.00
# Movie: Over the Garden Wall (2013), Similarity Rating: 0.16/1.00
# Movie: Chinatown (1974), Similarity Rating: 0.16/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.16/1.00
# Movie: Harry Potter and the Prisoner of Azkaban (2004), Similarity Rating: 0.16/1.00
# Movie: Great Beauty, The (Grande Bellezza, La) (2013), Similarity Rating: 0.16/1.00
# Movie: Unforgiven (1992), Similarity Rating: 0.16/1.00
# Movie: Girl with the Dragon Tattoo, The (Män som hatar kvinnor) (2009), Similarity Rating: 0.16/1.00
# Movie: The Raid: Redemption (2011), Similarity Rating: 0.16/1.00
# Movie: Tropic Thunder (2008), Similarity Rating: 0.16/1.00
# Movie: Inside Man (2006), Similarity Rating: 0.16/1.00
# Movie: Primer (2004), Similarity Rating: 0.16/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.15/1.00
# Movie: Star Wars: Episode III - Revenge of the Sith (2005), Similarity Rating: 0.15/1.00
# Movie: Princess and the Frog, The (2009), Similarity Rating: 0.15/1.00
# Movie: Diving Bell and the Butterfly, The (Scaphandre et le papillon, Le) (2007), Similarity Rating: 0.15/1.00
# Movie: Cast Away (2000), Similarity Rating: 0.15/1.00
# Movie: Tenet (2020), Similarity Rating: 0.15/1.00
# Movie: Boot, Das (Boat, The) (1981), Similarity Rating: 0.15/1.00
# Movie: Man with the Movie Camera, The (Chelovek s kino-apparatom) (1929), Similarity Rating: 0.15/1.00
# Movie: Downfall (Untergang, Der) (2004), Similarity Rating: 0.15/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.15/1.00
# Movie: Unbreakable (2000), Similarity Rating: 0.15/1.00
# Movie: South Park: Bigger, Longer and Uncut (1999), Similarity Rating: 0.15/1.00
# Movie: Brave (2012), Similarity Rating: 0.15/1.00
# Movie: Deer Hunter, The (1978), Similarity Rating: 0.15/1.00
# Movie: Master, The (2012), Similarity Rating: 0.15/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.15/1.00
# Movie: Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984), Similarity Rating: 0.15/1.00
# Movie: Triplets of Belleville, The (Les triplettes de Belleville) (2003), Similarity Rating: 0.15/1.00
# Movie: Thing, The (1982), Similarity Rating: 0.15/1.00
# Movie: Wild Strawberries (Smultronstället) (1957), Similarity Rating: 0.15/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.15/1.00
# Movie: History of Violence, A (2005), Similarity Rating: 0.15/1.00
# Movie: Anchorman: The Legend of Ron Burgundy (2004), Similarity Rating: 0.15/1.00
# Movie: Hercules (1997), Similarity Rating: 0.15/1.00
# Movie: Gran Torino (2008), Similarity Rating: 0.15/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.15/1.00
# Movie: Sleepy Hollow (1999), Similarity Rating: 0.15/1.00
# Movie: Melancholia (2011), Similarity Rating: 0.15/1.00
# Movie: Pi (1998), Similarity Rating: 0.15/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.15/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.15/1.00
# Movie: Eastern Promises (2007), Similarity Rating: 0.15/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.15/1.00
# Movie: Exit Through the Gift Shop (2010), Similarity Rating: 0.15/1.00
# Movie: 8 1/2 (8½) (1963), Similarity Rating: 0.15/1.00
# Movie: From Dusk Till Dawn (1996), Similarity Rating: 0.14/1.00
# Movie: Incendies (2010), Similarity Rating: 0.14/1.00
# Movie: Ready Player One, Similarity Rating: 0.14/1.00
# Movie: Room (2015), Similarity Rating: 0.14/1.00
# Movie: Harry Potter and the Chamber of Secrets (2002), Similarity Rating: 0.14/1.00
# Movie: 40-Year-Old Virgin, The (2005), Similarity Rating: 0.14/1.00
# Movie: The Wailing (2016), Similarity Rating: 0.14/1.00
# 'jo men det gör dom, har typ alla förrutom guardians of the galaxy på min watchlist haha\noch det stämmer att de jag redan hade sett som totoro hade jag inte rateat'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=zorrodor_ratings,
    my_data=zorrodor_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)

# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
# zorro:
# "Dom första 20 är alla bra filmer"
# "Eller de e nästan bara grejer jag gillar"
# "Några luriga dock men de mesta e gött"
# "Jag har rateat ganska lite också"
# "Så den har inte sååå mkt att gå på"
# Out:
# You've rated 45 movies
# Found 16255 movies you haven't rated
#
# Top Recommendations:
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.22/1.00
# Movie: Three Colors: White (Trzy kolory: Bialy) (1994), Similarity Rating: 0.16/1.00
# Movie: Fallen Angels (Duo luo tian shi) (1995), Similarity Rating: 0.12/1.00
# Movie: Three Colors: Blue (Trois couleurs: Bleu) (1993), Similarity Rating: 0.10/1.00
# Movie: Stalker (1979), Similarity Rating: 0.10/1.00
# Movie: Taxi Driver (1976), Similarity Rating: 0.09/1.00
# Movie: Yi Yi (2000), Similarity Rating: 0.08/1.00
# Movie: In Bruges (2008), Similarity Rating: 0.08/1.00
# Movie: Get Out (2017), Similarity Rating: 0.07/1.00
# Movie: 2046 (2004), Similarity Rating: 0.07/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.07/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.07/1.00
# Movie: Breaking the Waves (1996), Similarity Rating: 0.07/1.00
# Movie: Great Beauty, The (Grande Bellezza, La) (2013), Similarity Rating: 0.07/1.00
# Movie: Parasite (2019), Similarity Rating: 0.07/1.00
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.07/1.00
# Movie: Raise the Red Lantern (Da hong deng long gao gao gua) (1991), Similarity Rating: 0.06/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.06/1.00
# Movie: Raging Bull (1980), Similarity Rating: 0.06/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.06/1.00
# Movie: Rebel Without a Cause (1955), Similarity Rating: 0.06/1.00
# Movie: Before Sunrise (1995), Similarity Rating: 0.06/1.00
# Movie: Hiroshima Mon Amour (1959), Similarity Rating: 0.06/1.00
# Movie: Third Man, The (1949), Similarity Rating: 0.06/1.00
# Movie: Shaun of the Dead (2004), Similarity Rating: 0.06/1.00
# Movie: Fireworks (Hana-bi) (1997), Similarity Rating: 0.06/1.00
# Movie: Hot Fuzz (2007), Similarity Rating: 0.06/1.00
# Movie: Apocalypse Now (1979), Similarity Rating: 0.06/1.00
# Movie: Audition (Ôdishon) (1999), Similarity Rating: 0.06/1.00
# Movie: Talk to Her (Hable con Ella) (2002), Similarity Rating: 0.05/1.00
# Movie: Seven Samurai (Shichinin no samurai) (1954), Similarity Rating: 0.05/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.05/1.00
# Movie: Thin Red Line, The (1998), Similarity Rating: 0.05/1.00
# Movie: Her (2013), Similarity Rating: 0.05/1.00
# Movie: Paris, Texas (1984), Similarity Rating: 0.05/1.00
# Movie: Samouraï, Le (Godson, The) (1967), Similarity Rating: 0.05/1.00
# Movie: Chinatown (1974), Similarity Rating: 0.05/1.00
# Movie: Akira (1988), Similarity Rating: 0.05/1.00
# Movie: Texas Chainsaw Massacre, The (1974), Similarity Rating: 0.05/1.00
# Movie: 8 1/2 (8½) (1963), Similarity Rating: 0.05/1.00
# Movie: Fargo (1996), Similarity Rating: 0.05/1.00
# Movie: Little Miss Sunshine (2006), Similarity Rating: 0.05/1.00
# Movie: Irreversible (Irréversible) (2002), Similarity Rating: 0.05/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.05/1.00
# Movie: Red Violin, The (Violon rouge, Le) (1998), Similarity Rating: 0.05/1.00
# Movie: Burning (2018), Similarity Rating: 0.05/1.00
# Movie: Night, The (Notte, La) (1960), Similarity Rating: 0.05/1.00
# Movie: Bad Guy (Nabbeun namja) (2001), Similarity Rating: 0.05/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.05/1.00
# Movie: Ali: Fear Eats the Soul (Angst essen Seele auf) (1974), Similarity Rating: 0.05/1.00
# Movie: Life Aquatic with Steve Zissou, The (2004), Similarity Rating: 0.05/1.00
# Movie: Perfect Blue (1997), Similarity Rating: 0.05/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.05/1.00
# Movie: Elephant Man, The (1980), Similarity Rating: 0.05/1.00
# Movie: Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) (1983), Similarity Rating: 0.05/1.00
# Movie: Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966), Similarity Rating: 0.05/1.00
# Movie: Dead Poets Society (1989), Similarity Rating: 0.05/1.00
# Movie: Possession (1981), Similarity Rating: 0.05/1.00
# Movie: Piano Teacher, The (La pianiste) (2001), Similarity Rating: 0.05/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.05/1.00
# Movie: Long Day's Journey Into Night (2018), Similarity Rating: 0.05/1.00
# Movie: The French Dispatch (2020), Similarity Rating: 0.05/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.05/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.05/1.00
# Movie: Hate (Haine, La) (1995), Similarity Rating: 0.05/1.00
# Movie: Monsters, Inc. (2001), Similarity Rating: 0.04/1.00
# Movie: Nobody Knows (Dare mo shiranai) (2004), Similarity Rating: 0.04/1.00
# Movie: Sonatine (Sonachine) (1993), Similarity Rating: 0.04/1.00
# Movie: Ghost Dog: The Way of the Samurai (1999), Similarity Rating: 0.04/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.04/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.04/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.04/1.00
# Movie: Night of the Hunter, The (1955), Similarity Rating: 0.04/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.04/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.04/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.04/1.00
# Movie: Avventura, L' (Adventure, The) (1960), Similarity Rating: 0.04/1.00
# Movie: Open Hearts (Elsker dig for evigt) (2002), Similarity Rating: 0.04/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.04/1.00
# Movie: Haunting, The (1963), Similarity Rating: 0.04/1.00
# Movie: M (1931), Similarity Rating: 0.04/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.04/1.00
# Movie: Juno (2007), Similarity Rating: 0.04/1.00
# Movie: Seventh Seal, The (Sjunde inseglet, Det) (1957), Similarity Rating: 0.04/1.00
# Movie: Kill Bill: Vol. 1 (2003), Similarity Rating: 0.04/1.00
# Movie: Broken Flowers (2005), Similarity Rating: 0.04/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.04/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.04/1.00
# Movie: Spring, Summer, Fall, Winter... and Spring (Bom yeoreum gaeul gyeoul geurigo bom) (2003), Similarity Rating: 0.04/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.04/1.00
# Movie: Graduate, The (1967), Similarity Rating: 0.04/1.00
# Movie: House (Hausu) (1977), Similarity Rating: 0.04/1.00
# Movie: Hamlet (1996), Similarity Rating: 0.04/1.00
# Movie: Paprika (Papurika) (2006), Similarity Rating: 0.04/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.04/1.00
# Movie: Twin Peaks: Fire Walk with Me (1992), Similarity Rating: 0.04/1.00
# Movie: Blood Simple (1984), Similarity Rating: 0.04/1.00
# Movie: Benny & Joon (1993), Similarity Rating: 0.04/1.00
# Movie: Treasure of the Sierra Madre, The (1948), Similarity Rating: 0.04/1.00
# Movie: Punch-Drunk Love (2002), Similarity Rating: 0.04/1.00
# Movie: Prophet, A (Un Prophète) (2009), Similarity Rating: 0.04/1.00
# Movie: My Night At Maud's (Ma Nuit Chez Maud) (1969), Similarity Rating: 0.04/1.00
# Movie: American Psycho (2000), Similarity Rating: 0.04/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.04/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.04/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.04/1.00
# Movie: Cool Hand Luke (1967), Similarity Rating: 0.04/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.04/1.00
# Movie: Eraserhead (1977), Similarity Rating: 0.04/1.00
# Movie: Happy Together (a.k.a. Buenos Aires Affair) (Chun gwong cha sit) (1997), Similarity Rating: 0.04/1.00
# Movie: Fistful of Dollars, A (Per un pugno di dollari) (1964), Similarity Rating: 0.04/1.00
# Movie: Fat Girl (À ma soeur!) (2001), Similarity Rating: 0.04/1.00
# Movie: Reconstruction (2003), Similarity Rating: 0.04/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.04/1.00
# Movie: Onibaba (1964), Similarity Rating: 0.04/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.04/1.00
# Movie: Casablanca (1942), Similarity Rating: 0.04/1.00
# Movie: Hunt, The (Jagten) (2012), Similarity Rating: 0.04/1.00
# Movie: My Left Foot (1989), Similarity Rating: 0.04/1.00
# Movie: Cercle Rouge, Le (Red Circle, The) (1970), Similarity Rating: 0.04/1.00
# Movie: Barton Fink (1991), Similarity Rating: 0.04/1.00
# Movie: Night of the Living Dead (1968), Similarity Rating: 0.04/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.04/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.04/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.04/1.00
# Movie: 3-Iron (Bin-jip) (2004), Similarity Rating: 0.04/1.00
# Movie: Zombieland (2009), Similarity Rating: 0.04/1.00
# Movie: Yojimbo (1961), Similarity Rating: 0.04/1.00
# Movie: Touch of Evil (1958), Similarity Rating: 0.04/1.00
# Movie: Snatch (2000), Similarity Rating: 0.04/1.00
# Movie: Eclisse, L' (Eclipse) (1962), Similarity Rating: 0.04/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.04/1.00
# Movie: Kikujiro (Kikujirô no natsu) (1999), Similarity Rating: 0.04/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.04/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.04/1.00
# Movie: Room (2015), Similarity Rating: 0.04/1.00
# Movie: Blue Valentine (2010), Similarity Rating: 0.04/1.00
# Movie: WALL·E (2008), Similarity Rating: 0.04/1.00
# Movie: Once Upon a Time in the West (C'era una volta il West) (1968), Similarity Rating: 0.04/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.04/1.00
# Movie: Station Agent, The (2003), Similarity Rating: 0.04/1.00
# Movie: Paths of Glory (1957), Similarity Rating: 0.04/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.04/1.00
# Movie: Martyrs (2008), Similarity Rating: 0.04/1.00
# Movie: Breakfast Club, The (1985), Similarity Rating: 0.04/1.00
# Movie: World's End, The (2013), Similarity Rating: 0.04/1.00
# Movie: Breath (Soom) (2007), Similarity Rating: 0.04/1.00
# Movie: Citizen Kane (1941), Similarity Rating: 0.04/1.00
# Movie: Dark Knight, The (2008), Similarity Rating: 0.04/1.00
# Movie: Chorus, The (Choristes, Les) (2004), Similarity Rating: 0.04/1.00
# Movie: All About My Mother (Todo sobre mi madre) (1999), Similarity Rating: 0.04/1.00
# Movie: Consequences of Love, The (Conseguenze dell'amore, Le) (2004), Similarity Rating: 0.04/1.00
# Movie: Rushmore (1998), Similarity Rating: 0.04/1.00
# Movie: Double Life of Veronique, The (Double Vie de Véronique, La) (1991), Similarity Rating: 0.04/1.00
# Movie: Enter the Void (2009), Similarity Rating: 0.03/1.00
# Movie: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), Similarity Rating: 0.03/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.03/1.00
# Movie: Inland Empire (2006), Similarity Rating: 0.03/1.00
# Movie: Isle, The (Seom) (2000), Similarity Rating: 0.03/1.00
# Movie: Notebook, The (2004), Similarity Rating: 0.03/1.00
# Movie: Breathless (À bout de souffle) (1960), Similarity Rating: 0.03/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.03/1.00
# Movie: Soul (2020), Similarity Rating: 0.03/1.00
# Movie: River Runs Through It, A (1992), Similarity Rating: 0.03/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.03/1.00
# Movie: Rashomon (Rashômon) (1950), Similarity Rating: 0.03/1.00
# Movie: Annie Hall (1977), Similarity Rating: 0.03/1.00
# Movie: Ran (1985), Similarity Rating: 0.03/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.03/1.00
# Movie: Knives Out (2019), Similarity Rating: 0.03/1.00
# Movie: Youth (2015), Similarity Rating: 0.03/1.00
# Movie: Hangover, The (2009), Similarity Rating: 0.03/1.00
# Movie: Force Majeure (Turist) (2014), Similarity Rating: 0.03/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.03/1.00
# Movie: The Green Knight, Similarity Rating: 0.03/1.00
# Movie: Mean Streets (1973), Similarity Rating: 0.03/1.00
# Movie: First Reformed (2017), Similarity Rating: 0.03/1.00
# Movie: Inception (2010), Similarity Rating: 0.03/1.00
# Movie: Wages of Fear, The (Salaire de la peur, Le) (1953), Similarity Rating: 0.03/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.03/1.00
# Movie: The Square (2017), Similarity Rating: 0.03/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.03/1.00
# Movie: Dogman (2018), Similarity Rating: 0.03/1.00
# Movie: Kaili Blues (2016), Similarity Rating: 0.03/1.00
# Movie: Tropic Thunder (2008), Similarity Rating: 0.03/1.00
# Movie: Being There (1979), Similarity Rating: 0.03/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.03/1.00
# Movie: Up (2009), Similarity Rating: 0.03/1.00
# Movie: Eat Drink Man Woman (Yin shi nan nu) (1994), Similarity Rating: 0.03/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.03/1.00
# Movie: Gosford Park (2001), Similarity Rating: 0.03/1.00
# Movie: Pi (1998), Similarity Rating: 0.03/1.00
# Movie: Memento (2000), Similarity Rating: 0.03/1.00
# Movie: Magnificent Seven, The (1960), Similarity Rating: 0.03/1.00
# Movie: Synecdoche, New York (2008), Similarity Rating: 0.03/1.00
# Movie: Ravenous (1999), Similarity Rating: 0.03/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.03/1.00
# Movie: Slumdog Millionaire (2008), Similarity Rating: 0.03/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.03/1.00
# Movie: Midsommar (2019), Similarity Rating: 0.03/1.00
# '\nmin_avg_rating=2.5\nuser_min_percentile=0.25\nuser_max_percentile=0.999\nmin_ratings_per_movie=3\nmax_users_per_movie=250\nuser_similarity_threshold=0.15\nfit: \nn_components=200,\nsample_size=1,\nmax_iter=800\n'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=liv_ratings,
    my_data=liv_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 106 movies
# Found 16192 movies you haven't rated
#
# Top Recommendations:
# Movie: Her (2013), Similarity Rating: 0.21/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.17/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.17/1.00
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.17/1.00
# Movie: Parasite (2019), Similarity Rating: 0.16/1.00
# Movie: Love, Simon (2018), Similarity Rating: 0.16/1.00
# Movie: Room (2015), Similarity Rating: 0.16/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.16/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.15/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.14/1.00
# Movie: Mean Girls (2004), Similarity Rating: 0.14/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.14/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.14/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.14/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.13/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.13/1.00
# Movie: Knives Out (2019), Similarity Rating: 0.13/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.13/1.00
# Movie: American Hustle (2013), Similarity Rating: 0.12/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.12/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.12/1.00
# Movie: Nocturnal Animals, Similarity Rating: 0.12/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.12/1.00
# Movie: Kill Your Darlings (2013), Similarity Rating: 0.12/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.12/1.00
# Movie: Bridget Jones's Diary (2001), Similarity Rating: 0.12/1.00
# Movie: 27 Dresses (2008), Similarity Rating: 0.12/1.00
# Movie: Truman Show, The (1998), Similarity Rating: 0.12/1.00
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.12/1.00
# Movie: Wag the Dog (1997), Similarity Rating: 0.12/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.12/1.00
# Movie: Proposal, The (2009), Similarity Rating: 0.12/1.00
# Movie: Moonlight, Similarity Rating: 0.12/1.00
# Movie: Life Aquatic with Steve Zissou, The (2004), Similarity Rating: 0.12/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.11/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.11/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.11/1.00
# Movie: Deadpool (2016), Similarity Rating: 0.11/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.11/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.11/1.00
# Movie: Arrival (2016), Similarity Rating: 0.11/1.00
# Movie: Django Unchained (2012), Similarity Rating: 0.11/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.11/1.00
# Movie: Laurence Anyways (2012), Similarity Rating: 0.11/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.11/1.00
# Movie: Blue Valentine (2010), Similarity Rating: 0.11/1.00
# Movie: Old Boy (2003), Similarity Rating: 0.11/1.00
# Movie: Great Gatsby, The (2013), Similarity Rating: 0.10/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.10/1.00
# Movie: WALL·E (2008), Similarity Rating: 0.10/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.10/1.00
# Movie: Up (2009), Similarity Rating: 0.10/1.00
# Movie: Taxi Driver (1976), Similarity Rating: 0.10/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.10/1.00
# Movie: Perfect Blue (1997), Similarity Rating: 0.10/1.00
# Movie: Soul (2020), Similarity Rating: 0.10/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.10/1.00
# Movie: Wings of Desire (Himmel über Berlin, Der) (1987), Similarity Rating: 0.10/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.10/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.10/1.00
# Movie: Garden State (2004), Similarity Rating: 0.10/1.00
# Movie: The Way He Looks (2014), Similarity Rating: 0.10/1.00
# Movie: Rushmore (1998), Similarity Rating: 0.10/1.00
# Movie: Seeking a Friend for the End of the World (2012), Similarity Rating: 0.10/1.00
# Movie: Carol (2015), Similarity Rating: 0.10/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.10/1.00
# Movie: Akira (1988), Similarity Rating: 0.10/1.00
# Movie: Paprika (Papurika) (2006), Similarity Rating: 0.10/1.00
# Movie: The Favourite, Similarity Rating: 0.10/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.10/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.10/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.09/1.00
# Movie: Joker (2019), Similarity Rating: 0.09/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.09/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.09/1.00
# Movie: Lost Highway (1997), Similarity Rating: 0.09/1.00
# Movie: Mommy (2014), Similarity Rating: 0.09/1.00
# Movie: The Martian (2015), Similarity Rating: 0.09/1.00
# Movie: Wild Tales (2014), Similarity Rating: 0.09/1.00
# Movie: Mamma Mia! (2008), Similarity Rating: 0.09/1.00
# Movie: Superbad (2007), Similarity Rating: 0.09/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.09/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.09/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.09/1.00
# Movie: 50 First Dates (2004), Similarity Rating: 0.09/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.09/1.00
# Movie: Kingpin (1996), Similarity Rating: 0.09/1.00
# Movie: Hot Fuzz (2007), Similarity Rating: 0.09/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.09/1.00
# Movie: Ghost World (2001), Similarity Rating: 0.09/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.09/1.00
# Movie: The Edge of Seventeen (2016), Similarity Rating: 0.09/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.09/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.09/1.00
# Movie: She's the Man (2006), Similarity Rating: 0.09/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.09/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.09/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.09/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.09/1.00
# Movie: Edge of Tomorrow (2014), Similarity Rating: 0.09/1.00
# Movie: Atonement (2007), Similarity Rating: 0.09/1.00
# Movie: Kids (1995), Similarity Rating: 0.09/1.00
# Movie: Raw (2017), Similarity Rating: 0.09/1.00
# Movie: Coco (2017), Similarity Rating: 0.09/1.00
# Movie: 50/50 (2011), Similarity Rating: 0.09/1.00
# Movie: Shaun of the Dead (2004), Similarity Rating: 0.09/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.09/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.08/1.00
# Movie: Batman Begins (2005), Similarity Rating: 0.08/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.08/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.08/1.00
# Movie: Palo Alto (2013), Similarity Rating: 0.08/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.08/1.00
# Movie: Pitch Perfect (2012), Similarity Rating: 0.08/1.00
# Movie: Bruce Almighty (2003), Similarity Rating: 0.08/1.00
# Movie: Sound of Metal (2019), Similarity Rating: 0.08/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.08/1.00
# Movie: Closet Monster (2016), Similarity Rating: 0.08/1.00
# Movie: Punch-Drunk Love (2002), Similarity Rating: 0.08/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.08/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.08/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.08/1.00
# Movie: Before Midnight (2013), Similarity Rating: 0.08/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.08/1.00
# Movie: Midsommar (2019), Similarity Rating: 0.08/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.08/1.00
# Movie: 13 Going on 30 (2004), Similarity Rating: 0.08/1.00
# Movie: Chungking Express (Chung Hing sam lam) (1994), Similarity Rating: 0.08/1.00
# Movie: Birds of Prey (And the Fantabulous Emancipation of One Harley Quinn) (2020), Similarity Rating: 0.08/1.00
# Movie: Kingsman: The Golden Circle (2017), Similarity Rating: 0.08/1.00
# Movie: Some Like It Hot (1959), Similarity Rating: 0.08/1.00
# Movie: Before Sunset (2004), Similarity Rating: 0.08/1.00
# Movie: Now You See Me (2013), Similarity Rating: 0.08/1.00
# Movie: Heartbeats (Les amours imaginaires) (2010), Similarity Rating: 0.08/1.00
# Movie: What's Eating Gilbert Grape (1993), Similarity Rating: 0.08/1.00
# Movie: Slumdog Millionaire (2008), Similarity Rating: 0.08/1.00
# Movie: Welcome to the Dollhouse (1995), Similarity Rating: 0.08/1.00
# Movie: Dunkirk (2017), Similarity Rating: 0.08/1.00
# Movie: Iron Man 3 (2013), Similarity Rating: 0.08/1.00
# Movie: In Bruges (2008), Similarity Rating: 0.08/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.08/1.00
# Movie: Rocketman (2019), Similarity Rating: 0.08/1.00
# Movie: Love Actually (2003), Similarity Rating: 0.07/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.07/1.00
# Movie: Hamilton (2020), Similarity Rating: 0.07/1.00
# Movie: Avengers, The (2012), Similarity Rating: 0.07/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.07/1.00
# Movie: Demolition (2016), Similarity Rating: 0.07/1.00
# Movie: Monsters, Inc. (2001), Similarity Rating: 0.07/1.00
# Movie: Nightmare Before Christmas, The (1993), Similarity Rating: 0.07/1.00
# Movie: Rain Man (1988), Similarity Rating: 0.07/1.00
# Movie: Help, The (2011), Similarity Rating: 0.07/1.00
# Movie: Shang-Chi and the Legend of the Ten Rings (2021), Similarity Rating: 0.07/1.00
# Movie: Legally Blonde (2001), Similarity Rating: 0.07/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.07/1.00
# Movie: Safety Not Guaranteed (2012), Similarity Rating: 0.07/1.00
# Movie: Forgetting Sarah Marshall (2008), Similarity Rating: 0.07/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.07/1.00
# Movie: Shiva Baby (2020), Similarity Rating: 0.07/1.00
# Movie: Gattaca (1997), Similarity Rating: 0.07/1.00
# Movie: Monty Python's Life of Brian (1979), Similarity Rating: 0.07/1.00
# Movie: Wild at Heart (1990), Similarity Rating: 0.07/1.00
# Movie: Mr. Nobody (2009), Similarity Rating: 0.07/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.07/1.00
# Movie: Wrestler, The (2008), Similarity Rating: 0.07/1.00
# Movie: Single Man, A (2009), Similarity Rating: 0.07/1.00
# Movie: Thirteen (2003), Similarity Rating: 0.07/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.07/1.00
# Movie: Boys (2014), Similarity Rating: 0.07/1.00
# Movie: Mr. & Mrs. Smith (2005), Similarity Rating: 0.07/1.00
# Movie: Mission: Impossible (1996), Similarity Rating: 0.07/1.00
# Movie: Moon (2009), Similarity Rating: 0.07/1.00
# Movie: Triplets of Belleville, The (Les triplettes de Belleville) (2003), Similarity Rating: 0.07/1.00
# Movie: Cruel Intentions (1999), Similarity Rating: 0.07/1.00
# Movie: The Hateful Eight (2015), Similarity Rating: 0.07/1.00
# Movie: Friends with Benefits (2011), Similarity Rating: 0.07/1.00
# Movie: Eraserhead (1977), Similarity Rating: 0.07/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.07/1.00
# Movie: Terminal, The (2004), Similarity Rating: 0.07/1.00
# Movie: Broken Flowers (2005), Similarity Rating: 0.07/1.00
# Movie: Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984), Similarity Rating: 0.07/1.00
# Movie: The Gentlemen (2020), Similarity Rating: 0.07/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.07/1.00
# Movie: Anchorman: The Legend of Ron Burgundy (2004), Similarity Rating: 0.07/1.00
# Movie: Minari (2020), Similarity Rating: 0.07/1.00
# Movie: The Longest Week (2014), Similarity Rating: 0.07/1.00
# Movie: Holiday, The (2006), Similarity Rating: 0.07/1.00
# Movie: Moana (2016), Similarity Rating: 0.07/1.00
# Movie: The DUFF (2015), Similarity Rating: 0.07/1.00
# Movie: Synecdoche, New York (2008), Similarity Rating: 0.07/1.00
# Movie: Forrest Gump (1994), Similarity Rating: 0.07/1.00
# Movie: Yes Man (2008), Similarity Rating: 0.07/1.00
# Movie: Three Kings (1999), Similarity Rating: 0.07/1.00
# Movie: Luca (2021), Similarity Rating: 0.07/1.00
# Movie: Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966), Similarity Rating: 0.07/1.00
# Movie: Three Colors: Blue (Trois couleurs: Bleu) (1993), Similarity Rating: 0.07/1.00
# Movie: Wallace & Gromit: The Wrong Trousers (1993), Similarity Rating: 0.07/1.00
# Movie: Once Upon a Time in Hollywood (2019), Similarity Rating: 0.07/1.00
# Movie: Captain America: Civil War (2016), Similarity Rating: 0.07/1.00
# Movie: Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) (1983), Similarity Rating: 0.07/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=skellic_ratings,
    my_data=skellic_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 338 movies
# Found 15963 movies you haven't rated
#
# Top Recommendations:
# Movie: The Martian (2015), Similarity Rating: 0.43/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.42/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.40/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.38/1.00
# Movie: Moana (2016), Similarity Rating: 0.37/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.37/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.37/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.36/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.35/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.35/1.00
# Movie: Fargo (1996), Similarity Rating: 0.35/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.35/1.00
# Movie: Coco (2017), Similarity Rating: 0.35/1.00
# Movie: Inception (2010), Similarity Rating: 0.35/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.34/1.00
# Movie: Die Hard (1988), Similarity Rating: 0.34/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.34/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.34/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.33/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.33/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.32/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.32/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.32/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.32/1.00
# Movie: It Follows (2014), Similarity Rating: 0.31/1.00
# Movie: Akira (1988), Similarity Rating: 0.31/1.00
# Movie: Paprika (Papurika) (2006), Similarity Rating: 0.31/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.31/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.31/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.30/1.00
# Movie: Us (2019), Similarity Rating: 0.30/1.00
# Movie: Moon (2009), Similarity Rating: 0.29/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.29/1.00
# Movie: Trainspotting (1996), Similarity Rating: 0.28/1.00
# Movie: Avatar (2009), Similarity Rating: 0.28/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.28/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.28/1.00
# Movie: Lion King, The (1994), Similarity Rating: 0.28/1.00
# Movie: Lives of Others, The (Das leben der Anderen) (2006), Similarity Rating: 0.28/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.28/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.28/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.27/1.00
# Movie: Toy Story 3 (2010), Similarity Rating: 0.27/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.27/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.27/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.27/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.27/1.00
# Movie: Game Night (2018), Similarity Rating: 0.27/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.27/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.27/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.27/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.26/1.00
# Movie: Chinatown (1974), Similarity Rating: 0.26/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.26/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.26/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.26/1.00
# Movie: Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001), Similarity Rating: 0.26/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.26/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.25/1.00
# Movie: Logan (2017), Similarity Rating: 0.25/1.00
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.25/1.00
# Movie: Memento (2000), Similarity Rating: 0.25/1.00
# Movie: Star Wars: Episode III - Revenge of the Sith (2005), Similarity Rating: 0.25/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.25/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.25/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.25/1.00
# Movie: Charlie and the Chocolate Factory (2005), Similarity Rating: 0.25/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.25/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.25/1.00
# Movie: Rogue One: A Star Wars Story (2016), Similarity Rating: 0.24/1.00
# Movie: The Lego Movie (2014), Similarity Rating: 0.24/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.24/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.24/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.24/1.00
# Movie: Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966), Similarity Rating: 0.24/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.24/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.24/1.00
# Movie: Barton Fink (1991), Similarity Rating: 0.24/1.00
# Movie: Star Wars: Episode I - The Phantom Menace (1999), Similarity Rating: 0.23/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.23/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.23/1.00
# Movie: Sin City (2005), Similarity Rating: 0.23/1.00
# Movie: Top Gun: Maverick (2022), Similarity Rating: 0.23/1.00
# Movie: Act of Killing, The (2012), Similarity Rating: 0.23/1.00
# Movie: X-Men (2000), Similarity Rating: 0.23/1.00
# Movie: Harry Potter and the Prisoner of Azkaban (2004), Similarity Rating: 0.23/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.23/1.00
# Movie: Toy Story 2 (1999), Similarity Rating: 0.23/1.00
# Movie: Encanto (2021), Similarity Rating: 0.23/1.00
# Movie: Ice Age (2002), Similarity Rating: 0.23/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.23/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.23/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.22/1.00
# Movie: Battle Royale (Batoru rowaiaru) (2000), Similarity Rating: 0.22/1.00
# Movie: Room (2015), Similarity Rating: 0.22/1.00
# Movie: Great Beauty, The (Grande Bellezza, La) (2013), Similarity Rating: 0.22/1.00
# Movie: Ready Player One, Similarity Rating: 0.22/1.00
# Movie: Slumdog Millionaire (2008), Similarity Rating: 0.22/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.22/1.00
# Movie: Frozen (2013), Similarity Rating: 0.22/1.00
# Movie: Rosemary's Baby (1968), Similarity Rating: 0.22/1.00
# Movie: Tale of Princess Kaguya, The (Kaguyahime no monogatari) (2013), Similarity Rating: 0.22/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.22/1.00
# Movie: Men in Black (a.k.a. MIB) (1997), Similarity Rating: 0.22/1.00
# Movie: Matrix Reloaded, The (2003), Similarity Rating: 0.22/1.00
# Movie: Star Wars: Episode VII - The Force Awakens (2015), Similarity Rating: 0.22/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 2 (2011), Similarity Rating: 0.22/1.00
# Movie: Split (2017), Similarity Rating: 0.22/1.00
# Movie: Synecdoche, New York (2008), Similarity Rating: 0.22/1.00
# Movie: Hate (Haine, La) (1995), Similarity Rating: 0.22/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.22/1.00
# Movie: Citizen Kane (1941), Similarity Rating: 0.21/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.21/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.21/1.00
# Movie: Green Room (2015), Similarity Rating: 0.21/1.00
# Movie: Third Man, The (1949), Similarity Rating: 0.21/1.00
# Movie: Harry Potter and the Chamber of Secrets (2002), Similarity Rating: 0.21/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.21/1.00
# Movie: 8 1/2 (8½) (1963), Similarity Rating: 0.21/1.00
# Movie: Burn After Reading (2008), Similarity Rating: 0.21/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.21/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.21/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.21/1.00
# Movie: Aladdin (1992), Similarity Rating: 0.21/1.00
# Movie: Ponyo (Gake no ue no Ponyo) (2008), Similarity Rating: 0.21/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.21/1.00
# Movie: Man with the Movie Camera, The (Chelovek s kino-apparatom) (1929), Similarity Rating: 0.21/1.00
# Movie: Nope (2022), Similarity Rating: 0.21/1.00
# Movie: Ghost Dog: The Way of the Samurai (1999), Similarity Rating: 0.21/1.00
# Movie: Gran Torino (2008), Similarity Rating: 0.20/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.20/1.00
# Movie: Star Wars: Episode II - Attack of the Clones (2002), Similarity Rating: 0.20/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.20/1.00
# Movie: Princess and the Frog, The (2009), Similarity Rating: 0.20/1.00
# Movie: Brave (2012), Similarity Rating: 0.20/1.00
# Movie: Yojimbo (1961), Similarity Rating: 0.20/1.00
# Movie: Wind Rises, The (Kaze tachinu) (2013), Similarity Rating: 0.20/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.20/1.00
# Movie: Tenet (2020), Similarity Rating: 0.20/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.20/1.00
# Movie: Edge of Tomorrow (2014), Similarity Rating: 0.20/1.00
# Movie: Primer (2004), Similarity Rating: 0.20/1.00
# Movie: Band of Brothers (2001), Similarity Rating: 0.20/1.00
# Movie: Jungle Book, The (1967), Similarity Rating: 0.20/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.20/1.00
# Movie: Megamind (2010), Similarity Rating: 0.20/1.00
# Movie: True Grit (2010), Similarity Rating: 0.20/1.00
# Movie: Garden of Words, The (Koto no ha no niwa) (2013), Similarity Rating: 0.20/1.00
# Movie: Dunkirk (2017), Similarity Rating: 0.20/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.20/1.00
# Movie: X-Men: First Class (2011), Similarity Rating: 0.20/1.00
# Movie: Hitchhiker's Guide to the Galaxy, The (2005), Similarity Rating: 0.20/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.20/1.00
# Movie: Gravity (2013), Similarity Rating: 0.19/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.19/1.00
# Movie: Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005), Similarity Rating: 0.19/1.00
# Movie: [REC] (2007), Similarity Rating: 0.19/1.00
# Movie: Matrix Revolutions, The (2003), Similarity Rating: 0.19/1.00
# Movie: Monty Python's Life of Brian (1979), Similarity Rating: 0.19/1.00
# Movie: Guardians of the Galaxy 2 (2017), Similarity Rating: 0.19/1.00
# Movie: The Green Knight, Similarity Rating: 0.19/1.00
# Movie: Incredibles 2 (2018), Similarity Rating: 0.19/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.19/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.19/1.00
# Movie: Prophet, A (Un Prophète) (2009), Similarity Rating: 0.19/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.19/1.00
# Movie: 127 Hours (2010), Similarity Rating: 0.19/1.00
# Movie: Over the Garden Wall (2013), Similarity Rating: 0.19/1.00
# Movie: Love, Simon (2018), Similarity Rating: 0.19/1.00
# Movie: Raging Bull (1980), Similarity Rating: 0.19/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.19/1.00
# Movie: Cube (1997), Similarity Rating: 0.19/1.00
# Movie: Mean Girls (2004), Similarity Rating: 0.19/1.00
# Movie: Chungking Express (Chung Hing sam lam) (1994), Similarity Rating: 0.19/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.19/1.00
# Movie: The Machinist (2004), Similarity Rating: 0.19/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.19/1.00
# Movie: Triangle (2009), Similarity Rating: 0.19/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.19/1.00
# Movie: Little Women (2019), Similarity Rating: 0.19/1.00
# Movie: Tucker & Dale vs Evil (2010), Similarity Rating: 0.19/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.19/1.00
# Movie: Night of the Living Dead (1968), Similarity Rating: 0.18/1.00
# Movie: Girl Who Leapt Through Time, The (Toki o kakeru shôjo) (2006), Similarity Rating: 0.18/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 1 (2010), Similarity Rating: 0.18/1.00
# Movie: Unbreakable (2000), Similarity Rating: 0.18/1.00
# Movie: First Reformed (2017), Similarity Rating: 0.18/1.00
# Movie: Tropic Thunder (2008), Similarity Rating: 0.18/1.00
# Movie: Gladiator (2000), Similarity Rating: 0.18/1.00
# Movie: Moonlight, Similarity Rating: 0.18/1.00
# Movie: Exit Through the Gift Shop (2010), Similarity Rating: 0.18/1.00
# Movie: Inside Man (2006), Similarity Rating: 0.18/1.00
# Movie: Melancholia (2011), Similarity Rating: 0.18/1.00
# Movie: Nomadland (2020), Similarity Rating: 0.18/1.00
# Movie: Iron Giant, The (1999), Similarity Rating: 0.18/1.00
# Movie: Wreck-It Ralph (2012), Similarity Rating: 0.18/1.00
# Movie: A Silent Voice (2016), Similarity Rating: 0.18/1.00
# Movie: 21 Jump Street (2012), Similarity Rating: 0.18/1.00
# Movie: Millennium Actress (Sennen joyû) (2001), Similarity Rating: 0.18/1.00
# Movie: Pi (1998), Similarity Rating: 0.18/1.00
