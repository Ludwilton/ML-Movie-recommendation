# %%
import pandas as pd
from sklearn.decomposition import NMF
import numpy as np
import time
from sklearn.preprocessing import MinMaxScaler
import joblib
from joblib import load
from joblib import dump
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
ratings= pd.read_csv('./data/ratings.csv')
movies = pd.read_csv('./data/movies.csv')
movie_id_to_title = dict(zip(movies['movieId'], movies['title']))

# %%
def filter_by_average_rating(movies_df, ratings_df, min_rating=0):
    print(f"Filtering movies with average rating >= {min_rating}...")
    
    movies_with_ratings = pd.merge(movies_df, ratings_df, on='movieId', how='inner')
    
    average_ratings = movies_with_ratings.groupby('movieId')['rating'].mean()
    
    popular_movies = average_ratings[average_ratings >= min_rating].index
    
    filtered_movies_with_ratings = movies_with_ratings[movies_with_ratings['movieId'].isin(popular_movies)]
    
    print(f"Kept {len(popular_movies)} movies with average rating >= {min_rating}")
    
    return filtered_movies_with_ratings

# %%
def filter_users_by_activity(ratings_df, min_percentile, max_percentile):

    print(f"Filtering users with activity between {min_percentile*100:.0f}th and {max_percentile*100:.0f}th percentiles...")
    
    # Count ratings per user
    user_rating_counts = ratings_df.groupby('userId')['rating'].count()
    print(f"Before filtering: {len(user_rating_counts)} users with rating statistics:")
    print(user_rating_counts.describe())
    
    # Get percentile thresholds
    min_threshold = user_rating_counts.quantile(min_percentile)
    max_threshold = user_rating_counts.quantile(max_percentile)
    
    # Filter users
    filtered_users = user_rating_counts[(user_rating_counts >= min_threshold) & 
                                       (user_rating_counts <= max_threshold)].index
    
    filtered_ratings = ratings_df[ratings_df['userId'].isin(filtered_users)]
    
    # Get statistics after filtering
    user_rating_counts_after = filtered_ratings.groupby('userId')['rating'].count()
    print(f"After filtering: {len(user_rating_counts_after)} users with rating statistics:")
    print(user_rating_counts_after.describe())
    
    return filtered_ratings

# %%
def filter_movies_by_popularity(ratings_df, min_ratings):

    print(f"Filtering movies with at least {min_ratings} ratings...")
    
    # Count ratings per movie
    movie_rating_counts = ratings_df.groupby('movieId').size()
    
    print(f"Before filtering: {len(movie_rating_counts)} movies")
    print(f"Movies with <{min_ratings} ratings: {(movie_rating_counts < min_ratings).sum()}")
    
    # Filter movies with sufficient ratings
    popular_movies = movie_rating_counts[movie_rating_counts >= min_ratings].index
    
    filtered_ratings = ratings_df[ratings_df['movieId'].isin(popular_movies)]
    
    print(f"After filtering: {len(popular_movies)} movies kept")
    
    return filtered_ratings

# %%
def select_diverse_users(ratings_df, similarity_threshold=0.3, max_users_per_movie=500):
    """
    Select diverse users and return the filtered dataframe.
    """
    # Build user-movie and movie-user mappings
    user_to_movies = {}
    movie_user_counts = {}
    
    for _, row in ratings_df.iterrows():
        user_id = row['userId']
        movie_id = row['movieId']
        
        if user_id not in user_to_movies:
            user_to_movies[user_id] = set()
        user_to_movies[user_id].add(movie_id)
        
        if movie_id not in movie_user_counts:
            movie_user_counts[movie_id] = 0
    
    # Sort users by number of ratings (experts first)
    sorted_users = sorted(user_to_movies.keys(), 
                         key=lambda u: len(user_to_movies[u]), 
                         reverse=True)
    
    # Select diverse users
    selected_users = []
    
    for user_id in sorted_users:
        user_movies = user_to_movies[user_id]
        
        # Check movie limit
        if any(movie_user_counts.get(movie_id, 0) >= max_users_per_movie 
              for movie_id in user_movies):
            continue
        
        # Check similarity with existing users
        too_similar = False
        for selected_id in selected_users:
            selected_movies = user_to_movies[selected_id]
            
            # Calculate Jaccard similarity
            intersection = len(user_movies.intersection(selected_movies))
            union = len(user_movies.union(selected_movies))
            
            if intersection / union > similarity_threshold:
                too_similar = True
                break
        
        if not too_similar:
            selected_users.append(user_id)
            
            # Update movie counts
            for movie_id in user_movies:
                movie_user_counts[movie_id] += 1
    
    # Return the filtered dataframe
    return ratings_df[ratings_df['userId'].isin(selected_users)]

""" def select_diverse_users(ratings_df, max_users_per_movie=1000, similarity_threshold=0.3):

    print(f"Selecting diverse users with max {max_users_per_movie} users per movie...")
    
    # Get initial statistics
    total_users = ratings_df['userId'].nunique()
    total_movies = ratings_df['movieId'].nunique()
    total_ratings = len(ratings_df)
    
    print(f"Initial dataset: {total_ratings} ratings from {total_users} users on {total_movies} movies")
    
    # Create a movie-to-users dictionary to track how many users rated each movie
    movie_to_users = {}
    for movie_id, group in ratings_df.groupby('movieId'):
        movie_to_users[movie_id] = set(group['userId'])
    
    # Create a user-to-movies dictionary
    user_to_movies = {}
    for user_id, group in ratings_df.groupby('userId'):
        user_to_movies[user_id] = set(group['movieId'])
    
    # Sort users by the number of ratings (CHANGED: now in descending order)
    user_rating_counts = ratings_df.groupby('userId').size()
    sorted_users = user_rating_counts.sort_values(ascending=False).index.tolist()
    
    # Add some randomness within rating count groups to prevent bias
    # Group users by rating count
    rating_count_groups = {}
    for user_id, count in user_rating_counts.items():
        if count not in rating_count_groups:
            rating_count_groups[count] = []
        rating_count_groups[count].append(user_id)
    
    # Shuffle each group and rebuild the sorted users list
    shuffled_sorted_users = []
    for count in sorted(rating_count_groups.keys(), reverse=True):
        group = rating_count_groups[count]
        np.random.shuffle(group)
        shuffled_sorted_users.extend(group)
    
    selected_users = set()
    movie_user_counts = {movie_id: 0 for movie_id in movie_to_users.keys()}
    
    # Process users in the sorted order (now more ratings first)
    for user_id in shuffled_sorted_users:
        user_movies = user_to_movies[user_id]
        
        # Skip users with too few ratings (optional)
        if len(user_movies) < 0:  # Minimum threshold can be changed
            continue
            
        # Check if this user would exceed the max users for any movie
        exceeds_limit = False
        for movie_id in user_movies:
            if movie_user_counts[movie_id] >= max_users_per_movie:
                exceeds_limit = True
                break
        
        # Check similarity with already selected users
        too_similar = False
        if not exceeds_limit and len(selected_users) > 0:
            # Check similarity with ALL existing users (no sampling)
            for selected_user in selected_users:
                selected_user_movies = user_to_movies[selected_user]
                
                # Only calculate similarity if there's a minimum overlap
                if len(user_movies) > 0 and len(selected_user_movies) > 0:
                    # Calculate Jaccard similarity between users
                    intersection = len(user_movies.intersection(selected_user_movies))
                    union = len(user_movies.union(selected_user_movies))
                    
                    similarity = intersection / union
                    if similarity > similarity_threshold:
                        too_similar = True
                        break
        
        # Add user if they don't exceed limits and aren't too similar
        if not exceeds_limit and not too_similar:
            selected_users.add(user_id)
            
            # Update movie user counts
            for movie_id in user_movies:
                movie_user_counts[movie_id] += 1
    
    # Filter the ratings DataFrame to only include selected users
    filtered_ratings = ratings_df[ratings_df['userId'].isin(selected_users)]
    
    # Calculate and print statistics
    avg_ratings_per_user = filtered_ratings.groupby('userId').size().mean()
    
    print(f"After filtering: {len(filtered_ratings)} ratings from {len(selected_users)} users")
    print(f"Retained {len(filtered_ratings)/total_ratings:.1%} of original ratings")
    print(f"Average ratings per selected user: {avg_ratings_per_user:.1f}")
    
    return filtered_ratings """
# Out:
# ' def select_diverse_users(ratings_df, max_users_per_movie=1000, similarity_threshold=0.3):\n\n    print(f"Selecting diverse users with max {max_users_per_movie} users per movie...")\n\n    # Get initial statistics\n    total_users = ratings_df[\'userId\'].nunique()\n    total_movies = ratings_df[\'movieId\'].nunique()\n    total_ratings = len(ratings_df)\n\n    print(f"Initial dataset: {total_ratings} ratings from {total_users} users on {total_movies} movies")\n\n    # Create a movie-to-users dictionary to track how many users rated each movie\n    movie_to_users = {}\n    for movie_id, group in ratings_df.groupby(\'movieId\'):\n        movie_to_users[movie_id] = set(group[\'userId\'])\n\n    # Create a user-to-movies dictionary\n    user_to_movies = {}\n    for user_id, group in ratings_df.groupby(\'userId\'):\n        user_to_movies[user_id] = set(group[\'movieId\'])\n\n    # Sort users by the number of ratings (CHANGED: now in descending order)\n    user_rating_counts = ratings_df.groupby(\'userId\').size()\n    sorted_users = user_rating_counts.sort_values(ascending=False).index.tolist()\n\n    # Add some randomness within rating count groups to prevent bias\n    # Group users by rating count\n    rating_count_groups = {}\n    for user_id, count in user_rating_counts.items():\n        if count not in rating_count_groups:\n            rating_count_groups[count] = []\n        rating_count_groups[count].append(user_id)\n\n    # Shuffle each group and rebuild the sorted users list\n    shuffled_sorted_users = []\n    for count in sorted(rating_count_groups.keys(), reverse=True):\n        group = rating_count_groups[count]\n        np.random.shuffle(group)\n        shuffled_sorted_users.extend(group)\n\n    selected_users = set()\n    movie_user_counts = {movie_id: 0 for movie_id in movie_to_users.keys()}\n\n    # Process users in the sorted order (now more ratings first)\n    for user_id in shuffled_sorted_users:\n        user_movies = user_to_movies[user_id]\n\n        # Skip users with too few ratings (optional)\n        if len(user_movies) < 0:  # Minimum threshold can be changed\n            continue\n\n        # Check if this user would exceed the max users for any movie\n        exceeds_limit = False\n        for movie_id in user_movies:\n            if movie_user_counts[movie_id] >= max_users_per_movie:\n                exceeds_limit = True\n                break\n\n        # Check similarity with already selected users\n        too_similar = False\n        if not exceeds_limit and len(selected_users) > 0:\n            # Check similarity with ALL existing users (no sampling)\n            for selected_user in selected_users:\n                selected_user_movies = user_to_movies[selected_user]\n\n                # Only calculate similarity if there\'s a minimum overlap\n                if len(user_movies) > 0 and len(selected_user_movies) > 0:\n                    # Calculate Jaccard similarity between users\n                    intersection = len(user_movies.intersection(selected_user_movies))\n                    union = len(user_movies.union(selected_user_movies))\n\n                    similarity = intersection / union\n                    if similarity > similarity_threshold:\n                        too_similar = True\n                        break\n\n        # Add user if they don\'t exceed limits and aren\'t too similar\n        if not exceeds_limit and not too_similar:\n            selected_users.add(user_id)\n\n            # Update movie user counts\n            for movie_id in user_movies:\n                movie_user_counts[movie_id] += 1\n\n    # Filter the ratings DataFrame to only include selected users\n    filtered_ratings = ratings_df[ratings_df[\'userId\'].isin(selected_users)]\n\n    # Calculate and print statistics\n    avg_ratings_per_user = filtered_ratings.groupby(\'userId\').size().mean()\n\n    print(f"After filtering: {len(filtered_ratings)} ratings from {len(selected_users)} users")\n    print ...

# %%
def create_balanced_matrix_v3(ratings_df, min_ratings_per_movie=3, target_user_count=4000, 
                             target_tier_coverage=0.8, similarity_threshold=0.15, verbose=True):
    """
    Creates a matrix with enhanced representation of less popular movies.
    
    Parameters:
    -----------
    ratings_df : DataFrame
        Original ratings dataframe
    min_ratings_per_movie : int
        Minimum ratings for a movie to be included
    target_user_count : int
        Target number of users to include
    target_tier_coverage : float
        Target coverage for less popular tiers (0-1)
    similarity_threshold : float
        Threshold for Jaccard similarity
    verbose : bool
        Whether to print progress information
    
    Returns:
    --------
    DataFrame
        Filtered ratings dataframe with balanced representation
    """
    if verbose:
        print(f"Creating optimized matrix with enhanced lower tier coverage...")
        print(f"Target: {target_user_count} users with {target_tier_coverage:.0%} coverage of lower tiers")
        print(f"Original dataset: {ratings_df['userId'].nunique()} users, {ratings_df['movieId'].nunique()} movies")
    
    # Filter movies with minimum ratings
    movie_counts = ratings_df.groupby('movieId').size()
    valid_movies = movie_counts[movie_counts >= min_ratings_per_movie].index
    filtered_df = ratings_df[ratings_df['movieId'].isin(valid_movies)]
    
    # Create equal-sized popularity tiers
    movie_counts = filtered_df.groupby('movieId').size().sort_values(ascending=False)
    movies_list = list(movie_counts.index)
    total_movies = len(movies_list)
    tiers = 4
    tier_size = total_movies // tiers
    
    movie_tiers = {}
    for i in range(tiers):
        start_idx = i * tier_size
        end_idx = start_idx + tier_size if i < tiers - 1 else None
        tier_movies = set(movies_list[start_idx:end_idx])
        movie_tiers[i] = tier_movies
    
    if verbose:
        for tier, movies in movie_tiers.items():
            tier_name = ["most popular", "popular", "less popular", "least popular"][tier]
            print(f"Tier {tier} ({tier_name}): {len(movies)} movies")
    
    # Build user mappings optimized for tier analysis
    users_data = {}
    
    for user_id, group in filtered_df.groupby('userId'):
        user_movies = set(group['movieId'])
        tier_counts = {tier: len(user_movies.intersection(tier_movies)) 
                      for tier, tier_movies in movie_tiers.items()}
        
        users_data[user_id] = {
            'movies': user_movies,
            'tier_counts': tier_counts,
            'total_ratings': len(user_movies)
        }
    
    # IMPORTANT: Identify tier-specialist users who rate more in less popular tiers
    tier_specialists = {2: [], 3: []}
    
    for user_id, data in users_data.items():
        tier_counts = data['tier_counts']
        total = sum(tier_counts.values())
        
        if total < 10:  # Skip users with too few ratings
            continue
            
        # Calculate proportion of ratings in lower tiers
        lower_tier_proportion = (tier_counts[2] + tier_counts[3]) / total
        
        # Users with at least 30% ratings in lower tiers are specialists
        if lower_tier_proportion >= 0.3:
            # Further categorize based on which tier they lean toward
            if tier_counts[3] > tier_counts[2]:
                tier_specialists[3].append(user_id)
            else:
                tier_specialists[2].append(user_id)
    
    if verbose:
        print(f"Identified {len(tier_specialists[2])} tier 2 specialists and {len(tier_specialists[3])} tier 3 specialists")
    
    # Calculate extremely weighted user scores - massively favor lower tiers
    user_scores = {}
    for user_id, data in users_data.items():
        tier_counts = data['tier_counts']
        total = data['total_ratings']
        
        if total == 0:
            user_scores[user_id] = 0
            continue
        
        # Super-exponential weighting
        tier_weights = [1, 8, 64, 512]  # Even more aggressive weights
        weighted_sum = sum(tier_weights[tier] * count for tier, count in tier_counts.items())
        
        # Calculate tier coverage
        tiers_with_ratings = sum(1 for count in tier_counts.values() if count > 0)
        coverage_bonus = (tiers_with_ratings / 4) ** 2
        
        # Combine factors
        user_scores[user_id] = (weighted_sum / total) * (1 + coverage_bonus)
    
    # Two-phase matrix construction
    # Phase 1: Focus exclusively on tier specialists to maximize lower tier coverage
    # Phase 2: Fill remaining spots with high-scoring users
    
    # Initialize tracking
    selected_users = []
    movie_user_counts = {movie: 0 for movie in valid_movies}
    
    # Phase 1: Aggressively add tier specialists
    if verbose:
        print("\nPhase 1: Adding tier specialists...")
    
    # First add tier 3 specialists (least popular)
    tier3_target = min(int(target_user_count * 0.25), len(tier_specialists[3]))
    tier3_added = 0
    
    # Sort tier 3 specialists by their score
    sorted_tier3 = sorted(tier_specialists[3], key=lambda u: user_scores[u], reverse=True)
    
    # Very limited restrictions for popular tiers to prioritize tier 3 coverage
    tier_limits = [2, 5, 30, 10000]
    
    for user_id in sorted_tier3:
        # Skip already selected
        if user_id in selected_users:
            continue
            
        # Check tier limits
        user_movies = users_data[user_id]['movies']
        exceeds_limit = False
        
        for movie_id in user_movies:
            for tier, tier_movies in movie_tiers.items():
                if movie_id in tier_movies:
                    if movie_user_counts[movie_id] >= tier_limits[tier]:
                        exceeds_limit = True
                        break
            if exceeds_limit:
                break
                
        if exceeds_limit:
            continue
            
        # Simplified similarity check
        too_similar = False
        if len(selected_users) > 0:
            # Only check recent additions for efficiency
            recent_users = selected_users[-50:]
            for existing_user in recent_users:
                existing_movies = users_data[existing_user]['movies']
                intersection = len(user_movies.intersection(existing_movies))
                
                if intersection == 0:
                    continue
                    
                union = len(user_movies.union(existing_movies))
                similarity = intersection / union
                
                if similarity > similarity_threshold:
                    too_similar = True
                    break
        
        if not too_similar:
            selected_users.append(user_id)
            tier3_added += 1
            
            # Update movie counts
            for movie_id in user_movies:
                movie_user_counts[movie_id] += 1
                
            if tier3_added >= tier3_target:
                break
    
    if verbose:
        print(f"Added {tier3_added} tier 3 specialists")
    
    # Next add tier 2 specialists
    tier2_target = min(int(target_user_count * 0.25), len(tier_specialists[2]))
    tier2_added = 0
    
    # Sort tier 2 specialists by their score
    sorted_tier2 = sorted(tier_specialists[2], key=lambda u: user_scores[u], reverse=True)
    
    # Slightly relaxed tier limits for phase 2
    tier_limits = [3, 10, 50, 10000]
    
    for user_id in sorted_tier2:
        # Skip already selected
        if user_id in selected_users:
            continue
            
        # Check tier limits
        user_movies = users_data[user_id]['movies']
        exceeds_limit = False
        
        for movie_id in user_movies:
            for tier, tier_movies in movie_tiers.items():
                if movie_id in tier_movies:
                    if movie_user_counts[movie_id] >= tier_limits[tier]:
                        exceeds_limit = True
                        break
            if exceeds_limit:
                break
                
        if exceeds_limit:
            continue
            
        # Simplified similarity check
        too_similar = False
        if len(selected_users) > 0:
            # Only check recent additions
            recent_users = selected_users[-50:]
            for existing_user in recent_users:
                existing_movies = users_data[existing_user]['movies']
                intersection = len(user_movies.intersection(existing_movies))
                
                if intersection == 0:
                    continue
                    
                union = len(user_movies.union(existing_movies))
                similarity = intersection / union
                
                if similarity > similarity_threshold:
                    too_similar = True
                    break
        
        if not too_similar:
            selected_users.append(user_id)
            tier2_added += 1
            
            # Update movie counts
            for movie_id in user_movies:
                movie_user_counts[movie_id] += 1
                
            if tier2_added >= tier2_target:
                break
    
    if verbose:
        print(f"Added {tier2_added} tier 2 specialists")
        specialists_added = tier3_added + tier2_added
        print(f"Total specialists added: {specialists_added} ({len(selected_users)} total users so far)")
    
    # Phase 2: Add remaining users based on overall score
    remaining_target = target_user_count - len(selected_users)
    
    if verbose:
        print(f"\nPhase 2: Adding {remaining_target} more users to reach target...")
    
    # Gradually increasing limits for remaining slots
    remaining_phases = [
        {"limits": [5, 20, 100, 10000], "target": remaining_target * 0.3},
        {"limits": [10, 40, 10000, 10000], "target": remaining_target * 0.3},
        {"limits": [20, 10000, 10000, 10000], "target": remaining_target * 0.4}
    ]
    
    # Sort all users by score
    sorted_users = sorted(users_data.keys(), key=lambda u: user_scores[u], reverse=True)
    
    for phase_idx, phase in enumerate(remaining_phases):
        added_in_phase = 0
        phase_target = int(phase["target"])
        tier_limits = phase["limits"]
        
        if verbose:
            print(f"  Remaining phase {phase_idx+1}: target={phase_target}, limits={tier_limits}")
        
        for user_id in sorted_users:
            # Skip already selected
            if user_id in selected_users:
                continue
                
            # Check tier limits
            user_movies = users_data[user_id]['movies']
            exceeds_limit = False
            
            for movie_id in user_movies:
                for tier, tier_movies in movie_tiers.items():
                    if movie_id in tier_movies:
                        if movie_user_counts[movie_id] >= tier_limits[tier]:
                            exceeds_limit = True
                            break
                if exceeds_limit:
                    break
                    
            if exceeds_limit:
                continue
                
            # Simplified similarity check for first 2000 users
            too_similar = False
            if len(selected_users) < 2000:
                # Only check recent additions
                recent_users = selected_users[-50:]
                for existing_user in recent_users:
                    existing_movies = users_data[existing_user]['movies']
                    intersection = len(user_movies.intersection(existing_movies))
                    
                    if intersection == 0:
                        continue
                        
                    union = len(user_movies.union(existing_movies))
                    similarity = intersection / union
                    
                    if similarity > similarity_threshold:
                        too_similar = True
                        break
            
            if not too_similar:
                selected_users.append(user_id)
                added_in_phase += 1
                
                # Update movie counts
                for movie_id in user_movies:
                    movie_user_counts[movie_id] += 1
                    
                # Early stopping for this phase
                if added_in_phase >= phase_target or len(selected_users) >= target_user_count:
                    break
        
        if verbose:
            print(f"    Added {added_in_phase} users in phase {phase_idx+1}, total: {len(selected_users)}")
            
        # Break if target reached
        if len(selected_users) >= target_user_count:
            break
    
    # Final pass if needed
    if len(selected_users) < target_user_count:
        if verbose:
            remaining = target_user_count - len(selected_users)
            print(f"\nFinal pass: Adding {remaining} more users without constraints")
            
        # Sort remaining users by ratings in lower tiers (descending)
        remaining_users = [u for u in users_data.keys() if u not in selected_users]
        sorted_remaining = sorted(
            remaining_users, 
            key=lambda u: users_data[u]['tier_counts'][2] + users_data[u]['tier_counts'][3],
            reverse=True
        )
        
        for user_id in sorted_remaining:
            selected_users.append(user_id)
            
            if len(selected_users) >= target_user_count:
                break
    
    # Create final dataset
    final_df = filtered_df[filtered_df['userId'].isin(selected_users)]
    
    # Evaluate coverage statistics
    final_movies = set(final_df['movieId'].unique())
    tier_representation = {}
    for tier, tier_movies in movie_tiers.items():
        movies_in_tier = len(tier_movies)
        movies_kept = len(tier_movies.intersection(final_movies))
        tier_representation[tier] = movies_kept / movies_in_tier
    
    if verbose:
        print(f"\nFinal matrix statistics:")
        print(f"Selected {len(selected_users)} users ({len(selected_users)/len(users_data):.1%} of valid users)")
        print(f"Covered {len(final_movies)} movies ({len(final_movies)/len(valid_movies):.1%} of valid movies)")
        print(f"Total ratings in matrix: {len(final_df)}")
        
        print("\nTier representation (% of tier movies included):")
        for tier, percentage in tier_representation.items():
            tier_name = ["most popular", "popular", "less popular", "least popular"][tier]
            print(f"  Tier {tier} ({tier_name}): {percentage:.1%}")
        
        # Ratings distribution
        ratings_per_user = final_df.groupby('userId').size()
        print(f"\nRatings per user: min={ratings_per_user.min()}, max={ratings_per_user.max()}, " +
              f"mean={ratings_per_user.mean():.1f}, median={ratings_per_user.median():.1f}")
        
        # Tier distributions
        tier_ratings = {tier: 0 for tier in range(tiers)}
        for movie_id in final_movies:
            for tier, tier_movies in movie_tiers.items():
                if movie_id in tier_movies:
                    movie_ratings = len(final_df[final_df['movieId'] == movie_id])
                    tier_ratings[tier] += movie_ratings
                    break
        
        total_ratings = sum(tier_ratings.values())
        print("\nRating distribution across tiers:")
        for tier, count in tier_ratings.items():
            tier_name = ["most popular", "popular", "less popular", "least popular"][tier]
            percentage = count / total_ratings if total_ratings > 0 else 0
            print(f"  Tier {tier} ({tier_name}): {count} ratings ({percentage:.1%})")
    
    return final_df

# %%
def remove_columns(filtered_df):
    if 'timestamp' in filtered_df.columns:
        filtered_df.drop(columns=["timestamp"], inplace=True)
    if 'genres' in filtered_df.columns:
        filtered_df.drop(columns=["genres"], inplace=True)
    if 'title' in filtered_df.columns:
        filtered_df.drop(columns=["title"], inplace=True)
    
    print(f"Final dataset: {len(filtered_df)} ratings across {filtered_df['movieId'].nunique()} movies from {filtered_df['userId'].nunique()} users")

    return filtered_df

# %%
ratings = remove_columns(ratings)
# Out:
# Final dataset: 33832162 ratings across 83239 movies from 330975 users

# %%
min_avg_rating=0
user_min_percentile=0.50 # these seem to fit the average user best
user_max_percentile=0.97
min_ratings_per_movie=2
max_users_per_movie=80 # 250
user_similarity_threshold=1 # 0.15

# %%
# Step 3: Filter users by activity level
filtered_df = filter_users_by_activity(
    ratings,
    min_percentile=user_min_percentile,
    max_percentile=user_max_percentile
)
# Out:
# Filtering users with activity between 50th and 97th percentiles...
# Before filtering: 330975 users with rating statistics:
# count    330975.00000
# mean        102.21969
# std         232.15453
# min           1.00000
# 25%          15.00000
# 50%          31.00000
# 75%          98.00000
# max       33332.00000
# Name: rating, dtype: float64
# After filtering: 156971 users with rating statistics:
# count    156971.000000
# mean        134.058023
# std         116.407592
# min          31.000000
# 25%          51.000000
# 50%          90.000000
# 75%         173.000000
# max         579.000000
# Name: rating, dtype: float64

# %%
ratings_df = create_balanced_matrix_v3(
    filtered_df,
    min_ratings_per_movie=3,
    target_user_count=1000,
    target_tier_coverage=0.98,  # Target 80% coverage for lower tiers
    similarity_threshold=0.5,
    verbose=True
)
# Out:
# Creating optimized matrix with enhanced lower tier coverage...
# Target: 1000 users with 98% coverage of lower tiers
# Original dataset: 156971 users, 49671 movies
# Tier 0 (most popular): 7126 movies
# Tier 1 (popular): 7126 movies
# Tier 2 (less popular): 7126 movies
# Tier 3 (least popular): 7128 movies
# Identified 50 tier 2 specialists and 11 tier 3 specialists
#
# Phase 1: Adding tier specialists...
# Added 11 tier 3 specialists
# Added 24 tier 2 specialists
# Total specialists added: 35 (35 total users so far)
#
# Phase 2: Adding 965 more users to reach target...
#   Remaining phase 1: target=289, limits=[5, 20, 100, 10000]
#     Added 196 users in phase 1, total: 231
#   Remaining phase 2: target=289, limits=[10, 40, 10000, 10000]
#     Added 190 users in phase 2, total: 421
#   Remaining phase 3: target=386, limits=[20, 10000, 10000, 10000]
#     Added 285 users in phase 3, total: 706
#
# Final pass: Adding 294 more users without constraints
#
# Final matrix statistics:
# Selected 1000 users (0.6% of valid users)
# Covered 23133 movies (81.2% of valid movies)
# Total ratings in matrix: 164878
#
# Tier representation (% of tier movies included):
#   Tier 0 (most popular): 97.2%
#   Tier 1 (popular): 88.0%
#   Tier 2 (less popular): 77.2%
#   Tier 3 (least popular): 62.2%
#
# Ratings per user: min=7, max=568, mean=164.9, median=61.0
#
# Rating distribution across tiers:
#   Tier 0 (most popular): 119373 ratings (72.4%)
#   Tier 1 (popular): 25451 ratings (15.4%)
#   Tier 2 (less popular): 13000 ratings (7.9%)
#   Tier 3 (least popular): 7054 ratings (4.3%)

# %%
filtered_df = remove_columns(ratings_df)
# Out:
# Final dataset: 164878 ratings across 23133 movies from 1000 users

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (1000, 23133)

# %%
# Step 2: Filter by average rating
filtered_df = filter_by_average_rating(
    movies, 
    ratings_df, 
    min_rating=min_avg_rating
)
# Out:
# Filtering movies with average rating >= 0...
# Kept 23133 movies with average rating >= 0

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (1000, 23133)

# %%
filtered_df = filter_movies_by_popularity(
    filtered_df,
    min_ratings=min_ratings_per_movie
)
# Out:
# Filtering movies with at least 2 ratings...
# Before filtering: 23133 movies
# Movies with <2 ratings: 6009
# After filtering: 17124 movies kept

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (1000, 17124)

# %%
def scale_ratings(matrix):
    """
    Z-score normalization with clipping to avoid extreme values.
    Accounts for user rating tendencies while preserving relative importance.
    """
    data = matrix.copy().values
    rows = data.shape[0]
    
    # Calculate global mean (we'll only use this for documentation in comments)
    global_mean = np.mean(data[data > 0])
    
    for i in range(rows):
        # Find rated movies for this user
        nonzero_mask = data[i, :] > 0
        rated_indices = np.where(nonzero_mask)[0]
        
        # Get user's ratings
        user_ratings = data[i, rated_indices]
        
        if len(user_ratings) > 1:
            # Calculate user's own mean
            user_mean = np.mean(user_ratings)
            
            # Mean center relative to user's own mean
            centered_ratings = user_ratings - user_mean
            
            # Apply standardization if there's variance
            user_std = np.std(user_ratings)
            if user_std > 0:
                # Z-score normalize
                normalized_ratings = centered_ratings / user_std
                # Clip to avoid extreme values (-2.5 to 2.5 is ~99% of normal distribution)
                normalized_ratings = np.clip(normalized_ratings, -2.5, 2.5)
                # Scale to [0,1] range
                scaled_ratings = (normalized_ratings + 2.5) / 5.0
            else:
                # If all ratings are the same, set to neutral 0.5
                scaled_ratings = np.ones_like(user_ratings) * 0.5
                
            # Update the matrix with scaled ratings
            data[i, rated_indices] = scaled_ratings
    
    # Convert back to DataFrame
    scaled_matrix = pd.DataFrame(data, index=matrix.index, columns=matrix.columns)
    return scaled_matrix

# %%
def prepare_user_ratings(ratings_file_path, user_movie_matrix_columns):
    """
    Prepares and scales a single user's ratings using the same Z-score
    normalization approach as the training data.
    """
    user_data = pd.read_csv(ratings_file_path)
    user_data = user_data.dropna(subset=['movieId'])
    
    # Create user-movie ratings matrix with zero values
    user_ratings = pd.DataFrame(0.0, index=[0], columns=user_movie_matrix_columns, dtype=np.float64)
    
    # Fill with original ratings
    for _, row in user_data.iterrows():
        movie_id = row['movieId']
        if movie_id in user_ratings.columns:
            user_ratings.loc[0, movie_id] = float(row['Rating'])
    
    # Get indices of rated movies
    nonzero_mask = user_ratings.values > 0
    rated_indices = np.where(nonzero_mask[0])[0]
    
    # Get this user's ratings
    user_rating_values = user_ratings.iloc[0, rated_indices].values
    
    if len(user_rating_values) > 1:
        # Calculate user's mean and std
        user_mean = np.mean(user_rating_values)
        user_std = np.std(user_rating_values)
        
        # Apply Z-score normalization if there's variance
        if user_std > 0:
            # Center around mean and normalize by standard deviation
            normalized_ratings = (user_rating_values - user_mean) / user_std
            # Clip to avoid extreme values
            normalized_ratings = np.clip(normalized_ratings, -2.5, 2.5)
            # Scale to [0,1] range
            scaled_ratings = (normalized_ratings + 2.5) / 5.0
        else:
            # If all ratings are the same, set to neutral 0.5
            scaled_ratings = np.ones_like(user_rating_values) * 0.5
        
        # Update the user ratings with scaled values
        user_ratings.iloc[0, rated_indices] = scaled_ratings
    
    return user_data, user_ratings

# %%
def fit_model(
    user_movie_matrix,
    n_components=50,
    max_iter=100,
    init='random',
    solver='cd',
    tol=0.0001,

    sample_size=1.0
):

    print(f"\n--- Fitting model with {sample_size*100:.0f}% of users ---")
    
    # Sample users 
    if sample_size < 1.0:
        n_users = int(user_movie_matrix.shape[0] * sample_size)
        sampled_users = np.random.choice(user_movie_matrix.index, size=n_users, replace=False)
        training_matrix = user_movie_matrix.loc[sampled_users, :]
    else:
        training_matrix = user_movie_matrix
    
    print(f"Training matrix shape: {training_matrix.shape}")
    
    # Train the model
    start_time = time.time()
    nmf = NMF(
        n_components=n_components,
        max_iter=max_iter,
        verbose=0,
        init="nndsvd",
        solver=solver,
        tol=tol,
    )
    
    user_factors = nmf.fit_transform(training_matrix)
    item_factors = nmf.components_
    training_time = time.time() - start_time
    
    print(f"Training time: {training_time:.2f} seconds")
    print(f"Iterations completed: {nmf.n_iter_}")
    print(f"Final error: {nmf.reconstruction_err_}")
    
    return nmf, training_matrix, training_time

# %%
def get_recommendations(
    nmf_model,
    training_matrix,
    my_ratings,
    my_data,
    n_recommendations=20,
    movie_id_to_title_map=None
):
    # Transform personal ratings into factor space
    my_user_factors = nmf_model.transform(my_ratings)
    
    # Generate predictions
    predicted_ratings = np.dot(my_user_factors, nmf_model.components_)
    predicted_ratings_df = pd.DataFrame(predicted_ratings, columns=training_matrix.columns)
    
    # Get movies already rated
    rated_movies = set(int(movie_id) for movie_id in my_data['movieId'].values)
    print(f"You've rated {len(rated_movies)} movies")
    
    # Filter for unrated movies
    unrated_movies = [m for m in training_matrix.columns if int(m) not in rated_movies]
    print(f"Found {len(unrated_movies)} movies you haven't rated")
    
    # Get recommendations
    recommendations = []
    for movie_id in unrated_movies:
        pred_rating = predicted_ratings_df.loc[0, movie_id]
        recommendations.append((movie_id, pred_rating))
    
    recommendations.sort(key=lambda x: x[1], reverse=True)
    
    top_recommendations = recommendations[:n_recommendations]
    
    if movie_id_to_title_map:
        print("\nTop Recommendations:")
        for movie_id, predicted_rating in top_recommendations:
            # Convert from 0-1 scale back to 1-5 scale
            original_scale_rating = predicted_rating * 4 + 1 # this didnt work that well tbh
            
            movie_title = movie_id_to_title_map.get(movie_id, f"Unknown Movie (ID: {movie_id})")
            print(f"Movie: {movie_title}, Similarity Rating: {predicted_rating:.2f}/1.00")
    
    return top_recommendations

# %%
def evaluate_nmf_predictions(nmf_model, training_matrix, test_data):


    # Create a wide-format user vector (like ludde_ratings) filled with zeros
    user_vector = np.zeros(training_matrix.shape[1])
    
    # Map movie IDs to their indices in the model
    movie_indices = {}
    if hasattr(training_matrix, 'columns'):
        # If training_matrix is a DataFrame
        for i, col in enumerate(training_matrix.columns):
            movie_indices[col] = i
    else:
        # Assume movie IDs are consecutive integers starting from 1 or 0
        offset = 1 if training_matrix.shape[1] == 19915 else 0
        for i in range(training_matrix.shape[1]):
            movie_indices[i + offset] = i
    
    # Collect actual ratings and movie positions for comparison
    actual_ratings = []
    movie_positions = []
    
    # Fill the user vector with ratings from test_data
    for _, row in test_data.iterrows():
        movie_id = row['movieId']
        rating = row['Rating']
        
        if movie_id in movie_indices:
            position = movie_indices[movie_id]
            user_vector[position] = rating
            actual_ratings.append(rating)
            movie_positions.append(position)
    
    # Transform the user vector to get user factors
    user_factors = nmf_model.transform([user_vector])
    
    # Generate predictions for all movies
    predictions_all = user_factors @ nmf_model.components_
    
    # Extract predictions for only the movies we rated in test_data
    predicted_ratings = [predictions_all[0, pos] for pos in movie_positions]
    
    # Calculate metrics
    if len(actual_ratings) > 0:
        rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_ratings))
        mae = mean_absolute_error(actual_ratings, predicted_ratings)
        me = np.mean(np.array(predicted_ratings) - np.array(actual_ratings))
        corr = np.corrcoef(actual_ratings, predicted_ratings)[0, 1] if len(actual_ratings) > 1 else np.nan
    else:
        rmse, mae, me, corr = np.nan, np.nan, np.nan, np.nan
    
    return {
        'rmse': rmse,
        'mae': mae,
        'mean_error': me,
        'correlation': corr,
        'num_predictions': len(actual_ratings)
    }

# %%
user_movie_matrix = filtered_df.pivot(index='userId', columns='movieId', values='rating')
user_movie_matrix = user_movie_matrix.fillna(0)
user_movie_matrix_scaled = scale_ratings(user_movie_matrix)

# %%
nmf_model, training_matrix, _ = fit_model(
    user_movie_matrix_scaled,
    n_components=150, # 300 was og
    sample_size=1,
    max_iter=800,
)
# Out:
# --- Fitting model with 100% of users ---
# Training matrix shape: (1000, 17124)

# %%
import joblib
import pandas as pd
import numpy as np
import os
from sklearn.decomposition import NMF

# Create model_files directory if it doesn't exist
os.makedirs('model_files', exist_ok=True)


joblib.dump(nmf_model, 'model_files/nmf_model.joblib')


movie_ids = training_matrix.columns.tolist()
joblib.dump(movie_ids, 'model_files/movie_ids.joblib')


model_metadata = {
    'n_components': nmf_model.n_components,
    'trained_on': pd.Timestamp.now().strftime('%Y-%m-%d %H:%M'),
    'matrix_shape': training_matrix.shape,
    'scaling_method': 'z_score_normalization',
}
joblib.dump(model_metadata, 'model_files/model_metadata.joblib')

print(f"Model saved with {len(movie_ids)} movies and {nmf_model.n_components} components")
# Out:
# Model saved with 10593 movies and 300 components

# %%
elliott_data, elliott_ratings = prepare_user_ratings(
    "data/loelliot_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
ludde_data, ludde_ratings = prepare_user_ratings(
    "data/ludde_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
charlie_data, charlie_ratings = prepare_user_ratings(
    "data/chaarll_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
tilda_data, tilda_ratings = prepare_user_ratings(
    "data/tilda_h_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
zorrodor_data, zorrodor_ratings = prepare_user_ratings(
    "data/zorrodor_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
lukas_data, lukas_ratings = prepare_user_ratings(
    "data/lukas_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
clara_data, clara_ratings = prepare_user_ratings(
    "data/clar_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
voided_data, voided_ratings = prepare_user_ratings(
    "data/voided_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
skellic_data, skellic_ratings = prepare_user_ratings(
    "data/skellic_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
liv_data, liv_ratings = prepare_user_ratings(
    "data/liv_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)

# %%
ludde_data.info()

# %%
ludde_ratings.info()

# %%
# recommendations = get_recommendations(
#     nmf_model=nmf_model,
#     training_matrix=training_matrix,
#     my_ratings=ludde_ratings,
#     my_data=ludde_data,
#     n_recommendations=200,
#     movie_id_to_title_map=movie_id_to_title,
# )
# Evaluate the model with your test data
metrics = evaluate_nmf_predictions(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    test_data=ludde_data  # Your test data with  movie_id, rating columns
)

# Display metrics
print(f"RMSE: {metrics['rmse']:.4f}")
print(f"MAE: {metrics['mae']:.4f}")
print(f"Mean Error: {metrics['mean_error']:.4f}")
print(f"Correlation: {metrics['correlation']:.4f}")
print(f"Number of predictions: {metrics['num_predictions']}")
# Out:
# RMSE: 2.2123
# MAE: 1.9729
# Mean Error: -1.9364
# Correlation: 0.3753
# Number of predictions: 410

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=ludde_ratings,
    my_data=ludde_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 426 movies
# Found 10183 movies you haven't rated
#
# Top Recommendations:
# Movie: American Beauty (1999), Similarity Rating: 0.51/1.00
# Movie: Beautiful Mind, A (2001), Similarity Rating: 0.44/1.00
# Movie: Saving Private Ryan (1998), Similarity Rating: 0.44/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.39/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.39/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.38/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.37/1.00
# Movie: Cast Away (2000), Similarity Rating: 0.37/1.00
# Movie: Logan (2017), Similarity Rating: 0.37/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.35/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.35/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.35/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.34/1.00
# Movie: Kill Bill: Vol. 2 (2004), Similarity Rating: 0.34/1.00
# Movie: 12 Angry Men (1957), Similarity Rating: 0.34/1.00
# Movie: Pianist, The (2002), Similarity Rating: 0.34/1.00
# Movie: Coco (2017), Similarity Rating: 0.33/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.33/1.00
# Movie: Hidden Figures (2016), Similarity Rating: 0.32/1.00
# Movie: Terminator 2: Judgment Day (1991), Similarity Rating: 0.32/1.00
# Movie: Thor (2011), Similarity Rating: 0.32/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.32/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.32/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.31/1.00
# Movie: Pursuit of Happyness, The (2006), Similarity Rating: 0.31/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.31/1.00
# Movie: Fargo (1996), Similarity Rating: 0.31/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.31/1.00
# Movie: Hobbit: An Unexpected Journey, The (2012), Similarity Rating: 0.31/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.30/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.30/1.00
# Movie: Captain Phillips (2013), Similarity Rating: 0.30/1.00
# Movie: Green Book (2018), Similarity Rating: 0.30/1.00
# Movie: Soul (2020), Similarity Rating: 0.29/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.29/1.00
# Movie: There Will Be Blood (2007), Similarity Rating: 0.28/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.28/1.00
# Movie: The Hateful Eight (2015), Similarity Rating: 0.28/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.28/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.28/1.00
# Movie: Taxi Driver (1976), Similarity Rating: 0.27/1.00
# Movie: Tangled (2010), Similarity Rating: 0.27/1.00
# Movie: John Wick: Chapter Two (2017), Similarity Rating: 0.27/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.27/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.27/1.00
# Movie: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), Similarity Rating: 0.27/1.00
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.27/1.00
# Movie: The Irishman (2019), Similarity Rating: 0.27/1.00
# Movie: Hamilton (2020), Similarity Rating: 0.26/1.00
# Movie: Snatch (2000), Similarity Rating: 0.26/1.00
# Movie: Kung Fu Panda (2008), Similarity Rating: 0.26/1.00
# Movie: Goodfellas (1990), Similarity Rating: 0.26/1.00
# Movie: Prisoners (2013), Similarity Rating: 0.26/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.25/1.00
# Movie: Wonder Woman (2017), Similarity Rating: 0.25/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.25/1.00
# Movie: Zombieland (2009), Similarity Rating: 0.25/1.00
# Movie: CODA (2021), Similarity Rating: 0.25/1.00
# Movie: Hobbit: The Desolation of Smaug, The (2013), Similarity Rating: 0.24/1.00
# Movie: Mission: Impossible - Fallout (2018), Similarity Rating: 0.24/1.00
# Movie: Kingsman: The Golden Circle (2017), Similarity Rating: 0.24/1.00
# Movie: Bourne Supremacy, The (2004), Similarity Rating: 0.24/1.00
# Movie: The Witch (2015), Similarity Rating: 0.24/1.00
# Movie: Wreck-It Ralph (2012), Similarity Rating: 0.24/1.00
# Movie: Matrix Reloaded, The (2003), Similarity Rating: 0.24/1.00
# Movie: Minority Report (2002), Similarity Rating: 0.24/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.24/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.24/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.23/1.00
# Movie: Skyfall (2012), Similarity Rating: 0.23/1.00
# Movie: Aviator, The (2004), Similarity Rating: 0.23/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.23/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.23/1.00
# Movie: Ant-Man and the Wasp (2018), Similarity Rating: 0.23/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.23/1.00
# Movie: Hurt Locker, The (2008), Similarity Rating: 0.23/1.00
# Movie: Juno (2007), Similarity Rating: 0.23/1.00
# Movie: Terminal, The (2004), Similarity Rating: 0.22/1.00
# Movie: Slumdog Millionaire (2008), Similarity Rating: 0.22/1.00
# Movie: Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005), Similarity Rating: 0.22/1.00
# Movie: Room (2015), Similarity Rating: 0.22/1.00
# Movie: Coraline (2009), Similarity Rating: 0.22/1.00
# Movie: The Lego Movie (2014), Similarity Rating: 0.22/1.00
# Movie: 10 Cloverfield Lane (2016), Similarity Rating: 0.22/1.00
# Movie: Star Trek (2009), Similarity Rating: 0.22/1.00
# Movie: Home Alone 2: Lost in New York (1992), Similarity Rating: 0.22/1.00
# Movie: It Follows (2014), Similarity Rating: 0.22/1.00
# Movie: Breakfast Club, The (1985), Similarity Rating: 0.22/1.00
# Movie: About Time (2013), Similarity Rating: 0.22/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.22/1.00
# Movie: Life Is Beautiful (La Vita è bella) (1997), Similarity Rating: 0.22/1.00
# Movie: 300 (2007), Similarity Rating: 0.22/1.00
# Movie: World's End, The (2013), Similarity Rating: 0.22/1.00
# Movie: Monty Python's Life of Brian (1979), Similarity Rating: 0.21/1.00
# Movie: The Fault in Our Stars (2014), Similarity Rating: 0.21/1.00
# Movie: Wizard of Oz, The (1939), Similarity Rating: 0.21/1.00
# Movie: Argo (2012), Similarity Rating: 0.21/1.00
# Movie: Mission: Impossible - Ghost Protocol (2011), Similarity Rating: 0.21/1.00
# Movie: Old Boy (2003), Similarity Rating: 0.21/1.00
# Movie: Braveheart (1995), Similarity Rating: 0.21/1.00
# Movie: Oblivion (2013), Similarity Rating: 0.21/1.00
# Movie: Paddington 2 (2017), Similarity Rating: 0.21/1.00
# Movie: Requiem for a Dream (2000), Similarity Rating: 0.21/1.00
# Movie: Casino Royale (2006), Similarity Rating: 0.21/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.21/1.00
# Movie: Aladdin (1992), Similarity Rating: 0.21/1.00
# Movie: Mask, The (1994), Similarity Rating: 0.20/1.00
# Movie: Apollo 13 (1995), Similarity Rating: 0.20/1.00
# Movie: Moulin Rouge (2001), Similarity Rating: 0.20/1.00
# Movie: Incredibles 2 (2018), Similarity Rating: 0.20/1.00
# Movie: Moon (2009), Similarity Rating: 0.20/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.20/1.00
# Movie: Conjuring, The (2013), Similarity Rating: 0.20/1.00
# Movie: Matrix Revolutions, The (2003), Similarity Rating: 0.20/1.00
# Movie: Serenity (2005), Similarity Rating: 0.20/1.00
# Movie: Whiplash (2013), Similarity Rating: 0.19/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.19/1.00
# Movie: Nightmare Before Christmas, The (1993), Similarity Rating: 0.19/1.00
# Movie: Psycho (1960), Similarity Rating: 0.19/1.00
# Movie: (500) Days of Summer (2009), Similarity Rating: 0.19/1.00
# Movie: Now You See Me 2 (2016), Similarity Rating: 0.19/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.19/1.00
# Movie: The Father (2020), Similarity Rating: 0.19/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.19/1.00
# Movie: Moana (2016), Similarity Rating: 0.18/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.18/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.18/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.18/1.00
# Movie: In Bruges (2008), Similarity Rating: 0.18/1.00
# Movie: Sicario (2015), Similarity Rating: 0.18/1.00
# Movie: Kick-Ass (2010), Similarity Rating: 0.18/1.00
# Movie: O Brother, Where Art Thou? (2000), Similarity Rating: 0.18/1.00
# Movie: Saw (2004), Similarity Rating: 0.18/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.18/1.00
# Movie: Office Space (1999), Similarity Rating: 0.18/1.00
# Movie: Tucker & Dale vs Evil (2010), Similarity Rating: 0.18/1.00
# Movie: Indiana Jones and the Temple of Doom (1984), Similarity Rating: 0.18/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.18/1.00
# Movie: Despicable Me 2 (2013), Similarity Rating: 0.18/1.00
# Movie: Mission: Impossible II (2000), Similarity Rating: 0.18/1.00
# Movie: Fast and the Furious, The (2001), Similarity Rating: 0.17/1.00
# Movie: Stoning of Soraya M., The (2008), Similarity Rating: 0.17/1.00
# Movie: Apocalypse Now (1979), Similarity Rating: 0.17/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.17/1.00
# Movie: Charlie and the Chocolate Factory (2005), Similarity Rating: 0.17/1.00
# Movie: Separation, A (Jodaeiye Nader az Simin) (2011), Similarity Rating: 0.17/1.00
# Movie: Hangover Part III, The (2013), Similarity Rating: 0.17/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.17/1.00
# Movie: Casablanca (1942), Similarity Rating: 0.17/1.00
# Movie: La La Land (2016), Similarity Rating: 0.17/1.00
# Movie: Paddington (2014), Similarity Rating: 0.17/1.00
# Movie: Face/Off (1997), Similarity Rating: 0.17/1.00
# Movie: Back to the Future Part III (1990), Similarity Rating: 0.17/1.00
# Movie: Scarface (1983), Similarity Rating: 0.17/1.00
# Movie: Jiro Dreams of Sushi (2011), Similarity Rating: 0.17/1.00
# Movie: The Hitman's Bodyguard (2017), Similarity Rating: 0.17/1.00
# Movie: Ghostbusters (a.k.a. Ghost Busters) (1984), Similarity Rating: 0.17/1.00
# Movie: Hacksaw Ridge (2016), Similarity Rating: 0.17/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.17/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.17/1.00
# Movie: Training Day (2001), Similarity Rating: 0.17/1.00
# Movie: Sweeney Todd: The Demon Barber of Fleet Street (2007), Similarity Rating: 0.17/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.16/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.16/1.00
# Movie: Mission: Impossible - Rogue Nation (2015), Similarity Rating: 0.16/1.00
# Movie: Molly's Game (2017), Similarity Rating: 0.16/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.16/1.00
# Movie: Monsters University (2013), Similarity Rating: 0.16/1.00
# Movie: Goonies, The (1985), Similarity Rating: 0.16/1.00
# Movie: Last Samurai, The (2003), Similarity Rating: 0.16/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.16/1.00
# Movie: Emperor's New Groove, The (2000), Similarity Rating: 0.16/1.00
# Movie: Easy A (2010), Similarity Rating: 0.16/1.00
# Movie: Jumanji: Welcome to the Jungle (2017), Similarity Rating: 0.15/1.00
# Movie: Ring, The (2002), Similarity Rating: 0.15/1.00
# Movie: Suspiria (2017), Similarity Rating: 0.15/1.00
# Movie: Fantastic Beasts and Where to Find Them (2016), Similarity Rating: 0.15/1.00
# Movie: Airplane! (1980), Similarity Rating: 0.15/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.15/1.00
# Movie: Mulan (1998), Similarity Rating: 0.15/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.15/1.00
# Movie: Scream (1996), Similarity Rating: 0.15/1.00
# Movie: Sin City (2005), Similarity Rating: 0.15/1.00
# Movie: Minari (2020), Similarity Rating: 0.15/1.00
# Movie: Predestination (2014), Similarity Rating: 0.15/1.00
# Movie: Napoleon Dynamite (2004), Similarity Rating: 0.15/1.00
# Movie: Little Mermaid, The (1989), Similarity Rating: 0.15/1.00
# Movie: Darkest Hour (2017), Similarity Rating: 0.15/1.00
# Movie: Mary Poppins (1964), Similarity Rating: 0.15/1.00
# Movie: Curious Case of Benjamin Button, The (2008), Similarity Rating: 0.15/1.00
# Movie: Howl's Moving Castle (Hauru no ugoku shiro) (2004), Similarity Rating: 0.15/1.00
# Movie: Wolverine, The (2013), Similarity Rating: 0.15/1.00
# Movie: Beverly Hills Cop (1984), Similarity Rating: 0.15/1.00
# Movie: Legally Blonde (2001), Similarity Rating: 0.15/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.15/1.00
# Movie: Chronicles of Narnia: Prince Caspian, The (2008), Similarity Rating: 0.15/1.00
# Movie: Fury (2014), Similarity Rating: 0.15/1.00
# Movie: Me Before You (2016), Similarity Rating: 0.15/1.00
# Movie: Cloud Atlas (2012), Similarity Rating: 0.15/1.00
# Movie: We're the Millers (2013), Similarity Rating: 0.15/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=tilda_ratings,
    my_data=tilda_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 285 movies
# Found 10321 movies you haven't rated
#
# Top Recommendations:
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.35/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.34/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 2 (2011), Similarity Rating: 0.32/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.32/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.31/1.00
# Movie: The Martian (2015), Similarity Rating: 0.31/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.30/1.00
# Movie: Intouchables (2011), Similarity Rating: 0.30/1.00
# Movie: Little Women (2019), Similarity Rating: 0.30/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.29/1.00
# Movie: Django Unchained (2012), Similarity Rating: 0.28/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.28/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.27/1.00
# Movie: Seven (a.k.a. Se7en) (1995), Similarity Rating: 0.26/1.00
# Movie: Beautiful Mind, A (2001), Similarity Rating: 0.26/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.25/1.00
# Movie: Harry Potter and the Half-Blood Prince (2009), Similarity Rating: 0.25/1.00
# Movie: Memento (2000), Similarity Rating: 0.25/1.00
# Movie: Curious Case of Benjamin Button, The (2008), Similarity Rating: 0.24/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.24/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 1 (2010), Similarity Rating: 0.24/1.00
# Movie: Hidden Figures (2016), Similarity Rating: 0.24/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.24/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.23/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.23/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.23/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.23/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.22/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.22/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.22/1.00
# Movie: 1917 (2019), Similarity Rating: 0.22/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.21/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.21/1.00
# Movie: American Psycho (2000), Similarity Rating: 0.21/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.21/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.21/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.21/1.00
# Movie: Dunkirk (2017), Similarity Rating: 0.21/1.00
# Movie: Great Gatsby, The (2013), Similarity Rating: 0.21/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.21/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.21/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.21/1.00
# Movie: Lord of the Rings: The Two Towers, The (2002), Similarity Rating: 0.21/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.21/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.20/1.00
# Movie: Lord of the Rings: The Return of the King, The (2003), Similarity Rating: 0.20/1.00
# Movie: Psycho (1960), Similarity Rating: 0.20/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.20/1.00
# Movie: Cast Away (2000), Similarity Rating: 0.20/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.20/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.20/1.00
# Movie: Room (2015), Similarity Rating: 0.20/1.00
# Movie: Crazy Rich Asians (2018), Similarity Rating: 0.20/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.20/1.00
# Movie: Me Before You (2016), Similarity Rating: 0.20/1.00
# Movie: Before Sunset (2004), Similarity Rating: 0.20/1.00
# Movie: Tenet (2020), Similarity Rating: 0.20/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.20/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.20/1.00
# Movie: Pianist, The (2002), Similarity Rating: 0.20/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.19/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.19/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.19/1.00
# Movie: 12 Angry Men (1957), Similarity Rating: 0.19/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.19/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.19/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.19/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.19/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.19/1.00
# Movie: Saving Private Ryan (1998), Similarity Rating: 0.19/1.00
# Movie: Lord of the Rings: The Fellowship of the Ring, The (2001), Similarity Rating: 0.19/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.18/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.18/1.00
# Movie: Blue Valentine (2010), Similarity Rating: 0.18/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.18/1.00
# Movie: Captain Fantastic (2016), Similarity Rating: 0.18/1.00
# Movie: Help, The (2011), Similarity Rating: 0.18/1.00
# Movie: Wizard of Oz, The (1939), Similarity Rating: 0.18/1.00
# Movie: Atonement (2007), Similarity Rating: 0.18/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.18/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.17/1.00
# Movie: Moana (2016), Similarity Rating: 0.17/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.17/1.00
# Movie: Free Solo (2018), Similarity Rating: 0.17/1.00
# Movie: Tangled (2010), Similarity Rating: 0.17/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.17/1.00
# Movie: Persepolis (2007), Similarity Rating: 0.17/1.00
# Movie: Shrek 2 (2004), Similarity Rating: 0.17/1.00
# Movie: Me and Earl and the Dying Girl (2015), Similarity Rating: 0.17/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.17/1.00
# Movie: Moulin Rouge (2001), Similarity Rating: 0.17/1.00
# Movie: Hangover Part II, The (2011), Similarity Rating: 0.17/1.00
# Movie: Frozen (2013), Similarity Rating: 0.17/1.00
# Movie: Captain Phillips (2013), Similarity Rating: 0.17/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.17/1.00
# Movie: Batman Begins (2005), Similarity Rating: 0.17/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.17/1.00
# Movie: There Will Be Blood (2007), Similarity Rating: 0.16/1.00
# Movie: Aviator, The (2004), Similarity Rating: 0.16/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.16/1.00
# Movie: Perfect Blue (1997), Similarity Rating: 0.16/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.16/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.16/1.00
# Movie: Gladiator (2000), Similarity Rating: 0.16/1.00
# Movie: We're the Millers (2013), Similarity Rating: 0.16/1.00
# Movie: Ready Player One, Similarity Rating: 0.16/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.16/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.16/1.00
# Movie: The Irishman (2019), Similarity Rating: 0.16/1.00
# Movie: Incredibles, The (2004), Similarity Rating: 0.16/1.00
# Movie: Frances Ha (2012), Similarity Rating: 0.16/1.00
# Movie: Star Wars: The Last Jedi (2017), Similarity Rating: 0.15/1.00
# Movie: Fargo (1996), Similarity Rating: 0.15/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.15/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.15/1.00
# Movie: Paprika (Papurika) (2006), Similarity Rating: 0.15/1.00
# Movie: Wreck-It Ralph (2012), Similarity Rating: 0.15/1.00
# Movie: Hunt, The (Jagten) (2012), Similarity Rating: 0.15/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.15/1.00
# Movie: Incredibles 2 (2018), Similarity Rating: 0.15/1.00
# Movie: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), Similarity Rating: 0.15/1.00
# Movie: Carol (2015), Similarity Rating: 0.15/1.00
# Movie: The Big Sick (2017), Similarity Rating: 0.15/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.15/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.15/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.15/1.00
# Movie: Snowden (2016), Similarity Rating: 0.15/1.00
# Movie: Roma (2018), Similarity Rating: 0.15/1.00
# Movie: Goodfellas (1990), Similarity Rating: 0.15/1.00
# Movie: Simpsons Movie, The (2007), Similarity Rating: 0.15/1.00
# Movie: A Simple Favor (2018), Similarity Rating: 0.15/1.00
# Movie: Good Time (2017), Similarity Rating: 0.15/1.00
# Movie: Heathers (1989), Similarity Rating: 0.15/1.00
# Movie: Grave of the Fireflies (Hotaru no haka) (1988), Similarity Rating: 0.14/1.00
# Movie: Before Midnight (2013), Similarity Rating: 0.14/1.00
# Movie: Avatar (2009), Similarity Rating: 0.14/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.14/1.00
# Movie: Bourne Identity, The (2002), Similarity Rating: 0.14/1.00
# Movie: Princess Diaries 2: Royal Engagement, The (2004), Similarity Rating: 0.14/1.00
# Movie: I Am Legend (2007), Similarity Rating: 0.14/1.00
# Movie: Whiplash (2013), Similarity Rating: 0.14/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.14/1.00
# Movie: Monty Python's Life of Brian (1979), Similarity Rating: 0.14/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.14/1.00
# Movie: Proposal, The (2009), Similarity Rating: 0.14/1.00
# Movie: Moonlight, Similarity Rating: 0.14/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.14/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.14/1.00
# Movie: CODA (2021), Similarity Rating: 0.14/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.14/1.00
# Movie: American Honey (2016), Similarity Rating: 0.14/1.00
# Movie: Molly's Game (2017), Similarity Rating: 0.14/1.00
# Movie: Emperor's New Groove, The (2000), Similarity Rating: 0.14/1.00
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.14/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.14/1.00
# Movie: Darjeeling Limited, The (2007), Similarity Rating: 0.14/1.00
# Movie: Fury (2014), Similarity Rating: 0.14/1.00
# Movie: Training Day (2001), Similarity Rating: 0.14/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.14/1.00
# Movie: Split (2017), Similarity Rating: 0.14/1.00
# Movie: Kung Fu Panda (2008), Similarity Rating: 0.14/1.00
# Movie: Kick-Ass (2010), Similarity Rating: 0.14/1.00
# Movie: Sound of Metal (2019), Similarity Rating: 0.13/1.00
# Movie: Star Wars: Episode VII - The Force Awakens (2015), Similarity Rating: 0.13/1.00
# Movie: Despicable Me 2 (2013), Similarity Rating: 0.13/1.00
# Movie: Hangover Part III, The (2013), Similarity Rating: 0.13/1.00
# Movie: Casablanca (1942), Similarity Rating: 0.13/1.00
# Movie: Predestination (2014), Similarity Rating: 0.13/1.00
# Movie: Scarface (1983), Similarity Rating: 0.13/1.00
# Movie: Taxi Driver (1976), Similarity Rating: 0.13/1.00
# Movie: Us (2019), Similarity Rating: 0.13/1.00
# Movie: The Father (2020), Similarity Rating: 0.13/1.00
# Movie: Bridget Jones's Diary (2001), Similarity Rating: 0.13/1.00
# Movie: Swiss Army Man (2016), Similarity Rating: 0.13/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.13/1.00
# Movie: Hacksaw Ridge (2016), Similarity Rating: 0.13/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.13/1.00
# Movie: American History X (1998), Similarity Rating: 0.13/1.00
# Movie: Wonder Woman (2017), Similarity Rating: 0.13/1.00
# Movie: But I'm a Cheerleader (1999), Similarity Rating: 0.13/1.00
# Movie: Beetlejuice (1988), Similarity Rating: 0.13/1.00
# Movie: Spider-Man (2002), Similarity Rating: 0.13/1.00
# Movie: The Hunger Games: Catching Fire (2013), Similarity Rating: 0.13/1.00
# Movie: Mr. Nobody (2009), Similarity Rating: 0.13/1.00
# Movie: Aladdin (1992), Similarity Rating: 0.13/1.00
# Movie: Searching (2018), Similarity Rating: 0.13/1.00
# Movie: Promising Young Woman (2020), Similarity Rating: 0.13/1.00
# Movie: The Danish Girl (2015), Similarity Rating: 0.13/1.00
# Movie: Fantastic Beasts and Where to Find Them (2016), Similarity Rating: 0.13/1.00
# Movie: Mary Poppins (1964), Similarity Rating: 0.13/1.00
# Movie: Napoleon Dynamite (2004), Similarity Rating: 0.13/1.00
# Movie: Annie Hall (1977), Similarity Rating: 0.13/1.00
# Movie: The Gentlemen (2020), Similarity Rating: 0.13/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.13/1.00
# Movie: Alice in Wonderland (2010), Similarity Rating: 0.13/1.00
# Movie: Kill Bill: Vol. 1 (2003), Similarity Rating: 0.13/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.13/1.00
# Movie: Encanto (2021), Similarity Rating: 0.12/1.00
# Movie: Princess and the Frog, The (2009), Similarity Rating: 0.12/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.12/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=elliott_ratings,
    my_data=elliott_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
# response "Jag har sett typ en tredjedel av dessa filmer kanske, men inte sen jag började med letterboxd"
# Out:
# You've rated 177 movies
# Found 10457 movies you haven't rated
#
# Top Recommendations:
# Movie: Juno (2007), Similarity Rating: 0.27/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.27/1.00
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.23/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.22/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.22/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.22/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.21/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.20/1.00
# Movie: Arrival (2016), Similarity Rating: 0.19/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.19/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.19/1.00
# Movie: Nomadland (2020), Similarity Rating: 0.18/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.18/1.00
# Movie: Encanto (2021), Similarity Rating: 0.18/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.17/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.17/1.00
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.17/1.00
# Movie: It Follows (2014), Similarity Rating: 0.17/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.17/1.00
# Movie: Luca (2021), Similarity Rating: 0.17/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.16/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.16/1.00
# Movie: Little Miss Sunshine (2006), Similarity Rating: 0.16/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.16/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.15/1.00
# Movie: The Worst Person in the World (2021), Similarity Rating: 0.15/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 2 (2011), Similarity Rating: 0.15/1.00
# Movie: Legally Blonde (2001), Similarity Rating: 0.15/1.00
# Movie: The Half of It (2020), Similarity Rating: 0.15/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.15/1.00
# Movie: Spider-Man: No Way Home (2021), Similarity Rating: 0.14/1.00
# Movie: Truman Show, The (1998), Similarity Rating: 0.14/1.00
# Movie: Top Gun: Maverick (2022), Similarity Rating: 0.14/1.00
# Movie: The Favourite, Similarity Rating: 0.14/1.00
# Movie: Moonlight, Similarity Rating: 0.14/1.00
# Movie: Minari (2020), Similarity Rating: 0.14/1.00
# Movie: Coco (2017), Similarity Rating: 0.14/1.00
# Movie: Clueless (1995), Similarity Rating: 0.14/1.00
# Movie: Heathers (1989), Similarity Rating: 0.14/1.00
# Movie: The Social Dilemma (2020), Similarity Rating: 0.14/1.00
# Movie: Ocean's 8 (2018), Similarity Rating: 0.13/1.00
# Movie: Harry Potter and the Half-Blood Prince (2009), Similarity Rating: 0.13/1.00
# Movie: Creep (2014), Similarity Rating: 0.13/1.00
# Movie: The Big Sick (2017), Similarity Rating: 0.13/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.13/1.00
# Movie: Deadpool (2016), Similarity Rating: 0.13/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.13/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.13/1.00
# Movie: Requiem for a Dream (2000), Similarity Rating: 0.12/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.12/1.00
# Movie: Hustlers (2019), Similarity Rating: 0.12/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.12/1.00
# Movie: Mid90s (2018), Similarity Rating: 0.12/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.12/1.00
# Movie: The Witch (2015), Similarity Rating: 0.12/1.00
# Movie: Never Rarely Sometimes Always (2020), Similarity Rating: 0.12/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.12/1.00
# Movie: The Martian (2015), Similarity Rating: 0.12/1.00
# Movie: Jennifer's Body (2009), Similarity Rating: 0.12/1.00
# Movie: The Fault in Our Stars (2014), Similarity Rating: 0.12/1.00
# Movie: Another Round (2020), Similarity Rating: 0.12/1.00
# Movie: Django Unchained (2012), Similarity Rating: 0.12/1.00
# Movie: Sound of Music, The (1965), Similarity Rating: 0.12/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 1 (2010), Similarity Rating: 0.11/1.00
# Movie: Harold and Maude (1971), Similarity Rating: 0.11/1.00
# Movie: Over the Garden Wall (2013), Similarity Rating: 0.11/1.00
# Movie: Ready or Not (2019), Similarity Rating: 0.11/1.00
# Movie: A Quiet Place Part II (2020), Similarity Rating: 0.11/1.00
# Movie: Hamilton (2020), Similarity Rating: 0.11/1.00
# Movie: Howl's Moving Castle (Hauru no ugoku shiro) (2004), Similarity Rating: 0.11/1.00
# Movie: Captain Fantastic (2016), Similarity Rating: 0.11/1.00
# Movie: Pitch Perfect (2012), Similarity Rating: 0.11/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.11/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.11/1.00
# Movie: Superbad (2007), Similarity Rating: 0.11/1.00
# Movie: Persepolis (2007), Similarity Rating: 0.11/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.11/1.00
# Movie: Saw (2004), Similarity Rating: 0.11/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.11/1.00
# Movie: 22 Jump Street (2014), Similarity Rating: 0.11/1.00
# Movie: Virgin Suicides, The (1999), Similarity Rating: 0.11/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.11/1.00
# Movie: Honey Boy (2019), Similarity Rating: 0.10/1.00
# Movie: 10 Cloverfield Lane (2016), Similarity Rating: 0.10/1.00
# Movie: The Perfection (2018), Similarity Rating: 0.10/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.10/1.00
# Movie: Conjuring, The (2013), Similarity Rating: 0.10/1.00
# Movie: Love Actually (2003), Similarity Rating: 0.10/1.00
# Movie: Shirley (2020), Similarity Rating: 0.10/1.00
# Movie: Hidden Figures (2016), Similarity Rating: 0.10/1.00
# Movie: tick, tick...BOOM! (2021), Similarity Rating: 0.10/1.00
# Movie: Creep 2 (2017), Similarity Rating: 0.10/1.00
# Movie: My Neighbor Totoro (Tonari no Totoro) (1988), Similarity Rating: 0.10/1.00
# Movie: I'm Thinking of Ending Things, Similarity Rating: 0.10/1.00
# Movie: Shiva Baby (2020), Similarity Rating: 0.10/1.00
# Movie: Help, The (2011), Similarity Rating: 0.10/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.10/1.00
# Movie: Mamma Mia! (2008), Similarity Rating: 0.10/1.00
# Movie: Separation, A (Jodaeiye Nader az Simin) (2011), Similarity Rating: 0.10/1.00
# Movie: Princess Diaries, The (2001), Similarity Rating: 0.10/1.00
# Movie: Hush (2016), Similarity Rating: 0.10/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.10/1.00
# Movie: Silence of the Lambs, The (1991), Similarity Rating: 0.10/1.00
# Movie: Rear Window (1954), Similarity Rating: 0.10/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.10/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.10/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.09/1.00
# Movie: Moon (2009), Similarity Rating: 0.09/1.00
# Movie: Blair Witch Project, The (1999), Similarity Rating: 0.09/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.09/1.00
# Movie: Clue (1985), Similarity Rating: 0.09/1.00
# Movie: Big Time Adolescence (2020), Similarity Rating: 0.09/1.00
# Movie: Zombieland (2009), Similarity Rating: 0.09/1.00
# Movie: The Ritual (2017), Similarity Rating: 0.09/1.00
# Movie: Don't Breathe (2016), Similarity Rating: 0.09/1.00
# Movie: But I'm a Cheerleader (1999), Similarity Rating: 0.09/1.00
# Movie: The Night House (2020), Similarity Rating: 0.09/1.00
# Movie: The Conjuring 2 (2016), Similarity Rating: 0.09/1.00
# Movie: The Trial of the Chicago 7 (2020), Similarity Rating: 0.09/1.00
# Movie: The Endless (2017), Similarity Rating: 0.09/1.00
# Movie: Descent, The (2005), Similarity Rating: 0.09/1.00
# Movie: Cam (2018), Similarity Rating: 0.09/1.00
# Movie: Molly's Game (2017), Similarity Rating: 0.09/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.09/1.00
# Movie: 1BR (2019), Similarity Rating: 0.09/1.00
# Movie: Harakiri (Seppuku) (1962), Similarity Rating: 0.09/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.09/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.09/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.09/1.00
# Movie: The Fundamentals of Caring (2016), Similarity Rating: 0.09/1.00
# Movie: The Invitation (2015), Similarity Rating: 0.09/1.00
# Movie: Up (2009), Similarity Rating: 0.09/1.00
# Movie: Persona (1966), Similarity Rating: 0.09/1.00
# Movie: Twilight (2008), Similarity Rating: 0.09/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.09/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.09/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.08/1.00
# Movie: Long Shot (2019), Similarity Rating: 0.08/1.00
# Movie: (500) Days of Summer (2009), Similarity Rating: 0.08/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.08/1.00
# Movie: Wallace & Gromit in The Curse of the Were-Rabbit (2005), Similarity Rating: 0.08/1.00
# Movie: Proposal, The (2009), Similarity Rating: 0.08/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.08/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.08/1.00
# Movie: Brave (2012), Similarity Rating: 0.08/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.08/1.00
# Movie: Emma (2020), Similarity Rating: 0.08/1.00
# Movie: Saint Maud (2019), Similarity Rating: 0.08/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.08/1.00
# Movie: Hangover, The (2009), Similarity Rating: 0.08/1.00
# Movie: Soul (2020), Similarity Rating: 0.08/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.08/1.00
# Movie: Orphan (2009), Similarity Rating: 0.08/1.00
# Movie: 21 Jump Street (2012), Similarity Rating: 0.08/1.00
# Movie: WALL·E (2008), Similarity Rating: 0.08/1.00
# Movie: Gifted (2017), Similarity Rating: 0.08/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.08/1.00
# Movie: Hot Fuzz (2007), Similarity Rating: 0.08/1.00
# Movie: Scream (1996), Similarity Rating: 0.08/1.00
# Movie: Ford v. Ferrari (2019), Similarity Rating: 0.08/1.00
# Movie: Searching (2018), Similarity Rating: 0.08/1.00
# Movie: Great Gatsby, The (2013), Similarity Rating: 0.08/1.00
# Movie: American Honey (2016), Similarity Rating: 0.08/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.08/1.00
# Movie: Knock Down the House (2019), Similarity Rating: 0.08/1.00
# Movie: Bend It Like Beckham (2002), Similarity Rating: 0.08/1.00
# Movie: Scooby-Doo (2002), Similarity Rating: 0.08/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.08/1.00
# Movie: Billie Eilish: The World's a Little Blurry (2021), Similarity Rating: 0.08/1.00
# Movie: Sinister (2012), Similarity Rating: 0.08/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.08/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.08/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.08/1.00
# Movie: Green Room (2015), Similarity Rating: 0.08/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.08/1.00
# Movie: Moana (2016), Similarity Rating: 0.08/1.00
# Movie: Sicario (2015), Similarity Rating: 0.08/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.08/1.00
# Movie: You're Next (2011), Similarity Rating: 0.08/1.00
# Movie: Mother! (2017), Similarity Rating: 0.08/1.00
# Movie: La La Land (2016), Similarity Rating: 0.08/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.08/1.00
# Movie: Host (2020), Similarity Rating: 0.08/1.00
# Movie: American Psycho (2000), Similarity Rating: 0.08/1.00
# Movie: Da 5 Bloods (2020), Similarity Rating: 0.08/1.00
# Movie: Crimes and Misdemeanors (1989), Similarity Rating: 0.07/1.00
# Movie: The Lovebirds (2020), Similarity Rating: 0.07/1.00
# Movie: Way, Way Back, The (2013), Similarity Rating: 0.07/1.00
# Movie: Get Smart (2008), Similarity Rating: 0.07/1.00
# Movie: The Conjuring: The Devil Made Me Do It (2021), Similarity Rating: 0.07/1.00
# Movie: It: Chapter Two (2019), Similarity Rating: 0.07/1.00
# Movie: Shang-Chi and the Legend of the Ten Rings (2021), Similarity Rating: 0.07/1.00
# Movie: Memento (2000), Similarity Rating: 0.07/1.00
# Movie: Horse Girl (2020), Similarity Rating: 0.07/1.00
# Movie: Amazing Spider-Man, The (2012), Similarity Rating: 0.07/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.07/1.00
# Movie: About Time (2013), Similarity Rating: 0.07/1.00
# Movie: The Greatest Showman (2017), Similarity Rating: 0.07/1.00
# Movie: Scream (2022), Similarity Rating: 0.07/1.00
# Movie: Secret World of Arrietty, The (Kari-gurashi no Arietti) (2010), Similarity Rating: 0.07/1.00
# '\nmin_avg_rating=2.5\nuser_min_percentile=0.25\nuser_max_percentile=0.999\nmin_ratings_per_movie=3\nmax_users_per_movie=250\nuser_similarity_threshold=0.15\nfit: \nn_components=200,\nsample_size=1,\nmax_iter=800\n'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=voided_ratings,
    my_data=voided_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
"""jo men det gör dom, har typ alla förrutom guardians of the galaxy på min watchlist haha
och det stämmer att de jag redan hade sett som totoro hade jag inte rateat"""
# Out:
# You've rated 271 movies
# Found 10340 movies you haven't rated
#
# Top Recommendations:
# Movie: Prestige, The (2006), Similarity Rating: 0.46/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.40/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.40/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.39/1.00
# Movie: My Neighbor Totoro (Tonari no Totoro) (1988), Similarity Rating: 0.37/1.00
# Movie: Fargo (1996), Similarity Rating: 0.37/1.00
# Movie: Inception (2010), Similarity Rating: 0.36/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.36/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.34/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.33/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.33/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.32/1.00
# Movie: Dark Knight, The (2008), Similarity Rating: 0.32/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.32/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.31/1.00
# Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Similarity Rating: 0.30/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.28/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.28/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.27/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.27/1.00
# Movie: Juno (2007), Similarity Rating: 0.27/1.00
# Movie: Gran Torino (2008), Similarity Rating: 0.26/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.26/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.26/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.26/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.26/1.00
# Movie: World's End, The (2013), Similarity Rating: 0.26/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.25/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.25/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.25/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.25/1.00
# Movie: Monsters, Inc. (2001), Similarity Rating: 0.25/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.25/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.25/1.00
# Movie: 2001: A Space Odyssey (1968), Similarity Rating: 0.24/1.00
# Movie: Sorry to Bother You (2018), Similarity Rating: 0.24/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.24/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.24/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.24/1.00
# Movie: Snowpiercer (2013), Similarity Rating: 0.24/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.24/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.24/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.23/1.00
# Movie: WALL·E (2008), Similarity Rating: 0.23/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.23/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.23/1.00
# Movie: The Favourite, Similarity Rating: 0.23/1.00
# Movie: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981), Similarity Rating: 0.23/1.00
# Movie: Shrek (2001), Similarity Rating: 0.23/1.00
# Movie: The Martian (2015), Similarity Rating: 0.22/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.22/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.22/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.22/1.00
# Movie: Room, The (2003), Similarity Rating: 0.22/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.22/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.22/1.00
# Movie: Anchorman: The Legend of Ron Burgundy (2004), Similarity Rating: 0.22/1.00
# Movie: Psycho (1960), Similarity Rating: 0.21/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.21/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.21/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.21/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.21/1.00
# Movie: Blade Runner 2049 (2017), Similarity Rating: 0.21/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.20/1.00
# Movie: Shrek 2 (2004), Similarity Rating: 0.20/1.00
# Movie: Sin City (2005), Similarity Rating: 0.20/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.20/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.20/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.20/1.00
# Movie: Synecdoche, New York (2008), Similarity Rating: 0.20/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.19/1.00
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.19/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.19/1.00
# Movie: Clerks (1994), Similarity Rating: 0.19/1.00
# Movie: Terminator 2: Judgment Day (1991), Similarity Rating: 0.19/1.00
# Movie: Tucker & Dale vs Evil (2010), Similarity Rating: 0.18/1.00
# Movie: Coco (2017), Similarity Rating: 0.18/1.00
# Movie: Minority Report (2002), Similarity Rating: 0.18/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.18/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.18/1.00
# Movie: Barton Fink (1991), Similarity Rating: 0.18/1.00
# Movie: Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000), Similarity Rating: 0.18/1.00
# Movie: Thing, The (1982), Similarity Rating: 0.18/1.00
# Movie: Chinatown (1974), Similarity Rating: 0.18/1.00
# Movie: Soul (2020), Similarity Rating: 0.18/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.18/1.00
# Movie: Vertigo (1958), Similarity Rating: 0.18/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.17/1.00
# Movie: District 9 (2009), Similarity Rating: 0.17/1.00
# Movie: Edge of Tomorrow (2014), Similarity Rating: 0.17/1.00
# Movie: Hangover, The (2009), Similarity Rating: 0.17/1.00
# Movie: The Hateful Eight (2015), Similarity Rating: 0.17/1.00
# Movie: Moon (2009), Similarity Rating: 0.17/1.00
# Movie: Life Is Beautiful (La Vita è bella) (1997), Similarity Rating: 0.16/1.00
# Movie: The Platform (2019), Similarity Rating: 0.16/1.00
# Movie: Pig (2021), Similarity Rating: 0.16/1.00
# Movie: Master and Commander: The Far Side of the World (2003), Similarity Rating: 0.16/1.00
# Movie: The Big Sick (2017), Similarity Rating: 0.16/1.00
# Movie: Casino Royale (2006), Similarity Rating: 0.16/1.00
# Movie: Game Night (2018), Similarity Rating: 0.16/1.00
# Movie: Rear Window (1954), Similarity Rating: 0.16/1.00
# Movie: Moneyball (2011), Similarity Rating: 0.16/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.16/1.00
# Movie: Stranger than Fiction (2006), Similarity Rating: 0.16/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.16/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.16/1.00
# Movie: Garden State (2004), Similarity Rating: 0.15/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.15/1.00
# Movie: 10 Cloverfield Lane (2016), Similarity Rating: 0.15/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.15/1.00
# Movie: 21 Jump Street (2012), Similarity Rating: 0.15/1.00
# Movie: About Time (2013), Similarity Rating: 0.15/1.00
# Movie: Upgrade (2018), Similarity Rating: 0.15/1.00
# Movie: Beautiful Mind, A (2001), Similarity Rating: 0.15/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.15/1.00
# Movie: Star Wars: Episode VII - The Force Awakens (2015), Similarity Rating: 0.15/1.00
# Movie: Almost Famous (2000), Similarity Rating: 0.15/1.00
# Movie: Minari (2020), Similarity Rating: 0.15/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.15/1.00
# Movie: Incredibles, The (2004), Similarity Rating: 0.15/1.00
# Movie: Boot, Das (Boat, The) (1981), Similarity Rating: 0.15/1.00
# Movie: Million Dollar Baby (2004), Similarity Rating: 0.15/1.00
# Movie: It Follows (2014), Similarity Rating: 0.15/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.15/1.00
# Movie: Logan (2017), Similarity Rating: 0.14/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.14/1.00
# Movie: Mandy (2018), Similarity Rating: 0.14/1.00
# Movie: Triangle (2009), Similarity Rating: 0.14/1.00
# Movie: 21 Grams (2003), Similarity Rating: 0.14/1.00
# Movie: Bourne Identity, The (2002), Similarity Rating: 0.14/1.00
# Movie: Star Trek (2009), Similarity Rating: 0.14/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.14/1.00
# Movie: Night of the Living Dead (1968), Similarity Rating: 0.14/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.14/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.14/1.00
# Movie: Beverly Hills Cop (1984), Similarity Rating: 0.14/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.13/1.00
# Movie: Amores Perros (Love's a Bitch) (2000), Similarity Rating: 0.13/1.00
# Movie: Chungking Express (Chung Hing sam lam) (1994), Similarity Rating: 0.13/1.00
# Movie: Us (2019), Similarity Rating: 0.13/1.00
# Movie: Casablanca (1942), Similarity Rating: 0.13/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.13/1.00
# Movie: Wind River (2017), Similarity Rating: 0.13/1.00
# Movie: Skyfall (2012), Similarity Rating: 0.13/1.00
# Movie: Ran (1985), Similarity Rating: 0.13/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.13/1.00
# Movie: Now You See Me (2013), Similarity Rating: 0.13/1.00
# Movie: Annie Hall (1977), Similarity Rating: 0.13/1.00
# Movie: 12 Years a Slave (2013), Similarity Rating: 0.13/1.00
# Movie: Airplane! (1980), Similarity Rating: 0.13/1.00
# Movie: Seven Samurai (Shichinin no samurai) (1954), Similarity Rating: 0.13/1.00
# Movie: The Raid: Redemption (2011), Similarity Rating: 0.13/1.00
# Movie: Phone Booth (2002), Similarity Rating: 0.13/1.00
# Movie: Kiss Kiss Bang Bang (2005), Similarity Rating: 0.13/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.13/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.13/1.00
# Movie: Napoleon Dynamite (2004), Similarity Rating: 0.12/1.00
# Movie: Ju-on: The Grudge (2002), Similarity Rating: 0.12/1.00
# Movie: X-Men: First Class (2011), Similarity Rating: 0.12/1.00
# Movie: Watchmen (2009), Similarity Rating: 0.12/1.00
# Movie: Last Night in Soho (2021), Similarity Rating: 0.12/1.00
# Movie: Battle Royale (Batoru rowaiaru) (2000), Similarity Rating: 0.12/1.00
# Movie: Wild Tales (2014), Similarity Rating: 0.12/1.00
# Movie: Scream (1996), Similarity Rating: 0.12/1.00
# Movie: Yes Man (2008), Similarity Rating: 0.12/1.00
# Movie: Labyrinth (1986), Similarity Rating: 0.12/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.12/1.00
# Movie: Up in the Air (2009), Similarity Rating: 0.12/1.00
# Movie: Decision to Leave (2022), Similarity Rating: 0.12/1.00
# Movie: High Fidelity (2000), Similarity Rating: 0.12/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.12/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.12/1.00
# Movie: A Taxi Driver (2017), Similarity Rating: 0.12/1.00
# Movie: Hitchhiker's Guide to the Galaxy, The (2005), Similarity Rating: 0.12/1.00
# Movie: Mean Streets (1973), Similarity Rating: 0.12/1.00
# Movie: 10 Things I Hate About You (1999), Similarity Rating: 0.12/1.00
# Movie: Office Space (1999), Similarity Rating: 0.12/1.00
# Movie: Carrie (1976), Similarity Rating: 0.12/1.00
# Movie: Who Framed Roger Rabbit? (1988), Similarity Rating: 0.12/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.12/1.00
# Movie: Mask, The (1994), Similarity Rating: 0.12/1.00
# Movie: Indiana Jones and the Last Crusade (1989), Similarity Rating: 0.12/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.12/1.00
# Movie: Ford v. Ferrari (2019), Similarity Rating: 0.12/1.00
# Movie: Separation, A (Jodaeiye Nader az Simin) (2011), Similarity Rating: 0.12/1.00
# Movie: Wild at Heart (1990), Similarity Rating: 0.12/1.00
# Movie: Descent, The (2005), Similarity Rating: 0.12/1.00
# Movie: Room (2015), Similarity Rating: 0.12/1.00
# Movie: The Night Is Short, Walk on Girl (2017), Similarity Rating: 0.12/1.00
# Movie: The Conjuring 2 (2016), Similarity Rating: 0.12/1.00
# Movie: All About My Mother (Todo sobre mi madre) (1999), Similarity Rating: 0.12/1.00
# Movie: Rosemary's Baby (1968), Similarity Rating: 0.11/1.00
# Movie: Beetlejuice (1988), Similarity Rating: 0.11/1.00
# Movie: From Dusk Till Dawn (1996), Similarity Rating: 0.11/1.00
# Movie: I Am Legend (2007), Similarity Rating: 0.11/1.00
# Movie: Nightmare on Elm Street, A (1984), Similarity Rating: 0.11/1.00
# Movie: Punch-Drunk Love (2002), Similarity Rating: 0.11/1.00
# Movie: Boogie Nights (1997), Similarity Rating: 0.11/1.00
# Movie: Deer Hunter, The (1978), Similarity Rating: 0.11/1.00
# Movie: Before Sunset (2004), Similarity Rating: 0.11/1.00
# 'jo men det gör dom, har typ alla förrutom guardians of the galaxy på min watchlist haha\noch det stämmer att de jag redan hade sett som totoro hade jag inte rateat'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=zorrodor_ratings,
    my_data=zorrodor_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)

# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
# zorro:
# "Dom första 20 är alla bra filmer"
# "Eller de e nästan bara grejer jag gillar"
# "Några luriga dock men de mesta e gött"
# "Jag har rateat ganska lite också"
# "Så den har inte sååå mkt att gå på"
# Out:
# You've rated 45 movies
# Found 10558 movies you haven't rated
#
# Top Recommendations:
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.13/1.00
# Movie: Parasite (2019), Similarity Rating: 0.11/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.11/1.00
# Movie: Get Out (2017), Similarity Rating: 0.09/1.00
# Movie: Rear Window (1954), Similarity Rating: 0.09/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.08/1.00
# Movie: Separation, A (Jodaeiye Nader az Simin) (2011), Similarity Rating: 0.08/1.00
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.08/1.00
# Movie: In Bruges (2008), Similarity Rating: 0.07/1.00
# Movie: Her (2013), Similarity Rating: 0.07/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.07/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.06/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.06/1.00
# Movie: Persona (1966), Similarity Rating: 0.06/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.06/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.06/1.00
# Movie: Fargo (1996), Similarity Rating: 0.06/1.00
# Movie: American Psycho (2000), Similarity Rating: 0.06/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.06/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.06/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.06/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.06/1.00
# Movie: O Brother, Where Art Thou? (2000), Similarity Rating: 0.06/1.00
# Movie: Knives Out (2019), Similarity Rating: 0.06/1.00
# Movie: Everything Everywhere All at Once (2022), Similarity Rating: 0.06/1.00
# Movie: 8 1/2 (8½) (1963), Similarity Rating: 0.06/1.00
# Movie: Jules and Jim (Jules et Jim) (1961), Similarity Rating: 0.06/1.00
# Movie: There Will Be Blood (2007), Similarity Rating: 0.06/1.00
# Movie: Goodfellas (1990), Similarity Rating: 0.05/1.00
# Movie: Memento (2000), Similarity Rating: 0.05/1.00
# Movie: 12 Angry Men (1957), Similarity Rating: 0.05/1.00
# Movie: Diabolique (Les diaboliques) (1955), Similarity Rating: 0.05/1.00
# Movie: Motorcycle Diaries, The (Diarios de motocicleta) (2004), Similarity Rating: 0.05/1.00
# Movie: Solaris (Solyaris) (1972), Similarity Rating: 0.05/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.05/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.05/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.05/1.00
# Movie: Shaun of the Dead (2004), Similarity Rating: 0.05/1.00
# Movie: TÁR (2022), Similarity Rating: 0.05/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.05/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.05/1.00
# Movie: Before Sunrise (1995), Similarity Rating: 0.05/1.00
# Movie: Rushmore (1998), Similarity Rating: 0.05/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.05/1.00
# Movie: Vertigo (1958), Similarity Rating: 0.05/1.00
# Movie: Psycho (1960), Similarity Rating: 0.05/1.00
# Movie: Life Aquatic with Steve Zissou, The (2004), Similarity Rating: 0.05/1.00
# Movie: Casablanca (1942), Similarity Rating: 0.05/1.00
# Movie: Sorry to Bother You (2018), Similarity Rating: 0.05/1.00
# Movie: Great Beauty, The (Grande Bellezza, La) (2013), Similarity Rating: 0.05/1.00
# Movie: Hot Fuzz (2007), Similarity Rating: 0.05/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.05/1.00
# Movie: Three Colors: Blue (Trois couleurs: Bleu) (1993), Similarity Rating: 0.05/1.00
# Movie: Paterson, Similarity Rating: 0.05/1.00
# Movie: High Fidelity (2000), Similarity Rating: 0.05/1.00
# Movie: Citizen Kane (1941), Similarity Rating: 0.05/1.00
# Movie: Little Miss Sunshine (2006), Similarity Rating: 0.05/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.05/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.05/1.00
# Movie: Force Majeure (2014), Similarity Rating: 0.04/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.04/1.00
# Movie: Searching for Sugar Man (2012), Similarity Rating: 0.04/1.00
# Movie: Broken Flowers (2005), Similarity Rating: 0.04/1.00
# Movie: Song of the Little Road (Pather Panchali) (1955), Similarity Rating: 0.04/1.00
# Movie: Annie Hall (1977), Similarity Rating: 0.04/1.00
# Movie: Aliens (1986), Similarity Rating: 0.04/1.00
# Movie: Requiem for a Dream (2000), Similarity Rating: 0.04/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.04/1.00
# Movie: Garden State (2004), Similarity Rating: 0.04/1.00
# Movie: Cleo from 5 to 7 (Cléo de 5 à 7) (1962), Similarity Rating: 0.04/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.04/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.04/1.00
# Movie: All About My Mother (Todo sobre mi madre) (1999), Similarity Rating: 0.04/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.04/1.00
# Movie: Terminator 2: Judgment Day (1991), Similarity Rating: 0.04/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.04/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.04/1.00
# Movie: Perfect Blue (1997), Similarity Rating: 0.04/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.04/1.00
# Movie: Seven (a.k.a. Se7en) (1995), Similarity Rating: 0.04/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.04/1.00
# Movie: Incredibles, The (2004), Similarity Rating: 0.04/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.04/1.00
# Movie: Gone with the Wind (1939), Similarity Rating: 0.04/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.04/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.04/1.00
# Movie: Lord of the Rings: The Return of the King, The (2003), Similarity Rating: 0.04/1.00
# Movie: Wild at Heart (1990), Similarity Rating: 0.04/1.00
# Movie: M (1931), Similarity Rating: 0.04/1.00
# Movie: Tampopo (1985), Similarity Rating: 0.04/1.00
# Movie: Days of Being Wild (A Fei jingjyuhn) (1990), Similarity Rating: 0.04/1.00
# Movie: Toy Story 2 (1999), Similarity Rating: 0.04/1.00
# Movie: The Square (2017), Similarity Rating: 0.04/1.00
# Movie: Lawrence of Arabia (1962), Similarity Rating: 0.04/1.00
# Movie: North by Northwest (1959), Similarity Rating: 0.04/1.00
# Movie: Us (2019), Similarity Rating: 0.04/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.04/1.00
# Movie: Elevator to the Gallows (a.k.a. Frantic) (Ascenseur pour l'échafaud) (1958), Similarity Rating: 0.04/1.00
# Movie: Superbad (2007), Similarity Rating: 0.04/1.00
# Movie: Moonstruck (1987), Similarity Rating: 0.04/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.04/1.00
# Movie: Lord of the Rings: The Two Towers, The (2002), Similarity Rating: 0.04/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.04/1.00
# Movie: Ghost World (2001), Similarity Rating: 0.04/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.04/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.04/1.00
# Movie: Hero (Ying xiong) (2002), Similarity Rating: 0.04/1.00
# Movie: The Witch (2015), Similarity Rating: 0.04/1.00
# Movie: Office Space (1999), Similarity Rating: 0.04/1.00
# Movie: Before Midnight (2013), Similarity Rating: 0.04/1.00
# Movie: Harold and Maude (1971), Similarity Rating: 0.04/1.00
# Movie: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981), Similarity Rating: 0.04/1.00
# Movie: Pierrot le fou (1965), Similarity Rating: 0.04/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.04/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.04/1.00
# Movie: Old Boy (2003), Similarity Rating: 0.04/1.00
# Movie: High and Low (Tengoku to jigoku) (1963), Similarity Rating: 0.04/1.00
# Movie: Claire's Knee (Genou de Claire, Le) (1970), Similarity Rating: 0.04/1.00
# Movie: Man Bites Dog (C'est arrivé près de chez vous) (1992), Similarity Rating: 0.04/1.00
# Movie: Murder on the Orient Express (1974), Similarity Rating: 0.04/1.00
# Movie: 2001: A Space Odyssey (1968), Similarity Rating: 0.04/1.00
# Movie: 1917 (2019), Similarity Rating: 0.04/1.00
# Movie: Hunt, The (Jagten) (2012), Similarity Rating: 0.04/1.00
# Movie: Red Shoes, The (1948), Similarity Rating: 0.04/1.00
# Movie: The Favourite, Similarity Rating: 0.04/1.00
# Movie: 2046 (2004), Similarity Rating: 0.04/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.04/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.04/1.00
# Movie: One Cut of the Dead (2017), Similarity Rating: 0.04/1.00
# Movie: Spider-Man 2 (2004), Similarity Rating: 0.04/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.03/1.00
# Movie: Collateral (2004), Similarity Rating: 0.03/1.00
# Movie: Chinatown (1974), Similarity Rating: 0.03/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.03/1.00
# Movie: Django Unchained (2012), Similarity Rating: 0.03/1.00
# Movie: Taste of Cherry (Ta'm e guilass) (1997), Similarity Rating: 0.03/1.00
# Movie: Hiroshima Mon Amour (1959), Similarity Rating: 0.03/1.00
# Movie: Monsters, Inc. (2001), Similarity Rating: 0.03/1.00
# Movie: The Machinist (2004), Similarity Rating: 0.03/1.00
# Movie: Synecdoche, New York (2008), Similarity Rating: 0.03/1.00
# Movie: Heat (1995), Similarity Rating: 0.03/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.03/1.00
# Movie: Chorus, The (Choristes, Les) (2004), Similarity Rating: 0.03/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.03/1.00
# Movie: White Ribbon, The (Das weiße Band) (2009), Similarity Rating: 0.03/1.00
# Movie: Fanny and Alexander (Fanny och Alexander) (1982), Similarity Rating: 0.03/1.00
# Movie: Rashomon (Rashômon) (1950), Similarity Rating: 0.03/1.00
# Movie: Good Time (2017), Similarity Rating: 0.03/1.00
# Movie: Talk to Her (Hable con Ella) (2002), Similarity Rating: 0.03/1.00
# Movie: Inception (2010), Similarity Rating: 0.03/1.00
# Movie: Schindler's List (1993), Similarity Rating: 0.03/1.00
# Movie: Ginger Snaps (2000), Similarity Rating: 0.03/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.03/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.03/1.00
# Movie: Science of Sleep, The (La science des rêves) (2006), Similarity Rating: 0.03/1.00
# Movie: Rocky Horror Picture Show, The (1975), Similarity Rating: 0.03/1.00
# Movie: Elle (2016), Similarity Rating: 0.03/1.00
# Movie: Airplane! (1980), Similarity Rating: 0.03/1.00
# Movie: Kill Bill: Vol. 1 (2003), Similarity Rating: 0.03/1.00
# Movie: Melancholia (2011), Similarity Rating: 0.03/1.00
# Movie: Yi Yi (2000), Similarity Rating: 0.03/1.00
# Movie: Piano Teacher, The (La pianiste) (2001), Similarity Rating: 0.03/1.00
# Movie: Nights of Cabiria (Notti di Cabiria, Le) (1957), Similarity Rating: 0.03/1.00
# Movie: Hotel Rwanda (2004), Similarity Rating: 0.03/1.00
# Movie: Black Christmas (1974), Similarity Rating: 0.03/1.00
# Movie: Nosferatu the Vampyre (Nosferatu: Phantom der Nacht) (1979), Similarity Rating: 0.03/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.03/1.00
# Movie: Haunting, The (1963), Similarity Rating: 0.03/1.00
# Movie: This Is England (2006), Similarity Rating: 0.03/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.03/1.00
# Movie: E.T. the Extra-Terrestrial (1982), Similarity Rating: 0.03/1.00
# Movie: Thin Blue Line, The (1988), Similarity Rating: 0.03/1.00
# Movie: My Night At Maud's (Ma Nuit Chez Maud) (1969), Similarity Rating: 0.03/1.00
# Movie: Notorious (1946), Similarity Rating: 0.03/1.00
# Movie: Breathless (À bout de souffle) (1960), Similarity Rating: 0.03/1.00
# Movie: Paris, Texas (1984), Similarity Rating: 0.03/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.03/1.00
# Movie: House of Flying Daggers (Shi mian mai fu) (2004), Similarity Rating: 0.03/1.00
# Movie: Kill Bill: Vol. 2 (2004), Similarity Rating: 0.03/1.00
# Movie: Magnolia (1999), Similarity Rating: 0.03/1.00
# Movie: Aguirre: The Wrath of God (Aguirre, der Zorn Gottes) (1972), Similarity Rating: 0.03/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.03/1.00
# Movie: Black Orpheus (Orfeu Negro) (1959), Similarity Rating: 0.03/1.00
# Movie: Down by Law (1986), Similarity Rating: 0.03/1.00
# Movie: Beauty of the Day (Belle de jour) (1967), Similarity Rating: 0.03/1.00
# Movie: Silence of the Lambs, The (1991), Similarity Rating: 0.03/1.00
# Movie: Exterminating Angel, The (Ángel exterminador, El) (1962), Similarity Rating: 0.03/1.00
# Movie: Tomboy (2011), Similarity Rating: 0.03/1.00
# Movie: No Country for Old Men (2007), Similarity Rating: 0.03/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.03/1.00
# Movie: Barton Fink (1991), Similarity Rating: 0.03/1.00
# Movie: WALL·E (2008), Similarity Rating: 0.03/1.00
# Movie: American Werewolf in London, An (1981), Similarity Rating: 0.03/1.00
# Movie: Only Lovers Left Alive (2013), Similarity Rating: 0.03/1.00
# Movie: Sideways (2004), Similarity Rating: 0.03/1.00
# Movie: Intouchables (2011), Similarity Rating: 0.03/1.00
# Movie: Talented Mr. Ripley, The (1999), Similarity Rating: 0.03/1.00
# Movie: Con Air (1997), Similarity Rating: 0.03/1.00
# Movie: Aviator, The (2004), Similarity Rating: 0.03/1.00
# Movie: House on Haunted Hill (1959), Similarity Rating: 0.03/1.00
# '\nmin_avg_rating=2.5\nuser_min_percentile=0.25\nuser_max_percentile=0.999\nmin_ratings_per_movie=3\nmax_users_per_movie=250\nuser_similarity_threshold=0.15\nfit: \nn_components=200,\nsample_size=1,\nmax_iter=800\n'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=liv_ratings,
    my_data=liv_data,
    n_recommendations=100,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 106 movies
# Found 10501 movies you haven't rated
#
# Top Recommendations:
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.28/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.24/1.00
# Movie: Parasite (2019), Similarity Rating: 0.21/1.00
# Movie: Mean Girls (2004), Similarity Rating: 0.20/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.18/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.18/1.00
# Movie: Midsommar (2019), Similarity Rating: 0.17/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.17/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.17/1.00
# Movie: Her (2013), Similarity Rating: 0.16/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.16/1.00
# Movie: Carol (2015), Similarity Rating: 0.16/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.16/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.16/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.15/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.14/1.00
# Movie: The Favourite, Similarity Rating: 0.14/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.14/1.00
# Movie: Knives Out (2019), Similarity Rating: 0.14/1.00
# Movie: Over the Garden Wall (2013), Similarity Rating: 0.14/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.14/1.00
# Movie: Get Out (2017), Similarity Rating: 0.13/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.13/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.13/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.13/1.00
# Movie: Luca (2021), Similarity Rating: 0.13/1.00
# Movie: But I'm a Cheerleader (1999), Similarity Rating: 0.13/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.12/1.00
# Movie: Moonlight, Similarity Rating: 0.12/1.00
# Movie: Rushmore (1998), Similarity Rating: 0.12/1.00
# Movie: Persepolis (2007), Similarity Rating: 0.12/1.00
# Movie: When Marnie Was There (2014), Similarity Rating: 0.12/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.12/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.12/1.00
# Movie: Deadpool (2016), Similarity Rating: 0.11/1.00
# Movie: The Half of It (2020), Similarity Rating: 0.11/1.00
# Movie: Nightmare Before Christmas, The (1993), Similarity Rating: 0.11/1.00
# Movie: Secret World of Arrietty, The (Kari-gurashi no Arietti) (2010), Similarity Rating: 0.11/1.00
# Movie: Legally Blonde (2001), Similarity Rating: 0.11/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.11/1.00
# Movie: Before Sunset (2004), Similarity Rating: 0.11/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.11/1.00
# Movie: Up (2009), Similarity Rating: 0.11/1.00
# Movie: Superbad (2007), Similarity Rating: 0.11/1.00
# Movie: Arrival (2016), Similarity Rating: 0.11/1.00
# Movie: WALL·E (2008), Similarity Rating: 0.11/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.10/1.00
# Movie: From Up on Poppy Hill (Kokuriko-zaka kara) (2011), Similarity Rating: 0.10/1.00
# Movie: Truman Show, The (1998), Similarity Rating: 0.10/1.00
# Movie: Shiva Baby (2020), Similarity Rating: 0.10/1.00
# Movie: Atonement (2007), Similarity Rating: 0.10/1.00
# Movie: Ghost World (2001), Similarity Rating: 0.10/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.10/1.00
# Movie: Requiem for a Dream (2000), Similarity Rating: 0.10/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.10/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.10/1.00
# Movie: Mary and the Witch's Flower (2017), Similarity Rating: 0.10/1.00
# Movie: Almost Famous (2000), Similarity Rating: 0.10/1.00
# Movie: The Fault in Our Stars (2014), Similarity Rating: 0.10/1.00
# Movie: Love, Simon (2018), Similarity Rating: 0.10/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.10/1.00
# Movie: Pride & Prejudice (2005), Similarity Rating: 0.09/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.09/1.00
# Movie: Shrek (2001), Similarity Rating: 0.09/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.09/1.00
# Movie: Porco Rosso (Crimson Pig) (Kurenai no buta) (1992), Similarity Rating: 0.09/1.00
# Movie: The Big Sick (2017), Similarity Rating: 0.09/1.00
# Movie: Bend It Like Beckham (2002), Similarity Rating: 0.09/1.00
# Movie: The Edge of Seventeen (2016), Similarity Rating: 0.09/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.09/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.09/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.09/1.00
# Movie: Wolfwalkers (2020), Similarity Rating: 0.09/1.00
# Movie: Cruella (2021), Similarity Rating: 0.09/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.09/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.09/1.00
# Movie: Help, The (2011), Similarity Rating: 0.09/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.09/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.09/1.00
# Movie: Intouchables (2011), Similarity Rating: 0.09/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.09/1.00
# Movie: Song of the Sea (2014), Similarity Rating: 0.08/1.00
# Movie: The Florida Project (2017), Similarity Rating: 0.08/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.08/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.08/1.00
# Movie: Ocean's 8 (2018), Similarity Rating: 0.08/1.00
# Movie: Lord of the Rings: The Return of the King, The (2003), Similarity Rating: 0.08/1.00
# Movie: Whip It (2009), Similarity Rating: 0.08/1.00
# Movie: Minari (2020), Similarity Rating: 0.08/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.08/1.00
# Movie: Kubo and the Two Strings (2016), Similarity Rating: 0.08/1.00
# Movie: Django Unchained (2012), Similarity Rating: 0.08/1.00
# Movie: Wallace & Gromit in The Curse of the Were-Rabbit (2005), Similarity Rating: 0.08/1.00
# Movie: Kill Your Darlings (2013), Similarity Rating: 0.08/1.00
# Movie: D.E.B.S. (2004), Similarity Rating: 0.08/1.00
# Movie: Holiday, The (2006), Similarity Rating: 0.08/1.00
# Movie: Captain Fantastic (2016), Similarity Rating: 0.08/1.00
# Movie: Brave (2012), Similarity Rating: 0.08/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.08/1.00
# Movie: Heavenly Creatures (1994), Similarity Rating: 0.08/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=skellic_ratings,
    my_data=skellic_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 338 movies
# Found 10280 movies you haven't rated
#
# Top Recommendations:
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.46/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.46/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.44/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.43/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.43/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.41/1.00
# Movie: Fargo (1996), Similarity Rating: 0.41/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.40/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.38/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.38/1.00
# Movie: Inception (2010), Similarity Rating: 0.37/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.36/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.36/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.36/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.34/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.34/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.32/1.00
# Movie: Memento (2000), Similarity Rating: 0.32/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.32/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.31/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.31/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.30/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.30/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.30/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.30/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.29/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.28/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.28/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.28/1.00
# Movie: Monty Python's Life of Brian (1979), Similarity Rating: 0.28/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.28/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.28/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.28/1.00
# Movie: Coco (2017), Similarity Rating: 0.27/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.27/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.26/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.26/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.26/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.26/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.25/1.00
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.25/1.00
# Movie: Gran Torino (2008), Similarity Rating: 0.25/1.00
# Movie: Logan (2017), Similarity Rating: 0.24/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.24/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.24/1.00
# Movie: Back to the Future Part II (1989), Similarity Rating: 0.24/1.00
# Movie: Chinatown (1974), Similarity Rating: 0.24/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.24/1.00
# Movie: Tucker & Dale vs Evil (2010), Similarity Rating: 0.23/1.00
# Movie: Sin City (2005), Similarity Rating: 0.23/1.00
# Movie: Trainspotting (1996), Similarity Rating: 0.23/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.23/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.23/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.23/1.00
# Movie: Akira (1988), Similarity Rating: 0.23/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.22/1.00
# Movie: Edge of Tomorrow (2014), Similarity Rating: 0.22/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.22/1.00
# Movie: Avatar (2009), Similarity Rating: 0.22/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.22/1.00
# Movie: Casino Royale (2006), Similarity Rating: 0.22/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.22/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.22/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.22/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.21/1.00
# Movie: The Martian (2015), Similarity Rating: 0.21/1.00
# Movie: Thing, The (1982), Similarity Rating: 0.21/1.00
# Movie: Kiss Kiss Bang Bang (2005), Similarity Rating: 0.21/1.00
# Movie: Ponyo (Gake no ue no Ponyo) (2008), Similarity Rating: 0.20/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.20/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.20/1.00
# Movie: Skyfall (2012), Similarity Rating: 0.20/1.00
# Movie: Juno (2007), Similarity Rating: 0.20/1.00
# Movie: Top Gun: Maverick (2022), Similarity Rating: 0.20/1.00
# Movie: Chungking Express (Chung Hing sam lam) (1994), Similarity Rating: 0.20/1.00
# Movie: Anchorman: The Legend of Ron Burgundy (2004), Similarity Rating: 0.20/1.00
# Movie: 21 Jump Street (2012), Similarity Rating: 0.20/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.20/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.19/1.00
# Movie: Upgrade (2018), Similarity Rating: 0.19/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.19/1.00
# Movie: Psycho (1960), Similarity Rating: 0.19/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.19/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.19/1.00
# Movie: Vertigo (1958), Similarity Rating: 0.19/1.00
# Movie: The Big Sick (2017), Similarity Rating: 0.19/1.00
# Movie: Lion King, The (1994), Similarity Rating: 0.19/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.19/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.18/1.00
# Movie: Us (2019), Similarity Rating: 0.18/1.00
# Movie: Clerks (1994), Similarity Rating: 0.18/1.00
# Movie: Over the Garden Wall (2013), Similarity Rating: 0.18/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.18/1.00
# Movie: The Raid: Redemption (2011), Similarity Rating: 0.18/1.00
# Movie: Wreck-It Ralph (2012), Similarity Rating: 0.18/1.00
# Movie: Descent, The (2005), Similarity Rating: 0.18/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.18/1.00
# Movie: Master and Commander: The Far Side of the World (2003), Similarity Rating: 0.18/1.00
# Movie: Triangle (2009), Similarity Rating: 0.17/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.17/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.17/1.00
# Movie: 12 Years a Slave (2013), Similarity Rating: 0.17/1.00
# Movie: Synecdoche, New York (2008), Similarity Rating: 0.17/1.00
# Movie: Wind River (2017), Similarity Rating: 0.17/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.17/1.00
# Movie: Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000), Similarity Rating: 0.17/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.17/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.17/1.00
# Movie: X-Men: First Class (2011), Similarity Rating: 0.16/1.00
# Movie: Life Is Beautiful (La Vita è bella) (1997), Similarity Rating: 0.16/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.16/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.16/1.00
# Movie: Casablanca (1942), Similarity Rating: 0.16/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.16/1.00
# Movie: Minority Report (2002), Similarity Rating: 0.16/1.00
# Movie: Moneyball (2011), Similarity Rating: 0.16/1.00
# Movie: Borat Subsequent Moviefilm (2020), Similarity Rating: 0.16/1.00
# Movie: Star Trek (2009), Similarity Rating: 0.16/1.00
# Movie: Game Night (2018), Similarity Rating: 0.16/1.00
# Movie: The Platform (2019), Similarity Rating: 0.16/1.00
# Movie: Rear Window (1954), Similarity Rating: 0.16/1.00
# Movie: Ford v. Ferrari (2019), Similarity Rating: 0.16/1.00
# Movie: Yes Man (2008), Similarity Rating: 0.16/1.00
# Movie: Hangover, The (2009), Similarity Rating: 0.16/1.00
# Movie: Bohemian Rhapsody (2018), Similarity Rating: 0.16/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.16/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.16/1.00
# Movie: Harry Potter and the Prisoner of Azkaban (2004), Similarity Rating: 0.16/1.00
# Movie: Pig (2021), Similarity Rating: 0.15/1.00
# Movie: It Follows (2014), Similarity Rating: 0.15/1.00
# Movie: The Conjuring 2 (2016), Similarity Rating: 0.15/1.00
# Movie: Moon (2009), Similarity Rating: 0.15/1.00
# Movie: King Richard (2021), Similarity Rating: 0.15/1.00
# Movie: Die Hard (1988), Similarity Rating: 0.15/1.00
# Movie: Nomadland (2020), Similarity Rating: 0.15/1.00
# Movie: Ran (1985), Similarity Rating: 0.15/1.00
# Movie: Ringu (Ring) (1998), Similarity Rating: 0.15/1.00
# Movie: Phone Booth (2002), Similarity Rating: 0.15/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.15/1.00
# Movie: Rocky Horror Picture Show, The (1975), Similarity Rating: 0.15/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.15/1.00
# Movie: Death Proof (2007), Similarity Rating: 0.15/1.00
# Movie: Whisper of the Heart (Mimi wo sumaseba) (1995), Similarity Rating: 0.15/1.00
# Movie: Minari (2020), Similarity Rating: 0.15/1.00
# Movie: Paprika (Papurika) (2006), Similarity Rating: 0.15/1.00
# Movie: Room, The (2003), Similarity Rating: 0.15/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.15/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 2 (2011), Similarity Rating: 0.15/1.00
# Movie: Moana (2016), Similarity Rating: 0.14/1.00
# Movie: Frozen (2013), Similarity Rating: 0.14/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.14/1.00
# Movie: Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001), Similarity Rating: 0.14/1.00
# Movie: True Romance (1993), Similarity Rating: 0.14/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.14/1.00
# Movie: Up in the Air (2009), Similarity Rating: 0.14/1.00
# Movie: The Night Is Short, Walk on Girl (2017), Similarity Rating: 0.14/1.00
# Movie: Beautiful Mind, A (2001), Similarity Rating: 0.14/1.00
# Movie: Now You See Me (2013), Similarity Rating: 0.14/1.00
# Movie: Beverly Hills Cop (1984), Similarity Rating: 0.14/1.00
# Movie: Dogville (2003), Similarity Rating: 0.14/1.00
# Movie: From Dusk Till Dawn (1996), Similarity Rating: 0.14/1.00
# Movie: The Lego Movie (2014), Similarity Rating: 0.14/1.00
# Movie: Boondock Saints, The (2000), Similarity Rating: 0.14/1.00
# Movie: Weathering with You (2019), Similarity Rating: 0.14/1.00
# Movie: Rogue One: A Star Wars Story (2016), Similarity Rating: 0.14/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.14/1.00
# Movie: Million Dollar Baby (2004), Similarity Rating: 0.14/1.00
# Movie: Shang-Chi and the Legend of the Ten Rings (2021), Similarity Rating: 0.14/1.00
# Movie: Ready Player One, Similarity Rating: 0.13/1.00
# Movie: Ju-on: The Grudge (2002), Similarity Rating: 0.13/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.13/1.00
# Movie: Last Samurai, The (2003), Similarity Rating: 0.13/1.00
# Movie: Gravity (2013), Similarity Rating: 0.13/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.13/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.13/1.00
# Movie: Chronicle (2012), Similarity Rating: 0.13/1.00
# Movie: Room (2015), Similarity Rating: 0.13/1.00
# Movie: Audition (Ôdishon) (1999), Similarity Rating: 0.13/1.00
# Movie: It (2017), Similarity Rating: 0.13/1.00
# Movie: Anastasia (1997), Similarity Rating: 0.13/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.13/1.00
# Movie: Holy Mountain, The (Montaña sagrada, La) (1973), Similarity Rating: 0.13/1.00
# Movie: Nightmare on Elm Street, A (1984), Similarity Rating: 0.13/1.00
# Movie: The Green Knight, Similarity Rating: 0.13/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.13/1.00
# Movie: Harry Potter and the Chamber of Secrets (2002), Similarity Rating: 0.13/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.13/1.00
# Movie: Evil Dead II (Dead by Dawn) (1987), Similarity Rating: 0.13/1.00
# Movie: Office Space (1999), Similarity Rating: 0.13/1.00
# Movie: Megamind (2010), Similarity Rating: 0.13/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.13/1.00
# Movie: Contact (1997), Similarity Rating: 0.13/1.00
# Movie: Aladdin (1992), Similarity Rating: 0.13/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.13/1.00
# Movie: Toy Story 2 (1999), Similarity Rating: 0.13/1.00
# Movie: Brave (2012), Similarity Rating: 0.13/1.00
# Movie: 10 Things I Hate About You (1999), Similarity Rating: 0.12/1.00
# Movie: Alice in Wonderland (2010), Similarity Rating: 0.12/1.00
# Movie: Goonies, The (1985), Similarity Rating: 0.12/1.00
# Movie: Evil Dead, The (1981), Similarity Rating: 0.12/1.00
