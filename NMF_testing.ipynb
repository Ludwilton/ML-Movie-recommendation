# %%
import pandas as pd
from sklearn.decomposition import NMF
import numpy as np
import time
from sklearn.preprocessing import MinMaxScaler
import joblib
from joblib import load
from joblib import dump
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
ratings= pd.read_csv('./data/ratings.csv')
movies = pd.read_csv('./data/movies.csv')
movie_id_to_title = dict(zip(movies['movieId'], movies['title']))

# %%
def filter_by_average_rating(movies_df, ratings_df, min_rating=0):
    print(f"Filtering movies with average rating >= {min_rating}...")
    
    movies_with_ratings = pd.merge(movies_df, ratings_df, on='movieId', how='inner')
    
    average_ratings = movies_with_ratings.groupby('movieId')['rating'].mean()
    
    popular_movies = average_ratings[average_ratings >= min_rating].index
    
    filtered_movies_with_ratings = movies_with_ratings[movies_with_ratings['movieId'].isin(popular_movies)]
    
    print(f"Kept {len(popular_movies)} movies with average rating >= {min_rating}")
    
    return filtered_movies_with_ratings

# %%
def filter_users_by_activity(ratings_df, min_percentile, max_percentile):

    print(f"Filtering users with activity between {min_percentile*100:.0f}th and {max_percentile*100:.0f}th percentiles...")
    
    # Count ratings per user
    user_rating_counts = ratings_df.groupby('userId')['rating'].count()
    print(f"Before filtering: {len(user_rating_counts)} users with rating statistics:")
    print(user_rating_counts.describe())
    
    # Get percentile thresholds
    min_threshold = user_rating_counts.quantile(min_percentile)
    max_threshold = user_rating_counts.quantile(max_percentile)
    
    # Filter users
    filtered_users = user_rating_counts[(user_rating_counts >= min_threshold) & 
                                       (user_rating_counts <= max_threshold)].index
    
    filtered_ratings = ratings_df[ratings_df['userId'].isin(filtered_users)]
    
    # Get statistics after filtering
    user_rating_counts_after = filtered_ratings.groupby('userId')['rating'].count()
    print(f"After filtering: {len(user_rating_counts_after)} users with rating statistics:")
    print(user_rating_counts_after.describe())
    
    return filtered_ratings

# %%
def filter_movies_by_popularity(ratings_df, min_ratings):

    print(f"Filtering movies with at least {min_ratings} ratings...")
    
    # Count ratings per movie
    movie_rating_counts = ratings_df.groupby('movieId').size()
    
    print(f"Before filtering: {len(movie_rating_counts)} movies")
    print(f"Movies with <{min_ratings} ratings: {(movie_rating_counts < min_ratings).sum()}")
    
    # Filter movies with sufficient ratings
    popular_movies = movie_rating_counts[movie_rating_counts >= min_ratings].index
    
    filtered_ratings = ratings_df[ratings_df['movieId'].isin(popular_movies)]
    
    print(f"After filtering: {len(popular_movies)} movies kept")
    
    return filtered_ratings

# %%
def select_diverse_users_df(ratings_df, similarity_threshold=0.3, max_users_per_movie=500):
    """
    Select diverse users and return the filtered dataframe.
    """
    # Build user-movie and movie-user mappings
    user_to_movies = {}
    movie_user_counts = {}
    
    for _, row in ratings_df.iterrows():
        user_id = row['userId']
        movie_id = row['movieId']
        
        if user_id not in user_to_movies:
            user_to_movies[user_id] = set()
        user_to_movies[user_id].add(movie_id)
        
        if movie_id not in movie_user_counts:
            movie_user_counts[movie_id] = 0
    
    # Sort users by number of ratings (experts first)
    sorted_users = sorted(user_to_movies.keys(), 
                         key=lambda u: len(user_to_movies[u]), 
                         reverse=True)
    
    # Select diverse users
    selected_users = []
    
    for user_id in sorted_users:
        user_movies = user_to_movies[user_id]
        
        # Check movie limit
        if any(movie_user_counts.get(movie_id, 0) >= max_users_per_movie 
              for movie_id in user_movies):
            continue
        
        # Check similarity with existing users
        too_similar = False
        for selected_id in selected_users:
            selected_movies = user_to_movies[selected_id]
            
            # Calculate Jaccard similarity
            intersection = len(user_movies.intersection(selected_movies))
            union = len(user_movies.union(selected_movies))
            
            if intersection / union > similarity_threshold:
                too_similar = True
                break
        
        if not too_similar:
            selected_users.append(user_id)
            
            # Update movie counts
            for movie_id in user_movies:
                movie_user_counts[movie_id] += 1
    
    # Return the filtered dataframe
    return ratings_df[ratings_df['userId'].isin(selected_users)]

""" def select_diverse_users(ratings_df, max_users_per_movie=1000, similarity_threshold=0.3):

    print(f"Selecting diverse users with max {max_users_per_movie} users per movie...")
    
    # Get initial statistics
    total_users = ratings_df['userId'].nunique()
    total_movies = ratings_df['movieId'].nunique()
    total_ratings = len(ratings_df)
    
    print(f"Initial dataset: {total_ratings} ratings from {total_users} users on {total_movies} movies")
    
    # Create a movie-to-users dictionary to track how many users rated each movie
    movie_to_users = {}
    for movie_id, group in ratings_df.groupby('movieId'):
        movie_to_users[movie_id] = set(group['userId'])
    
    # Create a user-to-movies dictionary
    user_to_movies = {}
    for user_id, group in ratings_df.groupby('userId'):
        user_to_movies[user_id] = set(group['movieId'])
    
    # Sort users by the number of ratings (CHANGED: now in descending order)
    user_rating_counts = ratings_df.groupby('userId').size()
    sorted_users = user_rating_counts.sort_values(ascending=False).index.tolist()
    
    # Add some randomness within rating count groups to prevent bias
    # Group users by rating count
    rating_count_groups = {}
    for user_id, count in user_rating_counts.items():
        if count not in rating_count_groups:
            rating_count_groups[count] = []
        rating_count_groups[count].append(user_id)
    
    # Shuffle each group and rebuild the sorted users list
    shuffled_sorted_users = []
    for count in sorted(rating_count_groups.keys(), reverse=True):
        group = rating_count_groups[count]
        np.random.shuffle(group)
        shuffled_sorted_users.extend(group)
    
    selected_users = set()
    movie_user_counts = {movie_id: 0 for movie_id in movie_to_users.keys()}
    
    # Process users in the sorted order (now more ratings first)
    for user_id in shuffled_sorted_users:
        user_movies = user_to_movies[user_id]
        
        # Skip users with too few ratings (optional)
        if len(user_movies) < 0:  # Minimum threshold can be changed
            continue
            
        # Check if this user would exceed the max users for any movie
        exceeds_limit = False
        for movie_id in user_movies:
            if movie_user_counts[movie_id] >= max_users_per_movie:
                exceeds_limit = True
                break
        
        # Check similarity with already selected users
        too_similar = False
        if not exceeds_limit and len(selected_users) > 0:
            # Check similarity with ALL existing users (no sampling)
            for selected_user in selected_users:
                selected_user_movies = user_to_movies[selected_user]
                
                # Only calculate similarity if there's a minimum overlap
                if len(user_movies) > 0 and len(selected_user_movies) > 0:
                    # Calculate Jaccard similarity between users
                    intersection = len(user_movies.intersection(selected_user_movies))
                    union = len(user_movies.union(selected_user_movies))
                    
                    similarity = intersection / union
                    if similarity > similarity_threshold:
                        too_similar = True
                        break
        
        # Add user if they don't exceed limits and aren't too similar
        if not exceeds_limit and not too_similar:
            selected_users.add(user_id)
            
            # Update movie user counts
            for movie_id in user_movies:
                movie_user_counts[movie_id] += 1
    
    # Filter the ratings DataFrame to only include selected users
    filtered_ratings = ratings_df[ratings_df['userId'].isin(selected_users)]
    
    # Calculate and print statistics
    avg_ratings_per_user = filtered_ratings.groupby('userId').size().mean()
    
    print(f"After filtering: {len(filtered_ratings)} ratings from {len(selected_users)} users")
    print(f"Retained {len(filtered_ratings)/total_ratings:.1%} of original ratings")
    print(f"Average ratings per selected user: {avg_ratings_per_user:.1f}")
    
    return filtered_ratings """
# Out:
# ' def select_diverse_users(ratings_df, max_users_per_movie=1000, similarity_threshold=0.3):\n\n    print(f"Selecting diverse users with max {max_users_per_movie} users per movie...")\n\n    # Get initial statistics\n    total_users = ratings_df[\'userId\'].nunique()\n    total_movies = ratings_df[\'movieId\'].nunique()\n    total_ratings = len(ratings_df)\n\n    print(f"Initial dataset: {total_ratings} ratings from {total_users} users on {total_movies} movies")\n\n    # Create a movie-to-users dictionary to track how many users rated each movie\n    movie_to_users = {}\n    for movie_id, group in ratings_df.groupby(\'movieId\'):\n        movie_to_users[movie_id] = set(group[\'userId\'])\n\n    # Create a user-to-movies dictionary\n    user_to_movies = {}\n    for user_id, group in ratings_df.groupby(\'userId\'):\n        user_to_movies[user_id] = set(group[\'movieId\'])\n\n    # Sort users by the number of ratings (CHANGED: now in descending order)\n    user_rating_counts = ratings_df.groupby(\'userId\').size()\n    sorted_users = user_rating_counts.sort_values(ascending=False).index.tolist()\n\n    # Add some randomness within rating count groups to prevent bias\n    # Group users by rating count\n    rating_count_groups = {}\n    for user_id, count in user_rating_counts.items():\n        if count not in rating_count_groups:\n            rating_count_groups[count] = []\n        rating_count_groups[count].append(user_id)\n\n    # Shuffle each group and rebuild the sorted users list\n    shuffled_sorted_users = []\n    for count in sorted(rating_count_groups.keys(), reverse=True):\n        group = rating_count_groups[count]\n        np.random.shuffle(group)\n        shuffled_sorted_users.extend(group)\n\n    selected_users = set()\n    movie_user_counts = {movie_id: 0 for movie_id in movie_to_users.keys()}\n\n    # Process users in the sorted order (now more ratings first)\n    for user_id in shuffled_sorted_users:\n        user_movies = user_to_movies[user_id]\n\n        # Skip users with too few ratings (optional)\n        if len(user_movies) < 0:  # Minimum threshold can be changed\n            continue\n\n        # Check if this user would exceed the max users for any movie\n        exceeds_limit = False\n        for movie_id in user_movies:\n            if movie_user_counts[movie_id] >= max_users_per_movie:\n                exceeds_limit = True\n                break\n\n        # Check similarity with already selected users\n        too_similar = False\n        if not exceeds_limit and len(selected_users) > 0:\n            # Check similarity with ALL existing users (no sampling)\n            for selected_user in selected_users:\n                selected_user_movies = user_to_movies[selected_user]\n\n                # Only calculate similarity if there\'s a minimum overlap\n                if len(user_movies) > 0 and len(selected_user_movies) > 0:\n                    # Calculate Jaccard similarity between users\n                    intersection = len(user_movies.intersection(selected_user_movies))\n                    union = len(user_movies.union(selected_user_movies))\n\n                    similarity = intersection / union\n                    if similarity > similarity_threshold:\n                        too_similar = True\n                        break\n\n        # Add user if they don\'t exceed limits and aren\'t too similar\n        if not exceeds_limit and not too_similar:\n            selected_users.add(user_id)\n\n            # Update movie user counts\n            for movie_id in user_movies:\n                movie_user_counts[movie_id] += 1\n\n    # Filter the ratings DataFrame to only include selected users\n    filtered_ratings = ratings_df[ratings_df[\'userId\'].isin(selected_users)]\n\n    # Calculate and print statistics\n    avg_ratings_per_user = filtered_ratings.groupby(\'userId\').size().mean()\n\n    print(f"After filtering: {len(filtered_ratings)} ratings from {len(selected_users)} users")\n    print ...

# %%
def remove_columns(filtered_df):
    if 'timestamp' in filtered_df.columns:
        filtered_df.drop(columns=["timestamp"], inplace=True)
    if 'genres' in filtered_df.columns:
        filtered_df.drop(columns=["genres"], inplace=True)
    if 'title' in filtered_df.columns:
        filtered_df.drop(columns=["title"], inplace=True)
    
    print(f"Final dataset: {len(filtered_df)} ratings across {filtered_df['movieId'].nunique()} movies from {filtered_df['userId'].nunique()} users")

    return filtered_df

# %%
ratings = remove_columns(ratings)
# Out:
# Final dataset: 33832162 ratings across 83239 movies from 330975 users

# %%
min_avg_rating=0
user_min_percentile=0.20 # these seem to fit the average user best
user_max_percentile=0.97
min_ratings_per_movie=3
max_users_per_movie=160 # 250
user_similarity_threshold=0.15 # 0.15

# %%
# Step 3: Filter users by activity level
filtered_df = filter_users_by_activity(
    ratings,
    min_percentile=user_min_percentile,
    max_percentile=user_max_percentile
)
# Out:
# Filtering users with activity between 20th and 97th percentiles...
# Before filtering: 330975 users with rating statistics:
# count    330975.00000
# mean        102.21969
# std         232.15453
# min           1.00000
# 25%          15.00000
# 50%          31.00000
# 75%          98.00000
# max       33332.00000
# Name: rating, dtype: float64
# After filtering: 256848 users with rating statistics:
# count    256848.000000
# mean         89.284974
# std         106.963896
# min          12.000000
# 25%          20.000000
# 50%          44.000000
# 75%         111.000000
# max         579.000000
# Name: rating, dtype: float64

# %%
ratings_df = select_diverse_users(
    filtered_df, 
    max_users_per_movie=max_users_per_movie,
    similarity_threshold=user_similarity_threshold,
)

# %%
diverse_ratings_df = ratings_df[ratings_df['userId'].isin(ratings_df)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 diverse_ratings_df = ratings_df[ratings_df['userId'].isin(ratings_df)]
#
# TypeError: list indices must be integers or slices, not str

# %%
ratings_df
# Out:
# [np.float64(3723.0),
#  np.float64(21528.0),
#  np.float64(67077.0),
#  np.float64(97674.0),
#  np.float64(101793.0),
#  np.float64(206559.0),
#  np.float64(234847.0),
#  np.float64(143766.0),
#  np.float64(191309.0),
#  np.float64(213889.0),
#  np.float64(142872.0),
#  np.float64(271596.0),
#  np.float64(91955.0),
#  np.float64(98474.0),
#  np.float64(45521.0),
#  np.float64(307296.0),
#  np.float64(42065.0),
#  np.float64(222466.0),
#  np.float64(306740.0),
#  np.float64(1854.0),
#  np.float64(271215.0),
#  np.float64(45634.0),
#  np.float64(135753.0),
#  np.float64(301709.0),
#  np.float64(308143.0),
#  np.float64(250034.0),
#  np.float64(305511.0),
#  np.float64(318142.0),
#  np.float64(44103.0),
#  np.float64(116831.0),
#  np.float64(178417.0),
#  np.float64(40824.0),
#  np.float64(177638.0),
#  np.float64(180990.0),
#  np.float64(282883.0),
#  np.float64(131279.0),
#  np.float64(193676.0),
#  np.float64(49216.0),
#  np.float64(164189.0),
#  np.float64(318864.0),
#  np.float64(66068.0),
#  np.float64(157238.0),
#  np.float64(9453.0),
#  np.float64(40698.0),
#  np.float64(43034.0),
#  np.float64(92129.0),
#  np.float64(205170.0),
#  np.float64(318118.0),
#  np.float64(199205.0),
#  np.float64(78361.0),
#  np.float64(58881.0),
#  np.float64(130777.0),
#  np.float64(16374.0),
#  np.float64(249703.0),
#  np.float64(9082.0),
#  np.float64(142045.0),
#  np.float64(50519.0),
#  np.float64(89607.0),
#  np.float64(100757.0),
#  np.float64(265913.0),
#  np.float64(293162.0),
#  np.float64(7959.0),
#  np.float64(205542.0),
#  np.float64(271447.0),
#  np.float64(104326.0),
#  np.float64(174585.0),
#  np.float64(62576.0),
#  np.float64(227453.0),
#  np.float64(286323.0),
#  np.float64(23955.0),
#  np.float64(201627.0),
#  np.float64(158640.0),
#  np.float64(232385.0),
#  np.float64(245846.0),
#  np.float64(138176.0),
#  np.float64(167241.0),
#  np.float64(136391.0),
#  np.float64(41395.0),
#  np.float64(103894.0),
#  np.float64(81648.0),
#  np.float64(231549.0),
#  np.float64(246071.0),
#  np.float64(264718.0),
#  np.float64(252458.0),
#  np.float64(61066.0),
#  np.float64(262603.0),
#  np.float64(324013.0),
#  np.float64(96564.0),
#  np.float64(187275.0),
#  np.float64(261211.0),
#  np.float64(276405.0),
#  np.float64(326999.0),
#  np.float64(125713.0),
#  np.float64(263099.0),
#  np.float64(266625.0),
#  np.float64(7056.0),
#  np.float64(22890.0),
#  np.float64(139559.0),
#  np.float64(37035.0),
#  np.float64(251363.0),
#  np.float64(89404.0),
#  np.float64(40821.0),
#  np.float64(243227.0),
#  np.float64(15173.0),
#  np.float64(48975.0),
#  np.float64(167387.0),
#  np.float64(175519.0),
#  np.float64(44095.0),
#  np.float64(185724.0),
#  np.float64(170822.0),
#  np.float64(135095.0),
#  np.float64(188414.0),
#  np.float64(211450.0),
#  np.float64(250651.0),
#  np.float64(154382.0),
#  np.float64(242046.0),
#  np.float64(50886.0),
#  np.float64(133727.0),
#  np.float64(189403.0),
#  np.float64(193484.0),
#  np.float64(204072.0),
#  np.float64(158669.0),
#  np.float64(159089.0),
#  np.float64(313944.0),
#  np.float64(105340.0),
#  np.float64(141019.0),
#  np.float64(213436.0),
#  np.float64(112806.0),
#  np.float64(134815.0),
#  np.float64(180539.0),
#  np.float64(237860.0),
#  np.float64(286577.0),
#  np.float64(318228.0),
#  np.float64(196885.0),
#  np.float64(105577.0),
#  np.float64(199526.0),
#  np.float64(313291.0),
#  np.float64(283776.0),
#  np.float64(309941.0),
#  np.float64(69014.0),
#  np.float64(42955.0),
#  np.float64(295723.0),
#  np.float64(156025.0),
#  np.float64(291247.0),
#  np.float64(20590.0),
#  np.float64(124154.0),
#  np.float64(318867.0),
#  np.float64(257130.0),
#  np.float64(12332.0),
#  np.float64(32346.0),
#  np.float64(84697.0),
#  np.float64(284509.0),
#  np.float64(309184.0),
#  np.float64(309418.0),
#  np.float64(115511.0),
#  np.float64(29975.0),
#  np.float64(35745.0),
#  np.float64(147276.0),
#  np.float64(309217.0),
#  np.float64(54742.0),
#  np.float64(69011.0),
#  np.float64(108610.0),
#  np.float64(112760.0),
#  np.float64(246673.0),
#  np.float64(33010.0),
#  np.float64(96009.0),
#  np.float64(31517.0),
#  np.float64(269446.0),
#  np.float64(162358.0),
#  np.float64(298872.0),
#  np.float64(78191.0),
#  np.float64(81796.0),
#  np.float64(28536.0),
#  np.float64(194978.0),
#  np.float64(218835.0),
#  np.float64(310169.0),
#  np.float64(315466.0),
#  np.float64(11083.0),
#  np.float64(306572.0),
#  np.float64(160013.0),
#  np.float64(257516.0),
#  np.float64(158613.0),
#  np.float64(317126.0),
#  np.float64(66456.0),
#  np.float64(12547.0),
#  np.float64(48962.0),
#  np.float64(133571.0),
#  np.float64(135615.0),
#  np.float64(69542.0),
#  np.float64(268608.0),
#  np.float64(386.0),
#  np.float64(212734.0),
#  np.float64(327423.0),
#  np.float64(236354.0),
#  np.float64(255548.0),
#  np.float64(278892.0),
#  np.float64(92266.0),
#  np.float64(9884.0),
#  np.float64(51640.0),
#  np.float64(108624.0),
#  np.float64(74053.0),
#  np.float64(163025.0),
#  np.float64(264654.0),
#  np.float64(38827.0),
#  np.float64(158845.0),
#  np.float64(198822.0),
#  np.float64(58922.0),
#  np.float64(105351.0),
#  np.float64(162452.0),
#  np.float64(240405.0),
#  np.float64(299495.0),
#  np.float64(255022.0),
#  np.float64(67152.0),
#  np.float64(126341.0),
#  np.float64(281728.0),
#  np.float64(184337.0),
#  np.float64(33855.0),
#  np.float64(113273.0),
#  np.float64(301608.0),
#  np.float64(306078.0),
#  np.float64(318602.0),
#  np.float64(59476.0),
#  np.float64(169851.0),
#  np.float64(228153.0),
#  np.float64(62060.0),
#  np.float64(149212.0),
#  np.float64(227772.0),
#  np.float64(93762.0),
#  np.float64(120564.0),
#  np.float64(286407.0),
#  np.float64(294057.0),
#  np.float64(290193.0),
#  np.float64(54141.0),
#  np.float64(282658.0),
#  np.float64(3995.0),
#  np.float64(78779.0),
#  np.float64(204096.0),
#  np.float64(308925.0),
#  np.float64(61947.0),
#  np.float64(312707.0),
#  np.float64(18459.0),
#  np.float64(152238.0),
#  np.float64(29166.0),
#  np.float64(268155.0),
#  np.float64(170351.0),
#  np.float64(306463.0),
#  np.float64(218563.0),
#  np.float64(175392.0),
#  np.float64(206830.0),
#  np.float64(215575.0),
#  np.float64(151436.0),
#  np.float64(278477.0),
#  np.float64(257260.0),
#  np.float64(57730.0),
#  np.float64(241386.0),
#  np.float64(300803.0),
#  np.float64(4918.0),
#  np.float64(100217.0),
#  np.float64(179276.0),
#  np.float64(182223.0),
#  np.float64(284431.0),
#  np.float64(16416.0),
#  np.float64(238463.0),
#  np.float64(202009.0),
#  np.float64(250746.0),
#  np.float64(2345.0),
#  np.float64(10599.0),
#  np.float64(241840.0),
#  np.float64(310591.0),
#  np.float64(99749.0),
#  np.float64(16020.0),
#  np.float64(301929.0),
#  np.float64(87057.0),
#  np.float64(128892.0),
#  np.float64(227380.0),
#  np.float64(5222.0),
#  np.float64(39035.0),
#  np.float64(76693.0),
#  np.float64(277571.0),
#  np.float64(69643.0),
#  np.float64(67438.0),
#  np.float64(83766.0),
#  np.float64(177423.0),
#  np.float64(297792.0),
#  np.float64(170772.0),
#  np.float64(20521.0),
#  np.float64(166632.0),
#  np.float64(239875.0),
#  np.float64(264242.0),
#  np.float64(117388.0),
#  np.float64(47537.0),
#  np.float64(110084.0),
#  np.float64(302000.0),
#  np.float64(224299.0),
#  np.float64(95954.0),
#  np.float64(46218.0),
#  np.float64(61891.0),
#  np.float64(137709.0),
#  np.float64(258517.0),
#  np.float64(267095.0),
#  np.float64(206695.0),
#  np.float64(217377.0),
#  np.float64(298119.0),
#  np.float64(76687.0),
#  np.float64(130630.0),
#  np.float64(144713.0),
#  np.float64(241494.0),
#  np.float64(106041.0),
#  np.float64(229343.0),
#  np.float64(70027.0),
#  np.float64(84932.0),
#  np.float64(195713.0),
#  np.float64(76010.0),
#  np.float64(316142.0),
#  np.float64(309734.0),
#  np.float64(120001.0),
#  np.float64(187897.0),
#  np.float64(88213.0),
#  np.float64(48842.0),
#  np.float64(225334.0),
#  np.float64(225824.0),
#  np.float64(252766.0),
#  np.float64(68478.0),
#  np.float64(313011.0),
#  np.float64(328085.0),
#  np.float64(44151.0),
#  np.float64(3654.0),
#  np.float64(85560.0),
#  np.float64(271516.0),
#  np.float64(101982.0),
#  np.float64(135108.0),
#  np.float64(14845.0),
#  np.float64(144358.0),
#  np.float64(167458.0),
#  np.float64(234577.0),
#  np.float64(254706.0),
#  np.float64(328214.0),
#  np.float64(106905.0),
#  np.float64(91483.0),
#  np.float64(308628.0),
#  np.float64(319821.0),
#  np.float64(12374.0),
#  np.float64(33951.0),
#  np.float64(280317.0),
#  np.float64(140065.0),
#  np.float64(73796.0),
#  np.float64(68165.0),
#  np.float64(42658.0),
#  np.float64(96909.0),
#  np.float64(214474.0),
#  np.float64(325386.0),
#  np.float64(277967.0),
#  np.float64(291093.0),
#  np.float64(49121.0),
#  np.float64(10800.0),
#  np.float64(100571.0),
#  np.float64(211391.0),
#  np.float64(249055.0),
#  np.float64(181004.0),
#  np.float64(234956.0),
#  np.float64(37844.0),
#  np.float64(11624.0),
#  np.float64(301293.0),
#  np.float64(235820.0),
#  np.float64(52119.0),
#  np.float64(305932.0),
#  np.float64(283656.0),
#  np.float64(10144.0),
#  np.float64(122818.0),
#  np.float64(274138.0),
#  np.float64(38863.0),
#  np.float64(207082.0),
#  np.float64(168904.0),
#  np.float64(252778.0),
#  np.float64(90000.0),
#  np.float64(275828.0),
#  np.float64(255559.0),
#  np.float64(324935.0),
#  np.float64(28472.0),
#  np.float64(156925.0),
#  np.float64(2165.0),
#  np.float64(261708.0),
#  np.float64(96451.0),
#  np.float64(239372.0),
#  np.float64(200709.0),
#  np.float64(17263.0),
#  np.float64(112499.0),
#  np.float64(48692.0),
#  np.float64(55128.0),
#  np.float64(130599.0),
#  np.float64(222548.0),
#  np.float64(177588.0),
#  np.float64(206052.0),
#  np.float64(184069.0),
#  np.float64(236441.0),
#  np.float64(327142.0),
#  np.float64(14160.0),
#  np.float64(41901.0),
#  np.float64(85598.0),
#  np.float64(252811.0),
#  np.float64(213377.0),
#  np.float64(327914.0),
#  np.float64(313285.0),
#  np.float64(44094.0),
#  np.float64(192326.0),
#  np.float64(39780.0),
#  np.float64(21642.0),
#  np.float64(258443.0),
#  np.float64(148753.0),
#  np.float64(282428.0),
#  np.float64(296179.0),
#  np.float64(83417.0),
#  np.float64(174781.0),
#  np.float64(160602.0),
#  np.float64(327749.0),
#  np.float64(3422.0),
#  np.float64(268967.0),
#  np.float64(19938.0),
#  np.float64(195940.0),
#  np.float64(93635.0),
#  np.float64(105975.0),
#  np.float64(122051.0),
#  np.float64(196954.0),
#  np.float64(284925.0),
#  np.float64(201018.0),
#  np.float64(52429.0),
#  np.float64(76839.0),
#  np.float64(224626.0),
#  np.float64(48209.0),
#  np.float64(151349.0),
#  np.float64(270045.0),
#  np.float64(76827.0),
#  np.float64(8794.0),
#  np.float64(288488.0),
#  np.float64(82723.0),
#  np.float64(146245.0),
#  np.float64(18554.0),
#  np.float64(151636.0),
#  np.float64(244465.0),
#  np.float64(67640.0),
#  np.float64(17675.0),
#  np.float64(78280.0),
#  np.float64(256934.0),
#  np.float64(318041.0),
#  np.float64(15921.0),
#  np.float64(58496.0),
#  np.float64(112318.0),
#  np.float64(286179.0),
#  np.float64(259084.0),
#  np.float64(304630.0),
#  np.float64(193955.0),
#  np.float64(266156.0),
#  np.float64(238953.0),
#  np.float64(213560.0),
#  np.float64(93210.0),
#  np.float64(285933.0),
#  np.float64(38038.0),
#  np.float64(110469.0),
#  np.float64(246958.0),
#  np.float64(30440.0),
#  np.float64(63351.0),
#  np.float64(128061.0),
#  np.float64(264707.0),
#  np.float64(307908.0),
#  np.float64(124586.0),
#  np.float64(169894.0),
#  np.float64(181679.0),
#  np.float64(223046.0),
#  np.float64(300173.0),
#  np.float64(45353.0),
#  np.float64(158286.0),
#  np.float64(202805.0),
#  np.float64(236131.0),
#  np.float64(49573.0),
#  np.float64(115781.0),
#  np.float64(158326.0),
#  np.float64(196126.0),
#  np.float64(208436.0),
#  np.float64(269795.0),
#  np.float64(117585.0),
#  np.float64(162895.0),
#  np.float64(165189.0),
#  np.float64(160162.0),
#  np.float64(128886.0),
#  np.float64(245949.0),
#  np.float64(24560.0),
#  np.float64(49992.0),
#  np.float64(75702.0),
#  np.float64(88522.0),
#  np.float64(262997.0),
#  np.float64(162080.0),
#  np.float64(174741.0),
#  np.float64(36242.0),
#  np.float64(135071.0),
#  np.float64(152962.0),
#  np.float64(231544.0),
#  np.float64(252104.0),
#  np.float64(309386.0),
#  np.float64(60657.0),
#  np.float64(68154.0),
#  np.float64(120169.0),
#  np.float64(161158.0),
#  np.float64(177768.0),
#  np.float64(199116.0),
#  np.float64(38023.0),
#  np.float64(56680.0),
#  np.float64(316428.0),
#  np.float64(3532.0),
#  np.float64(23622.0),
#  np.float64(43263.0),
#  np.float64(73432.0),
#  np.float64(172737.0),
#  np.float64(261451.0),
#  np.float64(70843.0),
#  np.float64(224157.0),
#  np.float64(10373.0),
#  np.float64(12334.0),
#  np.float64(15637.0),
#  np.float64(9289.0),
#  np.float64(274981.0),
#  np.float64(293371.0),
#  np.float64(76117.0),
#  np.float64(109586.0),
#  np.float64(156942.0),
#  np.float64(268319.0),
#  np.float64(295783.0),
#  np.float64(40618.0),
#  np.float64(124549.0),
#  np.float64(225574.0),
#  np.float64(50358.0),
#  np.float64(60389.0),
#  np.float64(46806.0),
#  np.float64(31973.0),
#  np.float64(105403.0),
#  np.float64(296672.0),
#  np.float64(148867.0),
#  np.float64(171757.0),
#  np.float64(195184.0),
#  np.float64(96150.0),
#  np.float64(110755.0),
#  np.float64(163779.0),
#  np.float64(275300.0),
#  np.float64(296610.0),
#  np.float64(66937.0),
#  np.float64(269854.0),
#  np.float64(27993.0),
#  np.float64(308395.0),
#  np.float64(153686.0),
#  np.float64(154403.0),
#  np.float64(279715.0),
#  np.float64(179316.0),
#  np.float64(68420.0),
#  np.float64(128143.0),
#  np.float64(204722.0),
#  np.float64(306947.0),
#  np.float64(41734.0),
#  np.float64(38651.0),
#  np.float64(95826.0),
#  np.float64(129862.0),
#  np.float64(185659.0),
#  np.float64(15249.0),
#  np.float64(120517.0),
#  np.float64(123071.0),
#  np.float64(137642.0),
#  np.float64(328336.0),
#  np.float64(77397.0),
#  np.float64(188391.0),
#  np.float64(274157.0),
#  np.float64(288053.0),
#  np.float64(15615.0),
#  np.float64(47895.0),
#  np.float64(54014.0),
#  np.float64(82378.0),
#  np.float64(140443.0),
#  np.float64(168129.0),
#  np.float64(208167.0),
#  np.float64(330578.0),
#  np.float64(125699.0),
#  np.float64(253591.0),
#  np.float64(315208.0),
#  np.float64(53971.0),
#  np.float64(231924.0),
#  np.float64(270881.0),
#  np.float64(83715.0),
#  np.float64(98873.0),
#  np.float64(48454.0),
#  np.float64(52954.0),
#  np.float64(77277.0),
#  np.float64(119204.0),
#  np.float64(329268.0),
#  np.float64(8087.0),
#  np.float64(51679.0),
#  np.float64(73472.0),
#  np.float64(266028.0),
#  np.float64(67614.0),
#  np.float64(1908.0),
#  np.float64(61854.0),
#  np.float64(124955.0),
#  np.float64(279262.0),
#  np.float64(45134.0),
#  np.float64(58662.0),
#  np.float64(69162.0),
#  np.float64(85231.0),
#  np.float64(2726.0),
#  np.float64(27007.0),
#  np.float64(171735.0),
#  np.float64(179700.0),
#  np.float64(304706.0),
#  np.float64(18112.0),
#  np.float64(47582.0),
#  np.float64(75437.0),
#  np.float64(48163.0),
#  np.float64(50981.0),
#  np.float64(75070.0),
#  np.float64(183020.0),
#  np.float64(278877.0),
#  np.float64(289390.0),
#  np.float64(3430.0),
#  np.float64(23533.0),
#  np.float64(32302.0),
#  np.float64(122324.0),
#  np.float64(226626.0),
#  np.float64(242768.0),
#  np.float64(45050.0),
#  np.float64(82616.0),
#  np.float64(303853.0),
#  np.float64(31874.0),
#  np.float64(176571.0),
#  np.float64(230270.0),
#  np.float64(295102.0),
#  np.float64(16215.0),
#  np.float64(38461.0),
#  np.float64(65113.0),
#  np.float64(93144.0),
#  np.float64(285766.0),
#  np.float64(94806.0),
#  np.float64(322362.0),
#  np.float64(24288.0),
#  np.float64(276399.0),
#  np.float64(55345.0),
#  np.float64(70379.0),
#  np.float64(134543.0),
#  np.float64(2954.0),
#  np.float64(193711.0),
#  np.float64(241467.0),
#  np.float64(245308.0),
#  np.float64(330904.0),
#  np.float64(12691.0),
#  np.float64(29789.0),
#  np.float64(122049.0),
#  np.float64(154245.0),
#  np.float64(221461.0),
#  np.float64(54062.0),
#  np.float64(204791.0),
#  np.float64(242697.0),
#  np.float64(276893.0),
#  np.float64(16450.0),
#  np.float64(28763.0),
#  np.float64(65017.0),
#  np.float64(173316.0),
#  np.float64(178640.0),
#  np.float64(186509.0),
#  np.float64(307283.0),
#  np.float64(8564.0),
#  np.float64(122364.0),
#  np.float64(216705.0),
#  np.float64(255034.0),
#  np.float64(291993.0),
#  np.float64(29346.0),
#  np.float64(40548.0),
#  np.float64(49837.0),
#  np.float64(82324.0),
#  np.float64(120261.0),
#  np.float64(217561.0),
#  np.float64(225951.0),
#  np.float64(292847.0),
#  np.float64(64154.0),
#  np.float64(109946.0),
#  np.float64(137357.0),
#  np.float64(220069.0),
#  np.float64(330185.0),
#  np.float64(31326.0),
#  np.float64(63918.0),
#  np.float64(65828.0),
#  np.float64(185002.0),
#  np.float64(212741.0),
#  np.float64(246798.0),
#  np.float64(247386.0),
#  np.float64(11280.0),
#  np.float64(62827.0),
#  np.float64(95523.0),
#  np.float64(146542.0),
#  np.float64(148013.0),
#  np.float64(161981.0),
#  np.float64(178939.0),
#  np.float64(279176.0),
#  np.float64(35123.0),
#  np.float64(78384.0),
#  np.float64(88598.0),
#  np.float64(210731.0),
#  np.float64(211992.0),
#  np.float64(313009.0),
#  np.float64(315190.0),
#  np.float64(1385.0),
#  np.float64(44422.0),
#  np.float64(97391.0),
#  np.float64(113277.0),
#  np.float64(142648.0),
#  np.float64(293820.0),
#  np.float64(34183.0),
#  np.float64(116647.0),
#  np.float64(171671.0),
#  np.float64(173088.0),
#  np.float64(287679.0),
#  np.float64(308891.0),
#  np.float64(12605.0),
#  np.float64(80487.0),
#  np.float64(91861.0),
#  np.float64(1525.0),
#  np.float64(16481.0),
#  np.float64(27952.0),
#  np.float64(58112.0),
#  np.float64(71838.0),
#  np.float64(74307.0),
#  np.float64(189943.0),
#  np.float64(229087.0),
#  np.float64(240771.0),
#  np.float64(290669.0),
#  np.float64(290871.0),
#  np.float64(20034.0),
#  np.float64(58027.0),
#  np.float64(144053.0),
#  np.float64(153310.0),
#  np.float64(169687.0),
#  np.float64(185086.0),
#  np.float64(201406.0),
#  np.float64(223635.0),
#  np.float64(234888.0),
#  np.float64(237713.0),
#  np.float64(262616.0),
#  np.float64(275360.0),
#  np.float64(294061.0),
#  np.float64(318763.0),
#  np.float64(29738.0),
#  np.float64(75753.0),
#  np.float64(112086.0),
#  np.float64(163363.0),
#  np.float64(222211.0),
#  np.float64(235696.0),
#  np.float64(235922.0),
#  np.float64(286216.0),
#  np.float64(292647.0),
#  np.float64(59459.0),
#  np.float64(106771.0),
#  np.float64(159404.0),
#  np.float64(179956.0),
#  np.float64(181284.0),
#  np.float64(196082.0),
#  np.float64(263293.0),
#  np.float64(321630.0),
#  np.float64(42420.0),
#  np.float64(48545.0),
#  np.float64(61491.0),
#  np.float64(94408.0),
#  np.float64(150080.0),
#  np.float64(233633.0),
#  np.float64(300393.0),
#  np.float64(312494.0),
#  np.float64(2946.0),
#  np.float64(92448.0),
#  np.float64(187984.0),
#  np.float64(215694.0),
#  np.float64(234873.0),
#  np.float64(251148.0),
#  np.float64(309334.0),
#  np.float64(11639.0),
#  np.float64(75052.0),
#  np.float64(80392.0),
#  np.float64(96643.0),
#  np.float64(145629.0),
#  np.float64(145961.0),
#  np.float64(217455.0),
#  np.float64(247268.0),
#  np.float64(286153.0),
#  np.float64(306722.0),
#  np.float64(309155.0),
#  np.float64(319862.0),
#  np.float64(329863.0),
#  np.float64(15071.0),
#  np.float64(21759.0),
#  np.float64(74663.0),
#  np.float64(75952.0),
#  np.float64(104558.0),
#  np.float64(126149.0),
#  np.float64(150098.0),
#  np.float64(159895.0),
#  np.float64(162549.0),
#  np.float64(239328.0),
#  np.float64(241126.0),
#  np.float64(252636.0),
#  np.float64(276322.0),
#  np.float64(318052.0),
#  np.float64(21213.0),
#  np.float64(34220.0),
#  np.float64(48658.0),
#  np.float64(56840.0),
#  np.float64(81826.0),
#  np.float64(93778.0),
#  np.float64(141577.0),
#  np.float64(182306.0),
#  np.float64(186808.0),
#  np.float64(249285.0),
#  np.float64(260894.0),
#  np.float64(22464.0),
#  np.float64(31705.0),
#  np.float64(52320.0),
#  np.float64(84284.0),
#  np.float64(126419.0),
#  np.float64(142098.0),
#  np.float64(164855.0),
#  np.float64(164966.0),
#  np.float64(176826.0),
#  np.float64(211792.0),
#  np.float64(215730.0),
#  np.float64(242180.0),
#  np.float64(312329.0),
#  np.float64(6554.0),
#  np.float64(33935.0),
#  np.float64(109808.0),
#  np.float64(111565.0),
#  np.float64(150759.0),
#  np.float64(176631.0),
#  np.float64(183895.0),
#  np.float64(214078.0),
#  np.float64(215784.0),
#  np.float64(256842.0),
#  np.float64(266582.0),
#  np.float64(284508.0),
#  np.float64(295006.0),
#  np.float64(37405.0),
#  np.float64(64114.0),
#  np.float64(68043.0),
#  np.float64(103067.0),
#  np.float64(143549.0),
#  np.float64(145609.0),
#  np.float64(176012.0),
#  np.float64(193185.0),
#  np.float64(193871.0),
#  np.float64(217421.0),
#  np.float64(222802.0),
#  np.float64(283897.0),
#  np.float64(328958.0),
#  np.float64(11577.0),
#  np.float64(25085.0),
#  np.float64(64554.0),
#  np.float64(67712.0),
#  np.float64(88200.0),
#  np.float64(105844.0),
#  np.float64(107377.0),
#  np.float64(132506.0),
#  np.float64(137949.0),
#  np.float64(208559.0),
#  np.float64(210978.0),
#  np.float64(228250.0),
#  np.float64(238145.0),
#  np.float64(262543.0),
#  np.float64(290744.0),
#  np.float64(309986.0),
#  np.float64(321238.0),
#  np.float64(7143.0),
#  np.float64(36478.0),
#  np.float64(53588.0),
#  np.float64(77659.0),
#  np.float64(79128.0),
#  np.float64(112013.0),
#  np.float64(113279.0),
#  np.float64(113920.0),
#  np.float64(137304.0),
#  np.float64(153403.0),
#  np.float64(192931.0),
#  np.float64(212167.0),
#  np.float64(221759.0),
#  np.float64(236688.0),
#  np.float64(248524.0),
#  np.float64(290626.0),
#  np.float64(320369.0),
#  np.float64(22323.0),
#  np.float64(42241.0),
#  np.float64(146552.0),
#  np.float64(188472.0),
#  np.float64(222505.0),
#  np.float64(265503.0),
#  np.float64(287338.0),
#  np.float64(292722.0),
#  np.float64(293140.0),
#  np.float64(322322.0),
#  np.float64(23513.0),
#  np.float64(25216.0),
#  np.float64(28590.0),
#  np.float64(38304.0),
#  np.float64(53664.0),
#  np.float64(89266.0),
#  np.float64(103826.0),
#  np.float64(119713.0),
#  np.float64(133731.0),
#  np.float64(145680.0),
#  np.float64(147590.0),
#  np.float64(168489.0),
#  np.float64(178073.0),
#  np.float64(210435.0),
#  np.float64(210450.0),
#  np.float64(292468.0),
#  np.float64(315982.0),
#  np.float64(7671.0),
#  np.float64(7839.0),
#  np.float64(58510.0),
#  np.float64(76991.0),
#  np.float64(82289.0),
#  np.float64(87979.0),
#  np.float64(92804.0),
#  np.float64(120493.0),
#  np.float64(145285.0),
#  np.float64(150875.0),
#  np.float64(161030.0),
#  np.float64(177591.0),
#  np.float64(197414.0),
#  np.float64(216797.0),
#  np.float64(224743.0),
#  np.float64(232500.0),
#  np.float64(233356.0),
#  np.float64(236255.0),
#  np.float64(245687.0),
#  np.float64(249179.0),
#  np.float64(303364.0),
#  np.float64(13944.0),
#  np.float64(14086.0),
#  np.float64(34519.0),
#  np.float64(51215.0),
#  np.float64(99572.0),
#  np.float64(106533.0),
#  np.float64(122810.0),
#  np.float64(150674.0),
#  np.float64(162992.0),
#  np.float64(178276.0),
#  np.float64(181064.0),
#  np.float64(181230.0),
#  np.float64(201454.0),
#  np.float64(215478.0),
#  np.float64(319484.0),
#  np.float64(323326.0),
#  np.float64(30435.0),
#  np.float64(63481.0),
#  np.float64(79132.0),
#  np.float64(150082.0),
#  np.float64(159762.0),
#  np.float64(160614.0),
#  np.float64(192566.0),
#  np.float64(194134.0),
#  np.float64(209063.0),
#  np.float64(221610.0),
#  np.float64(240016.0),
#  np.float64(299934.0),
#  np.float64(320349.0),
#  np.float64(8127.0),
#  np.float64(17063.0),
#  np.float64(31781.0),
#  np.float64(54628.0),
#  np.float64(111289.0),
#  np.float64(124936.0),
#  np.float64(130463.0),
#  np.float64(176150.0),
#  np.float64(224671.0),
#  np.float64(231645.0),
#  np.float64(237788.0),
#  np.float64(239662.0),
#  np.float64(281692.0),
#  np.float64(290088.0),
#  np.float64(295240.0),
#  np.float64(303948.0),
#  np.float64(1169.0),
#  np.float64(63799.0),
#  np.float64(81984.0),
#  np.float64(95326.0),
#  np.float64(99163.0),
#  np.float64(106035.0),
#  np.float64(134126.0),
#  np.float64(152049.0),
#  np.float64(154442.0),
#  np.float64(165439.0),
#  np.float64(195071.0),
#  np.float64(212366.0),
#  np.float64(222602.0),
#  np.float64(231933.0),
#  np.float64(263605.0),
#  np.float64(319476.0),
#  np.float64(2867.0),
#  np.float64(56462.0),
#  np.float64(58098.0),
#  np.float64(69098.0),
#  np.float64(77016.0),
#  ...]

# %%
ratings_df["userId"].nunique(),ratings_df["movieId"].nunique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 ratings_df["userId"].nunique(),ratings_df["movieId"].nunique()
#
# TypeError: list indices must be integers or slices, not str

# %%
filtered_df = remove_columns(ratings_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 filtered_df = remove_columns(ratings_df)
#
# Cell In[45], line 2, in remove_columns(filtered_df)
#       1 def remove_columns(filtered_df):
# ----> 2     if 'timestamp' in filtered_df.columns:
#       3         filtered_df.drop(columns=["timestamp"], inplace=True)
#       4     if 'genres' in filtered_df.columns:
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (256848, 50710)

# %%
# Step 2: Filter by average rating
filtered_df = filter_by_average_rating(
    movies, 
    ratings_df, 
    min_rating=min_avg_rating
)
# Out:
# Filtering movies with average rating >= 0...
# Kept 28277 movies with average rating >= 0

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (8896, 28277)

# %%
filtered_df = filter_movies_by_popularity(
    filtered_df,
    min_ratings=min_ratings_per_movie
)
# Out:
# Filtering movies with at least 3 ratings...
# Before filtering: 28277 movies
# Movies with <3 ratings: 14709
# After filtering: 13568 movies kept

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (8896, 13568)

# %%
def scale_ratings(matrix):
    """
    Z-score normalization with clipping to avoid extreme values.
    Accounts for user rating tendencies while preserving relative importance.
    """
    data = matrix.copy().values
    rows = data.shape[0]
    
    # Calculate global mean (we'll only use this for documentation in comments)
    global_mean = np.mean(data[data > 0])
    
    for i in range(rows):
        # Find rated movies for this user
        nonzero_mask = data[i, :] > 0
        rated_indices = np.where(nonzero_mask)[0]
        
        # Get user's ratings
        user_ratings = data[i, rated_indices]
        
        if len(user_ratings) > 1:
            # Calculate user's own mean
            user_mean = np.mean(user_ratings)
            
            # Mean center relative to user's own mean
            centered_ratings = user_ratings - user_mean
            
            # Apply standardization if there's variance
            user_std = np.std(user_ratings)
            if user_std > 0:
                # Z-score normalize
                normalized_ratings = centered_ratings / user_std
                # Clip to avoid extreme values (-2.5 to 2.5 is ~99% of normal distribution)
                normalized_ratings = np.clip(normalized_ratings, -2.5, 2.5)
                # Scale to [0,1] range
                scaled_ratings = (normalized_ratings + 2.5) / 5.0
            else:
                # If all ratings are the same, set to neutral 0.5
                scaled_ratings = np.ones_like(user_ratings) * 0.5
                
            # Update the matrix with scaled ratings
            data[i, rated_indices] = scaled_ratings
    
    # Convert back to DataFrame
    scaled_matrix = pd.DataFrame(data, index=matrix.index, columns=matrix.columns)
    return scaled_matrix

# %%
def prepare_user_ratings(ratings_file_path, user_movie_matrix_columns):
    """
    Prepares and scales a single user's ratings using the same Z-score
    normalization approach as the training data.
    """
    user_data = pd.read_csv(ratings_file_path)
    user_data = user_data.dropna(subset=['movieId'])
    
    # Create user-movie ratings matrix with zero values
    user_ratings = pd.DataFrame(0.0, index=[0], columns=user_movie_matrix_columns, dtype=np.float64)
    
    # Fill with original ratings
    for _, row in user_data.iterrows():
        movie_id = row['movieId']
        if movie_id in user_ratings.columns:
            user_ratings.loc[0, movie_id] = float(row['Rating'])
    
    # Get indices of rated movies
    nonzero_mask = user_ratings.values > 0
    rated_indices = np.where(nonzero_mask[0])[0]
    
    # Get this user's ratings
    user_rating_values = user_ratings.iloc[0, rated_indices].values
    
    if len(user_rating_values) > 1:
        # Calculate user's mean and std
        user_mean = np.mean(user_rating_values)
        user_std = np.std(user_rating_values)
        
        # Apply Z-score normalization if there's variance
        if user_std > 0:
            # Center around mean and normalize by standard deviation
            normalized_ratings = (user_rating_values - user_mean) / user_std
            # Clip to avoid extreme values
            normalized_ratings = np.clip(normalized_ratings, -2.5, 2.5)
            # Scale to [0,1] range
            scaled_ratings = (normalized_ratings + 2.5) / 5.0
        else:
            # If all ratings are the same, set to neutral 0.5
            scaled_ratings = np.ones_like(user_rating_values) * 0.5
        
        # Update the user ratings with scaled values
        user_ratings.iloc[0, rated_indices] = scaled_ratings
    
    return user_data, user_ratings

# %%
def fit_model(
    user_movie_matrix,
    n_components=50,
    max_iter=200,
    init='random',
    solver='cd',
    tol=0.0001,

    sample_size=1.0
):

    print(f"\n--- Fitting model with {sample_size*100:.0f}% of users ---")
    
    # Sample users 
    if sample_size < 1.0:
        n_users = int(user_movie_matrix.shape[0] * sample_size)
        sampled_users = np.random.choice(user_movie_matrix.index, size=n_users, replace=False)
        training_matrix = user_movie_matrix.loc[sampled_users, :]
    else:
        training_matrix = user_movie_matrix
    
    print(f"Training matrix shape: {training_matrix.shape}")
    
    # Train the model
    start_time = time.time()
    nmf = NMF(
        n_components=n_components,
        max_iter=max_iter,
        verbose=0,
        init="nndsvd",
        solver=solver,
        tol=tol,
    )
    
    user_factors = nmf.fit_transform(training_matrix)
    item_factors = nmf.components_
    training_time = time.time() - start_time
    
    print(f"Training time: {training_time:.2f} seconds")
    print(f"Iterations completed: {nmf.n_iter_}")
    print(f"Final error: {nmf.reconstruction_err_}")
    
    return nmf, training_matrix, training_time

# %%
def get_recommendations(
    nmf_model,
    training_matrix,
    my_ratings,
    my_data,
    n_recommendations=20,
    movie_id_to_title_map=None
):
    # Transform personal ratings into factor space
    my_user_factors = nmf_model.transform(my_ratings)
    
    # Generate predictions
    predicted_ratings = np.dot(my_user_factors, nmf_model.components_)
    predicted_ratings_df = pd.DataFrame(predicted_ratings, columns=training_matrix.columns)
    
    # Get movies already rated
    rated_movies = set(int(movie_id) for movie_id in my_data['movieId'].values)
    print(f"You've rated {len(rated_movies)} movies")
    
    # Filter for unrated movies
    unrated_movies = [m for m in training_matrix.columns if int(m) not in rated_movies]
    print(f"Found {len(unrated_movies)} movies you haven't rated")
    
    # Get recommendations
    recommendations = []
    for movie_id in unrated_movies:
        pred_rating = predicted_ratings_df.loc[0, movie_id]
        recommendations.append((movie_id, pred_rating))
    
    recommendations.sort(key=lambda x: x[1], reverse=True)
    
    top_recommendations = recommendations[:n_recommendations]
    
    if movie_id_to_title_map:
        print("\nTop Recommendations:")
        for movie_id, predicted_rating in top_recommendations:
            # Convert from 0-1 scale back to 1-5 scale
            original_scale_rating = predicted_rating * 4 + 1 # this didnt work that well tbh
            
            movie_title = movie_id_to_title_map.get(movie_id, f"Unknown Movie (ID: {movie_id})")
            print(f"Movie: {movie_title}, Similarity Rating: {predicted_rating:.2f}/1.00")
    
    return top_recommendations

# %%
def evaluate_nmf_predictions(nmf_model, training_matrix, test_data):


    # Create a wide-format user vector (like ludde_ratings) filled with zeros
    user_vector = np.zeros(training_matrix.shape[1])
    
    # Map movie IDs to their indices in the model
    movie_indices = {}
    if hasattr(training_matrix, 'columns'):
        # If training_matrix is a DataFrame
        for i, col in enumerate(training_matrix.columns):
            movie_indices[col] = i
    else:
        # Assume movie IDs are consecutive integers starting from 1 or 0
        offset = 1 if training_matrix.shape[1] == 19915 else 0
        for i in range(training_matrix.shape[1]):
            movie_indices[i + offset] = i
    
    # Collect actual ratings and movie positions for comparison
    actual_ratings = []
    movie_positions = []
    
    # Fill the user vector with ratings from test_data
    for _, row in test_data.iterrows():
        movie_id = row['movieId']
        rating = row['Rating']
        
        if movie_id in movie_indices:
            position = movie_indices[movie_id]
            user_vector[position] = rating
            actual_ratings.append(rating)
            movie_positions.append(position)
    
    # Transform the user vector to get user factors
    user_factors = nmf_model.transform([user_vector])
    
    # Generate predictions for all movies
    predictions_all = user_factors @ nmf_model.components_
    
    # Extract predictions for only the movies we rated in test_data
    predicted_ratings = [predictions_all[0, pos] for pos in movie_positions]
    
    # Calculate metrics
    if len(actual_ratings) > 0:
        rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_ratings))
        mae = mean_absolute_error(actual_ratings, predicted_ratings)
        me = np.mean(np.array(predicted_ratings) - np.array(actual_ratings))
        corr = np.corrcoef(actual_ratings, predicted_ratings)[0, 1] if len(actual_ratings) > 1 else np.nan
    else:
        rmse, mae, me, corr = np.nan, np.nan, np.nan, np.nan
    
    return {
        'rmse': rmse,
        'mae': mae,
        'mean_error': me,
        'correlation': corr,
        'num_predictions': len(actual_ratings)
    }

# %%
user_movie_matrix = filtered_df.pivot(index='userId', columns='movieId', values='rating')
user_movie_matrix = user_movie_matrix.fillna(0)
user_movie_matrix_scaled = scale_ratings(user_movie_matrix)

# %%
nmf_model, training_matrix, _ = fit_model(
    user_movie_matrix_scaled,
    n_components=200,
    sample_size=1,
    max_iter=800,
)
# Out:
# --- Fitting model with 100% of users ---
# Training matrix shape: (8896, 13568)
# Training time: 521.64 seconds
# Iterations completed: 319
# Final error: 277.0130533157461

# %%
""" # Save the model
dump(nmf_model, 'nmf_model_100comp.joblib')

# Save the training matrix
dump(training_matrix, 'training_matrix_100comp.joblib')

# Alternatively, save everything in one file
model_data = {
    'model': nmf_model,
    'training_matrix': training_matrix,
    'n_components': 100,
    'timestamp': pd.Timestamp.now().strftime('%Y-%m-%d %H:%M')
}
dump(model_data, 'recommender_data_100comp.joblib')

print("Model and training matrix saved successfully!") """
# Out:
# ' # Save the model\ndump(nmf_model, \'nmf_model_100comp.joblib\')\n\n# Save the training matrix\ndump(training_matrix, \'training_matrix_100comp.joblib\')\n\n# Alternatively, save everything in one file\nmodel_data = {\n    \'model\': nmf_model,\n    \'training_matrix\': training_matrix,\n    \'n_components\': 100,\n    \'timestamp\': pd.Timestamp.now().strftime(\'%Y-%m-%d %H:%M\')\n}\ndump(model_data, \'recommender_data_100comp.joblib\')\n\nprint("Model and training matrix saved successfully!") '

# %%
elliott_data, elliott_ratings = prepare_user_ratings(
    "data/loelliot_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
ludde_data, ludde_ratings = prepare_user_ratings(
    "data/ludde_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
charlie_data, charlie_ratings = prepare_user_ratings(
    "data/chaarll_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
tilda_data, tilda_ratings = prepare_user_ratings(
    "data/tilda_h_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
zorrodor_data, zorrodor_ratings = prepare_user_ratings(
    "data/zorrodor_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
lukas_data, lukas_ratings = prepare_user_ratings(
    "data/lukas_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
clara_data, clara_ratings = prepare_user_ratings(
    "data/clar_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
voided_data, voided_ratings = prepare_user_ratings(
    "data/voided_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
skellic_data, skellic_ratings = prepare_user_ratings(
    "data/skellic_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
liv_data, liv_ratings = prepare_user_ratings(
    "data/liv_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)

# %%
training_matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5679 entries, 59 to 330943
# Columns: 11659 entries, 1 to 286897
# dtypes: float64(11659)
# memory usage: 505.2 MB

# %%
ludde_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rating   426 non-null    float64
#  1   movieId  426 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 6.8 KB

# %%
ludde_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 0 to 0
# Columns: 11659 entries, 1 to 286897
# dtypes: float64(11659)
# memory usage: 91.2 KB

# %%
# recommendations = get_recommendations(
#     nmf_model=nmf_model,
#     training_matrix=training_matrix,
#     my_ratings=ludde_ratings,
#     my_data=ludde_data,
#     n_recommendations=200,
#     movie_id_to_title_map=movie_id_to_title,
# )
# Evaluate the model with your test data
metrics = evaluate_nmf_predictions(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    test_data=ludde_data  # Your test data with  movie_id, rating columns
)

# Display metrics
print(f"RMSE: {metrics['rmse']:.4f}")
print(f"MAE: {metrics['mae']:.4f}")
print(f"Mean Error: {metrics['mean_error']:.4f}")
print(f"Correlation: {metrics['correlation']:.4f}")
print(f"Number of predictions: {metrics['num_predictions']}")
# Out:
# RMSE: 2.2629
# MAE: 2.0519
# Mean Error: -2.0293
# Correlation: 0.3203
# Number of predictions: 413

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=ludde_ratings,
    my_data=ludde_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 426 movies
# Found 13155 movies you haven't rated
#
# Top Recommendations:
# Movie: Coco (2017), Similarity Rating: 0.39/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.37/1.00
# Movie: Terminator 2: Judgment Day (1991), Similarity Rating: 0.37/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.36/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.36/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.35/1.00
# Movie: Thor (2011), Similarity Rating: 0.34/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.34/1.00
# Movie: La La Land (2016), Similarity Rating: 0.33/1.00
# Movie: Saving Private Ryan (1998), Similarity Rating: 0.32/1.00
# Movie: Wonder Woman (2017), Similarity Rating: 0.32/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.32/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.32/1.00
# Movie: Room (2015), Similarity Rating: 0.32/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.31/1.00
# Movie: Kill Bill: Vol. 2 (2004), Similarity Rating: 0.31/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.31/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.30/1.00
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.30/1.00
# Movie: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), Similarity Rating: 0.30/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.30/1.00
# Movie: Hobbit: An Unexpected Journey, The (2012), Similarity Rating: 0.29/1.00
# Movie: Cast Away (2000), Similarity Rating: 0.29/1.00
# Movie: Logan (2017), Similarity Rating: 0.28/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.28/1.00
# Movie: Zombieland (2009), Similarity Rating: 0.28/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.27/1.00
# Movie: Prisoners (2013), Similarity Rating: 0.27/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.27/1.00
# Movie: Kung Fu Panda (2008), Similarity Rating: 0.27/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.26/1.00
# Movie: (500) Days of Summer (2009), Similarity Rating: 0.26/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.26/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.26/1.00
# Movie: Incredibles 2 (2018), Similarity Rating: 0.25/1.00
# Movie: Drive (2011), Similarity Rating: 0.25/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.25/1.00
# Movie: Casino Royale (2006), Similarity Rating: 0.25/1.00
# Movie: Limitless (2011), Similarity Rating: 0.25/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.25/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.25/1.00
# Movie: Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005), Similarity Rating: 0.25/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.25/1.00
# Movie: Soul (2020), Similarity Rating: 0.25/1.00
# Movie: Taxi Driver (1976), Similarity Rating: 0.25/1.00
# Movie: Minority Report (2002), Similarity Rating: 0.24/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.24/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.24/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.24/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.24/1.00
# Movie: Tangled (2010), Similarity Rating: 0.24/1.00
# Movie: Moana (2016), Similarity Rating: 0.24/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.24/1.00
# Movie: Source Code (2011), Similarity Rating: 0.23/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.23/1.00
# Movie: Bourne Supremacy, The (2004), Similarity Rating: 0.23/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.23/1.00
# Movie: Fargo (1996), Similarity Rating: 0.23/1.00
# Movie: Moon (2009), Similarity Rating: 0.23/1.00
# Movie: Game, The (1997), Similarity Rating: 0.23/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.22/1.00
# Movie: Conjuring, The (2013), Similarity Rating: 0.22/1.00
# Movie: Fantastic Beasts and Where to Find Them (2016), Similarity Rating: 0.22/1.00
# Movie: Pursuit of Happyness, The (2006), Similarity Rating: 0.22/1.00
# Movie: Curious Case of Benjamin Button, The (2008), Similarity Rating: 0.22/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.22/1.00
# Movie: Thing, The (1982), Similarity Rating: 0.22/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.22/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.22/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.22/1.00
# Movie: Ant-Man and the Wasp (2018), Similarity Rating: 0.21/1.00
# Movie: Beautiful Mind, A (2001), Similarity Rating: 0.21/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.21/1.00
# Movie: Braveheart (1995), Similarity Rating: 0.21/1.00
# Movie: Breakfast Club, The (1985), Similarity Rating: 0.21/1.00
# Movie: Upgrade (2018), Similarity Rating: 0.21/1.00
# Movie: Goodfellas (1990), Similarity Rating: 0.21/1.00
# Movie: 10 Cloverfield Lane (2016), Similarity Rating: 0.21/1.00
# Movie: The Hateful Eight (2015), Similarity Rating: 0.21/1.00
# Movie: Easy A (2010), Similarity Rating: 0.21/1.00
# Movie: Elf (2003), Similarity Rating: 0.21/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.21/1.00
# Movie: John Wick: Chapter Two (2017), Similarity Rating: 0.21/1.00
# Movie: Watchmen (2009), Similarity Rating: 0.21/1.00
# Movie: Ready Player One, Similarity Rating: 0.20/1.00
# Movie: Juno (2007), Similarity Rating: 0.20/1.00
# Movie: Indiana Jones and the Temple of Doom (1984), Similarity Rating: 0.20/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.20/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.20/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.20/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.20/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.20/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.20/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.20/1.00
# Movie: Hobbit: The Desolation of Smaug, The (2013), Similarity Rating: 0.20/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.19/1.00
# Movie: Good Time (2017), Similarity Rating: 0.19/1.00
# Movie: In Bruges (2008), Similarity Rating: 0.19/1.00
# Movie: Skyfall (2012), Similarity Rating: 0.19/1.00
# Movie: 300 (2007), Similarity Rating: 0.19/1.00
# Movie: Promising Young Woman (2020), Similarity Rating: 0.19/1.00
# Movie: Napoleon Dynamite (2004), Similarity Rating: 0.19/1.00
# Movie: Sin City (2005), Similarity Rating: 0.19/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.19/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.19/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.19/1.00
# Movie: 28 Days Later (2002), Similarity Rating: 0.19/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.19/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.19/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.19/1.00
# Movie: Snatch (2000), Similarity Rating: 0.19/1.00
# Movie: Game Night (2018), Similarity Rating: 0.19/1.00
# Movie: 12 Angry Men (1957), Similarity Rating: 0.19/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.19/1.00
# Movie: The Butterfly Effect (2004), Similarity Rating: 0.18/1.00
# Movie: Kick-Ass (2010), Similarity Rating: 0.18/1.00
# Movie: Jaws (1975), Similarity Rating: 0.18/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.18/1.00
# Movie: Before Sunrise (1995), Similarity Rating: 0.18/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.18/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.18/1.00
# Movie: Hidden Figures (2016), Similarity Rating: 0.18/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.18/1.00
# Movie: Life Is Beautiful (La Vita è bella) (1997), Similarity Rating: 0.18/1.00
# Movie: Star Trek (2009), Similarity Rating: 0.18/1.00
# Movie: Mummy Returns, The (2001), Similarity Rating: 0.18/1.00
# Movie: Slumdog Millionaire (2008), Similarity Rating: 0.18/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.18/1.00
# Movie: Aladdin (1992), Similarity Rating: 0.18/1.00
# Movie: Da Vinci Code, The (2006), Similarity Rating: 0.18/1.00
# Movie: The Lego Movie (2014), Similarity Rating: 0.17/1.00
# Movie: Nightmare Before Christmas, The (1993), Similarity Rating: 0.17/1.00
# Movie: Argo (2012), Similarity Rating: 0.17/1.00
# Movie: Matrix Reloaded, The (2003), Similarity Rating: 0.17/1.00
# Movie: Knocked Up (2007), Similarity Rating: 0.17/1.00
# Movie: Green Book (2018), Similarity Rating: 0.17/1.00
# Movie: Charlie and the Chocolate Factory (2005), Similarity Rating: 0.17/1.00
# Movie: Fugitive, The (1993), Similarity Rating: 0.17/1.00
# Movie: Terminal, The (2004), Similarity Rating: 0.17/1.00
# Movie: X-Men: The Last Stand (2006), Similarity Rating: 0.17/1.00
# Movie: Minari (2020), Similarity Rating: 0.17/1.00
# Movie: Great Gatsby, The (2013), Similarity Rating: 0.17/1.00
# Movie: Now You See Me 2 (2016), Similarity Rating: 0.17/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.17/1.00
# Movie: Brave (2012), Similarity Rating: 0.17/1.00
# Movie: Illusionist, The (2006), Similarity Rating: 0.17/1.00
# Movie: Misery (1990), Similarity Rating: 0.17/1.00
# Movie: Sorry to Bother You (2018), Similarity Rating: 0.17/1.00
# Movie: Before Sunset (2004), Similarity Rating: 0.16/1.00
# Movie: Blue Valentine (2010), Similarity Rating: 0.16/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.16/1.00
# Movie: Stardust (2007), Similarity Rating: 0.16/1.00
# Movie: Ocean's Twelve (2004), Similarity Rating: 0.16/1.00
# Movie: Mummy, The (1999), Similarity Rating: 0.16/1.00
# Movie: Old Boy (2003), Similarity Rating: 0.16/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.16/1.00
# Movie: Legally Blonde (2001), Similarity Rating: 0.16/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.16/1.00
# Movie: Others, The (2001), Similarity Rating: 0.16/1.00
# Movie: True Grit (2010), Similarity Rating: 0.16/1.00
# Movie: Fury (2014), Similarity Rating: 0.16/1.00
# Movie: Last Samurai, The (2003), Similarity Rating: 0.16/1.00
# Movie: The Devil's Advocate (1997), Similarity Rating: 0.16/1.00
# Movie: The Witch (2015), Similarity Rating: 0.16/1.00
# Movie: Pianist, The (2002), Similarity Rating: 0.16/1.00
# Movie: Wedding Crashers (2005), Similarity Rating: 0.16/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.16/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.16/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.16/1.00
# Movie: Predator (1987), Similarity Rating: 0.16/1.00
# Movie: Burn After Reading (2008), Similarity Rating: 0.16/1.00
# Movie: Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966), Similarity Rating: 0.16/1.00
# Movie: Cloverfield (2008), Similarity Rating: 0.16/1.00
# Movie: Notting Hill (1999), Similarity Rating: 0.16/1.00
# Movie: Million Dollar Baby (2004), Similarity Rating: 0.16/1.00
# Movie: We're the Millers (2013), Similarity Rating: 0.15/1.00
# Movie: Darjeeling Limited, The (2007), Similarity Rating: 0.15/1.00
# Movie: Ford v. Ferrari (2019), Similarity Rating: 0.15/1.00
# Movie: Beauty and the Beast (2017), Similarity Rating: 0.15/1.00
# Movie: Roma (2018), Similarity Rating: 0.15/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.15/1.00
# Movie: Mulan (1998), Similarity Rating: 0.15/1.00
# Movie: Ocean's Thirteen (2007), Similarity Rating: 0.15/1.00
# Movie: Forgetting Sarah Marshall (2008), Similarity Rating: 0.15/1.00
# Movie: Live Free or Die Hard (2007), Similarity Rating: 0.15/1.00
# Movie: O Brother, Where Art Thou? (2000), Similarity Rating: 0.15/1.00
# Movie: Sicario (2015), Similarity Rating: 0.15/1.00
# Movie: Liar Liar (1997), Similarity Rating: 0.15/1.00
# Movie: Coherence (2013), Similarity Rating: 0.15/1.00
# Movie: Eastern Promises (2007), Similarity Rating: 0.15/1.00
# Movie: Psycho (1960), Similarity Rating: 0.15/1.00
# Movie: The Disaster Artist (2017), Similarity Rating: 0.15/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.15/1.00
# Movie: Tucker & Dale vs Evil (2010), Similarity Rating: 0.15/1.00
# Movie: Ring, The (2002), Similarity Rating: 0.15/1.00
# Movie: A.I. Artificial Intelligence (2001), Similarity Rating: 0.15/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.15/1.00
# Movie: Step Brothers (2008), Similarity Rating: 0.15/1.00
# Movie: Mission: Impossible - Fallout (2018), Similarity Rating: 0.15/1.00
# Movie: Dodgeball: A True Underdog Story (2004), Similarity Rating: 0.15/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=tilda_ratings,
    my_data=tilda_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 285 movies
# Found 13291 movies you haven't rated
#
# Top Recommendations:
# Movie: Inside Out (2015), Similarity Rating: 0.35/1.00
# Movie: Room (2015), Similarity Rating: 0.33/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.33/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.29/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.29/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.28/1.00
# Movie: Little Women (2019), Similarity Rating: 0.28/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.27/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.27/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.27/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.27/1.00
# Movie: Avatar (2009), Similarity Rating: 0.26/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.25/1.00
# Movie: Django Unchained (2012), Similarity Rating: 0.25/1.00
# Movie: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), Similarity Rating: 0.25/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.25/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.25/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.24/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.24/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.24/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 2 (2011), Similarity Rating: 0.24/1.00
# Movie: Seven (a.k.a. Se7en) (1995), Similarity Rating: 0.23/1.00
# Movie: The Martian (2015), Similarity Rating: 0.23/1.00
# Movie: Intouchables (2011), Similarity Rating: 0.23/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.23/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.23/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.22/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.22/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.22/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.22/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.22/1.00
# Movie: Harry Potter and the Half-Blood Prince (2009), Similarity Rating: 0.21/1.00
# Movie: Moonlight, Similarity Rating: 0.21/1.00
# Movie: Kill Bill: Vol. 1 (2003), Similarity Rating: 0.21/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.21/1.00
# Movie: Tangled (2010), Similarity Rating: 0.21/1.00
# Movie: Atonement (2007), Similarity Rating: 0.21/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 1 (2010), Similarity Rating: 0.21/1.00
# Movie: Wonder Woman (2017), Similarity Rating: 0.20/1.00
# Movie: Beautiful Mind, A (2001), Similarity Rating: 0.20/1.00
# Movie: Promising Young Woman (2020), Similarity Rating: 0.20/1.00
# Movie: The Hunger Games: Catching Fire (2013), Similarity Rating: 0.20/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.19/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.19/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.19/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.19/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.19/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.19/1.00
# Movie: Before Sunset (2004), Similarity Rating: 0.19/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.19/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.18/1.00
# Movie: Minari (2020), Similarity Rating: 0.18/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.18/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.18/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.18/1.00
# Movie: Us (2019), Similarity Rating: 0.18/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.18/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.18/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.18/1.00
# Movie: Incredibles, The (2004), Similarity Rating: 0.18/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.17/1.00
# Movie: Lord of the Rings: The Fellowship of the Ring, The (2001), Similarity Rating: 0.17/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.17/1.00
# Movie: The Age of Adaline (2015), Similarity Rating: 0.17/1.00
# Movie: Captain Fantastic (2016), Similarity Rating: 0.17/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.17/1.00
# Movie: Curious Case of Benjamin Button, The (2008), Similarity Rating: 0.17/1.00
# Movie: Memento (2000), Similarity Rating: 0.17/1.00
# Movie: Me Before You (2016), Similarity Rating: 0.17/1.00
# Movie: How to Train Your Dragon (2010), Similarity Rating: 0.17/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.17/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.17/1.00
# Movie: Moana (2016), Similarity Rating: 0.17/1.00
# Movie: Proposal, The (2009), Similarity Rating: 0.16/1.00
# Movie: Sound of Metal (2019), Similarity Rating: 0.16/1.00
# Movie: Passengers (2016), Similarity Rating: 0.16/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.16/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.16/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.16/1.00
# Movie: Toy Story 3 (2010), Similarity Rating: 0.16/1.00
# Movie: The Witch (2015), Similarity Rating: 0.16/1.00
# Movie: Lord of the Rings: The Two Towers, The (2002), Similarity Rating: 0.16/1.00
# Movie: One Day (2011), Similarity Rating: 0.16/1.00
# Movie: Me and Earl and the Dying Girl (2015), Similarity Rating: 0.16/1.00
# Movie: Paperman (2012), Similarity Rating: 0.16/1.00
# Movie: 1917 (2019), Similarity Rating: 0.16/1.00
# Movie: Alien (1979), Similarity Rating: 0.16/1.00
# Movie: Beauty and the Beast (1991), Similarity Rating: 0.16/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.16/1.00
# Movie: American Psycho (2000), Similarity Rating: 0.16/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.15/1.00
# Movie: Batman Begins (2005), Similarity Rating: 0.15/1.00
# Movie: Lord of the Rings: The Return of the King, The (2003), Similarity Rating: 0.15/1.00
# Movie: Limitless (2011), Similarity Rating: 0.15/1.00
# Movie: Dunkirk (2017), Similarity Rating: 0.15/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.15/1.00
# Movie: Kill Bill: Vol. 2 (2004), Similarity Rating: 0.15/1.00
# Movie: Searching (2018), Similarity Rating: 0.15/1.00
# Movie: Aladdin (1992), Similarity Rating: 0.15/1.00
# Movie: Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005), Similarity Rating: 0.15/1.00
# Movie: Help, The (2011), Similarity Rating: 0.15/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.15/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.15/1.00
# Movie: Kung Fu Panda (2008), Similarity Rating: 0.15/1.00
# Movie: Good Time (2017), Similarity Rating: 0.15/1.00
# Movie: Snowpiercer (2013), Similarity Rating: 0.15/1.00
# Movie: Little Mermaid, The (1989), Similarity Rating: 0.15/1.00
# Movie: Taxi Driver (1976), Similarity Rating: 0.15/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.15/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.15/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.15/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.14/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.14/1.00
# Movie: Love, Rosie (2014), Similarity Rating: 0.14/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.14/1.00
# Movie: Mulan (1998), Similarity Rating: 0.14/1.00
# Movie: Illusionist, The (2006), Similarity Rating: 0.14/1.00
# Movie: Hidden Figures (2016), Similarity Rating: 0.14/1.00
# Movie: Napoleon Dynamite (2004), Similarity Rating: 0.14/1.00
# Movie: Terminator 2: Judgment Day (1991), Similarity Rating: 0.14/1.00
# Movie: Mr. & Mrs. Smith (2005), Similarity Rating: 0.14/1.00
# Movie: Great Gatsby, The (2013), Similarity Rating: 0.14/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.14/1.00
# Movie: Fantastic Beasts and Where to Find Them (2016), Similarity Rating: 0.14/1.00
# Movie: The Intern (2015), Similarity Rating: 0.14/1.00
# Movie: Frozen (2013), Similarity Rating: 0.14/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.14/1.00
# Movie: Bridget Jones's Diary (2001), Similarity Rating: 0.14/1.00
# Movie: The Butterfly Effect (2004), Similarity Rating: 0.14/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.14/1.00
# Movie: Gladiator (2000), Similarity Rating: 0.14/1.00
# Movie: Split (2017), Similarity Rating: 0.14/1.00
# Movie: Shaun of the Dead (2004), Similarity Rating: 0.14/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.14/1.00
# Movie: Gattaca (1997), Similarity Rating: 0.14/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.14/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.14/1.00
# Movie: Blue Valentine (2010), Similarity Rating: 0.14/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.14/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.14/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.14/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.14/1.00
# Movie: Before Midnight (2013), Similarity Rating: 0.14/1.00
# Movie: Pineapple Express (2008), Similarity Rating: 0.13/1.00
# Movie: A Simple Favor (2018), Similarity Rating: 0.13/1.00
# Movie: Mother! (2017), Similarity Rating: 0.13/1.00
# Movie: Step Up (2006), Similarity Rating: 0.13/1.00
# Movie: Virgin Suicides, The (1999), Similarity Rating: 0.13/1.00
# Movie: Roma (2018), Similarity Rating: 0.13/1.00
# Movie: The Big Sick (2017), Similarity Rating: 0.13/1.00
# Movie: Stardust (2007), Similarity Rating: 0.13/1.00
# Movie: Shrek 2 (2004), Similarity Rating: 0.13/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.13/1.00
# Movie: Enemy (2013), Similarity Rating: 0.13/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.13/1.00
# Movie: The Hunger Games: Mockingjay - Part 1 (2014), Similarity Rating: 0.13/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.13/1.00
# Movie: Anchorman: The Legend of Ron Burgundy (2004), Similarity Rating: 0.13/1.00
# Movie: I'm Thinking of Ending Things, Similarity Rating: 0.13/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.13/1.00
# Movie: Tenet (2020), Similarity Rating: 0.13/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.13/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.13/1.00
# Movie: Moon (2009), Similarity Rating: 0.13/1.00
# Movie: Coherence (2013), Similarity Rating: 0.13/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.13/1.00
# Movie: 10 Cloverfield Lane (2016), Similarity Rating: 0.13/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.13/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.13/1.00
# Movie: Upgrade (2018), Similarity Rating: 0.13/1.00
# Movie: Nocturnal Animals, Similarity Rating: 0.13/1.00
# Movie: 2001: A Space Odyssey (1968), Similarity Rating: 0.13/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.13/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.13/1.00
# Movie: Spider-Man: No Way Home (2021), Similarity Rating: 0.13/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.13/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.13/1.00
# Movie: Moulin Rouge (2001), Similarity Rating: 0.13/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.13/1.00
# Movie: Hitch (2005), Similarity Rating: 0.13/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.12/1.00
# Movie: 12 Years a Slave (2013), Similarity Rating: 0.12/1.00
# Movie: 50 First Dates (2004), Similarity Rating: 0.12/1.00
# Movie: Perfect Blue (1997), Similarity Rating: 0.12/1.00
# Movie: Misérables, Les (2012), Similarity Rating: 0.12/1.00
# Movie: Ghost World (2001), Similarity Rating: 0.12/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.12/1.00
# Movie: Hobbit: An Unexpected Journey, The (2012), Similarity Rating: 0.12/1.00
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.12/1.00
# Movie: Burning (2018), Similarity Rating: 0.12/1.00
# Movie: Memories of Murder (Salinui chueok) (2003), Similarity Rating: 0.12/1.00
# Movie: Office Space (1999), Similarity Rating: 0.12/1.00
# Movie: We're the Millers (2013), Similarity Rating: 0.12/1.00
# Movie: Frances Ha (2012), Similarity Rating: 0.12/1.00
# Movie: Hamilton (2020), Similarity Rating: 0.12/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.12/1.00
# Movie: 3 Idiots (2009), Similarity Rating: 0.12/1.00
# Movie: Maleficent (2014), Similarity Rating: 0.12/1.00
# Movie: The Spectacular Now (2013), Similarity Rating: 0.12/1.00
# Movie: Game, The (1997), Similarity Rating: 0.12/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=elliott_ratings,
    my_data=elliott_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
# response "Jag har sett typ en tredjedel av dessa filmer kanske, men inte sen jag började med letterboxd"
# Out:
# You've rated 177 movies
# Found 13416 movies you haven't rated
#
# Top Recommendations:
# Movie: Arrival (2016), Similarity Rating: 0.29/1.00
# Movie: The Favourite, Similarity Rating: 0.24/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.22/1.00
# Movie: Coco (2017), Similarity Rating: 0.22/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.22/1.00
# Movie: La La Land (2016), Similarity Rating: 0.21/1.00
# Movie: Moonlight, Similarity Rating: 0.20/1.00
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.20/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.19/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.19/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.19/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.18/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.18/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.18/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.18/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.17/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.17/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.17/1.00
# Movie: Soul (2020), Similarity Rating: 0.16/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.16/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.15/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.15/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.15/1.00
# Movie: Minari (2020), Similarity Rating: 0.14/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.14/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.14/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.14/1.00
# Movie: Harry Potter and the Half-Blood Prince (2009), Similarity Rating: 0.14/1.00
# Movie: Once Upon a Time in Hollywood (2019), Similarity Rating: 0.13/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.13/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.13/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.13/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.13/1.00
# Movie: Upgrade (2018), Similarity Rating: 0.13/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.13/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 2 (2011), Similarity Rating: 0.13/1.00
# Movie: The Big Sick (2017), Similarity Rating: 0.13/1.00
# Movie: Searching (2018), Similarity Rating: 0.13/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.13/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 1 (2010), Similarity Rating: 0.13/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.13/1.00
# Movie: Judas and the Black Messiah (2021), Similarity Rating: 0.12/1.00
# Movie: Lion (2016), Similarity Rating: 0.12/1.00
# Movie: The Martian (2015), Similarity Rating: 0.12/1.00
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.12/1.00
# Movie: Spider-Man: No Way Home (2021), Similarity Rating: 0.12/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.12/1.00
# Movie: Before Sunrise (1995), Similarity Rating: 0.12/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.12/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.12/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.12/1.00
# Movie: Inception (2010), Similarity Rating: 0.12/1.00
# Movie: Blade Runner 2049 (2017), Similarity Rating: 0.12/1.00
# Movie: Captain Fantastic (2016), Similarity Rating: 0.12/1.00
# Movie: Avatar (2009), Similarity Rating: 0.12/1.00
# Movie: 21 Jump Street (2012), Similarity Rating: 0.12/1.00
# Movie: 20th Century Women (2016), Similarity Rating: 0.11/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.11/1.00
# Movie: Frances Ha (2012), Similarity Rating: 0.11/1.00
# Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Similarity Rating: 0.11/1.00
# Movie: Nocturnal Animals, Similarity Rating: 0.11/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.11/1.00
# Movie: The Two Popes (2019), Similarity Rating: 0.11/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.11/1.00
# Movie: Proposal, The (2009), Similarity Rating: 0.11/1.00
# Movie: Moana (2016), Similarity Rating: 0.11/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.11/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.11/1.00
# Movie: Nomadland (2020), Similarity Rating: 0.11/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.11/1.00
# Movie: The Hunger Games (2012), Similarity Rating: 0.11/1.00
# Movie: Roma (2018), Similarity Rating: 0.10/1.00
# Movie: Onward (2020), Similarity Rating: 0.10/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.10/1.00
# Movie: Sound of Metal (2019), Similarity Rating: 0.10/1.00
# Movie: Me and Earl and the Dying Girl (2015), Similarity Rating: 0.10/1.00
# Movie: Before Sunset (2004), Similarity Rating: 0.10/1.00
# Movie: Ready Player One, Similarity Rating: 0.10/1.00
# Movie: Ready or Not (2019), Similarity Rating: 0.10/1.00
# Movie: CODA (2021), Similarity Rating: 0.10/1.00
# Movie: A Simple Favor (2018), Similarity Rating: 0.10/1.00
# Movie: Deadpool (2016), Similarity Rating: 0.10/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.10/1.00
# Movie: Before Midnight (2013), Similarity Rating: 0.10/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.10/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.10/1.00
# Movie: The Father (2020), Similarity Rating: 0.10/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.10/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.10/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.10/1.00
# Movie: Okja (2017), Similarity Rating: 0.10/1.00
# Movie: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), Similarity Rating: 0.10/1.00
# Movie: (500) Days of Summer (2009), Similarity Rating: 0.09/1.00
# Movie: The Trial of the Chicago 7 (2020), Similarity Rating: 0.09/1.00
# Movie: The Hunger Games: Catching Fire (2013), Similarity Rating: 0.09/1.00
# Movie: Good Time (2017), Similarity Rating: 0.09/1.00
# Movie: Snowpiercer (2013), Similarity Rating: 0.09/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.09/1.00
# Movie: Mid90s (2018), Similarity Rating: 0.09/1.00
# Movie: Little Miss Sunshine (2006), Similarity Rating: 0.09/1.00
# Movie: Kingsman: The Secret Service (2015), Similarity Rating: 0.09/1.00
# Movie: Free Solo (2018), Similarity Rating: 0.09/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.09/1.00
# Movie: The Worst Person in the World (2021), Similarity Rating: 0.09/1.00
# Movie: The Irishman (2019), Similarity Rating: 0.09/1.00
# Movie: Long Shot (2019), Similarity Rating: 0.09/1.00
# Movie: Hustlers (2019), Similarity Rating: 0.09/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.09/1.00
# Movie: Black Widow (2021), Similarity Rating: 0.09/1.00
# Movie: The Suicide Squad (2021), Similarity Rating: 0.09/1.00
# Movie: Mr. & Mrs. Smith (2005), Similarity Rating: 0.09/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.09/1.00
# Movie: The Disaster Artist (2017), Similarity Rating: 0.09/1.00
# Movie: Passengers (2016), Similarity Rating: 0.09/1.00
# Movie: Shiva Baby (2020), Similarity Rating: 0.09/1.00
# Movie: Wonder Woman (2017), Similarity Rating: 0.09/1.00
# Movie: Still Alice (2014), Similarity Rating: 0.09/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.09/1.00
# Movie: Brooklyn (2015), Similarity Rating: 0.09/1.00
# Movie: Green Book (2018), Similarity Rating: 0.09/1.00
# Movie: Connected (2020), Similarity Rating: 0.09/1.00
# Movie: Hunt, The (Jagten) (2012), Similarity Rating: 0.09/1.00
# Movie: Rocketman (2019), Similarity Rating: 0.09/1.00
# Movie: Wind River (2017), Similarity Rating: 0.09/1.00
# Movie: Mother! (2017), Similarity Rating: 0.09/1.00
# Movie: The Hunger Games: Mockingjay - Part 1 (2014), Similarity Rating: 0.08/1.00
# Movie: Love Actually (2003), Similarity Rating: 0.08/1.00
# Movie: Klaus (2019), Similarity Rating: 0.08/1.00
# Movie: Hot Fuzz (2007), Similarity Rating: 0.08/1.00
# Movie: Paddington 2 (2017), Similarity Rating: 0.08/1.00
# Movie: The Old Guard (2020), Similarity Rating: 0.08/1.00
# Movie: Paul (2011), Similarity Rating: 0.08/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.08/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.08/1.00
# Movie: Anomalisa (2015), Similarity Rating: 0.08/1.00
# Movie: But I'm a Cheerleader (1999), Similarity Rating: 0.08/1.00
# Movie: Carol (2015), Similarity Rating: 0.08/1.00
# Movie: Exit Through the Gift Shop (2010), Similarity Rating: 0.08/1.00
# Movie: The Half of It (2020), Similarity Rating: 0.08/1.00
# Movie: It: Chapter Two (2019), Similarity Rating: 0.08/1.00
# Movie: Life (2017), Similarity Rating: 0.08/1.00
# Movie: The Intern (2015), Similarity Rating: 0.08/1.00
# Movie: Wild Tales (2014), Similarity Rating: 0.08/1.00
# Movie: Emma (2020), Similarity Rating: 0.08/1.00
# Movie: Never Rarely Sometimes Always (2020), Similarity Rating: 0.08/1.00
# Movie: Pineapple Express (2008), Similarity Rating: 0.08/1.00
# Movie: I Am Mother (2019), Similarity Rating: 0.08/1.00
# Movie: Intouchables (2011), Similarity Rating: 0.08/1.00
# Movie: Burning (2018), Similarity Rating: 0.08/1.00
# Movie: Venom (2018), Similarity Rating: 0.08/1.00
# Movie: The Fault in Our Stars (2014), Similarity Rating: 0.08/1.00
# Movie: The Hunt (2020), Similarity Rating: 0.08/1.00
# Movie: The Art of Self-Defense (2019), Similarity Rating: 0.08/1.00
# Movie: No Country for Old Men (2007), Similarity Rating: 0.08/1.00
# Movie: Gravity (2013), Similarity Rating: 0.08/1.00
# Movie: About Time (2013), Similarity Rating: 0.08/1.00
# Movie: Shang-Chi and the Legend of the Ten Rings (2021), Similarity Rating: 0.08/1.00
# Movie: Escape Room (2019), Similarity Rating: 0.08/1.00
# Movie: Thoroughbreds (2018), Similarity Rating: 0.08/1.00
# Movie: Another Round (2020), Similarity Rating: 0.08/1.00
# Movie: The Platform (2019), Similarity Rating: 0.08/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.08/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.08/1.00
# Movie: Pirates of the Caribbean: Dead Man's Chest (2006), Similarity Rating: 0.08/1.00
# Movie: The Hate U Give (2018), Similarity Rating: 0.08/1.00
# Movie: Hannah Gadsby: Nanette (2018), Similarity Rating: 0.08/1.00
# Movie: Kubo and the Two Strings (2016), Similarity Rating: 0.08/1.00
# Movie: Up (2009), Similarity Rating: 0.08/1.00
# Movie: Now You See Me 2 (2016), Similarity Rating: 0.08/1.00
# Movie: I, Robot (2004), Similarity Rating: 0.08/1.00
# Movie: The Witch (2015), Similarity Rating: 0.07/1.00
# Movie: The Square (2017), Similarity Rating: 0.07/1.00
# Movie: Pitch Perfect (2012), Similarity Rating: 0.07/1.00
# Movie: 10 Cloverfield Lane (2016), Similarity Rating: 0.07/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.07/1.00
# Movie: Terminal, The (2004), Similarity Rating: 0.07/1.00
# Movie: Mamma Mia! (2008), Similarity Rating: 0.07/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.07/1.00
# Movie: Men in Black (a.k.a. MIB) (1997), Similarity Rating: 0.07/1.00
# Movie: I Don't Feel at Home in This World Anymore (2017), Similarity Rating: 0.07/1.00
# Movie: Freaky (2020), Similarity Rating: 0.07/1.00
# Movie: Valerian and the City of a Thousand Planets (2017), Similarity Rating: 0.07/1.00
# Movie: Bird Box (2018), Similarity Rating: 0.07/1.00
# Movie: Great Gatsby, The (2013), Similarity Rating: 0.07/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.07/1.00
# Movie: Wonder (2017), Similarity Rating: 0.07/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.07/1.00
# Movie: The Death of Stalin (2017), Similarity Rating: 0.07/1.00
# Movie: Swiss Army Man (2016), Similarity Rating: 0.07/1.00
# Movie: Ford v. Ferrari (2019), Similarity Rating: 0.07/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.07/1.00
# Movie: Song of the Sea (2014), Similarity Rating: 0.07/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.07/1.00
# Movie: Blindspotting (2018), Similarity Rating: 0.07/1.00
# Movie: Act of Killing, The (2012), Similarity Rating: 0.07/1.00
# Movie: Juno (2007), Similarity Rating: 0.07/1.00
# Movie: Birds of Prey (And the Fantabulous Emancipation of One Harley Quinn) (2020), Similarity Rating: 0.07/1.00
# Movie: Chungking Express (Chung Hing sam lam) (1994), Similarity Rating: 0.07/1.00
# Movie: Luca (2021), Similarity Rating: 0.07/1.00
# Movie: Requiem for a Dream (2000), Similarity Rating: 0.07/1.00
# '\nmin_avg_rating=2.5\nuser_min_percentile=0.25\nuser_max_percentile=0.999\nmin_ratings_per_movie=3\nmax_users_per_movie=250\nuser_similarity_threshold=0.15\nfit: \nn_components=200,\nsample_size=1,\nmax_iter=800\n'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=voided_ratings,
    my_data=voided_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
"""jo men det gör dom, har typ alla förrutom guardians of the galaxy på min watchlist haha
och det stämmer att de jag redan hade sett som totoro hade jag inte rateat"""
# Out:
# You've rated 271 movies
# Found 13307 movies you haven't rated
#
# Top Recommendations:
# Movie: Matrix, The (1999), Similarity Rating: 0.39/1.00
# Movie: 2001: A Space Odyssey (1968), Similarity Rating: 0.38/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.36/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.34/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.33/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.31/1.00
# Movie: Dark Knight, The (2008), Similarity Rating: 0.31/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.30/1.00
# Movie: Inception (2010), Similarity Rating: 0.30/1.00
# Movie: Fargo (1996), Similarity Rating: 0.30/1.00
# Movie: My Neighbor Totoro (Tonari no Totoro) (1988), Similarity Rating: 0.29/1.00
# Movie: Blade Runner 2049 (2017), Similarity Rating: 0.28/1.00
# Movie: WALL·E (2008), Similarity Rating: 0.28/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.28/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.27/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.27/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.26/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.26/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.26/1.00
# Movie: Moon (2009), Similarity Rating: 0.26/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.26/1.00
# Movie: Monsters, Inc. (2001), Similarity Rating: 0.26/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.25/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.25/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.24/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.24/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.24/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.24/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.24/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.23/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.23/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.23/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.23/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.23/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.23/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.23/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.22/1.00
# Movie: The Hateful Eight (2015), Similarity Rating: 0.22/1.00
# Movie: Shrek (2001), Similarity Rating: 0.22/1.00
# Movie: The Favourite, Similarity Rating: 0.22/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.21/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.21/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.21/1.00
# Movie: Incredibles, The (2004), Similarity Rating: 0.21/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.21/1.00
# Movie: Gattaca (1997), Similarity Rating: 0.21/1.00
# Movie: Coco (2017), Similarity Rating: 0.21/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.21/1.00
# Movie: Boogie Nights (1997), Similarity Rating: 0.21/1.00
# Movie: Thing, The (1982), Similarity Rating: 0.21/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.21/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.21/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.20/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.20/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.20/1.00
# Movie: Run Lola Run (Lola rennt) (1998), Similarity Rating: 0.20/1.00
# Movie: Rear Window (1954), Similarity Rating: 0.20/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.20/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.20/1.00
# Movie: Sin City (2005), Similarity Rating: 0.20/1.00
# Movie: Rosemary's Baby (1968), Similarity Rating: 0.20/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.20/1.00
# Movie: Lock, Stock & Two Smoking Barrels (1998), Similarity Rating: 0.20/1.00
# Movie: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981), Similarity Rating: 0.20/1.00
# Movie: Psycho (1960), Similarity Rating: 0.19/1.00
# Movie: 28 Days Later (2002), Similarity Rating: 0.19/1.00
# Movie: Burn After Reading (2008), Similarity Rating: 0.19/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.19/1.00
# Movie: Vertigo (1958), Similarity Rating: 0.19/1.00
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.18/1.00
# Movie: Terminator 2: Judgment Day (1991), Similarity Rating: 0.18/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.18/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.18/1.00
# Movie: Climax (2018), Similarity Rating: 0.18/1.00
# Movie: Soul (2020), Similarity Rating: 0.18/1.00
# Movie: Beetlejuice (1988), Similarity Rating: 0.18/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.18/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.17/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.17/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.17/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.17/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.17/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.17/1.00
# Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Similarity Rating: 0.17/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.17/1.00
# Movie: Heat (1995), Similarity Rating: 0.17/1.00
# Movie: You Were Never Really Here (2017), Similarity Rating: 0.17/1.00
# Movie: Beautiful Mind, A (2001), Similarity Rating: 0.17/1.00
# Movie: It Follows (2014), Similarity Rating: 0.17/1.00
# Movie: Snowpiercer (2013), Similarity Rating: 0.17/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.17/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.17/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.17/1.00
# Movie: Room (2015), Similarity Rating: 0.17/1.00
# Movie: Mandy (2018), Similarity Rating: 0.17/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.17/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.16/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.16/1.00
# Movie: Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000), Similarity Rating: 0.16/1.00
# Movie: Clerks (1994), Similarity Rating: 0.16/1.00
# Movie: The House That Jack Built (2018), Similarity Rating: 0.16/1.00
# Movie: Office Space (1999), Similarity Rating: 0.16/1.00
# Movie: Watchmen (2009), Similarity Rating: 0.16/1.00
# Movie: Looper (2012), Similarity Rating: 0.16/1.00
# Movie: Casino (1995), Similarity Rating: 0.16/1.00
# Movie: Us (2019), Similarity Rating: 0.16/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.16/1.00
# Movie: Misery (1990), Similarity Rating: 0.16/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.16/1.00
# Movie: The Lego Movie (2014), Similarity Rating: 0.16/1.00
# Movie: Evil Dead, The (1981), Similarity Rating: 0.15/1.00
# Movie: Sound of Metal (2019), Similarity Rating: 0.15/1.00
# Movie: Seven Samurai (Shichinin no samurai) (1954), Similarity Rating: 0.15/1.00
# Movie: The Florida Project (2017), Similarity Rating: 0.15/1.00
# Movie: Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984), Similarity Rating: 0.15/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.15/1.00
# Movie: Pi (1998), Similarity Rating: 0.15/1.00
# Movie: Twin Peaks: Fire Walk with Me (1992), Similarity Rating: 0.15/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.15/1.00
# Movie: Moonlight, Similarity Rating: 0.15/1.00
# Movie: Bohemian Rhapsody (2018), Similarity Rating: 0.15/1.00
# Movie: Green Room (2015), Similarity Rating: 0.15/1.00
# Movie: The Martian (2015), Similarity Rating: 0.15/1.00
# Movie: Bronson (2009), Similarity Rating: 0.15/1.00
# Movie: Upgrade (2018), Similarity Rating: 0.15/1.00
# Movie: La La Land (2016), Similarity Rating: 0.15/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.14/1.00
# Movie: Shrek 2 (2004), Similarity Rating: 0.14/1.00
# Movie: Ghostbusters (a.k.a. Ghost Busters) (1984), Similarity Rating: 0.14/1.00
# Movie: Punch-Drunk Love (2002), Similarity Rating: 0.14/1.00
# Movie: Synecdoche, New York (2008), Similarity Rating: 0.14/1.00
# Movie: Tenet (2020), Similarity Rating: 0.14/1.00
# Movie: Suspiria (1977), Similarity Rating: 0.14/1.00
# Movie: Logan (2017), Similarity Rating: 0.14/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.14/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.14/1.00
# Movie: Promising Young Woman (2020), Similarity Rating: 0.14/1.00
# Movie: Lost Highway (1997), Similarity Rating: 0.14/1.00
# Movie: Minority Report (2002), Similarity Rating: 0.14/1.00
# Movie: Moana (2016), Similarity Rating: 0.14/1.00
# Movie: The Irishman (2019), Similarity Rating: 0.14/1.00
# Movie: Indiana Jones and the Last Crusade (1989), Similarity Rating: 0.14/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.14/1.00
# Movie: Videodrome (1983), Similarity Rating: 0.14/1.00
# Movie: Over the Garden Wall (2013), Similarity Rating: 0.14/1.00
# Movie: Sorry to Bother You (2018), Similarity Rating: 0.14/1.00
# Movie: Perfect Blue (1997), Similarity Rating: 0.14/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.14/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.14/1.00
# Movie: Eastern Promises (2007), Similarity Rating: 0.14/1.00
# Movie: Magnolia (1999), Similarity Rating: 0.14/1.00
# Movie: Chinatown (1974), Similarity Rating: 0.13/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.13/1.00
# Movie: Girl with the Dragon Tattoo, The (2011), Similarity Rating: 0.13/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.13/1.00
# Movie: Avatar (2009), Similarity Rating: 0.13/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.13/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.13/1.00
# Movie: Toy Story 3 (2010), Similarity Rating: 0.13/1.00
# Movie: Sicario (2015), Similarity Rating: 0.13/1.00
# Movie: Raging Bull (1980), Similarity Rating: 0.13/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.13/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.13/1.00
# Movie: Lives of Others, The (Das leben der Anderen) (2006), Similarity Rating: 0.13/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.13/1.00
# Movie: Serious Man, A (2009), Similarity Rating: 0.13/1.00
# Movie: Source Code (2011), Similarity Rating: 0.13/1.00
# Movie: Life Is Beautiful (La Vita è bella) (1997), Similarity Rating: 0.13/1.00
# Movie: Roma (2018), Similarity Rating: 0.13/1.00
# Movie: True Grit (2010), Similarity Rating: 0.13/1.00
# Movie: Halloween (1978), Similarity Rating: 0.13/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.13/1.00
# Movie: Last Night in Soho (2021), Similarity Rating: 0.12/1.00
# Movie: Unbreakable (2000), Similarity Rating: 0.12/1.00
# Movie: Close Encounters of the Third Kind (1977), Similarity Rating: 0.12/1.00
# Movie: Contact (1997), Similarity Rating: 0.12/1.00
# Movie: Slumdog Millionaire (2008), Similarity Rating: 0.12/1.00
# Movie: Others, The (2001), Similarity Rating: 0.12/1.00
# Movie: Frozen (2013), Similarity Rating: 0.12/1.00
# Movie: Downfall (Untergang, Der) (2004), Similarity Rating: 0.12/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.12/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.12/1.00
# Movie: Rocky (1976), Similarity Rating: 0.12/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.12/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.12/1.00
# Movie: Sexy Beast (2000), Similarity Rating: 0.12/1.00
# Movie: Barton Fink (1991), Similarity Rating: 0.12/1.00
# Movie: Coherence (2013), Similarity Rating: 0.12/1.00
# Movie: Paprika (Papurika) (2006), Similarity Rating: 0.12/1.00
# Movie: Gran Torino (2008), Similarity Rating: 0.12/1.00
# Movie: Last Samurai, The (2003), Similarity Rating: 0.12/1.00
# Movie: Napoleon Dynamite (2004), Similarity Rating: 0.12/1.00
# Movie: Blues Brothers, The (1980), Similarity Rating: 0.12/1.00
# Movie: Yojimbo (1961), Similarity Rating: 0.12/1.00
# Movie: Collateral (2004), Similarity Rating: 0.12/1.00
# Movie: Juno (2007), Similarity Rating: 0.12/1.00
# Movie: Lord of War (2005), Similarity Rating: 0.12/1.00
# Movie: It (2017), Similarity Rating: 0.12/1.00
# Movie: Graduate, The (1967), Similarity Rating: 0.12/1.00
# Movie: Iron Giant, The (1999), Similarity Rating: 0.12/1.00
# 'jo men det gör dom, har typ alla förrutom guardians of the galaxy på min watchlist haha\noch det stämmer att de jag redan hade sett som totoro hade jag inte rateat'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=zorrodor_ratings,
    my_data=zorrodor_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)

# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
# zorro:
# "Dom första 20 är alla bra filmer"
# "Eller de e nästan bara grejer jag gillar"
# "Några luriga dock men de mesta e gött"
# "Jag har rateat ganska lite också"
# "Så den har inte sååå mkt att gå på"
# Out:
# You've rated 45 movies
# Found 13532 movies you haven't rated
#
# Top Recommendations:
# Movie: Parasite (2019), Similarity Rating: 0.08/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.06/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.06/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.06/1.00
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.05/1.00
# Movie: Three Colors: Blue (Trois couleurs: Bleu) (1993), Similarity Rating: 0.05/1.00
# Movie: Stalker (1979), Similarity Rating: 0.05/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.05/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.05/1.00
# Movie: 2001: A Space Odyssey (1968), Similarity Rating: 0.05/1.00
# Movie: Get Out (2017), Similarity Rating: 0.05/1.00
# Movie: Mirror, The (Zerkalo) (1975), Similarity Rating: 0.05/1.00
# Movie: Taxi Driver (1976), Similarity Rating: 0.04/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.04/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.04/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.04/1.00
# Movie: Her (2013), Similarity Rating: 0.04/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.04/1.00
# Movie: Children of Men (2006), Similarity Rating: 0.04/1.00
# Movie: La La Land (2016), Similarity Rating: 0.04/1.00
# Movie: Seventh Seal, The (Sjunde inseglet, Det) (1957), Similarity Rating: 0.04/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.04/1.00
# Movie: Before Sunrise (1995), Similarity Rating: 0.04/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.04/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.04/1.00
# Movie: Requiem for a Dream (2000), Similarity Rating: 0.04/1.00
# Movie: Solaris (Solyaris) (1972), Similarity Rating: 0.04/1.00
# Movie: Persona (1966), Similarity Rating: 0.04/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.04/1.00
# Movie: Hunt, The (Jagten) (2012), Similarity Rating: 0.04/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.04/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.04/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.04/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.04/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.04/1.00
# Movie: Little Miss Sunshine (2006), Similarity Rating: 0.04/1.00
# Movie: Wild Strawberries (Smultronstället) (1957), Similarity Rating: 0.04/1.00
# Movie: Fargo (1996), Similarity Rating: 0.04/1.00
# Movie: Memento (2000), Similarity Rating: 0.04/1.00
# Movie: 8 1/2 (8½) (1963), Similarity Rating: 0.04/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.04/1.00
# Movie: Three Colors: White (Trzy kolory: Bialy) (1994), Similarity Rating: 0.04/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.04/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.04/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.04/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.04/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.04/1.00
# Movie: Room (2015), Similarity Rating: 0.04/1.00
# Movie: BlacKkKlansman (2018), Similarity Rating: 0.04/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.04/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.04/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.04/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.04/1.00
# Movie: Coco (2017), Similarity Rating: 0.04/1.00
# Movie: Metropolis (1927), Similarity Rating: 0.04/1.00
# Movie: Knives Out (2019), Similarity Rating: 0.04/1.00
# Movie: Amour (2012), Similarity Rating: 0.04/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.04/1.00
# Movie: Rashomon (Rashômon) (1950), Similarity Rating: 0.03/1.00
# Movie: Apocalypse Now (1979), Similarity Rating: 0.03/1.00
# Movie: Act of Killing, The (2012), Similarity Rating: 0.03/1.00
# Movie: Eraserhead (1977), Similarity Rating: 0.03/1.00
# Movie: Discreet Charm of the Bourgeoisie, The (Charme discret de la bourgeoisie, Le) (1972), Similarity Rating: 0.03/1.00
# Movie: Dolce Vita, La (1960), Similarity Rating: 0.03/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.03/1.00
# Movie: Avventura, L' (Adventure, The) (1960), Similarity Rating: 0.03/1.00
# Movie: Little Women (2019), Similarity Rating: 0.03/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.03/1.00
# Movie: Breathless (À bout de souffle) (1960), Similarity Rating: 0.03/1.00
# Movie: The Favourite, Similarity Rating: 0.03/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.03/1.00
# Movie: Inception (2010), Similarity Rating: 0.03/1.00
# Movie: Lives of Others, The (Das leben der Anderen) (2006), Similarity Rating: 0.03/1.00
# Movie: Sacrifice, The (Offret - Sacraficatio) (1986), Similarity Rating: 0.03/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.03/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.03/1.00
# Movie: Jules and Jim (Jules et Jim) (1961), Similarity Rating: 0.03/1.00
# Movie: Night on Earth (1991), Similarity Rating: 0.03/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.03/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.03/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.03/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.03/1.00
# Movie: Melancholia (2011), Similarity Rating: 0.03/1.00
# Movie: Andrei Rublev (Andrey Rublyov) (1969), Similarity Rating: 0.03/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.03/1.00
# Movie: Moon (2009), Similarity Rating: 0.03/1.00
# Movie: Joker (2019), Similarity Rating: 0.03/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.03/1.00
# Movie: Before Midnight (2013), Similarity Rating: 0.03/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.03/1.00
# Movie: Lord of the Rings: The Fellowship of the Ring, The (2001), Similarity Rating: 0.03/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.03/1.00
# Movie: Passion of Joan of Arc, The (Passion de Jeanne d'Arc, La) (1928), Similarity Rating: 0.03/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.03/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.03/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.03/1.00
# Movie: Aguirre: The Wrath of God (Aguirre, der Zorn Gottes) (1972), Similarity Rating: 0.03/1.00
# Movie: Burning (2018), Similarity Rating: 0.03/1.00
# Movie: Juno (2007), Similarity Rating: 0.03/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.03/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.03/1.00
# Movie: Sunset Blvd. (a.k.a. Sunset Boulevard) (1950), Similarity Rating: 0.03/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.03/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.03/1.00
# Movie: Lost Highway (1997), Similarity Rating: 0.03/1.00
# Movie: Ghost World (2001), Similarity Rating: 0.03/1.00
# Movie: Citizen Kane (1941), Similarity Rating: 0.03/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.03/1.00
# Movie: Broken Flowers (2005), Similarity Rating: 0.03/1.00
# Movie: No Country for Old Men (2007), Similarity Rating: 0.03/1.00
# Movie: Dogville (2003), Similarity Rating: 0.03/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.03/1.00
# Movie: WALL·E (2008), Similarity Rating: 0.03/1.00
# Movie: Lord of the Rings: The Two Towers, The (2002), Similarity Rating: 0.03/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.03/1.00
# Movie: Amadeus (1984), Similarity Rating: 0.03/1.00
# Movie: Fallen Angels (Duo luo tian shi) (1995), Similarity Rating: 0.03/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.03/1.00
# Movie: Ran (1985), Similarity Rating: 0.03/1.00
# Movie: Pierrot le fou (1965), Similarity Rating: 0.03/1.00
# Movie: Dark Knight, The (2008), Similarity Rating: 0.03/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.03/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.03/1.00
# Movie: Exterminating Angel, The (Ángel exterminador, El) (1962), Similarity Rating: 0.03/1.00
# Movie: Piano Teacher, The (La pianiste) (2001), Similarity Rating: 0.03/1.00
# Movie: White Ribbon, The (Das weiße Band) (2009), Similarity Rating: 0.03/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.03/1.00
# Movie: Blade Runner 2049 (2017), Similarity Rating: 0.03/1.00
# Movie: Vertigo (1958), Similarity Rating: 0.03/1.00
# Movie: Cleo from 5 to 7 (Cléo de 5 à 7) (1962), Similarity Rating: 0.03/1.00
# Movie: Monty Python's Life of Brian (1979), Similarity Rating: 0.03/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.03/1.00
# Movie: Monsters, Inc. (2001), Similarity Rating: 0.03/1.00
# Movie: Everything Everywhere All at Once (2022), Similarity Rating: 0.03/1.00
# Movie: Lord of the Rings: The Return of the King, The (2003), Similarity Rating: 0.03/1.00
# Movie: Beauty of the Day (Belle de jour) (1967), Similarity Rating: 0.03/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.03/1.00
# Movie: Jurassic Park (1993), Similarity Rating: 0.03/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.03/1.00
# Movie: Au Hasard Balthazar (1966), Similarity Rating: 0.03/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.03/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.03/1.00
# Movie: Paris, Texas (1984), Similarity Rating: 0.03/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.03/1.00
# Movie: Snowpiercer (2013), Similarity Rating: 0.03/1.00
# Movie: Double Life of Veronique, The (Double Vie de Véronique, La) (1991), Similarity Rating: 0.03/1.00
# Movie: Exotica (1994), Similarity Rating: 0.03/1.00
# Movie: Kill Bill: Vol. 1 (2003), Similarity Rating: 0.03/1.00
# Movie: Silence of the Lambs, The (1991), Similarity Rating: 0.03/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.03/1.00
# Movie: American Psycho (2000), Similarity Rating: 0.03/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.03/1.00
# Movie: Seven Samurai (Shichinin no samurai) (1954), Similarity Rating: 0.03/1.00
# Movie: 2046 (2004), Similarity Rating: 0.03/1.00
# Movie: Midsommar (2019), Similarity Rating: 0.03/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.03/1.00
# Movie: Mulholland Dr. (1999), Similarity Rating: 0.03/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.03/1.00
# Movie: Harold and Maude (1971), Similarity Rating: 0.03/1.00
# Movie: Ghost in the Shell (Kôkaku kidôtai) (1995), Similarity Rating: 0.03/1.00
# Movie: Inland Empire (2006), Similarity Rating: 0.03/1.00
# Movie: Rosemary's Baby (1968), Similarity Rating: 0.02/1.00
# Movie: Old Boy (2003), Similarity Rating: 0.02/1.00
# Movie: Seven (a.k.a. Se7en) (1995), Similarity Rating: 0.02/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.02/1.00
# Movie: Aliens (1986), Similarity Rating: 0.02/1.00
# Movie: Soul (2020), Similarity Rating: 0.02/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.02/1.00
# Movie: Pi (1998), Similarity Rating: 0.02/1.00
# Movie: Phantom of Liberty, The (Fantôme de la liberté, Le) (1974), Similarity Rating: 0.02/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.02/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.02/1.00
# Movie: 12 Angry Men (1957), Similarity Rating: 0.02/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.02/1.00
# Movie: Frances Ha (2012), Similarity Rating: 0.02/1.00
# Movie: Girl Walks Home Alone at Night, A (2014), Similarity Rating: 0.02/1.00
# Movie: My Neighbor Totoro (Tonari no Totoro) (1988), Similarity Rating: 0.02/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.02/1.00
# Movie: Over the Garden Wall (2013), Similarity Rating: 0.02/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.02/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.02/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.02/1.00
# Movie: Spring, Summer, Fall, Winter... and Spring (Bom yeoreum gaeul gyeoul geurigo bom) (2003), Similarity Rating: 0.02/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.02/1.00
# Movie: Forrest Gump (1994), Similarity Rating: 0.02/1.00
# Movie: Life Aquatic with Steve Zissou, The (2004), Similarity Rating: 0.02/1.00
# Movie: Night, The (Notte, La) (1960), Similarity Rating: 0.02/1.00
# Movie: Vivre sa vie: Film en douze tableaux (My Life to Live) (1962), Similarity Rating: 0.02/1.00
# Movie: Hidden (a.k.a. Cache) (Caché) (2005), Similarity Rating: 0.02/1.00
# Movie: Rules of the Game, The (La règle du jeu) (1939), Similarity Rating: 0.02/1.00
# Movie: Fanny and Alexander (Fanny och Alexander) (1982), Similarity Rating: 0.02/1.00
# Movie: Come and See (Idi i smotri) (1985), Similarity Rating: 0.02/1.00
# Movie: Alphaville (Alphaville, une étrange aventure de Lemmy Caution) (1965), Similarity Rating: 0.02/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.02/1.00
# Movie: Days of Heaven (1978), Similarity Rating: 0.02/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.02/1.00
# Movie: Sorry to Bother You (2018), Similarity Rating: 0.02/1.00
# Movie: All About My Mother (Todo sobre mi madre) (1999), Similarity Rating: 0.02/1.00
# Movie: The Witch (2015), Similarity Rating: 0.02/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.02/1.00
# '\nmin_avg_rating=2.5\nuser_min_percentile=0.25\nuser_max_percentile=0.999\nmin_ratings_per_movie=3\nmax_users_per_movie=250\nuser_similarity_threshold=0.15\nfit: \nn_components=200,\nsample_size=1,\nmax_iter=800\n'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=liv_ratings,
    my_data=liv_data,
    n_recommendations=100,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 106 movies
# Found 13474 movies you haven't rated
#
# Top Recommendations:
# Movie: Parasite (2019), Similarity Rating: 0.18/1.00
# Movie: Spirited Away (Sen to Chihiro no kamikakushi) (2001), Similarity Rating: 0.16/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.13/1.00
# Movie: The Favourite, Similarity Rating: 0.13/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.13/1.00
# Movie: Get Out (2017), Similarity Rating: 0.13/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.13/1.00
# Movie: Arrival (2016), Similarity Rating: 0.12/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.12/1.00
# Movie: Her (2013), Similarity Rating: 0.12/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.12/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.12/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.12/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.11/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.11/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.11/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.10/1.00
# Movie: Knives Out (2019), Similarity Rating: 0.10/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.10/1.00
# Movie: Love Actually (2003), Similarity Rating: 0.10/1.00
# Movie: Requiem for a Dream (2000), Similarity Rating: 0.10/1.00
# Movie: Moonlight, Similarity Rating: 0.10/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.10/1.00
# Movie: Coco (2017), Similarity Rating: 0.10/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.10/1.00
# Movie: Inception (2010), Similarity Rating: 0.10/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.10/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.10/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.10/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.09/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.09/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.09/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.09/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.09/1.00
# Movie: Trainspotting (1996), Similarity Rating: 0.09/1.00
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.09/1.00
# Movie: Room (2015), Similarity Rating: 0.09/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.09/1.00
# Movie: Titanic (1997), Similarity Rating: 0.09/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.09/1.00
# Movie: Slumdog Millionaire (2008), Similarity Rating: 0.09/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.09/1.00
# Movie: Notebook, The (2004), Similarity Rating: 0.09/1.00
# Movie: Silence of the Lambs, The (1991), Similarity Rating: 0.09/1.00
# Movie: Nightmare Before Christmas, The (1993), Similarity Rating: 0.09/1.00
# Movie: Atonement (2007), Similarity Rating: 0.09/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.09/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.09/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.08/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.08/1.00
# Movie: Pride & Prejudice (2005), Similarity Rating: 0.08/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.08/1.00
# Movie: Intouchables (2011), Similarity Rating: 0.08/1.00
# Movie: Memento (2000), Similarity Rating: 0.08/1.00
# Movie: Before Sunset (2004), Similarity Rating: 0.08/1.00
# Movie: Mean Girls (2004), Similarity Rating: 0.08/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.08/1.00
# Movie: Blue Is the Warmest Color (La vie d'Adèle) (2013), Similarity Rating: 0.08/1.00
# Movie: Seven (a.k.a. Se7en) (1995), Similarity Rating: 0.08/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.08/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.08/1.00
# Movie: No Country for Old Men (2007), Similarity Rating: 0.08/1.00
# Movie: Bridget Jones's Diary (2001), Similarity Rating: 0.08/1.00
# Movie: Billy Elliot (2000), Similarity Rating: 0.08/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.07/1.00
# Movie: Once Upon a Time in Hollywood (2019), Similarity Rating: 0.07/1.00
# Movie: Hunt, The (Jagten) (2012), Similarity Rating: 0.07/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.07/1.00
# Movie: About Time (2013), Similarity Rating: 0.07/1.00
# Movie: Forrest Gump (1994), Similarity Rating: 0.07/1.00
# Movie: Sweeney Todd: The Demon Barber of Fleet Street (2007), Similarity Rating: 0.07/1.00
# Movie: Annie Hall (1977), Similarity Rating: 0.07/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.07/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.07/1.00
# Movie: Mamma Mia! (2008), Similarity Rating: 0.07/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.07/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.07/1.00
# Movie: Changeling (2008), Similarity Rating: 0.07/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.07/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.07/1.00
# Movie: Dogville (2003), Similarity Rating: 0.07/1.00
# Movie: Legally Blonde (2001), Similarity Rating: 0.07/1.00
# Movie: Midsommar (2019), Similarity Rating: 0.07/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.07/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.07/1.00
# Movie: The Florida Project (2017), Similarity Rating: 0.07/1.00
# Movie: Django Unchained (2012), Similarity Rating: 0.07/1.00
# Movie: Life Is Beautiful (La Vita è bella) (1997), Similarity Rating: 0.07/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.07/1.00
# Movie: Minari (2020), Similarity Rating: 0.07/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.07/1.00
# Movie: Superbad (2007), Similarity Rating: 0.07/1.00
# Movie: Run Lola Run (Lola rennt) (1998), Similarity Rating: 0.07/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.07/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.07/1.00
# Movie: Truman Show, The (1998), Similarity Rating: 0.07/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.07/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.07/1.00
# Movie: Shrek (2001), Similarity Rating: 0.07/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.06/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=skellic_ratings,
    my_data=skellic_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 338 movies
# Found 13244 movies you haven't rated
#
# Top Recommendations:
# Movie: Shining, The (1980), Similarity Rating: 0.41/1.00
# Movie: Inception (2010), Similarity Rating: 0.38/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.37/1.00
# Movie: Coco (2017), Similarity Rating: 0.36/1.00
# Movie: Memento (2000), Similarity Rating: 0.36/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.35/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.34/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.34/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.34/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.34/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.33/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.33/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.33/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.32/1.00
# Movie: Moon (2009), Similarity Rating: 0.30/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.29/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.28/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.27/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.27/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.26/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.26/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.26/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.26/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.26/1.00
# Movie: Die Hard (1988), Similarity Rating: 0.25/1.00
# Movie: Fargo (1996), Similarity Rating: 0.25/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.25/1.00
# Movie: Moana (2016), Similarity Rating: 0.25/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.25/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.25/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.25/1.00
# Movie: Trainspotting (1996), Similarity Rating: 0.25/1.00
# Movie: Thing, The (1982), Similarity Rating: 0.25/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.25/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.25/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.24/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.24/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.24/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.23/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.23/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.23/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.23/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.23/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.23/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.23/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.23/1.00
# Movie: Room (2015), Similarity Rating: 0.23/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.23/1.00
# Movie: Prestige, The (2006), Similarity Rating: 0.23/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.23/1.00
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.23/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.22/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.22/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.22/1.00
# Movie: 28 Days Later (2002), Similarity Rating: 0.22/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.21/1.00
# Movie: Lion King, The (1994), Similarity Rating: 0.21/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.21/1.00
# Movie: Us (2019), Similarity Rating: 0.21/1.00
# Movie: Heat (1995), Similarity Rating: 0.21/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.21/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.21/1.00
# Movie: Logan (2017), Similarity Rating: 0.21/1.00
# Movie: Brazil (1985), Similarity Rating: 0.21/1.00
# Movie: Moonlight, Similarity Rating: 0.21/1.00
# Movie: Minority Report (2002), Similarity Rating: 0.21/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.20/1.00
# Movie: Akira (1988), Similarity Rating: 0.20/1.00
# Movie: Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966), Similarity Rating: 0.20/1.00
# Movie: Paprika (Papurika) (2006), Similarity Rating: 0.20/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.20/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.20/1.00
# Movie: Sin City (2005), Similarity Rating: 0.20/1.00
# Movie: Vertigo (1958), Similarity Rating: 0.20/1.00
# Movie: The Martian (2015), Similarity Rating: 0.20/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.20/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.20/1.00
# Movie: Gladiator (2000), Similarity Rating: 0.19/1.00
# Movie: Gattaca (1997), Similarity Rating: 0.19/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.19/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.19/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.19/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.19/1.00
# Movie: Looper (2012), Similarity Rating: 0.19/1.00
# Movie: Frozen (2013), Similarity Rating: 0.19/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.19/1.00
# Movie: Wreck-It Ralph (2012), Similarity Rating: 0.18/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.18/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.18/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.18/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.18/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.18/1.00
# Movie: Ford v. Ferrari (2019), Similarity Rating: 0.18/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.18/1.00
# Movie: Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000), Similarity Rating: 0.18/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.18/1.00
# Movie: Run Lola Run (Lola rennt) (1998), Similarity Rating: 0.18/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.18/1.00
# Movie: Upgrade (2018), Similarity Rating: 0.18/1.00
# Movie: Lives of Others, The (Das leben der Anderen) (2006), Similarity Rating: 0.18/1.00
# Movie: Coherence (2013), Similarity Rating: 0.18/1.00
# Movie: Rosemary's Baby (1968), Similarity Rating: 0.18/1.00
# Movie: Monty Python's Life of Brian (1979), Similarity Rating: 0.18/1.00
# Movie: Brave (2012), Similarity Rating: 0.18/1.00
# Movie: Green Room (2015), Similarity Rating: 0.17/1.00
# Movie: Toy Story 2 (1999), Similarity Rating: 0.17/1.00
# Movie: The Lego Movie (2014), Similarity Rating: 0.17/1.00
# Movie: Split (2017), Similarity Rating: 0.17/1.00
# Movie: Bohemian Rhapsody (2018), Similarity Rating: 0.17/1.00
# Movie: Avatar (2009), Similarity Rating: 0.17/1.00
# Movie: Social Network, The (2010), Similarity Rating: 0.17/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.17/1.00
# Movie: Mandy (2018), Similarity Rating: 0.17/1.00
# Movie: Ip Man (2008), Similarity Rating: 0.17/1.00
# Movie: Psycho (1960), Similarity Rating: 0.17/1.00
# Movie: Toy Story 3 (2010), Similarity Rating: 0.17/1.00
# Movie: Sound of Metal (2019), Similarity Rating: 0.17/1.00
# Movie: Little Women (2019), Similarity Rating: 0.17/1.00
# Movie: Mean Girls (2004), Similarity Rating: 0.17/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.17/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.17/1.00
# Movie: Hidden Figures (2016), Similarity Rating: 0.17/1.00
# Movie: Kung Fu Hustle (Gong fu) (2004), Similarity Rating: 0.17/1.00
# Movie: It (2017), Similarity Rating: 0.17/1.00
# Movie: The House That Jack Built (2018), Similarity Rating: 0.16/1.00
# Movie: Incredibles 2 (2018), Similarity Rating: 0.16/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.16/1.00
# Movie: Downfall (Untergang, Der) (2004), Similarity Rating: 0.16/1.00
# Movie: Men in Black (a.k.a. MIB) (1997), Similarity Rating: 0.16/1.00
# Movie: Beetlejuice (1988), Similarity Rating: 0.16/1.00
# Movie: The Raid: Redemption (2011), Similarity Rating: 0.16/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.16/1.00
# Movie: The Florida Project (2017), Similarity Rating: 0.16/1.00
# Movie: Dunkirk (2017), Similarity Rating: 0.16/1.00
# Movie: Office Space (1999), Similarity Rating: 0.16/1.00
# Movie: Halloween (1978), Similarity Rating: 0.16/1.00
# Movie: Edge of Tomorrow (2014), Similarity Rating: 0.16/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.16/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.15/1.00
# Movie: 300 (2007), Similarity Rating: 0.15/1.00
# Movie: Videodrome (1983), Similarity Rating: 0.15/1.00
# Movie: Roma (2018), Similarity Rating: 0.15/1.00
# Movie: Rear Window (1954), Similarity Rating: 0.15/1.00
# Movie: Pitch Perfect (2012), Similarity Rating: 0.15/1.00
# Movie: Casino Royale (2006), Similarity Rating: 0.15/1.00
# Movie: The Machinist (2004), Similarity Rating: 0.15/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.15/1.00
# Movie: Skin I Live In, The (La piel que habito) (2011), Similarity Rating: 0.15/1.00
# Movie: Source Code (2011), Similarity Rating: 0.15/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.15/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.15/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.15/1.00
# Movie: Over the Garden Wall (2013), Similarity Rating: 0.15/1.00
# Movie: First Blood (Rambo: First Blood) (1982), Similarity Rating: 0.15/1.00
# Movie: Ghostbusters (a.k.a. Ghost Busters) (1984), Similarity Rating: 0.15/1.00
# Movie: The Death of Stalin (2017), Similarity Rating: 0.15/1.00
# Movie: Pacific Rim (2013), Similarity Rating: 0.15/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.15/1.00
# Movie: Bronson (2009), Similarity Rating: 0.15/1.00
# Movie: Gravity (2013), Similarity Rating: 0.15/1.00
# Movie: Boogie Nights (1997), Similarity Rating: 0.15/1.00
# Movie: Song of the Sea (2014), Similarity Rating: 0.15/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.15/1.00
# Movie: Clerks (1994), Similarity Rating: 0.15/1.00
# Movie: Wonder Woman (2017), Similarity Rating: 0.14/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.14/1.00
# Movie: Minari (2020), Similarity Rating: 0.14/1.00
# Movie: Legally Blonde (2001), Similarity Rating: 0.14/1.00
# Movie: Cars (2006), Similarity Rating: 0.14/1.00
# Movie: Airplane! (1980), Similarity Rating: 0.14/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.14/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.14/1.00
# Movie: Girl with the Dragon Tattoo, The (2011), Similarity Rating: 0.14/1.00
# Movie: Chinatown (1974), Similarity Rating: 0.14/1.00
# Movie: It Follows (2014), Similarity Rating: 0.14/1.00
# Movie: I Saw the Devil (Akmareul boatda) (2010), Similarity Rating: 0.14/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.14/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.14/1.00
# Movie: Nope (2022), Similarity Rating: 0.14/1.00
# Movie: Finding Dory (2016), Similarity Rating: 0.14/1.00
# Movie: Simpsons Movie, The (2007), Similarity Rating: 0.14/1.00
# Movie: Luca (2021), Similarity Rating: 0.14/1.00
# Movie: Misery (1990), Similarity Rating: 0.14/1.00
# Movie: Princess and the Frog, The (2009), Similarity Rating: 0.14/1.00
# Movie: Ready Player One, Similarity Rating: 0.14/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.14/1.00
# Movie: Tenet (2020), Similarity Rating: 0.14/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.14/1.00
# Movie: Aguirre: The Wrath of God (Aguirre, der Zorn Gottes) (1972), Similarity Rating: 0.14/1.00
# Movie: After Hours (1985), Similarity Rating: 0.13/1.00
# Movie: Doctor Sleep (2019), Similarity Rating: 0.13/1.00
# Movie: True Grit (2010), Similarity Rating: 0.13/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.13/1.00
# Movie: Skyfall (2012), Similarity Rating: 0.13/1.00
# Movie: Burn After Reading (2008), Similarity Rating: 0.13/1.00
# Movie: Life Is Beautiful (La Vita è bella) (1997), Similarity Rating: 0.13/1.00
# Movie: Breakfast Club, The (1985), Similarity Rating: 0.13/1.00
# Movie: Casablanca (1942), Similarity Rating: 0.13/1.00
# Movie: End of Watch (2012), Similarity Rating: 0.13/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.13/1.00
