# %%
import pandas as pd
from sklearn.decomposition import NMF
import numpy as np
import time
from sklearn.preprocessing import MinMaxScaler

# %%
ratings= pd.read_csv('./data/ratings.csv')
movies = pd.read_csv('./data/movies.csv')
movie_id_to_title = dict(zip(movies['movieId'], movies['title']))

# %%
def filter_by_average_rating(movies_df, ratings_df, min_rating=0):
    print(f"Filtering movies with average rating >= {min_rating}...")
    
    movies_with_ratings = pd.merge(movies_df, ratings_df, on='movieId', how='inner')
    
    average_ratings = movies_with_ratings.groupby('movieId')['rating'].mean()
    
    popular_movies = average_ratings[average_ratings >= min_rating].index
    
    filtered_movies_with_ratings = movies_with_ratings[movies_with_ratings['movieId'].isin(popular_movies)]
    
    print(f"Kept {len(popular_movies)} movies with average rating >= {min_rating}")
    
    return filtered_movies_with_ratings

# %%
def filter_users_by_activity(ratings_df, min_percentile, max_percentile):

    print(f"Filtering users with activity between {min_percentile*100:.0f}th and {max_percentile*100:.0f}th percentiles...")
    
    # Count ratings per user
    user_rating_counts = ratings_df.groupby('userId')['rating'].count()
    print(f"Before filtering: {len(user_rating_counts)} users with rating statistics:")
    print(user_rating_counts.describe())
    
    # Get percentile thresholds
    min_threshold = user_rating_counts.quantile(min_percentile)
    max_threshold = user_rating_counts.quantile(max_percentile)
    
    # Filter users
    filtered_users = user_rating_counts[(user_rating_counts >= min_threshold) & 
                                       (user_rating_counts <= max_threshold)].index
    
    filtered_ratings = ratings_df[ratings_df['userId'].isin(filtered_users)]
    
    # Get statistics after filtering
    user_rating_counts_after = filtered_ratings.groupby('userId')['rating'].count()
    print(f"After filtering: {len(user_rating_counts_after)} users with rating statistics:")
    print(user_rating_counts_after.describe())
    
    return filtered_ratings

# %%
def filter_movies_by_popularity(ratings_df, min_ratings):

    print(f"Filtering movies with at least {min_ratings} ratings...")
    
    # Count ratings per movie
    movie_rating_counts = ratings_df.groupby('movieId').size()
    
    print(f"Before filtering: {len(movie_rating_counts)} movies")
    print(f"Movies with <{min_ratings} ratings: {(movie_rating_counts < min_ratings).sum()}")
    
    # Filter movies with sufficient ratings
    popular_movies = movie_rating_counts[movie_rating_counts >= min_ratings].index
    
    filtered_ratings = ratings_df[ratings_df['movieId'].isin(popular_movies)]
    
    print(f"After filtering: {len(popular_movies)} movies kept")
    
    return filtered_ratings

# %%
def select_diverse_users(ratings_df, max_users_per_movie=1000, similarity_threshold=0.3):

    print(f"Selecting diverse users with max {max_users_per_movie} users per movie...")
    

    # Get initial statistics
    total_users = ratings_df['userId'].nunique()
    total_movies = ratings_df['movieId'].nunique()
    total_ratings = len(ratings_df)
    
    print(f"Initial dataset: {total_ratings} ratings from {total_users} users on {total_movies} movies")
    
    # Create a movie-to-users dictionary to track how many users rated each movie
    movie_to_users = {}
    for movie_id, group in ratings_df.groupby('movieId'):
        movie_to_users[movie_id] = set(group['userId'])
    
    # Create a user-to-movies dictionary
    user_to_movies = {}
    for user_id, group in ratings_df.groupby('userId'):
        user_to_movies[user_id] = set(group['movieId'])
    
    # Sort users by the number of ratings (to prioritize users with fewer ratings)
    user_rating_counts = ratings_df.groupby('userId').size()
    sorted_users = user_rating_counts.sort_values().index.tolist()
    
    # Shuffle the users to avoid bias toward specific user IDs
    np.random.shuffle(sorted_users)
    
    selected_users = set()
    movie_user_counts = {movie_id: 0 for movie_id in movie_to_users.keys()}
    
    # Process users in the sorted order
    for user_id in sorted_users:
        user_movies = user_to_movies[user_id]
        
        # Check if this user would exceed the max users for any movie
        exceeds_limit = False
        for movie_id in user_movies:
            if movie_user_counts[movie_id] >= max_users_per_movie:
                exceeds_limit = True
                break
        
        # Check similarity with already selected users
        too_similar = False
        if not exceeds_limit:
            for selected_user in selected_users:
                selected_user_movies = user_to_movies[selected_user]
                
                # Calculate Jaccard similarity between users
                intersection = len(user_movies.intersection(selected_user_movies))
                union = len(user_movies.union(selected_user_movies))
                
                if union > 0:
                    similarity = intersection / union
                    if similarity > similarity_threshold:
                        too_similar = True
                        break
        
        # Add user if they don't exceed limits and aren't too similar
        if not exceeds_limit and not too_similar:
            selected_users.add(user_id)
            
            # Update movie user counts
            for movie_id in user_movies:
                movie_user_counts[movie_id] += 1
    
    # Filter the ratings DataFrame to only include selected users
    filtered_ratings = ratings_df[ratings_df['userId'].isin(selected_users)]
    
    print(f"After filtering: {len(filtered_ratings)} ratings from {len(selected_users)} users")
    print(f"Retained {len(filtered_ratings)/total_ratings:.1%} of original ratings")
    
    return filtered_ratings

# %%
def remove_columns(filtered_df):
    if 'timestamp' in filtered_df.columns:
        filtered_df.drop(columns=["timestamp"], inplace=True)
    if 'genres' in filtered_df.columns:
        filtered_df.drop(columns=["genres"], inplace=True)
    if 'title' in filtered_df.columns:
        filtered_df.drop(columns=["title"], inplace=True)
    
    print(f"Final dataset: {len(filtered_df)} ratings across {filtered_df['movieId'].nunique()} movies from {filtered_df['userId'].nunique()} users")

    return filtered_df

# %%
ratings = remove_columns(ratings)
# Out:
# Final dataset: 33832162 ratings across 83239 movies from 330975 users

# %%
min_avg_rating=0
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=2
max_users_per_movie=110 # 250
user_similarity_threshold=0.15 # 0.15

# %%
# Step 3: Filter users by activity level
filtered_df = filter_users_by_activity(
    ratings,
    min_percentile=user_min_percentile,
    max_percentile=user_max_percentile
)
# Out:
# Filtering users with activity between 25th and 100th percentiles...
# Before filtering: 330975 users with rating statistics:
# count    330975.00000
# mean        102.21969
# std         232.15453
# min           1.00000
# 25%          15.00000
# 50%          31.00000
# 75%          98.00000
# max       33332.00000
# Name: rating, dtype: float64
# After filtering: 253970 users with rating statistics:
# count    253970.000000
# mean        126.353069
# std         212.502895
# min          15.000000
# 25%          23.000000
# 50%          51.000000
# 75%         132.000000
# max        2546.000000
# Name: rating, dtype: float64

# %%
ratings_df = select_diverse_users(
    filtered_df, 
    max_users_per_movie=max_users_per_movie,
    similarity_threshold=user_similarity_threshold,
)
# Out:
# Selecting diverse users with max 110 users per movie...
# Initial dataset: 32089889 ratings from 253970 users on 73029 movies
# After filtering: 172050 ratings from 6930 users
# Retained 0.5% of original ratings

# %%
ratings_df["userId"].nunique(),ratings_df["movieId"].nunique()
# Out:
# (6930, 15449)

# %%
filtered_df = remove_columns(ratings_df)
# Out:
# Final dataset: 172050 ratings across 15449 movies from 6930 users

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (6930, 15449)

# %%
# Step 2: Filter by average rating
filtered_df = filter_by_average_rating(
    movies, 
    ratings_df, 
    min_rating=min_avg_rating
)
# Out:
# Filtering movies with average rating >= 0...
# Kept 15449 movies with average rating >= 0

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (6930, 15449)

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (6930, 15449)

# %%
filtered_df = filter_movies_by_popularity(
    filtered_df,
    min_ratings=min_ratings_per_movie
)
# Out:
# Filtering movies with at least 2 ratings...
# Before filtering: 15449 movies
# Movies with <2 ratings: 6389
# After filtering: 9060 movies kept

# %%
filtered_df["userId"].nunique(),filtered_df["movieId"].nunique()
# Out:
# (6929, 9060)

# %%
def scale_ratings(matrix):

    data = matrix.copy().values
    rows = data.shape[0]
    
    # Scale each user's ratings (each row)
    for i in range(rows):
        # Find rated movies for this user
        nonzero_mask = data[i, :] > 0
        rated_indices = np.where(nonzero_mask)[0]
        
        # Get user's ratings and reshape for scaler
        user_ratings = data[i, rated_indices].reshape(-1, 1)
        
        # Apply MinMaxScaler
        scaler = MinMaxScaler()
        scaled_ratings = scaler.fit_transform(user_ratings).flatten()
        
        # Update the matrix with scaled ratings
        data[i, rated_indices] = scaled_ratings
    
    # Convert back to DataFrame
    scaled_matrix = pd.DataFrame(data, index=matrix.index, columns=matrix.columns)
    return scaled_matrix

# %%
def prepare_user_ratings(ratings_file_path, user_movie_matrix_columns):

    user_data = pd.read_csv(ratings_file_path)
    user_data = user_data.dropna(subset=['movieId'])
    
    # Create user-movie ratings matrix with zero values - using float dtype
    user_ratings = pd.DataFrame(0.0, index=[0], columns=user_movie_matrix_columns, dtype=np.float64)
    
    # Fill with original ratings
    for _, row in user_data.iterrows():
        movie_id = row['movieId']
        if movie_id in user_ratings.columns:
            user_ratings.loc[0, movie_id] = float(row['Rating'])
    
    # Get indices of rated movies
    nonzero_mask = user_ratings.values > 0
    rated_indices = np.where(nonzero_mask[0])[0]
    
    # Get this user's ratings
    user_rating_values = user_ratings.iloc[0, rated_indices].values.reshape(-1, 1)
    
    # Apply MinMaxScaler
    scaler = MinMaxScaler()
    scaled_ratings = scaler.fit_transform(user_rating_values).flatten()
    
    # Update the user ratings with scaled values
    user_ratings.iloc[0, rated_indices] = scaled_ratings
    
    return user_data, user_ratings

# %%
def get_recommendations1(user_ratings, nmf_model, movie_data, ratings_data, n=10, min_ratings=5):
    """
    Get movie recommendations for a user based on their ratings.
    
    Parameters:
    -----------
    user_ratings : pandas.DataFrame
        DataFrame with user ratings in the same format as the training matrix
    nmf_model : sklearn.decomposition.NMF
        Trained NMF model
    movie_data : pandas.DataFrame
        DataFrame with movie information (title, genres)
    ratings_data : pandas.DataFrame
        DataFrame with all ratings (userId, movieId, rating)
    n : int
        Number of recommendations to return
    min_ratings : int
        Minimum number of ratings a movie must have to be recommended
        
    Returns:
    --------
    pandas.DataFrame
        DataFrame with recommended movies
    """
    # Get user latent factors for the input user
    user_factors = nmf_model.transform(user_ratings)
    
    # Get item latent factors from the model
    item_factors = nmf_model.components_
    
    # Calculate predicted ratings for all movies
    predicted_ratings = np.dot(user_factors, item_factors).flatten()
    
    # Create a DataFrame with predicted ratings
    recommendations = pd.DataFrame({
        'movieId': user_ratings.columns,
        'predicted_rating': predicted_ratings
    })
    
    # Calculate average rating for each movie from the ratings dataframe
    movie_avg_ratings = ratings_data.groupby('movieId')['rating'].agg(['mean', 'count']).reset_index()
    movie_avg_ratings.columns = ['movieId', 'avg_rating', 'rating_count']
    
    # Create mappings
    movie_to_avg_rating = dict(zip(movie_avg_ratings['movieId'], movie_avg_ratings['avg_rating']))
    movie_to_rating_count = dict(zip(movie_avg_ratings['movieId'], movie_avg_ratings['rating_count']))
    
    # Add average ratings and rating counts
    recommendations['avg_rating'] = recommendations['movieId'].map(movie_to_avg_rating).fillna(0)
    recommendations['rating_count'] = recommendations['movieId'].map(movie_to_rating_count).fillna(0)
    
    # Normalize both scores for fair combination (handle edge cases)
    if recommendations['predicted_rating'].max() != recommendations['predicted_rating'].min():
        recommendations['predicted_norm'] = (recommendations['predicted_rating'] - recommendations['predicted_rating'].min()) / \
                                         (recommendations['predicted_rating'].max() - recommendations['predicted_rating'].min())
    else:
        recommendations['predicted_norm'] = 1.0
        
    if recommendations['avg_rating'].max() != recommendations['avg_rating'].min():
        recommendations['avg_norm'] = (recommendations['avg_rating'] - recommendations['avg_rating'].min()) / \
                                   (recommendations['avg_rating'].max() - recommendations['avg_rating'].min())
    else:
        recommendations['avg_norm'] = 1.0
    
    # Create composite score: 90% predicted rating + 10% average rating
    recommendations['composite_score'] = 0.9 * recommendations['predicted_norm'] + 0.1 * recommendations['avg_norm']
    
    # Filter out movies the user has already rated
    rated_movies = user_ratings.columns[user_ratings.values[0] > 0]
    unrated_movies = recommendations[~recommendations['movieId'].isin(rated_movies)]
    
    # Filter out movies with too few ratings
    unrated_movies = unrated_movies[unrated_movies['rating_count'] >= min_ratings]
    
    # Sort by composite score and get top N
    top_recommendations = unrated_movies.sort_values('composite_score', ascending=False).head(n)
    
    # Merge with movie information
    top_recommendations = pd.merge(top_recommendations, movie_data[['movieId', 'title', 'genres']], on='movieId')
    
    # Format the output
    result = top_recommendations[['movieId', 'title', 'genres', 'predicted_rating', 'avg_rating', 'rating_count', 'composite_score']]
    result = result.sort_values('composite_score', ascending=False)
    
    return result

# %%
def fit_model(
    user_movie_matrix_scaled,
    n_components=50,
    max_iter=200,
    init='random',
    solver='cd',
    tol=0.0001,

    sample_size=1.0
):

    print(f"\n--- Fitting model with {sample_size*100:.0f}% of users ---")
    
    # Sample users 
    if sample_size < 1.0:
        n_users = int(user_movie_matrix.shape[0] * sample_size)
        sampled_users = np.random.choice(user_movie_matrix.index, size=n_users, replace=False)
        training_matrix = user_movie_matrix.loc[sampled_users, :]
    else:
        training_matrix = user_movie_matrix
    
    print(f"Training matrix shape: {training_matrix.shape}")
    
    # Train the model
    start_time = time.time()
    nmf = NMF(
        n_components=n_components,
        max_iter=max_iter,
        verbose=0,
        init="nndsvd",
        #solver=solver,
        #tol=tol,
        #l1_ratio=l1_ratio
    )
    
    user_factors = nmf.fit_transform(training_matrix)
    item_factors = nmf.components_
    training_time = time.time() - start_time
    
    print(f"Training time: {training_time:.2f} seconds")
    print(f"Iterations completed: {nmf.n_iter_}")
    print(f"Final error: {nmf.reconstruction_err_}")
    
    return nmf, training_matrix, training_time

# %%
def get_recommendations(
    nmf_model,
    training_matrix,
    my_ratings,
    my_data,
    n_recommendations=20,
    movie_id_to_title_map=None
):
    # Transform personal ratings into factor space
    my_user_factors = nmf_model.transform(my_ratings)
    
    # Generate predictions
    predicted_ratings = np.dot(my_user_factors, nmf_model.components_)
    predicted_ratings_df = pd.DataFrame(predicted_ratings, columns=training_matrix.columns)
    
    # Get movies already rated
    rated_movies = set(int(movie_id) for movie_id in my_data['movieId'].values)
    print(f"You've rated {len(rated_movies)} movies")
    
    # Filter for unrated movies
    unrated_movies = [m for m in training_matrix.columns if int(m) not in rated_movies]
    print(f"Found {len(unrated_movies)} movies you haven't rated")
    
    # Get recommendations
    recommendations = []
    for movie_id in unrated_movies:
        pred_rating = predicted_ratings_df.loc[0, movie_id]
        recommendations.append((movie_id, pred_rating))
    
    recommendations.sort(key=lambda x: x[1], reverse=True)
    
    top_recommendations = recommendations[:n_recommendations]
    
    if movie_id_to_title_map:
        print("\nTop Recommendations:")
        for movie_id, predicted_rating in top_recommendations:
            # Convert from 0-1 scale back to 1-5 scale
            original_scale_rating = predicted_rating * 4 + 1 # this didnt work that well tbh
            
            movie_title = movie_id_to_title_map.get(movie_id, f"Unknown Movie (ID: {movie_id})")
            print(f"Movie: {movie_title}, Similarity Rating: {predicted_rating:.2f}/1.00")
    
    return top_recommendations

# %%
user_movie_matrix = filtered_df.pivot(index='userId', columns='movieId', values='rating')
user_movie_matrix = user_movie_matrix.fillna(0)
user_movie_matrix_scaled = scale_ratings(user_movie_matrix)

# %%
nmf_model, training_matrix, _ = fit_model(
    user_movie_matrix_scaled,
    n_components=600,
    sample_size=1,
    max_iter=800,
)
# Out:
# --- Fitting model with 100% of users ---
# Training matrix shape: (6929, 9060)

# %%
# save model
import joblib
joblib.dump(nmf_model, "nmf_model.pkl")
# Out:
# ['nmf_model800.pkl']

# %%
elliott_data, elliott_ratings = prepare_user_ratings(
    "data/loelliot_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
ludde_data, ludde_ratings = prepare_user_ratings(
    "data/ludde_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
charlie_data, charlie_ratings = prepare_user_ratings(
    "data/chaarll_ratings_with_ids.csv", 
    user_movie_matrix_scaled.columns
)
tilda_data, tilda_ratings = prepare_user_ratings(
    "data/tilda_h_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
zorrodor_data, zorrodor_ratings = prepare_user_ratings(
    "data/zorrodor_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
lukas_data, lukas_ratings = prepare_user_ratings(
    "data/lukas_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
clara_data, clara_ratings = prepare_user_ratings(
    "data/clar_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
voided_data, voided_ratings = prepare_user_ratings(
    "data/voided_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)
skellic_data, skellic_ratings = prepare_user_ratings(
    "data/skellic_ratings_with_ids.csv",
    user_movie_matrix_scaled.columns
)

# %%
recommendations1 = get_recommendations1(
    user_ratings=ludde_ratings,
    nmf_model=nmf_model,
    movie_data=movies,
    ratings_data=ratings,  # Add this parameter
    n=20,
    min_ratings=5
)
print("\nRecommendations for Ludde:")
print(recommendations1)
# Out:
# Recommendations for Ludde:
#     movieId                                              title  \
# 0    152081                                    Zootopia (2016)
# 1      1089                              Reservoir Dogs (1992)
# 2     81564                                    Megamind (2010)
# 3    203375                             Ford v. Ferrari (2019)
# 4      1136             Monty Python and the Holy Grail (1975)
# 5     71535                                  Zombieland (2009)
# 6     56782                         There Will Be Blood (2007)
# 7      4878                                Donnie Darko (2001)
# 8    177765                                        Coco (2017)
# 9       293  Léon: The Professional (a.k.a. The Professiona...
# 10   183869                                  Hereditary (2018)
# 11      541                                Blade Runner (1982)
# 12     1265                               Groundhog Day (1993)
# 13    72226                           Fantastic Mr. Fox (2009)
# 14   115569                                Nightcrawler (2014)
# 15   168252                                       Logan (2017)
# 16    86332                                        Thor (2011)
# 17   115617                                  Big Hero 6 (2014)
# 18      858                              Godfather, The (1972)
# 19    41566  Chronicles of Narnia: The Lion, the Witch and ...
#
#                                           genres  predicted_rating  \
# 0     Action|Adventure|Animation|Children|Comedy          0.524252
# 1                         Crime|Mystery|Thriller          0.478020
# 2   Action|Animation|Children|Comedy|Sci-Fi|IMAX          0.455571
# 3                                   Action|Drama          0.434720
# 4                       Adventure|Comedy|Fantasy          0.424948
# 5                           Action|Comedy|Horror          0.434306
# 6                                  Drama|Western          0.413267
# 7                  Drama|Mystery|Sci-Fi|Thriller          0.411741
# 8                   Adventure|Animation|Children          0.400961
# 9                    Action|Crime|Drama|Thriller          0.396324
# 10                            (no genres listed)          0.403093
# 11                        Action|Sci-Fi|Thriller          0.384094
# 12                        Comedy|Fantasy|Romance          0.385260
# 13     Adventure|Animation|Children|Comedy|Crime          0.383033
# 14                          Crime|Drama|Thriller          0.376267
# 15                                 Action|Sci-Fi          0.365045
# 16           Action|Adventure|Drama|Fantasy|IMAX          0.385421
# 17                       Action|Animation|Comedy          0.362162
# 18                                   Crime|Drama          0.342582
# 19                    Adventure|Children|Fantasy          0.374816
#
#     avg_rating  rating_count  composite_score
# 0     3.864311         15086         0.459632
# 1     4.094179         45318         0.432899
# 2     3.563637          8352         0.401512
# 3     3.963295          5190         0.397939
# 4     4.137099         47845         0.395878
# 5     3.738976         20456         0.391211
# 6     4.033481         15800         0.384489
# 7     3.942373         36667         0.380778
# 8     4.033522         10083         0.375620
# 9     4.097545         43539         0.374113
# 10    3.872490          4631         0.372541
# 11    4.113712         47695         0.365762
# 12    3.903829         47956         0.360586
# 13    3.894344          9990         0.358710
# 14    3.977386         13465         0.356213
# 15    3.916783         13567         0.346388
# 16    3.321812         14900         0.344020
# 17    3.874691         16563         0.343104
# 18    4.326603         75004         0.341944
# 19    3.391738         17042         0.338381

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=tilda_ratings,
    my_data=tilda_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 285 movies
# Found 9323 movies you haven't rated
#
# Top Recommendations:
# Movie: Pulp Fiction (1994), Similarity Rating: 0.52/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.49/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.42/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.40/1.00
# Movie: Little Women (2019), Similarity Rating: 0.38/1.00
# Movie: Kingsman: The Secret Service (2015), Similarity Rating: 0.36/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.35/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.35/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.33/1.00
# Movie: Meet the Parents (2000), Similarity Rating: 0.33/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.32/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.31/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.31/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.31/1.00
# Movie: Bridget Jones's Diary (2001), Similarity Rating: 0.31/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.31/1.00
# Movie: 1917 (2019), Similarity Rating: 0.31/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.29/1.00
# Movie: Luca (2021), Similarity Rating: 0.29/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.29/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.29/1.00
# Movie: Spider-Man: No Way Home (2021), Similarity Rating: 0.29/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.29/1.00
# Movie: There Will Be Blood (2007), Similarity Rating: 0.29/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.28/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.28/1.00
# Movie: Armageddon (1998), Similarity Rating: 0.28/1.00
# Movie: Dunkirk (2017), Similarity Rating: 0.27/1.00
# Movie: Wreck-It Ralph (2012), Similarity Rating: 0.26/1.00
# Movie: Pretty Woman (1990), Similarity Rating: 0.26/1.00
# Movie: Moonlight, Similarity Rating: 0.26/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.26/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.25/1.00
# Movie: The Spectacular Now (2013), Similarity Rating: 0.25/1.00
# Movie: Us (2019), Similarity Rating: 0.25/1.00
# Movie: Spider-Man (2002), Similarity Rating: 0.25/1.00
# Movie: Beauty and the Beast (1991), Similarity Rating: 0.25/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.24/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.24/1.00
# Movie: Harry Potter and the Half-Blood Prince (2009), Similarity Rating: 0.24/1.00
# Movie: Me and Earl and the Dying Girl (2015), Similarity Rating: 0.24/1.00
# Movie: Free Solo (2018), Similarity Rating: 0.24/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.24/1.00
# Movie: Blind Side, The  (2009), Similarity Rating: 0.24/1.00
# Movie: Aladdin (1992), Similarity Rating: 0.23/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.23/1.00
# Movie: Monty Python and the Holy Grail (1975), Similarity Rating: 0.23/1.00
# Movie: Willy Wonka & the Chocolate Factory (1971), Similarity Rating: 0.23/1.00
# Movie: Erin Brockovich (2000), Similarity Rating: 0.23/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.23/1.00
# Movie: Mary Poppins (1964), Similarity Rating: 0.23/1.00
# Movie: Moana (2016), Similarity Rating: 0.23/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.23/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.23/1.00
# Movie: We're the Millers (2013), Similarity Rating: 0.22/1.00
# Movie: The Witch (2015), Similarity Rating: 0.22/1.00
# Movie: Shrek 2 (2004), Similarity Rating: 0.22/1.00
# Movie: Help, The (2011), Similarity Rating: 0.21/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.21/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.21/1.00
# Movie: Sully (2016), Similarity Rating: 0.21/1.00
# Movie: Ocean's Thirteen (2007), Similarity Rating: 0.21/1.00
# Movie: Split (2017), Similarity Rating: 0.21/1.00
# Movie: Chocolat (2000), Similarity Rating: 0.21/1.00
# Movie: Edge of Tomorrow (2014), Similarity Rating: 0.21/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.20/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.20/1.00
# Movie: Ant-Man (2015), Similarity Rating: 0.20/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.20/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.20/1.00
# Movie: EuroTrip (2004), Similarity Rating: 0.19/1.00
# Movie: Austin Powers: International Man of Mystery (1997), Similarity Rating: 0.19/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.19/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.19/1.00
# Movie: Hamilton (2020), Similarity Rating: 0.19/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.19/1.00
# Movie: Kings of Summer, The (2013), Similarity Rating: 0.19/1.00
# Movie: Brave (2012), Similarity Rating: 0.18/1.00
# Movie: Wedding Crashers (2005), Similarity Rating: 0.18/1.00
# Movie: Megamind (2010), Similarity Rating: 0.18/1.00
# Movie: Ready or Not (2019), Similarity Rating: 0.18/1.00
# Movie: Maze Runner, The (2014), Similarity Rating: 0.18/1.00
# Movie: A Quiet Place Part II (2020), Similarity Rating: 0.18/1.00
# Movie: Hush (2016), Similarity Rating: 0.18/1.00
# Movie: Moon (2009), Similarity Rating: 0.18/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 1 (2010), Similarity Rating: 0.17/1.00
# Movie: Cars (2006), Similarity Rating: 0.17/1.00
# Movie: Corpse Bride (2005), Similarity Rating: 0.17/1.00
# Movie: Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984), Similarity Rating: 0.17/1.00
# Movie: Knocked Up (2007), Similarity Rating: 0.17/1.00
# Movie: Ready Player One, Similarity Rating: 0.17/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.17/1.00
# Movie: Blue Valentine (2010), Similarity Rating: 0.17/1.00
# Movie: Definitely, Maybe (2008), Similarity Rating: 0.17/1.00
# Movie: Roma (2018), Similarity Rating: 0.17/1.00
# Movie: Source Code (2011), Similarity Rating: 0.17/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.17/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.17/1.00
# Movie: Spider-Man 3 (2007), Similarity Rating: 0.16/1.00
# Movie: Palo Alto (2013), Similarity Rating: 0.16/1.00
# Movie: Hangover Part II, The (2011), Similarity Rating: 0.16/1.00
# Movie: Life Aquatic with Steve Zissou, The (2004), Similarity Rating: 0.16/1.00
# Movie: Limitless (2011), Similarity Rating: 0.16/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.16/1.00
# Movie: Captain Fantastic (2016), Similarity Rating: 0.16/1.00
# Movie: Pretty in Pink (1986), Similarity Rating: 0.16/1.00
# Movie: About a Boy (2002), Similarity Rating: 0.16/1.00
# Movie: Wedding Singer, The (1998), Similarity Rating: 0.16/1.00
# Movie: Onward (2020), Similarity Rating: 0.16/1.00
# Movie: Ocean's Twelve (2004), Similarity Rating: 0.16/1.00
# Movie: Up in the Air (2009), Similarity Rating: 0.16/1.00
# Movie: Terminal, The (2004), Similarity Rating: 0.16/1.00
# Movie: Say Anything... (1989), Similarity Rating: 0.16/1.00
# Movie: Sicario (2015), Similarity Rating: 0.16/1.00
# Movie: Snowpiercer (2013), Similarity Rating: 0.16/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.16/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.15/1.00
# Movie: Pirates of the Caribbean: At World's End (2007), Similarity Rating: 0.15/1.00
# Movie: Darjeeling Limited, The (2007), Similarity Rating: 0.15/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.15/1.00
# Movie: 10 Cloverfield Lane (2016), Similarity Rating: 0.15/1.00
# Movie: American Sniper (2014), Similarity Rating: 0.15/1.00
# Movie: The Hunger Games: Mockingjay - Part 1 (2014), Similarity Rating: 0.15/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.15/1.00
# Movie: Incredibles 2 (2018), Similarity Rating: 0.15/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.15/1.00
# Movie: Klaus (2019), Similarity Rating: 0.15/1.00
# Movie: Frozen (2013), Similarity Rating: 0.15/1.00
# Movie: Children of Men (2006), Similarity Rating: 0.15/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.15/1.00
# Movie: Enola Holmes, Similarity Rating: 0.15/1.00
# Movie: Raya and the Last Dragon (2021), Similarity Rating: 0.15/1.00
# Movie: Beetlejuice (1988), Similarity Rating: 0.15/1.00
# Movie: Black Widow (2021), Similarity Rating: 0.15/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.14/1.00
# Movie: Room (2015), Similarity Rating: 0.14/1.00
# Movie: Hurt Locker, The (2008), Similarity Rating: 0.14/1.00
# Movie: Remember the Titans (2000), Similarity Rating: 0.14/1.00
# Movie: Hangover Part III, The (2013), Similarity Rating: 0.14/1.00
# Movie: Stuck in Love (2012), Similarity Rating: 0.14/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.14/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.14/1.00
# Movie: Hugo (2011), Similarity Rating: 0.14/1.00
# Movie: Star Wars: Episode VII - The Force Awakens (2015), Similarity Rating: 0.14/1.00
# Movie: Kubo and the Two Strings (2016), Similarity Rating: 0.14/1.00
# Movie: The Hunger Games: Catching Fire (2013), Similarity Rating: 0.14/1.00
# Movie: Hacksaw Ridge (2016), Similarity Rating: 0.14/1.00
# Movie: Talented Mr. Ripley, The (1999), Similarity Rating: 0.14/1.00
# Movie: In Bruges (2008), Similarity Rating: 0.14/1.00
# Movie: Me Before You (2016), Similarity Rating: 0.14/1.00
# Movie: Searching (2018), Similarity Rating: 0.14/1.00
# Movie: American Psycho (2000), Similarity Rating: 0.14/1.00
# Movie: While You Were Sleeping (1995), Similarity Rating: 0.14/1.00
# Movie: Captain Phillips (2013), Similarity Rating: 0.14/1.00
# Movie: 27 Dresses (2008), Similarity Rating: 0.14/1.00
# Movie: Wizard of Oz, The (1939), Similarity Rating: 0.14/1.00
# Movie: Project X (2012), Similarity Rating: 0.13/1.00
# Movie: Porco Rosso (Crimson Pig) (Kurenai no buta) (1992), Similarity Rating: 0.13/1.00
# Movie: 50/50 (2011), Similarity Rating: 0.13/1.00
# Movie: Submarine (2010), Similarity Rating: 0.13/1.00
# Movie: Turning Red (2022), Similarity Rating: 0.13/1.00
# Movie: Connected (2020), Similarity Rating: 0.13/1.00
# Movie: Old Boy (2003), Similarity Rating: 0.13/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.13/1.00
# Movie: Shang-Chi and the Legend of the Ten Rings (2021), Similarity Rating: 0.13/1.00
# Movie: A Simple Favor (2018), Similarity Rating: 0.13/1.00
# Movie: Dark Waters (2019), Similarity Rating: 0.13/1.00
# Movie: Inside Man (2006), Similarity Rating: 0.13/1.00
# Movie: Step Brothers (2008), Similarity Rating: 0.13/1.00
# Movie: The Hunger Games: Mockingjay - Part 2 (2015), Similarity Rating: 0.13/1.00
# Movie: Fugitive, The (1993), Similarity Rating: 0.13/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.13/1.00
# Movie: Nobody (2021), Similarity Rating: 0.13/1.00
# Movie: The Revenant (2015), Similarity Rating: 0.13/1.00
# Movie: It Follows (2014), Similarity Rating: 0.13/1.00
# Movie: Logan (2017), Similarity Rating: 0.13/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.13/1.00
# Movie: Adventureland (2009), Similarity Rating: 0.13/1.00
# Movie: The Greatest Showman (2017), Similarity Rating: 0.13/1.00
# Movie: Creep (2014), Similarity Rating: 0.13/1.00
# Movie: Mandy (2018), Similarity Rating: 0.13/1.00
# Movie: Emperor's New Groove, The (2000), Similarity Rating: 0.13/1.00
# Movie: Nurse Betty (2000), Similarity Rating: 0.12/1.00
# Movie: Clerks (1994), Similarity Rating: 0.12/1.00
# Movie: Jaws (1975), Similarity Rating: 0.12/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.12/1.00
# Movie: Julie & Julia (2009), Similarity Rating: 0.12/1.00
# Movie: Moulin Rouge (2001), Similarity Rating: 0.12/1.00
# Movie: Proposal, The (2009), Similarity Rating: 0.12/1.00
# Movie: Pitch Perfect 2 (2015), Similarity Rating: 0.12/1.00
# Movie: Ted 2 (2015), Similarity Rating: 0.12/1.00
# Movie: Prometheus (2012), Similarity Rating: 0.12/1.00
# Movie: Serendipity (2001), Similarity Rating: 0.12/1.00
# Movie: Toy Story 4 (2019), Similarity Rating: 0.12/1.00
# Movie: The Lego Batman Movie (2017), Similarity Rating: 0.12/1.00
# Movie: Step Up (2006), Similarity Rating: 0.12/1.00
# Movie: 21 (2008), Similarity Rating: 0.12/1.00
# Movie: Tangled (2010), Similarity Rating: 0.12/1.00
# Movie: The Adam Project (2022), Similarity Rating: 0.12/1.00
# Movie: American Made (2017), Similarity Rating: 0.12/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=elliott_ratings,
    my_data=elliott_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
# response "Jag har sett typ en tredjedel av dessa filmer kanske, men inte sen jag började med letterboxd"
# Out:
# You've rated 177 movies
# Found 9458 movies you haven't rated
#
# Top Recommendations:
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.41/1.00
# Movie: Moonlight, Similarity Rating: 0.28/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.27/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.26/1.00
# Movie: Ford v. Ferrari (2019), Similarity Rating: 0.26/1.00
# Movie: Once Upon a Time in Hollywood (2019), Similarity Rating: 0.26/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.25/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.24/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.24/1.00
# Movie: Clueless (1995), Similarity Rating: 0.23/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.23/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.23/1.00
# Movie: Pitch Perfect (2012), Similarity Rating: 0.20/1.00
# Movie: The Witch (2015), Similarity Rating: 0.20/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.20/1.00
# Movie: Mandy (2018), Similarity Rating: 0.19/1.00
# Movie: The Fault in Our Stars (2014), Similarity Rating: 0.19/1.00
# Movie: To All the Boys I've Loved Before (2018), Similarity Rating: 0.19/1.00
# Movie: It's Kind of a Funny Story (2010), Similarity Rating: 0.18/1.00
# Movie: Eighth Grade (2018), Similarity Rating: 0.18/1.00
# Movie: Green Book (2018), Similarity Rating: 0.17/1.00
# Movie: Bridesmaids (2011), Similarity Rating: 0.17/1.00
# Movie: The Spectacular Now (2013), Similarity Rating: 0.17/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.16/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.16/1.00
# Movie: Spider-Man: No Way Home (2021), Similarity Rating: 0.16/1.00
# Movie: Frances Ha (2012), Similarity Rating: 0.16/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.15/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.15/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.15/1.00
# Movie: Me and Earl and the Dying Girl (2015), Similarity Rating: 0.15/1.00
# Movie: Help, The (2011), Similarity Rating: 0.15/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.15/1.00
# Movie: Life Aquatic with Steve Zissou, The (2004), Similarity Rating: 0.15/1.00
# Movie: Elf (2003), Similarity Rating: 0.14/1.00
# Movie: Ocean's 8 (2018), Similarity Rating: 0.14/1.00
# Movie: Darjeeling Limited, The (2007), Similarity Rating: 0.13/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.13/1.00
# Movie: Top Gun: Maverick (2022), Similarity Rating: 0.13/1.00
# Movie: A Simple Favor (2018), Similarity Rating: 0.13/1.00
# Movie: Paterson, Similarity Rating: 0.13/1.00
# Movie: Good Time (2017), Similarity Rating: 0.13/1.00
# Movie: Hot Fuzz (2007), Similarity Rating: 0.13/1.00
# Movie: Short Term 12 (2013), Similarity Rating: 0.13/1.00
# Movie: Snowpiercer (2013), Similarity Rating: 0.13/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.12/1.00
# Movie: 20th Century Women (2016), Similarity Rating: 0.12/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.12/1.00
# Movie: Harry Potter and the Half-Blood Prince (2009), Similarity Rating: 0.12/1.00
# Movie: Mother! (2017), Similarity Rating: 0.12/1.00
# Movie: It Follows (2014), Similarity Rating: 0.12/1.00
# Movie: Bo Burnham: Inside (2021), Similarity Rating: 0.12/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.12/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.11/1.00
# Movie: Columbus (2017), Similarity Rating: 0.11/1.00
# Movie: Luca (2021), Similarity Rating: 0.11/1.00
# Movie: Kubo and the Two Strings (2016), Similarity Rating: 0.11/1.00
# Movie: Phantom Thread (2017), Similarity Rating: 0.11/1.00
# Movie: Mid90s (2018), Similarity Rating: 0.11/1.00
# Movie: Coco (2017), Similarity Rating: 0.11/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.11/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.11/1.00
# Movie: Beautiful Boy (2018), Similarity Rating: 0.11/1.00
# Movie: Raw (2017), Similarity Rating: 0.11/1.00
# Movie: Boys (2014), Similarity Rating: 0.11/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.11/1.00
# Movie: Blue Is the Warmest Color (La vie d'Adèle) (2013), Similarity Rating: 0.11/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.10/1.00
# Movie: Spider-Man (2002), Similarity Rating: 0.10/1.00
# Movie: Shang-Chi and the Legend of the Ten Rings (2021), Similarity Rating: 0.10/1.00
# Movie: La La Land (2016), Similarity Rating: 0.10/1.00
# Movie: Walk to Remember, A (2002), Similarity Rating: 0.10/1.00
# Movie: The Way He Looks (2014), Similarity Rating: 0.10/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.10/1.00
# Movie: Step Brothers (2008), Similarity Rating: 0.10/1.00
# Movie: The Last Black Man in San Francisco (2019), Similarity Rating: 0.10/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.10/1.00
# Movie: The Two Popes (2019), Similarity Rating: 0.10/1.00
# Movie: The Irishman (2019), Similarity Rating: 0.10/1.00
# Movie: Thirteen (2003), Similarity Rating: 0.10/1.00
# Movie: Ready Player One, Similarity Rating: 0.10/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.10/1.00
# Movie: Set It Up (2018), Similarity Rating: 0.10/1.00
# Movie: Captain America: The Winter Soldier (2014), Similarity Rating: 0.10/1.00
# Movie: But I'm a Cheerleader (1999), Similarity Rating: 0.10/1.00
# Movie: Kill Your Darlings (2013), Similarity Rating: 0.10/1.00
# Movie: A Quiet Place Part II (2020), Similarity Rating: 0.10/1.00
# Movie: 13 Going on 30 (2004), Similarity Rating: 0.10/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.10/1.00
# Movie: The Perfect Date, Similarity Rating: 0.10/1.00
# Movie: Nerve (2016), Similarity Rating: 0.10/1.00
# Movie: Ready or Not (2019), Similarity Rating: 0.09/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.09/1.00
# Movie: Cars (2006), Similarity Rating: 0.09/1.00
# Movie: Way, Way Back, The (2013), Similarity Rating: 0.09/1.00
# Movie: Paper Towns (2015), Similarity Rating: 0.09/1.00
# Movie: Minari (2020), Similarity Rating: 0.09/1.00
# Movie: Wild Tales (2014), Similarity Rating: 0.09/1.00
# Movie: Freaky Friday (2003), Similarity Rating: 0.09/1.00
# Movie: Free Fall (2013), Similarity Rating: 0.09/1.00
# Movie: Wedding Crashers (2005), Similarity Rating: 0.09/1.00
# Movie: The Suicide Squad (2021), Similarity Rating: 0.09/1.00
# Movie: Cinderella Story, A (2004), Similarity Rating: 0.09/1.00
# Movie: She's All That (1999), Similarity Rating: 0.09/1.00
# Movie: Five Feet Apart (2019), Similarity Rating: 0.09/1.00
# Movie: Onward (2020), Similarity Rating: 0.09/1.00
# Movie: Pitch Perfect 2 (2015), Similarity Rating: 0.09/1.00
# Movie: Leave No Trace (2018), Similarity Rating: 0.09/1.00
# Movie: Captain America: Civil War (2016), Similarity Rating: 0.09/1.00
# Movie: Swiss Army Man (2016), Similarity Rating: 0.09/1.00
# Movie: Glass (2019), Similarity Rating: 0.09/1.00
# Movie: Ant-Man and the Wasp (2018), Similarity Rating: 0.09/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.09/1.00
# Movie: Spider-Man 3 (2007), Similarity Rating: 0.09/1.00
# Movie: Now You See Me 2 (2016), Similarity Rating: 0.09/1.00
# Movie: Enola Holmes, Similarity Rating: 0.09/1.00
# Movie: The Girl on the Train (2016), Similarity Rating: 0.09/1.00
# Movie: Nocturnal Animals, Similarity Rating: 0.09/1.00
# Movie: American Hustle (2013), Similarity Rating: 0.09/1.00
# Movie: Punch-Drunk Love (2002), Similarity Rating: 0.09/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.09/1.00
# Movie: Mommy (2014), Similarity Rating: 0.09/1.00
# Movie: The Disaster Artist (2017), Similarity Rating: 0.09/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.08/1.00
# Movie: The Courier (2021), Similarity Rating: 0.08/1.00
# Movie: Closet Monster (2016), Similarity Rating: 0.08/1.00
# Movie: RRR (2022), Similarity Rating: 0.08/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.08/1.00
# Movie: Black Widow (2021), Similarity Rating: 0.08/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.08/1.00
# Movie: I'm Thinking of Ending Things, Similarity Rating: 0.08/1.00
# Movie: Tag (2018), Similarity Rating: 0.08/1.00
# Movie: CODA (2021), Similarity Rating: 0.08/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.08/1.00
# Movie: Miss Peregrine's Home for Peculiar Children (2016), Similarity Rating: 0.08/1.00
# Movie: Logan (2017), Similarity Rating: 0.08/1.00
# Movie: Adventureland (2009), Similarity Rating: 0.08/1.00
# Movie: Don't Breathe (2016), Similarity Rating: 0.08/1.00
# Movie: Captain America: The First Avenger (2011), Similarity Rating: 0.08/1.00
# Movie: Orphan: First Kill (2022), Similarity Rating: 0.08/1.00
# Movie: The Nice Guys (2016), Similarity Rating: 0.08/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.08/1.00
# Movie: Emma (2020), Similarity Rating: 0.08/1.00
# Movie: Flipped (2010), Similarity Rating: 0.08/1.00
# Movie: Seeking a Friend for the End of the World (2012), Similarity Rating: 0.08/1.00
# Movie: First Reformed (2017), Similarity Rating: 0.08/1.00
# Movie: Men, Women & Children (2014), Similarity Rating: 0.08/1.00
# Movie: Coherence (2013), Similarity Rating: 0.08/1.00
# Movie: My Own Private Idaho (1991), Similarity Rating: 0.08/1.00
# Movie: Submarine (2010), Similarity Rating: 0.08/1.00
# Movie: Princess and the Frog, The (2009), Similarity Rating: 0.08/1.00
# Movie: Over the Garden Wall (2013), Similarity Rating: 0.08/1.00
# Movie: 17 Again (2009), Similarity Rating: 0.08/1.00
# Movie: Soul (2020), Similarity Rating: 0.08/1.00
# Movie: Hacksaw Ridge (2016), Similarity Rating: 0.08/1.00
# Movie: Guardians of the Galaxy 2 (2017), Similarity Rating: 0.08/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.08/1.00
# Movie: Laurence Anyways (2012), Similarity Rating: 0.08/1.00
# Movie: Great Gatsby, The (2013), Similarity Rating: 0.08/1.00
# Movie: Ant-Man (2015), Similarity Rating: 0.08/1.00
# Movie: Judas and the Black Messiah (2021), Similarity Rating: 0.08/1.00
# Movie: Ghost World (2001), Similarity Rating: 0.08/1.00
# Movie: Watchmen (2009), Similarity Rating: 0.08/1.00
# Movie: Barbarian (2022), Similarity Rating: 0.08/1.00
# Movie: I Killed My Mother (J'ai tué ma mère) (2009), Similarity Rating: 0.08/1.00
# Movie: Snake Eyes: G.I. Joe Origins (2021), Similarity Rating: 0.08/1.00
# Movie: The Gentlemen (2020), Similarity Rating: 0.08/1.00
# Movie: Molly's Game (2017), Similarity Rating: 0.08/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.08/1.00
# Movie: John Wick: Chapter Two (2017), Similarity Rating: 0.08/1.00
# Movie: Little Miss Sunshine (2006), Similarity Rating: 0.08/1.00
# Movie: The Miseducation of Cameron Post (2018), Similarity Rating: 0.08/1.00
# Movie: Harry Potter and the Deathly Hallows: Part 1 (2010), Similarity Rating: 0.08/1.00
# Movie: Sideways (2004), Similarity Rating: 0.08/1.00
# Movie: I Heart Huckabees (2004), Similarity Rating: 0.08/1.00
# Movie: Maze Runner: The Death Cure (2018), Similarity Rating: 0.07/1.00
# Movie: Hello, My Name Is Doris (2016), Similarity Rating: 0.07/1.00
# Movie: Paulette (2012), Similarity Rating: 0.07/1.00
# Movie: Color Out of Space (2019), Similarity Rating: 0.07/1.00
# Movie: Demolition (2016), Similarity Rating: 0.07/1.00
# Movie: The Longest Week (2014), Similarity Rating: 0.07/1.00
# Movie: Stuck in Love (2012), Similarity Rating: 0.07/1.00
# Movie: The Ritual (2017), Similarity Rating: 0.07/1.00
# Movie: Tangled (2010), Similarity Rating: 0.07/1.00
# Movie: Horrible Bosses (2011), Similarity Rating: 0.07/1.00
# Movie: Forgetting Sarah Marshall (2008), Similarity Rating: 0.07/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.07/1.00
# Movie: Hell or High Water (2016), Similarity Rating: 0.07/1.00
# Movie: The Platform (2019), Similarity Rating: 0.07/1.00
# Movie: The House That Jack Built (2018), Similarity Rating: 0.07/1.00
# Movie: The Founder (2016), Similarity Rating: 0.07/1.00
# Movie: She's the Man (2006), Similarity Rating: 0.07/1.00
# Movie: Carol (2015), Similarity Rating: 0.07/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.07/1.00
# Movie: Doctor Strange in the Multiverse of Madness (2022), Similarity Rating: 0.07/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.07/1.00
# Movie: What a Girl Wants (2003), Similarity Rating: 0.07/1.00
# Movie: Free Solo (2018), Similarity Rating: 0.07/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.07/1.00
# Movie: John Tucker Must Die (2006), Similarity Rating: 0.07/1.00
# '\nmin_avg_rating=2.5\nuser_min_percentile=0.25\nuser_max_percentile=0.999\nmin_ratings_per_movie=3\nmax_users_per_movie=250\nuser_similarity_threshold=0.15\nfit: \nn_components=200,\nsample_size=1,\nmax_iter=800\n'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=charlie_ratings,
    my_data=charlie_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 81 movies
# Found 9223 movies you haven't rated
#
# Top Recommendations:
# Movie: The Martian (2015), Similarity Rating: 0.64/1.00
# Movie: Get Out (2017), Similarity Rating: 0.40/1.00
# Movie: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981), Similarity Rating: 0.38/1.00
# Movie: Aliens (1986), Similarity Rating: 0.37/1.00
# Movie: Forrest Gump (1994), Similarity Rating: 0.34/1.00
# Movie: Silence of the Lambs, The (1991), Similarity Rating: 0.33/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.29/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.29/1.00
# Movie: Lord of the Rings: The Return of the King, The (2003), Similarity Rating: 0.28/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.27/1.00
# Movie: Dead Poets Society (1989), Similarity Rating: 0.27/1.00
# Movie: Lord of the Rings: The Two Towers, The (2002), Similarity Rating: 0.27/1.00
# Movie: Midsommar (2019), Similarity Rating: 0.27/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.27/1.00
# Movie: Memento (2000), Similarity Rating: 0.26/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.25/1.00
# Movie: Her (2013), Similarity Rating: 0.24/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.24/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.24/1.00
# Movie: Limitless (2011), Similarity Rating: 0.23/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.22/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.22/1.00
# Movie: Back to the Future (1985), Similarity Rating: 0.22/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.18/1.00
# Movie: Illusionist, The (2006), Similarity Rating: 0.18/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.18/1.00
# Movie: I Am Legend (2007), Similarity Rating: 0.16/1.00
# Movie: Us (2019), Similarity Rating: 0.16/1.00
# Movie: Indiana Jones and the Last Crusade (1989), Similarity Rating: 0.16/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.16/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.16/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.14/1.00
# Movie: Hotel Rwanda (2004), Similarity Rating: 0.14/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.13/1.00
# Movie: Howl's Moving Castle (Hauru no ugoku shiro) (2004), Similarity Rating: 0.13/1.00
# Movie: Snowpiercer (2013), Similarity Rating: 0.13/1.00
# Movie: 12 Angry Men (1957), Similarity Rating: 0.13/1.00
# Movie: Blue Velvet (1986), Similarity Rating: 0.13/1.00
# Movie: Baby Driver (2017), Similarity Rating: 0.13/1.00
# Movie: Moonlight, Similarity Rating: 0.12/1.00
# Movie: My Neighbor Totoro (Tonari no Totoro) (1988), Similarity Rating: 0.12/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.12/1.00
# Movie: Snatch (2000), Similarity Rating: 0.12/1.00
# Movie: Blood Diamond (2006), Similarity Rating: 0.12/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.12/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.11/1.00
# Movie: The Witch (2015), Similarity Rating: 0.11/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.11/1.00
# Movie: Kingsman: The Secret Service (2015), Similarity Rating: 0.11/1.00
# Movie: District 9 (2009), Similarity Rating: 0.11/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.11/1.00
# Movie: Godfather, The (1972), Similarity Rating: 0.11/1.00
# Movie: The Hateful Eight (2015), Similarity Rating: 0.11/1.00
# Movie: Little Women (2019), Similarity Rating: 0.11/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.10/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.10/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.10/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.10/1.00
# Movie: Saving Private Ryan (1998), Similarity Rating: 0.10/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.10/1.00
# Movie: Passengers (2016), Similarity Rating: 0.10/1.00
# Movie: La La Land (2016), Similarity Rating: 0.10/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.10/1.00
# Movie: Inside Man (2006), Similarity Rating: 0.10/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.10/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.10/1.00
# Movie: Alien³ (a.k.a. Alien 3) (1992), Similarity Rating: 0.10/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.10/1.00
# Movie: Fury (2014), Similarity Rating: 0.10/1.00
# Movie: Oblivion (2013), Similarity Rating: 0.09/1.00
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.09/1.00
# Movie: Source Code (2011), Similarity Rating: 0.09/1.00
# Movie: No Country for Old Men (2007), Similarity Rating: 0.09/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.09/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.09/1.00
# Movie: Lord of War (2005), Similarity Rating: 0.09/1.00
# Movie: The Platform (2019), Similarity Rating: 0.09/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.09/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.09/1.00
# Movie: Braveheart (1995), Similarity Rating: 0.09/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.09/1.00
# Movie: The Theory of Everything (2014), Similarity Rating: 0.09/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.09/1.00
# Movie: Argo (2012), Similarity Rating: 0.09/1.00
# Movie: The Lobster (2015), Similarity Rating: 0.09/1.00
# Movie: Lucy (2014), Similarity Rating: 0.09/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.08/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.08/1.00
# Movie: Prisoners (2013), Similarity Rating: 0.08/1.00
# Movie: Split (2017), Similarity Rating: 0.08/1.00
# Movie: Gladiator (2000), Similarity Rating: 0.08/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.08/1.00
# Movie: Dial M for Murder (1954), Similarity Rating: 0.08/1.00
# Movie: Lucky Number Slevin (2006), Similarity Rating: 0.08/1.00
# Movie: Green Book (2018), Similarity Rating: 0.08/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.08/1.00
# Movie: Sorry to Bother You (2018), Similarity Rating: 0.08/1.00
# Movie: Burning (2018), Similarity Rating: 0.08/1.00
# Movie: Mid90s (2018), Similarity Rating: 0.08/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.08/1.00
# Movie: Chappie (2015), Similarity Rating: 0.08/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.08/1.00
# Movie: In Time (2011), Similarity Rating: 0.08/1.00
# Movie: Good Time (2017), Similarity Rating: 0.08/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.08/1.00
# Movie: Zombieland (2009), Similarity Rating: 0.08/1.00
# Movie: Children of Men (2006), Similarity Rating: 0.08/1.00
# Movie: Titanic (1997), Similarity Rating: 0.08/1.00
# Movie: Ponyo (Gake no ue no Ponyo) (2008), Similarity Rating: 0.08/1.00
# Movie: Life of Pi (2012), Similarity Rating: 0.07/1.00
# Movie: Die Hard (1988), Similarity Rating: 0.07/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.07/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.07/1.00
# Movie: Thank You for Smoking (2006), Similarity Rating: 0.07/1.00
# Movie: Apollo 13 (1995), Similarity Rating: 0.07/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.07/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.07/1.00
# Movie: Pacific Rim (2013), Similarity Rating: 0.07/1.00
# Movie: Girl with the Dragon Tattoo, The (2011), Similarity Rating: 0.07/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.07/1.00
# Movie: Elysium (2013), Similarity Rating: 0.07/1.00
# Movie: Akira (1988), Similarity Rating: 0.07/1.00
# Movie: Brazil (1985), Similarity Rating: 0.07/1.00
# Movie: Indiana Jones and the Temple of Doom (1984), Similarity Rating: 0.07/1.00
# Movie: Sin City (2005), Similarity Rating: 0.07/1.00
# Movie: Promising Young Woman (2020), Similarity Rating: 0.07/1.00
# Movie: Coraline (2009), Similarity Rating: 0.07/1.00
# Movie: Coco (2017), Similarity Rating: 0.07/1.00
# Movie: Apocalypto (2006), Similarity Rating: 0.06/1.00
# Movie: Ghostbusters (a.k.a. Ghost Busters) (1984), Similarity Rating: 0.06/1.00
# Movie: Last Samurai, The (2003), Similarity Rating: 0.06/1.00
# Movie: Birdman: Or (The Unexpected Virtue of Ignorance) (2014), Similarity Rating: 0.06/1.00
# Movie: Curious Case of Benjamin Button, The (2008), Similarity Rating: 0.06/1.00
# Movie: Deadpool (2016), Similarity Rating: 0.06/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.06/1.00
# Movie: Boyhood (2014), Similarity Rating: 0.06/1.00
# Movie: Lock, Stock & Two Smoking Barrels (1998), Similarity Rating: 0.06/1.00
# Movie: When Harry Met Sally... (1989), Similarity Rating: 0.06/1.00
# Movie: A Star Is Born (2018), Similarity Rating: 0.06/1.00
# Movie: Room (2015), Similarity Rating: 0.06/1.00
# Movie: World War Z (2013), Similarity Rating: 0.06/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.06/1.00
# Movie: Last King of Scotland, The (2006), Similarity Rating: 0.06/1.00
# Movie: Alien: Resurrection (1997), Similarity Rating: 0.06/1.00
# Movie: Trainspotting (1996), Similarity Rating: 0.06/1.00
# Movie: Requiem for a Dream (2000), Similarity Rating: 0.06/1.00
# Movie: Bohemian Rhapsody (2018), Similarity Rating: 0.06/1.00
# Movie: Godfather: Part II, The (1974), Similarity Rating: 0.06/1.00
# Movie: Jurassic World (2015), Similarity Rating: 0.06/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.06/1.00
# Movie: Mud (2012), Similarity Rating: 0.06/1.00
# Movie: The Butterfly Effect (2004), Similarity Rating: 0.06/1.00
# Movie: Suspiria (2017), Similarity Rating: 0.06/1.00
# Movie: Jaws (1975), Similarity Rating: 0.06/1.00
# Movie: True Grit (2010), Similarity Rating: 0.06/1.00
# Movie: Casino Royale (2006), Similarity Rating: 0.06/1.00
# Movie: I, Robot (2004), Similarity Rating: 0.06/1.00
# Movie: Lion King, The (1994), Similarity Rating: 0.06/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.06/1.00
# Movie: Day After Tomorrow, The (2004), Similarity Rating: 0.06/1.00
# Movie: Munich (2005), Similarity Rating: 0.06/1.00
# Movie: 10 Cloverfield Lane (2016), Similarity Rating: 0.06/1.00
# Movie: Million Dollar Baby (2004), Similarity Rating: 0.06/1.00
# Movie: Nocturnal Animals, Similarity Rating: 0.06/1.00
# Movie: Awakenings (1990), Similarity Rating: 0.06/1.00
# Movie: I, Tonya (2017), Similarity Rating: 0.06/1.00
# Movie: American Sniper (2014), Similarity Rating: 0.06/1.00
# Movie: Predestination (2014), Similarity Rating: 0.06/1.00
# Movie: Men in Black (a.k.a. MIB) (1997), Similarity Rating: 0.06/1.00
# Movie: Nomadland (2020), Similarity Rating: 0.06/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.06/1.00
# Movie: Ready Player One, Similarity Rating: 0.06/1.00
# Movie: (500) Days of Summer (2009), Similarity Rating: 0.05/1.00
# Movie: Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984), Similarity Rating: 0.05/1.00
# Movie: Rise of the Planet of the Apes (2011), Similarity Rating: 0.05/1.00
# Movie: I'm Thinking of Ending Things, Similarity Rating: 0.05/1.00
# Movie: Red Dragon (2002), Similarity Rating: 0.05/1.00
# Movie: Blind Side, The  (2009), Similarity Rating: 0.05/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.05/1.00
# Movie: The Irishman (2019), Similarity Rating: 0.05/1.00
# Movie: Wreck-It Ralph (2012), Similarity Rating: 0.05/1.00
# Movie: The Man from U.N.C.L.E. (2015), Similarity Rating: 0.05/1.00
# Movie: Mr. Nobody (2009), Similarity Rating: 0.05/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.05/1.00
# Movie: Ant-Man (2015), Similarity Rating: 0.05/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.05/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.05/1.00
# Movie: Spectral (2016), Similarity Rating: 0.05/1.00
# Movie: Batman (1989), Similarity Rating: 0.05/1.00
# Movie: 13th Warrior, The (1999), Similarity Rating: 0.05/1.00
# Movie: Apocalypse Now (1979), Similarity Rating: 0.05/1.00
# Movie: Moon (2009), Similarity Rating: 0.05/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.05/1.00
# Movie: 20,000 Leagues Under the Sea (1954), Similarity Rating: 0.05/1.00
# Movie: One Flew Over the Cuckoo's Nest (1975), Similarity Rating: 0.05/1.00
# Movie: Escape from New York (1981), Similarity Rating: 0.05/1.00
# Movie: Fountain, The (2006), Similarity Rating: 0.05/1.00
# Movie: Pursuit of Happyness, The (2006), Similarity Rating: 0.05/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.05/1.00
# Movie: Sicario (2015), Similarity Rating: 0.05/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=voided_ratings,
    my_data=voided_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
"""jo men det gör dom, har typ alla förrutom guardians of the galaxy på min watchlist haha
och det stämmer att de jag redan hade sett som totoro hade jag inte rateat"""
# Out:
# You've rated 271 movies
# Found 9050 movies you haven't rated
#
# Top Recommendations:
# Movie: Fargo (1996), Similarity Rating: 0.58/1.00
# Movie: Braveheart (1995), Similarity Rating: 0.53/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.49/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.47/1.00
# Movie: The Imitation Game (2014), Similarity Rating: 0.46/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.46/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.44/1.00
# Movie: Gone Girl (2014), Similarity Rating: 0.43/1.00
# Movie: My Neighbor Totoro (Tonari no Totoro) (1988), Similarity Rating: 0.42/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.38/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.37/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.37/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.36/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.35/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.35/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.33/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.33/1.00
# Movie: Coco (2017), Similarity Rating: 0.32/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.31/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.30/1.00
# Movie: 2001: A Space Odyssey (1968), Similarity Rating: 0.29/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.29/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.28/1.00
# Movie: Moonlight, Similarity Rating: 0.28/1.00
# Movie: Soul (2020), Similarity Rating: 0.27/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.27/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.26/1.00
# Movie: Office Space (1999), Similarity Rating: 0.26/1.00
# Movie: Inception (2010), Similarity Rating: 0.26/1.00
# Movie: High Fidelity (2000), Similarity Rating: 0.24/1.00
# Movie: Lock, Stock & Two Smoking Barrels (1998), Similarity Rating: 0.24/1.00
# Movie: Moana (2016), Similarity Rating: 0.23/1.00
# Movie: Juno (2007), Similarity Rating: 0.23/1.00
# Movie: Garden State (2004), Similarity Rating: 0.23/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.23/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.23/1.00
# Movie: Us (2019), Similarity Rating: 0.23/1.00
# Movie: Moon (2009), Similarity Rating: 0.22/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.22/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.22/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.22/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.22/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.21/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.21/1.00
# Movie: Wreck-It Ralph (2012), Similarity Rating: 0.21/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.21/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.21/1.00
# Movie: Marriage Story (2019), Similarity Rating: 0.20/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.20/1.00
# Movie: Nocturnal Animals, Similarity Rating: 0.20/1.00
# Movie: Psycho (1960), Similarity Rating: 0.20/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.20/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.20/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.20/1.00
# Movie: Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984), Similarity Rating: 0.20/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.20/1.00
# Movie: Sorry to Bother You (2018), Similarity Rating: 0.19/1.00
# Movie: The Favourite, Similarity Rating: 0.19/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.19/1.00
# Movie: Frozen (2013), Similarity Rating: 0.19/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.19/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.19/1.00
# Movie: Hell or High Water (2016), Similarity Rating: 0.19/1.00
# Movie: Suspiria (2017), Similarity Rating: 0.19/1.00
# Movie: 101 Dalmatians (One Hundred and One Dalmatians) (1961), Similarity Rating: 0.19/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.19/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.19/1.00
# Movie: Alice in Wonderland (2010), Similarity Rating: 0.18/1.00
# Movie: Gattaca (1997), Similarity Rating: 0.18/1.00
# Movie: Sin City (2005), Similarity Rating: 0.18/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.18/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.18/1.00
# Movie: Lives of Others, The (Das leben der Anderen) (2006), Similarity Rating: 0.18/1.00
# Movie: Peter Pan (1953), Similarity Rating: 0.18/1.00
# Movie: Casino (1995), Similarity Rating: 0.18/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.18/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.17/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.17/1.00
# Movie: Burn After Reading (2008), Similarity Rating: 0.17/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.17/1.00
# Movie: Green Room (2015), Similarity Rating: 0.17/1.00
# Movie: The Machinist (2004), Similarity Rating: 0.17/1.00
# Movie: Martha Marcy May Marlene (2011), Similarity Rating: 0.17/1.00
# Movie: Collateral (2004), Similarity Rating: 0.17/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.17/1.00
# Movie: How to Train Your Dragon 2 (2014), Similarity Rating: 0.17/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.17/1.00
# Movie: Persepolis (2007), Similarity Rating: 0.17/1.00
# Movie: Mother! (2017), Similarity Rating: 0.17/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.17/1.00
# Movie: Boondock Saints, The (2000), Similarity Rating: 0.16/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.16/1.00
# Movie: This Is Spinal Tap (1984), Similarity Rating: 0.16/1.00
# Movie: The Hateful Eight (2015), Similarity Rating: 0.16/1.00
# Movie: Sunshine (2007), Similarity Rating: 0.16/1.00
# Movie: It Follows (2014), Similarity Rating: 0.16/1.00
# Movie: The Platform (2019), Similarity Rating: 0.16/1.00
# Movie: Clerks (1994), Similarity Rating: 0.16/1.00
# Movie: Incredibles, The (2004), Similarity Rating: 0.16/1.00
# Movie: Seven Psychopaths (2012), Similarity Rating: 0.16/1.00
# Movie: Jungle Book, The (1967), Similarity Rating: 0.16/1.00
# Movie: Dark Knight, The (2008), Similarity Rating: 0.16/1.00
# Movie: Rosemary's Baby (1968), Similarity Rating: 0.15/1.00
# Movie: Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000), Similarity Rating: 0.15/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.15/1.00
# Movie: District 9 (2009), Similarity Rating: 0.15/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.15/1.00
# Movie: Charlie and the Chocolate Factory (2005), Similarity Rating: 0.15/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.15/1.00
# Movie: Winter's Bone (2010), Similarity Rating: 0.15/1.00
# Movie: Watchmen (2009), Similarity Rating: 0.15/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.15/1.00
# Movie: Inherent Vice (2014), Similarity Rating: 0.15/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.15/1.00
# Movie: Almost Famous (2000), Similarity Rating: 0.15/1.00
# Movie: Blue Ruin (2013), Similarity Rating: 0.14/1.00
# Movie: 12 Years a Slave (2013), Similarity Rating: 0.14/1.00
# Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Similarity Rating: 0.14/1.00
# Movie: Megamind (2010), Similarity Rating: 0.14/1.00
# Movie: Thank You for Smoking (2006), Similarity Rating: 0.14/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.14/1.00
# Movie: Split (2017), Similarity Rating: 0.14/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.14/1.00
# Movie: Apollo 13 (1995), Similarity Rating: 0.14/1.00
# Movie: Help, The (2011), Similarity Rating: 0.14/1.00
# Movie: Austin Powers: International Man of Mystery (1997), Similarity Rating: 0.14/1.00
# Movie: Grosse Pointe Blank (1997), Similarity Rating: 0.14/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.14/1.00
# Movie: Million Dollar Baby (2004), Similarity Rating: 0.14/1.00
# Movie: Hurt Locker, The (2008), Similarity Rating: 0.14/1.00
# Movie: La La Land (2016), Similarity Rating: 0.14/1.00
# Movie: Hitchhiker's Guide to the Galaxy, The (2005), Similarity Rating: 0.14/1.00
# Movie: Princess Bride, The (1987), Similarity Rating: 0.14/1.00
# Movie: Armageddon (1998), Similarity Rating: 0.14/1.00
# Movie: 21 Jump Street (2012), Similarity Rating: 0.13/1.00
# Movie: I Saw the Devil (Akmareul boatda) (2010), Similarity Rating: 0.13/1.00
# Movie: Sicario (2015), Similarity Rating: 0.13/1.00
# Movie: Tarzan (1999), Similarity Rating: 0.13/1.00
# Movie: Sideways (2004), Similarity Rating: 0.13/1.00
# Movie: Looper (2012), Similarity Rating: 0.13/1.00
# Movie: It Comes at Night (2017), Similarity Rating: 0.13/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.13/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.13/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.13/1.00
# Movie: Ice Age (2002), Similarity Rating: 0.13/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.13/1.00
# Movie: Before Midnight (2013), Similarity Rating: 0.13/1.00
# Movie: Grave of the Fireflies (Hotaru no haka) (1988), Similarity Rating: 0.13/1.00
# Movie: The Lego Movie (2014), Similarity Rating: 0.13/1.00
# Movie: Battle Royale (Batoru rowaiaru) (2000), Similarity Rating: 0.13/1.00
# Movie: Argo (2012), Similarity Rating: 0.13/1.00
# Movie: Snowpiercer (2013), Similarity Rating: 0.13/1.00
# Movie: Little Women (2019), Similarity Rating: 0.13/1.00
# Movie: Harry Potter and the Prisoner of Azkaban (2004), Similarity Rating: 0.13/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.13/1.00
# Movie: Frances Ha (2012), Similarity Rating: 0.13/1.00
# Movie: Tenet (2020), Similarity Rating: 0.13/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.13/1.00
# Movie: Primer (2004), Similarity Rating: 0.13/1.00
# Movie: Great Beauty, The (Grande Bellezza, La) (2013), Similarity Rating: 0.13/1.00
# Movie: Mommy (2014), Similarity Rating: 0.13/1.00
# Movie: Independence Day (a.k.a. ID4) (1996), Similarity Rating: 0.13/1.00
# Movie: Blazing Saddles (1974), Similarity Rating: 0.13/1.00
# Movie: Taken (2008), Similarity Rating: 0.13/1.00
# Movie: Beetlejuice (1988), Similarity Rating: 0.13/1.00
# Movie: Hercules (1997), Similarity Rating: 0.13/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.13/1.00
# Movie: Bug's Life, A (1998), Similarity Rating: 0.12/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.12/1.00
# Movie: Tucker & Dale vs Evil (2010), Similarity Rating: 0.12/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.12/1.00
# Movie: Love Actually (2003), Similarity Rating: 0.12/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.12/1.00
# Movie: Pi (1998), Similarity Rating: 0.12/1.00
# Movie: Only Lovers Left Alive (2013), Similarity Rating: 0.12/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.12/1.00
# Movie: About Time (2013), Similarity Rating: 0.12/1.00
# Movie: Jaws (1975), Similarity Rating: 0.12/1.00
# Movie: Matrix Reloaded, The (2003), Similarity Rating: 0.12/1.00
# Movie: Blue Is the Warmest Color (La vie d'Adèle) (2013), Similarity Rating: 0.12/1.00
# Movie: When Harry Met Sally... (1989), Similarity Rating: 0.12/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.12/1.00
# Movie: Blade Runner 2049 (2017), Similarity Rating: 0.12/1.00
# Movie: Carol (2015), Similarity Rating: 0.12/1.00
# Movie: Thoroughbreds (2018), Similarity Rating: 0.12/1.00
# Movie: Life of Pi (2012), Similarity Rating: 0.12/1.00
# Movie: Limitless (2011), Similarity Rating: 0.12/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.12/1.00
# Movie: Whisper of the Heart (Mimi wo sumaseba) (1995), Similarity Rating: 0.12/1.00
# Movie: Young Frankenstein (1974), Similarity Rating: 0.12/1.00
# Movie: Hugo (2011), Similarity Rating: 0.12/1.00
# Movie: Brawl in Cell Block 99 (2017), Similarity Rating: 0.12/1.00
# Movie: Climax (2018), Similarity Rating: 0.12/1.00
# Movie: Brave (2012), Similarity Rating: 0.12/1.00
# Movie: Logan (2017), Similarity Rating: 0.12/1.00
# Movie: Inside Man (2006), Similarity Rating: 0.12/1.00
# Movie: Swingers (1996), Similarity Rating: 0.12/1.00
# Movie: Dark City (1998), Similarity Rating: 0.12/1.00
# Movie: Hunt for Red October, The (1990), Similarity Rating: 0.11/1.00
# Movie: Sleeping Beauty (1959), Similarity Rating: 0.11/1.00
# 'jo men det gör dom, har typ alla förrutom guardians of the galaxy på min watchlist haha\noch det stämmer att de jag redan hade sett som totoro hade jag inte rateat'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=zorrodor_ratings,
    my_data=zorrodor_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)

# params:    
"""
min_avg_rating=2.5
user_min_percentile=0.25
user_max_percentile=0.999
min_ratings_per_movie=3
max_users_per_movie=250
user_similarity_threshold=0.15
fit: 
n_components=200,
sample_size=1,
max_iter=800
"""
# zorro:
# "Dom första 20 är alla bra filmer"
# "Eller de e nästan bara grejer jag gillar"
# "Några luriga dock men de mesta e gött"
# "Jag har rateat ganska lite också"
# "Så den har inte sååå mkt att gå på"
# Out:
# You've rated 45 movies
# Found 9270 movies you haven't rated
#
# Top Recommendations:
# Movie: Welcome to the Dollhouse (1995), Similarity Rating: 0.35/1.00
# Movie: Aliens (1986), Similarity Rating: 0.27/1.00
# Movie: Rushmore (1998), Similarity Rating: 0.25/1.00
# Movie: Royal Tenenbaums, The (2001), Similarity Rating: 0.23/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.22/1.00
# Movie: Three Colors: Blue (Trois couleurs: Bleu) (1993), Similarity Rating: 0.21/1.00
# Movie: Three Colors: White (Trzy kolory: Bialy) (1994), Similarity Rating: 0.16/1.00
# Movie: Big Lebowski, The (1998), Similarity Rating: 0.15/1.00
# Movie: Gosford Park (2001), Similarity Rating: 0.14/1.00
# Movie: Shallow Grave (1994), Similarity Rating: 0.14/1.00
# Movie: Waiting for Guffman (1996), Similarity Rating: 0.14/1.00
# Movie: Parasite (2019), Similarity Rating: 0.12/1.00
# Movie: Life Aquatic with Steve Zissou, The (2004), Similarity Rating: 0.11/1.00
# Movie: 10 Things I Hate About You (1999), Similarity Rating: 0.10/1.00
# Movie: No Country for Old Men (2007), Similarity Rating: 0.10/1.00
# Movie: Jacob's Ladder (1990), Similarity Rating: 0.09/1.00
# Movie: High Fidelity (2000), Similarity Rating: 0.09/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.09/1.00
# Movie: Garden State (2004), Similarity Rating: 0.09/1.00
# Movie: Adaptation (2002), Similarity Rating: 0.08/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.08/1.00
# Movie: Being There (1979), Similarity Rating: 0.08/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.08/1.00
# Movie: Office Space (1999), Similarity Rating: 0.08/1.00
# Movie: Delicatessen (1991), Similarity Rating: 0.08/1.00
# Movie: Get Out (2017), Similarity Rating: 0.08/1.00
# Movie: Before Sunrise (1995), Similarity Rating: 0.08/1.00
# Movie: Alien³ (a.k.a. Alien 3) (1992), Similarity Rating: 0.07/1.00
# Movie: Knives Out (2019), Similarity Rating: 0.07/1.00
# Movie: Persona (1966), Similarity Rating: 0.07/1.00
# Movie: Man on the Moon (1999), Similarity Rating: 0.07/1.00
# Movie: This Is Spinal Tap (1984), Similarity Rating: 0.07/1.00
# Movie: 50 First Dates (2004), Similarity Rating: 0.07/1.00
# Movie: Sideways (2004), Similarity Rating: 0.07/1.00
# Movie: Moonstruck (1987), Similarity Rating: 0.07/1.00
# Movie: Separation, A (Jodaeiye Nader az Simin) (2011), Similarity Rating: 0.06/1.00
# Movie: Solaris (Solyaris) (1972), Similarity Rating: 0.06/1.00
# Movie: Perfect Blue (1997), Similarity Rating: 0.06/1.00
# Movie: Old Boy (2003), Similarity Rating: 0.06/1.00
# Movie: 13 Going on 30 (2004), Similarity Rating: 0.06/1.00
# Movie: Avventura, L' (Adventure, The) (1960), Similarity Rating: 0.06/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.06/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.06/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.06/1.00
# Movie: American Werewolf in London, An (1981), Similarity Rating: 0.06/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.06/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.06/1.00
# Movie: Alien: Resurrection (1997), Similarity Rating: 0.06/1.00
# Movie: Happiness (1998), Similarity Rating: 0.06/1.00
# Movie: Fargo (1996), Similarity Rating: 0.06/1.00
# Movie: 8 1/2 (8½) (1963), Similarity Rating: 0.05/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.05/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.05/1.00
# Movie: Stalker (1979), Similarity Rating: 0.05/1.00
# Movie: 2046 (2004), Similarity Rating: 0.05/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.05/1.00
# Movie: 27 Dresses (2008), Similarity Rating: 0.05/1.00
# Movie: Swingers (1996), Similarity Rating: 0.05/1.00
# Movie: Everything Everywhere All at Once (2022), Similarity Rating: 0.05/1.00
# Movie: 40-Year-Old Virgin, The (2005), Similarity Rating: 0.05/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.05/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.05/1.00
# Movie: M (1931), Similarity Rating: 0.05/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.05/1.00
# Movie: Whiplash (2014), Similarity Rating: 0.05/1.00
# Movie: RoboCop (1987), Similarity Rating: 0.05/1.00
# Movie: Mystery Science Theater 3000: The Movie (1996), Similarity Rating: 0.05/1.00
# Movie: O Brother, Where Art Thou? (2000), Similarity Rating: 0.05/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.05/1.00
# Movie: Lost Boys, The (1987), Similarity Rating: 0.05/1.00
# Movie: Discreet Charm of the Bourgeoisie, The (Charme discret de la bourgeoisie, Le) (1972), Similarity Rating: 0.05/1.00
# Movie: Exterminating Angel, The (Ángel exterminador, El) (1962), Similarity Rating: 0.05/1.00
# Movie: Mirror, The (Zerkalo) (1975), Similarity Rating: 0.05/1.00
# Movie: Akira (1988), Similarity Rating: 0.05/1.00
# Movie: Before Midnight (2013), Similarity Rating: 0.05/1.00
# Movie: Joker (2019), Similarity Rating: 0.05/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.05/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.05/1.00
# Movie: Crumb (1994), Similarity Rating: 0.05/1.00
# Movie: Wonder Boys (2000), Similarity Rating: 0.05/1.00
# Movie: Days of Being Wild (A Fei jingjyuhn) (1990), Similarity Rating: 0.04/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.04/1.00
# Movie: Almost Famous (2000), Similarity Rating: 0.04/1.00
# Movie: It Happened One Night (1934), Similarity Rating: 0.04/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.04/1.00
# Movie: Sunny (Sseo-ni) (2011), Similarity Rating: 0.04/1.00
# Movie: It Follows (2014), Similarity Rating: 0.04/1.00
# Movie: Dead Man (1995), Similarity Rating: 0.04/1.00
# Movie: Color Purple, The (1985), Similarity Rating: 0.04/1.00
# Movie: Saw (2004), Similarity Rating: 0.04/1.00
# Movie: There Will Be Blood (2007), Similarity Rating: 0.04/1.00
# Movie: Her (2013), Similarity Rating: 0.04/1.00
# Movie: Punch-Drunk Love (2002), Similarity Rating: 0.04/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.04/1.00
# Movie: Inglourious Basterds (2009), Similarity Rating: 0.04/1.00
# Movie: The Favourite, Similarity Rating: 0.04/1.00
# Movie: Little Miss Sunshine (2006), Similarity Rating: 0.04/1.00
# Movie: Diabolique (Les diaboliques) (1955), Similarity Rating: 0.04/1.00
# Movie: Fallen Angels (Duo luo tian shi) (1995), Similarity Rating: 0.04/1.00
# Movie: Haunting, The (1963), Similarity Rating: 0.04/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.04/1.00
# Movie: Fly, The (1958), Similarity Rating: 0.04/1.00
# Movie: Brazil (1985), Similarity Rating: 0.04/1.00
# Movie: Blazing Saddles (1974), Similarity Rating: 0.04/1.00
# Movie: Children of Men (2006), Similarity Rating: 0.04/1.00
# Movie: Saw II (2005), Similarity Rating: 0.04/1.00
# Movie: Apartment, The (1960), Similarity Rating: 0.04/1.00
# Movie: Us (2019), Similarity Rating: 0.04/1.00
# Movie: Full Metal Jacket (1987), Similarity Rating: 0.04/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.04/1.00
# Movie: Frances Ha (2012), Similarity Rating: 0.04/1.00
# Movie: Helter Skelter (2012), Similarity Rating: 0.04/1.00
# Movie: Letter from an Unknown Woman (1948), Similarity Rating: 0.04/1.00
# Movie: Only Lovers Left Alive (2013), Similarity Rating: 0.04/1.00
# Movie: Ghost Dog: The Way of the Samurai (1999), Similarity Rating: 0.04/1.00
# Movie: Nightcrawler (2014), Similarity Rating: 0.04/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.04/1.00
# Movie: All About My Mother (Todo sobre mi madre) (1999), Similarity Rating: 0.04/1.00
# Movie: Brokeback Mountain (2005), Similarity Rating: 0.04/1.00
# Movie: My Left Foot (1989), Similarity Rating: 0.04/1.00
# Movie: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), Similarity Rating: 0.04/1.00
# Movie: Burning (2018), Similarity Rating: 0.04/1.00
# Movie: Midnight Cowboy (1969), Similarity Rating: 0.04/1.00
# Movie: Noriko's Dinner Table (Noriko no shokutaku) (2005), Similarity Rating: 0.04/1.00
# Movie: Day the Earth Stood Still, The (1951), Similarity Rating: 0.04/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.04/1.00
# Movie: About a Boy (2002), Similarity Rating: 0.04/1.00
# Movie: Ice Storm, The (1997), Similarity Rating: 0.04/1.00
# Movie: Mystic River (2003), Similarity Rating: 0.04/1.00
# Movie: Sorry to Bother You (2018), Similarity Rating: 0.04/1.00
# Movie: Ginger Snaps (2000), Similarity Rating: 0.04/1.00
# Movie: Elephant Man, The (1980), Similarity Rating: 0.04/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.04/1.00
# Movie: Notebook, The (2004), Similarity Rating: 0.04/1.00
# Movie: Repo Man (1984), Similarity Rating: 0.04/1.00
# Movie: Blair Witch Project, The (1999), Similarity Rating: 0.04/1.00
# Movie: In The Heights (2021), Similarity Rating: 0.04/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.04/1.00
# Movie: Red Shoes, The (1948), Similarity Rating: 0.04/1.00
# Movie: Seven (a.k.a. Se7en) (1995), Similarity Rating: 0.03/1.00
# Movie: Fisher King, The (1991), Similarity Rating: 0.03/1.00
# Movie: Andrei Rublev (Andrey Rublyov) (1969), Similarity Rating: 0.03/1.00
# Movie: Dolce Vita, La (1960), Similarity Rating: 0.03/1.00
# Movie: Shazam! (2019), Similarity Rating: 0.03/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.03/1.00
# Movie: Miller's Crossing (1990), Similarity Rating: 0.03/1.00
# Movie: The Witch (2015), Similarity Rating: 0.03/1.00
# Movie: Network (1976), Similarity Rating: 0.03/1.00
# Movie: Dragonslayer (1981), Similarity Rating: 0.03/1.00
# Movie: Chinatown (1974), Similarity Rating: 0.03/1.00
# Movie: Frighteners, The (1996), Similarity Rating: 0.03/1.00
# Movie: Goodfellas (1990), Similarity Rating: 0.03/1.00
# Movie: Cube (1997), Similarity Rating: 0.03/1.00
# Movie: One Cut of the Dead (2017), Similarity Rating: 0.03/1.00
# Movie: Hudsucker Proxy, The (1994), Similarity Rating: 0.03/1.00
# Movie: Seventh Seal, The (Sjunde inseglet, Det) (1957), Similarity Rating: 0.03/1.00
# Movie: Eclisse, L' (Eclipse) (1962), Similarity Rating: 0.03/1.00
# Movie: Blade (1998), Similarity Rating: 0.03/1.00
# Movie: Sunset Blvd. (a.k.a. Sunset Boulevard) (1950), Similarity Rating: 0.03/1.00
# Movie: Under the Blossoming Cherry Trees (1975), Similarity Rating: 0.03/1.00
# Movie: Million Dollar Baby (2004), Similarity Rating: 0.03/1.00
# Movie: 101 Dalmatians (1996), Similarity Rating: 0.03/1.00
# Movie: Squid and the Whale, The (2005), Similarity Rating: 0.03/1.00
# Movie: Killing Fields, The (1984), Similarity Rating: 0.03/1.00
# Movie: Science of Sleep, The (La science des rêves) (2006), Similarity Rating: 0.03/1.00
# Movie: Into the Wild (2007), Similarity Rating: 0.03/1.00
# Movie: Godzilla (Gojira) (1954), Similarity Rating: 0.03/1.00
# Movie: Women on the Verge of a Nervous Breakdown (Mujeres al borde de un ataque de nervios) (1988), Similarity Rating: 0.03/1.00
# Movie: Cleo from 5 to 7 (Cléo de 5 à 7) (1962), Similarity Rating: 0.03/1.00
# Movie: Psycho (1960), Similarity Rating: 0.03/1.00
# Movie: The Endless (2017), Similarity Rating: 0.03/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.03/1.00
# Movie: Silent Hill (2006), Similarity Rating: 0.03/1.00
# Movie: Eve's Bayou (1997), Similarity Rating: 0.03/1.00
# Movie: Samouraï, Le (Godson, The) (1967), Similarity Rating: 0.03/1.00
# Movie: Hunt, The (Jagten) (2012), Similarity Rating: 0.03/1.00
# Movie: First Reformed (2017), Similarity Rating: 0.03/1.00
# Movie: Strada, La (1954), Similarity Rating: 0.03/1.00
# Movie: Kwaidan (Kaidan) (1964), Similarity Rating: 0.03/1.00
# Movie: Panic Room (2002), Similarity Rating: 0.03/1.00
# Movie: Curious Case of Benjamin Button, The (2008), Similarity Rating: 0.03/1.00
# Movie: Young Guns (1988), Similarity Rating: 0.03/1.00
# Movie: Big Chill, The (1983), Similarity Rating: 0.03/1.00
# Movie: Ghost World (2001), Similarity Rating: 0.03/1.00
# Movie: Wild Strawberries (Smultronstället) (1957), Similarity Rating: 0.03/1.00
# Movie: Mad Max: Fury Road (2015), Similarity Rating: 0.03/1.00
# Movie: The Machinist (2004), Similarity Rating: 0.03/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.03/1.00
# Movie: Clerks (1994), Similarity Rating: 0.03/1.00
# Movie: Lives of Others, The (Das leben der Anderen) (2006), Similarity Rating: 0.03/1.00
# Movie: The Ritual (2017), Similarity Rating: 0.03/1.00
# Movie: Falling Down (1993), Similarity Rating: 0.03/1.00
# Movie: In Bruges (2008), Similarity Rating: 0.03/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.03/1.00
# Movie: Short Cuts (1993), Similarity Rating: 0.03/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.03/1.00
# Movie: Moon (2009), Similarity Rating: 0.03/1.00
# Movie: Once (2006), Similarity Rating: 0.03/1.00
# Movie: Metropolis (1927), Similarity Rating: 0.03/1.00
# Movie: Resolution (2012), Similarity Rating: 0.03/1.00
# '\nmin_avg_rating=2.5\nuser_min_percentile=0.25\nuser_max_percentile=0.999\nmin_ratings_per_movie=3\nmax_users_per_movie=250\nuser_similarity_threshold=0.15\nfit: \nn_components=200,\nsample_size=1,\nmax_iter=800\n'

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=lukas_ratings,
    my_data=lukas_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 151 movies
# Found 9173 movies you haven't rated
#
# Top Recommendations:
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.81/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.49/1.00
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.45/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.38/1.00
# Movie: Parasite (2019), Similarity Rating: 0.36/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.32/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.30/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.29/1.00
# Movie: Monsters, Inc. (2001), Similarity Rating: 0.29/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.27/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.25/1.00
# Movie: Avengers, The (2012), Similarity Rating: 0.23/1.00
# Movie: Deadpool (2016), Similarity Rating: 0.22/1.00
# Movie: Shrek (2001), Similarity Rating: 0.22/1.00
# Movie: Doctor Strange (2016), Similarity Rating: 0.21/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.21/1.00
# Movie: Joker (2019), Similarity Rating: 0.21/1.00
# Movie: Ready Player One, Similarity Rating: 0.19/1.00
# Movie: Coco (2017), Similarity Rating: 0.18/1.00
# Movie: Iron Man 2 (2010), Similarity Rating: 0.18/1.00
# Movie: Wonder Woman (2017), Similarity Rating: 0.18/1.00
# Movie: Logan (2017), Similarity Rating: 0.18/1.00
# Movie: Howl's Moving Castle (Hauru no ugoku shiro) (2004), Similarity Rating: 0.18/1.00
# Movie: Arrival (2016), Similarity Rating: 0.17/1.00
# Movie: Avengers: Age of Ultron (2015), Similarity Rating: 0.17/1.00
# Movie: Now You See Me 2 (2016), Similarity Rating: 0.17/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.16/1.00
# Movie: My Neighbor Totoro (Tonari no Totoro) (1988), Similarity Rating: 0.16/1.00
# Movie: Ghostbusters (a.k.a. Ghost Busters) (1984), Similarity Rating: 0.16/1.00
# Movie: Indiana Jones and the Temple of Doom (1984), Similarity Rating: 0.15/1.00
# Movie: Ant-Man and the Wasp (2018), Similarity Rating: 0.15/1.00
# Movie: Now You See Me (2013), Similarity Rating: 0.15/1.00
# Movie: Aladdin (1992), Similarity Rating: 0.15/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.15/1.00
# Movie: Moana (2016), Similarity Rating: 0.15/1.00
# Movie: E.T. the Extra-Terrestrial (1982), Similarity Rating: 0.15/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.14/1.00
# Movie: X-Men: First Class (2011), Similarity Rating: 0.14/1.00
# Movie: Iron Man 3 (2013), Similarity Rating: 0.14/1.00
# Movie: Cars (2006), Similarity Rating: 0.14/1.00
# Movie: Ex Machina (2015), Similarity Rating: 0.14/1.00
# Movie: Silence of the Lambs, The (1991), Similarity Rating: 0.14/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.13/1.00
# Movie: Ponyo (Gake no ue no Ponyo) (2008), Similarity Rating: 0.13/1.00
# Movie: Passengers (2016), Similarity Rating: 0.13/1.00
# Movie: Princess Mononoke (Mononoke-hime) (1997), Similarity Rating: 0.13/1.00
# Movie: Kingsman: The Secret Service (2015), Similarity Rating: 0.13/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.13/1.00
# Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Similarity Rating: 0.13/1.00
# Movie: Die Hard (1988), Similarity Rating: 0.13/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.13/1.00
# Movie: Jumanji: Welcome to the Jungle (2017), Similarity Rating: 0.13/1.00
# Movie: Casino Royale (2006), Similarity Rating: 0.13/1.00
# Movie: Apollo 13 (1995), Similarity Rating: 0.13/1.00
# Movie: Ant-Man (2015), Similarity Rating: 0.13/1.00
# Movie: Jojo Rabbit (2019), Similarity Rating: 0.13/1.00
# Movie: The Hunger Games: Catching Fire (2013), Similarity Rating: 0.13/1.00
# Movie: Frozen (2013), Similarity Rating: 0.12/1.00
# Movie: Thor (2011), Similarity Rating: 0.12/1.00
# Movie: X-Men (2000), Similarity Rating: 0.12/1.00
# Movie: John Wick (2014), Similarity Rating: 0.12/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.12/1.00
# Movie: Moneyball (2011), Similarity Rating: 0.12/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.12/1.00
# Movie: Up (2009), Similarity Rating: 0.12/1.00
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.12/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.12/1.00
# Movie: Incredibles 2 (2018), Similarity Rating: 0.12/1.00
# Movie: Lion King, The (1994), Similarity Rating: 0.12/1.00
# Movie: Skyfall (2012), Similarity Rating: 0.12/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.12/1.00
# Movie: Bohemian Rhapsody (2018), Similarity Rating: 0.11/1.00
# Movie: Maze Runner, The (2014), Similarity Rating: 0.11/1.00
# Movie: Midsommar (2019), Similarity Rating: 0.11/1.00
# Movie: Grand Budapest Hotel, The (2014), Similarity Rating: 0.11/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.11/1.00
# Movie: Soul (2020), Similarity Rating: 0.11/1.00
# Movie: Shrek 2 (2004), Similarity Rating: 0.11/1.00
# Movie: Pursuit of Happyness, The (2006), Similarity Rating: 0.11/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.11/1.00
# Movie: The Lighthouse (2019), Similarity Rating: 0.11/1.00
# Movie: National Treasure (2004), Similarity Rating: 0.11/1.00
# Movie: Amazing Spider-Man, The (2012), Similarity Rating: 0.11/1.00
# Movie: Star Trek (2009), Similarity Rating: 0.11/1.00
# Movie: Captain Marvel (2018), Similarity Rating: 0.11/1.00
# Movie: Mulan (1998), Similarity Rating: 0.11/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.11/1.00
# Movie: Shazam! (2019), Similarity Rating: 0.11/1.00
# Movie: District 9 (2009), Similarity Rating: 0.10/1.00
# Movie: Superbad (2007), Similarity Rating: 0.10/1.00
# Movie: Venom (2018), Similarity Rating: 0.10/1.00
# Movie: Speed (1994), Similarity Rating: 0.10/1.00
# Movie: Fantastic Beasts and Where to Find Them (2016), Similarity Rating: 0.10/1.00
# Movie: Ferris Bueller's Day Off (1986), Similarity Rating: 0.10/1.00
# Movie: O Brother, Where Art Thou? (2000), Similarity Rating: 0.10/1.00
# Movie: Us (2019), Similarity Rating: 0.10/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.10/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.10/1.00
# Movie: National Lampoon's Vacation (1983), Similarity Rating: 0.10/1.00
# Movie: Hereditary (2018), Similarity Rating: 0.10/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.10/1.00
# Movie: Eternal Sunshine of the Spotless Mind (2004), Similarity Rating: 0.10/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.10/1.00
# Movie: Incredible Hulk, The (2008), Similarity Rating: 0.10/1.00
# Movie: Edge of Tomorrow (2014), Similarity Rating: 0.10/1.00
# Movie: Fletch (1985), Similarity Rating: 0.10/1.00
# Movie: Call Me by Your Name (2017), Similarity Rating: 0.10/1.00
# Movie: Cloudy with a Chance of Meatballs (2009), Similarity Rating: 0.10/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.09/1.00
# Movie: Searching (2018), Similarity Rating: 0.09/1.00
# Movie: Fantastic Mr. Fox (2009), Similarity Rating: 0.09/1.00
# Movie: Her (2013), Similarity Rating: 0.09/1.00
# Movie: The Greatest Showman (2017), Similarity Rating: 0.09/1.00
# Movie: X-Men Origins: Wolverine (2009), Similarity Rating: 0.09/1.00
# Movie: Back to the Future Part II (1989), Similarity Rating: 0.09/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.09/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.09/1.00
# Movie: Moonlight, Similarity Rating: 0.09/1.00
# Movie: Monsters University (2013), Similarity Rating: 0.09/1.00
# Movie: Hidden Figures (2016), Similarity Rating: 0.09/1.00
# Movie: Limitless (2011), Similarity Rating: 0.09/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.09/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.09/1.00
# Movie: Onward (2020), Similarity Rating: 0.09/1.00
# Movie: Tangled (2010), Similarity Rating: 0.09/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.09/1.00
# Movie: Nightmare Before Christmas, The (1993), Similarity Rating: 0.09/1.00
# Movie: Once Upon a Time in Hollywood (2019), Similarity Rating: 0.09/1.00
# Movie: Bug's Life, A (1998), Similarity Rating: 0.09/1.00
# Movie: Top Gun (1986), Similarity Rating: 0.09/1.00
# Movie: Antz (1998), Similarity Rating: 0.09/1.00
# Movie: La La Land (2016), Similarity Rating: 0.09/1.00
# Movie: Brave (2012), Similarity Rating: 0.09/1.00
# Movie: Little Women (2019), Similarity Rating: 0.09/1.00
# Movie: Cast Away (2000), Similarity Rating: 0.09/1.00
# Movie: Ocean's 8 (2018), Similarity Rating: 0.09/1.00
# Movie: Coraline (2009), Similarity Rating: 0.08/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.08/1.00
# Movie: Chicken Run (2000), Similarity Rating: 0.08/1.00
# Movie: John Wick: Chapter Two (2017), Similarity Rating: 0.08/1.00
# Movie: Frozen II (2019), Similarity Rating: 0.08/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.08/1.00
# Movie: Hobbit: An Unexpected Journey, The (2012), Similarity Rating: 0.08/1.00
# Movie: Trading Places (1983), Similarity Rating: 0.08/1.00
# Movie: Inception (2010), Similarity Rating: 0.08/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.08/1.00
# Movie: Dances with Wolves (1990), Similarity Rating: 0.08/1.00
# Movie: The Fault in Our Stars (2014), Similarity Rating: 0.08/1.00
# Movie: Ender's Game (2013), Similarity Rating: 0.08/1.00
# Movie: Independence Day (a.k.a. ID4) (1996), Similarity Rating: 0.08/1.00
# Movie: Blade Runner 2049 (2017), Similarity Rating: 0.08/1.00
# Movie: Office Space (1999), Similarity Rating: 0.08/1.00
# Movie: Spider-Man (2002), Similarity Rating: 0.08/1.00
# Movie: Drive (2011), Similarity Rating: 0.08/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.08/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.08/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.08/1.00
# Movie: Dunkirk (2017), Similarity Rating: 0.08/1.00
# Movie: A Quiet Place (2018), Similarity Rating: 0.08/1.00
# Movie: Serenity (2005), Similarity Rating: 0.08/1.00
# Movie: Thor: The Dark World (2013), Similarity Rating: 0.08/1.00
# Movie: Raya and the Last Dragon (2021), Similarity Rating: 0.08/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.08/1.00
# Movie: Spider-Man 3 (2007), Similarity Rating: 0.08/1.00
# Movie: Despicable Me 2 (2013), Similarity Rating: 0.08/1.00
# Movie: The Hunger Games: Mockingjay - Part 1 (2014), Similarity Rating: 0.08/1.00
# Movie: BlacKkKlansman (2018), Similarity Rating: 0.08/1.00
# Movie: X2: X-Men United (2003), Similarity Rating: 0.08/1.00
# Movie: Batman (1989), Similarity Rating: 0.08/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.08/1.00
# Movie: Divergent (2014), Similarity Rating: 0.08/1.00
# Movie: Star Trek Into Darkness (2013), Similarity Rating: 0.08/1.00
# Movie: The Martian (2015), Similarity Rating: 0.08/1.00
# Movie: The Amazing Spider-Man 2 (2014), Similarity Rating: 0.08/1.00
# Movie: Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006), Similarity Rating: 0.08/1.00
# Movie: Children of Men (2006), Similarity Rating: 0.08/1.00
# Movie: Dead Poets Society (1989), Similarity Rating: 0.08/1.00
# Movie: Mr. & Mrs. Smith (2005), Similarity Rating: 0.08/1.00
# Movie: Percy Jackson & the Olympians: The Lightning Thief (2010), Similarity Rating: 0.08/1.00
# Movie: Blind Side, The  (2009), Similarity Rating: 0.08/1.00
# Movie: Pokémon: Detective Pikachu (2019), Similarity Rating: 0.08/1.00
# Movie: Aladdin (2019), Similarity Rating: 0.08/1.00
# Movie: 1917 (2019), Similarity Rating: 0.08/1.00
# Movie: How to Train Your Dragon 2 (2014), Similarity Rating: 0.08/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.08/1.00
# Movie: The Fate of the Furious (2017), Similarity Rating: 0.08/1.00
# Movie: Alita: Battle Angel (2019), Similarity Rating: 0.07/1.00
# Movie: Train to Busan (2016), Similarity Rating: 0.07/1.00
# Movie: The Big Sick (2017), Similarity Rating: 0.07/1.00
# Movie: Mrs. Doubtfire (1993), Similarity Rating: 0.07/1.00
# Movie: Upgrade (2018), Similarity Rating: 0.07/1.00
# Movie: Gravity (2013), Similarity Rating: 0.07/1.00
# Movie: Matrix Reloaded, The (2003), Similarity Rating: 0.07/1.00
# Movie: Green Book (2018), Similarity Rating: 0.07/1.00
# Movie: Yes Man (2008), Similarity Rating: 0.07/1.00
# Movie: Moon (2009), Similarity Rating: 0.07/1.00
# Movie: A Star Is Born (2018), Similarity Rating: 0.07/1.00
# Movie: Rock, The (1996), Similarity Rating: 0.07/1.00
# Movie: Spaceballs (1987), Similarity Rating: 0.07/1.00
# Movie: Stargate (1994), Similarity Rating: 0.07/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=clara_ratings,
    my_data=clara_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 83 movies
# Found 9226 movies you haven't rated
#
# Top Recommendations:
# Movie: Fight Club (1999), Similarity Rating: 0.32/1.00
# Movie: Forrest Gump (1994), Similarity Rating: 0.31/1.00
# Movie: Matrix, The (1999), Similarity Rating: 0.31/1.00
# Movie: X-Men: First Class (2011), Similarity Rating: 0.28/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.25/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.24/1.00
# Movie: Spider-Man: Into the Spider-Verse (2018), Similarity Rating: 0.24/1.00
# Movie: Bourne Ultimatum, The (2007), Similarity Rating: 0.21/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.19/1.00
# Movie: Amazing Spider-Man, The (2012), Similarity Rating: 0.19/1.00
# Movie: Lord of the Rings: The Return of the King, The (2003), Similarity Rating: 0.16/1.00
# Movie: Guardians of the Galaxy 2 (2017), Similarity Rating: 0.16/1.00
# Movie: Lord of the Rings: The Two Towers, The (2002), Similarity Rating: 0.15/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.15/1.00
# Movie: Pulp Fiction (1994), Similarity Rating: 0.15/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.14/1.00
# Movie: Illusionist, The (2006), Similarity Rating: 0.14/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.12/1.00
# Movie: Proposal, The (2009), Similarity Rating: 0.12/1.00
# Movie: X-Men: Days of Future Past (2014), Similarity Rating: 0.12/1.00
# Movie: Now You See Me (2013), Similarity Rating: 0.11/1.00
# Movie: Catch Me If You Can (2002), Similarity Rating: 0.11/1.00
# Movie: Blood Diamond (2006), Similarity Rating: 0.11/1.00
# Movie: Incredible Hulk, The (2008), Similarity Rating: 0.11/1.00
# Movie: Holiday, The (2006), Similarity Rating: 0.11/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.11/1.00
# Movie: Eyes Wide Shut (1999), Similarity Rating: 0.11/1.00
# Movie: Deadpool (2016), Similarity Rating: 0.10/1.00
# Movie: Inside Out (2015), Similarity Rating: 0.10/1.00
# Movie: Zootopia (2016), Similarity Rating: 0.10/1.00
# Movie: Spider-Man 2 (2004), Similarity Rating: 0.10/1.00
# Movie: Kingsman: The Secret Service (2015), Similarity Rating: 0.10/1.00
# Movie: Now You See Me 2 (2016), Similarity Rating: 0.09/1.00
# Movie: Coco (2017), Similarity Rating: 0.09/1.00
# Movie: Star Wars: Episode VII - The Force Awakens (2015), Similarity Rating: 0.09/1.00
# Movie: Memento (2000), Similarity Rating: 0.09/1.00
# Movie: The Amazing Spider-Man 2 (2014), Similarity Rating: 0.09/1.00
# Movie: X-Men (2000), Similarity Rating: 0.09/1.00
# Movie: Logan (2017), Similarity Rating: 0.09/1.00
# Movie: Lion King, The (1994), Similarity Rating: 0.08/1.00
# Movie: Spider-Man (2002), Similarity Rating: 0.08/1.00
# Movie: Spider-Man: No Way Home (2021), Similarity Rating: 0.08/1.00
# Movie: Love Actually (2003), Similarity Rating: 0.08/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.08/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.08/1.00
# Movie: Crazy, Stupid, Love. (2011), Similarity Rating: 0.08/1.00
# Movie: Cruel Intentions (1999), Similarity Rating: 0.08/1.00
# Movie: Pitch Perfect (2012), Similarity Rating: 0.08/1.00
# Movie: Knives Out (2019), Similarity Rating: 0.08/1.00
# Movie: Star Trek Into Darkness (2013), Similarity Rating: 0.08/1.00
# Movie: Sex, Lies, and Videotape (1989), Similarity Rating: 0.07/1.00
# Movie: Moana (2016), Similarity Rating: 0.07/1.00
# Movie: Baby Driver (2017), Similarity Rating: 0.07/1.00
# Movie: Wonder Woman (2017), Similarity Rating: 0.07/1.00
# Movie: Inside Man (2006), Similarity Rating: 0.07/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.07/1.00
# Movie: Lucky Number Slevin (2006), Similarity Rating: 0.07/1.00
# Movie: X2: X-Men United (2003), Similarity Rating: 0.07/1.00
# Movie: To All the Boys I've Loved Before (2018), Similarity Rating: 0.07/1.00
# Movie: Usual Suspects, The (1995), Similarity Rating: 0.06/1.00
# Movie: Taken (2008), Similarity Rating: 0.06/1.00
# Movie: Pacific Rim (2013), Similarity Rating: 0.06/1.00
# Movie: 13 Going on 30 (2004), Similarity Rating: 0.06/1.00
# Movie: Hitch (2005), Similarity Rating: 0.06/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.06/1.00
# Movie: Fast Five (Fast and the Furious 5, The) (2011), Similarity Rating: 0.06/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.06/1.00
# Movie: Ready Player One, Similarity Rating: 0.06/1.00
# Movie: How to Lose a Guy in 10 Days (2003), Similarity Rating: 0.06/1.00
# Movie: Schindler's List (1993), Similarity Rating: 0.06/1.00
# Movie: Pan's Labyrinth (Laberinto del fauno, El) (2006), Similarity Rating: 0.06/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.06/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.06/1.00
# Movie: The Fault in Our Stars (2014), Similarity Rating: 0.06/1.00
# Movie: Thomas Crown Affair, The (1999), Similarity Rating: 0.06/1.00
# Movie: Captain Marvel (2018), Similarity Rating: 0.06/1.00
# Movie: Apocalypto (2006), Similarity Rating: 0.06/1.00
# Movie: Groundhog Day (1993), Similarity Rating: 0.06/1.00
# Movie: Rise of the Planet of the Apes (2011), Similarity Rating: 0.06/1.00
# Movie: Spider-Man 3 (2007), Similarity Rating: 0.06/1.00
# Movie: Lethal Weapon 4 (1998), Similarity Rating: 0.06/1.00
# Movie: 21 Jump Street (2012), Similarity Rating: 0.06/1.00
# Movie: Boogie Nights (1997), Similarity Rating: 0.06/1.00
# Movie: Frozen (2013), Similarity Rating: 0.06/1.00
# Movie: Hobbit: An Unexpected Journey, The (2012), Similarity Rating: 0.06/1.00
# Movie: The Lego Movie (2014), Similarity Rating: 0.05/1.00
# Movie: Soul (2020), Similarity Rating: 0.05/1.00
# Movie: We're the Millers (2013), Similarity Rating: 0.05/1.00
# Movie: Munich (2005), Similarity Rating: 0.05/1.00
# Movie: Hotel Rwanda (2004), Similarity Rating: 0.05/1.00
# Movie: Green Mile, The (1999), Similarity Rating: 0.05/1.00
# Movie: Dial M for Murder (1954), Similarity Rating: 0.05/1.00
# Movie: Batman Begins (2005), Similarity Rating: 0.05/1.00
# Movie: Tangled (2010), Similarity Rating: 0.05/1.00
# Movie: Underworld (2003), Similarity Rating: 0.05/1.00
# Movie: Green Lantern (2011), Similarity Rating: 0.05/1.00
# Movie: Two Weeks Notice (2002), Similarity Rating: 0.05/1.00
# Movie: The Greatest Showman (2017), Similarity Rating: 0.05/1.00
# Movie: Bridget Jones's Diary (2001), Similarity Rating: 0.05/1.00
# Movie: Showgirls (1995), Similarity Rating: 0.05/1.00
# Movie: Italian Job, The (2003), Similarity Rating: 0.05/1.00
# Movie: Rogue One: A Star Wars Story (2016), Similarity Rating: 0.05/1.00
# Movie: Venom (2018), Similarity Rating: 0.05/1.00
# Movie: Something's Gotta Give (2003), Similarity Rating: 0.05/1.00
# Movie: Last King of Scotland, The (2006), Similarity Rating: 0.05/1.00
# Movie: Basic Instinct 2 (2006), Similarity Rating: 0.05/1.00
# Movie: Joker (2019), Similarity Rating: 0.05/1.00
# Movie: Dreamers, The (2003), Similarity Rating: 0.05/1.00
# Movie: Original Sin (2001), Similarity Rating: 0.05/1.00
# Movie: Piano Teacher, The (La pianiste) (2001), Similarity Rating: 0.04/1.00
# Movie: Casino Royale (2006), Similarity Rating: 0.04/1.00
# Movie: Furious 7 (2015), Similarity Rating: 0.04/1.00
# Movie: X-Men: The Last Stand (2006), Similarity Rating: 0.04/1.00
# Movie: Star Trek (2009), Similarity Rating: 0.04/1.00
# Movie: Frozen II (2019), Similarity Rating: 0.04/1.00
# Movie: Fifty Shades of Grey (2015), Similarity Rating: 0.04/1.00
# Movie: Alita: Battle Angel (2019), Similarity Rating: 0.04/1.00
# Movie: Other Woman, The (2014), Similarity Rating: 0.04/1.00
# Movie: Blind Side, The  (2009), Similarity Rating: 0.04/1.00
# Movie: Constantine (2005), Similarity Rating: 0.04/1.00
# Movie: Oblivion (2013), Similarity Rating: 0.04/1.00
# Movie: Percy Jackson & the Olympians: The Lightning Thief (2010), Similarity Rating: 0.04/1.00
# Movie: Wild Things (1998), Similarity Rating: 0.04/1.00
# Movie: Underworld: Rise of the Lycans (2009), Similarity Rating: 0.04/1.00
# Movie: Percy Jackson: Sea of Monsters (2013), Similarity Rating: 0.04/1.00
# Movie: Jumanji: Welcome to the Jungle (2017), Similarity Rating: 0.04/1.00
# Movie: Pursuit of Happyness, The (2006), Similarity Rating: 0.04/1.00
# Movie: Hobbit: The Desolation of Smaug, The (2013), Similarity Rating: 0.04/1.00
# Movie: Man of Steel (2013), Similarity Rating: 0.04/1.00
# Movie: Secretary (2002), Similarity Rating: 0.04/1.00
# Movie: Cars (2006), Similarity Rating: 0.04/1.00
# Movie: Entrapment (1999), Similarity Rating: 0.04/1.00
# Movie: Passengers (2016), Similarity Rating: 0.04/1.00
# Movie: Transformers: Revenge of the Fallen (2009), Similarity Rating: 0.04/1.00
# Movie: Girl Next Door, The (2004), Similarity Rating: 0.04/1.00
# Movie: Justice League (2017), Similarity Rating: 0.04/1.00
# Movie: Wedding Date, The (2005), Similarity Rating: 0.04/1.00
# Movie: The Adam Project (2022), Similarity Rating: 0.04/1.00
# Movie: Insurgent (2015), Similarity Rating: 0.04/1.00
# Movie: Horrible Bosses (2011), Similarity Rating: 0.04/1.00
# Movie: Jurassic World (2015), Similarity Rating: 0.04/1.00
# Movie: Nymphomaniac: Volume I (2013), Similarity Rating: 0.04/1.00
# Movie: Underworld: Evolution (2006), Similarity Rating: 0.04/1.00
# Movie: Jurassic Park (1993), Similarity Rating: 0.04/1.00
# Movie: Ocean's 8 (2018), Similarity Rating: 0.04/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.04/1.00
# Movie: Magnolia (1999), Similarity Rating: 0.04/1.00
# Movie: Ocean's Thirteen (2007), Similarity Rating: 0.04/1.00
# Movie: Crash (2004), Similarity Rating: 0.04/1.00
# Movie: Blended (2014), Similarity Rating: 0.04/1.00
# Movie: Divergent (2014), Similarity Rating: 0.04/1.00
# Movie: Sin City (2005), Similarity Rating: 0.04/1.00
# Movie: Sex and Lucia (Lucía y el sexo) (2001), Similarity Rating: 0.04/1.00
# Movie: Transformers: Age of Extinction (2014), Similarity Rating: 0.04/1.00
# Movie: Lord of War (2005), Similarity Rating: 0.04/1.00
# Movie: Lock, Stock & Two Smoking Barrels (1998), Similarity Rating: 0.04/1.00
# Movie: Independence Day (a.k.a. ID4) (1996), Similarity Rating: 0.04/1.00
# Movie: Fifty Shades Darker (2017), Similarity Rating: 0.04/1.00
# Movie: Notebook, The (2004), Similarity Rating: 0.04/1.00
# Movie: Source Code (2011), Similarity Rating: 0.04/1.00
# Movie: Bridesmaids (2011), Similarity Rating: 0.04/1.00
# Movie: Lethal Weapon 3 (1992), Similarity Rating: 0.04/1.00
# Movie: Ice Age (2002), Similarity Rating: 0.04/1.00
# Movie: John Wick (2014), Similarity Rating: 0.04/1.00
# Movie: Notting Hill (1999), Similarity Rating: 0.04/1.00
# Movie: Prometheus (2012), Similarity Rating: 0.04/1.00
# Movie: Easy A (2010), Similarity Rating: 0.04/1.00
# Movie: Ugly Truth, The (2009), Similarity Rating: 0.04/1.00
# Movie: The Perfect Date, Similarity Rating: 0.04/1.00
# Movie: Shazam! (2019), Similarity Rating: 0.04/1.00
# Movie: The Fate of the Furious (2017), Similarity Rating: 0.04/1.00
# Movie: Don't Look Up (2021), Similarity Rating: 0.04/1.00
# Movie: Truman Show, The (1998), Similarity Rating: 0.04/1.00
# Movie: Fugitive, The (1993), Similarity Rating: 0.04/1.00
# Movie: Star Trek Beyond (2016), Similarity Rating: 0.04/1.00
# Movie: Brave (2012), Similarity Rating: 0.04/1.00
# Movie: Clueless (1995), Similarity Rating: 0.04/1.00
# Movie: Caligula (1979), Similarity Rating: 0.04/1.00
# Movie: Under the Tuscan Sun (2003), Similarity Rating: 0.04/1.00
# Movie: Escape Plan (2013), Similarity Rating: 0.04/1.00
# Movie: John Wick: Chapter 3 – Parabellum (2019), Similarity Rating: 0.04/1.00
# Movie: Shang-Chi and the Legend of the Ten Rings (2021), Similarity Rating: 0.03/1.00
# Movie: Irreversible (Irréversible) (2002), Similarity Rating: 0.03/1.00
# Movie: Sex and the City (2008), Similarity Rating: 0.03/1.00
# Movie: Antichrist (2009), Similarity Rating: 0.03/1.00
# Movie: Friends with Benefits (2011), Similarity Rating: 0.03/1.00
# Movie: What If (2013), Similarity Rating: 0.03/1.00
# Movie: My Best Friend's Wedding (1997), Similarity Rating: 0.03/1.00
# Movie: It's Complicated (2009), Similarity Rating: 0.03/1.00
# Movie: When Harry Met Sally... (1989), Similarity Rating: 0.03/1.00
# Movie: Pokémon: Detective Pikachu (2019), Similarity Rating: 0.03/1.00
# Movie: Twilight Saga: Eclipse, The (2010), Similarity Rating: 0.03/1.00
# Movie: Free Guy (2020), Similarity Rating: 0.03/1.00
# Movie: Princess and the Frog, The (2009), Similarity Rating: 0.03/1.00
# Movie: Glass Onion: A Knives Out Mystery (2022), Similarity Rating: 0.03/1.00
# Movie: What Women Want (2000), Similarity Rating: 0.03/1.00
# Movie: I Am Number Four (2011), Similarity Rating: 0.03/1.00
# Movie: 22 Jump Street (2014), Similarity Rating: 0.03/1.00
# Movie: To Kill a Mockingbird (1962), Similarity Rating: 0.03/1.00
# Movie: Just Go with It (2011), Similarity Rating: 0.03/1.00

# %%
recommendations = get_recommendations(
    nmf_model=nmf_model,
    training_matrix=training_matrix,
    my_ratings=skellic_ratings,
    my_data=skellic_data,
    n_recommendations=200,
    movie_id_to_title_map=movie_id_to_title,
)
# Out:
# You've rated 338 movies
# Found 8990 movies you haven't rated
#
# Top Recommendations:
# Movie: Wolf of Wall Street, The (2013), Similarity Rating: 0.64/1.00
# Movie: Blade Runner (1982), Similarity Rating: 0.53/1.00
# Movie: Finding Nemo (2003), Similarity Rating: 0.52/1.00
# Movie: Black Swan (2010), Similarity Rating: 0.52/1.00
# Movie: Fargo (1996), Similarity Rating: 0.50/1.00
# Movie: Inception (2010), Similarity Rating: 0.46/1.00
# Movie: Scott Pilgrim vs. the World (2010), Similarity Rating: 0.45/1.00
# Movie: Fight Club (1999), Similarity Rating: 0.45/1.00
# Movie: Moonrise Kingdom (2012), Similarity Rating: 0.42/1.00
# Movie: Zodiac (2007), Similarity Rating: 0.41/1.00
# Movie: Reservoir Dogs (1992), Similarity Rating: 0.40/1.00
# Movie: Terminator, The (1984), Similarity Rating: 0.40/1.00
# Movie: Gladiator (2000), Similarity Rating: 0.39/1.00
# Movie: The Killing of a Sacred Deer (2017), Similarity Rating: 0.39/1.00
# Movie: Pirates of the Caribbean: At World's End (2007), Similarity Rating: 0.37/1.00
# Movie: Big Hero 6 (2014), Similarity Rating: 0.36/1.00
# Movie: City of God (Cidade de Deus) (2002), Similarity Rating: 0.36/1.00
# Movie: Ratatouille (2007), Similarity Rating: 0.35/1.00
# Movie: Lost in Translation (2003), Similarity Rating: 0.34/1.00
# Movie: Lady Bird (2017), Similarity Rating: 0.33/1.00
# Movie: Uncut Gems (2019), Similarity Rating: 0.33/1.00
# Movie: Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986), Similarity Rating: 0.32/1.00
# Movie: Us (2019), Similarity Rating: 0.32/1.00
# Movie: Ponyo (Gake no ue no Ponyo) (2008), Similarity Rating: 0.31/1.00
# Movie: The Handmaiden (2016), Similarity Rating: 0.31/1.00
# Movie: Cabin in the Woods, The (2012), Similarity Rating: 0.31/1.00
# Movie: Toy Story (1995), Similarity Rating: 0.31/1.00
# Movie: Moonlight, Similarity Rating: 0.30/1.00
# Movie: Good Will Hunting (1997), Similarity Rating: 0.30/1.00
# Movie: Three Billboards Outside Ebbing, Missouri (2017), Similarity Rating: 0.30/1.00
# Movie: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Similarity Rating: 0.30/1.00
# Movie: Star Wars: Episode IV - A New Hope (1977), Similarity Rating: 0.30/1.00
# Movie: Shutter Island (2010), Similarity Rating: 0.30/1.00
# Movie: Avengers: Infinity War - Part II (2019), Similarity Rating: 0.29/1.00
# Movie: Shawshank Redemption, The (1994), Similarity Rating: 0.29/1.00
# Movie: Coco (2017), Similarity Rating: 0.29/1.00
# Movie: Shining, The (1980), Similarity Rating: 0.28/1.00
# Movie: 101 Dalmatians (One Hundred and One Dalmatians) (1961), Similarity Rating: 0.28/1.00
# Movie: Your Name. (2016), Similarity Rating: 0.28/1.00
# Movie: Kiki's Delivery Service (Majo no takkyûbin) (1989), Similarity Rating: 0.27/1.00
# Movie: What We Do in the Shadows (2014), Similarity Rating: 0.27/1.00
# Movie: Wreck-It Ralph (2012), Similarity Rating: 0.27/1.00
# Movie: Interstellar (2014), Similarity Rating: 0.27/1.00
# Movie: Trainspotting (1996), Similarity Rating: 0.26/1.00
# Movie: Midnight in Paris (2011), Similarity Rating: 0.26/1.00
# Movie: Memento (2000), Similarity Rating: 0.26/1.00
# Movie: Akira (1988), Similarity Rating: 0.26/1.00
# Movie: Lives of Others, The (Das leben der Anderen) (2006), Similarity Rating: 0.26/1.00
# Movie: King's Speech, The (2010), Similarity Rating: 0.26/1.00
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Similarity Rating: 0.25/1.00
# Movie: Alice in Wonderland (2010), Similarity Rating: 0.25/1.00
# Movie: Portrait of a Lady on Fire (2019), Similarity Rating: 0.25/1.00
# Movie: Thor: Ragnarok (2017), Similarity Rating: 0.25/1.00
# Movie: Seven Psychopaths (2012), Similarity Rating: 0.25/1.00
# Movie: It Follows (2014), Similarity Rating: 0.25/1.00
# Movie: V for Vendetta (2006), Similarity Rating: 0.25/1.00
# Movie: Guardians of the Galaxy (2014), Similarity Rating: 0.25/1.00
# Movie: Office Space (1999), Similarity Rating: 0.24/1.00
# Movie: Avengers: Infinity War - Part I (2018), Similarity Rating: 0.24/1.00
# Movie: Peter Pan (1953), Similarity Rating: 0.24/1.00
# Movie: American Beauty (1999), Similarity Rating: 0.24/1.00
# Movie: Being John Malkovich (1999), Similarity Rating: 0.23/1.00
# Movie: Departed, The (2006), Similarity Rating: 0.23/1.00
# Movie: Big Short, The (2015), Similarity Rating: 0.23/1.00
# Movie: Black Panther (2017), Similarity Rating: 0.23/1.00
# Movie: The Invisible Man (2020), Similarity Rating: 0.23/1.00
# Movie: Star Wars: Episode V - The Empire Strikes Back (1980), Similarity Rating: 0.23/1.00
# Movie: Star Wars: Episode VI - Return of the Jedi (1983), Similarity Rating: 0.22/1.00
# Movie: Moon (2009), Similarity Rating: 0.22/1.00
# Movie: Jungle Book, The (1967), Similarity Rating: 0.22/1.00
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Similarity Rating: 0.22/1.00
# Movie: Isle of Dogs (2018), Similarity Rating: 0.21/1.00
# Movie: Big Fish (2003), Similarity Rating: 0.21/1.00
# Movie: Fifth Element, The (1997), Similarity Rating: 0.21/1.00
# Movie: Sixth Sense, The (1999), Similarity Rating: 0.21/1.00
# Movie: Mulholland Drive (2001), Similarity Rating: 0.21/1.00
# Movie: 21 Jump Street (2012), Similarity Rating: 0.21/1.00
# Movie: Spotlight (2015), Similarity Rating: 0.21/1.00
# Movie: Silver Linings Playbook (2012), Similarity Rating: 0.21/1.00
# Movie: Let the Right One In (Låt den rätte komma in) (2008), Similarity Rating: 0.20/1.00
# Movie: Inherent Vice (2014), Similarity Rating: 0.20/1.00
# Movie: Hunt for the Wilderpeople (2016), Similarity Rating: 0.20/1.00
# Movie: Tenet (2020), Similarity Rating: 0.20/1.00
# Movie: The Platform (2019), Similarity Rating: 0.20/1.00
# Movie: 20,000 Leagues Under the Sea (1954), Similarity Rating: 0.20/1.00
# Movie: The Shape of Water (2017), Similarity Rating: 0.20/1.00
# Movie: Lion King, The (1994), Similarity Rating: 0.20/1.00
# Movie: Tucker & Dale vs Evil (2010), Similarity Rating: 0.20/1.00
# Movie: The Machinist (2004), Similarity Rating: 0.20/1.00
# Movie: Dallas Buyers Club (2013), Similarity Rating: 0.20/1.00
# Movie: Hell or High Water (2016), Similarity Rating: 0.20/1.00
# Movie: Mother! (2017), Similarity Rating: 0.20/1.00
# Movie: Persepolis (2007), Similarity Rating: 0.20/1.00
# Movie: We Need to Talk About Kevin (2011), Similarity Rating: 0.20/1.00
# Movie: Sunshine (2007), Similarity Rating: 0.20/1.00
# Movie: Dark Knight Rises, The (2012), Similarity Rating: 0.19/1.00
# Movie: Megamind (2010), Similarity Rating: 0.19/1.00
# Movie: Solaris (Solyaris) (1972), Similarity Rating: 0.19/1.00
# Movie: Burn After Reading (2008), Similarity Rating: 0.19/1.00
# Movie: Ice Age (2002), Similarity Rating: 0.19/1.00
# Movie: Moana (2016), Similarity Rating: 0.19/1.00
# Movie: Clockwork Orange, A (1971), Similarity Rating: 0.19/1.00
# Movie: Green Room (2015), Similarity Rating: 0.19/1.00
# Movie: Tarzan (1999), Similarity Rating: 0.19/1.00
# Movie: Mean Girls (2004), Similarity Rating: 0.19/1.00
# Movie: Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005), Similarity Rating: 0.18/1.00
# Movie: Despicable Me (2010), Similarity Rating: 0.18/1.00
# Movie: Harry Potter and the Prisoner of Azkaban (2004), Similarity Rating: 0.18/1.00
# Movie: Taken (2008), Similarity Rating: 0.18/1.00
# Movie: Toy Story 2 (1999), Similarity Rating: 0.18/1.00
# Movie: Pineapple Express (2008), Similarity Rating: 0.18/1.00
# Movie: Independence Day (a.k.a. ID4) (1996), Similarity Rating: 0.18/1.00
# Movie: Deadpool 2 (2018), Similarity Rating: 0.18/1.00
# Movie: Split (2017), Similarity Rating: 0.18/1.00
# Movie: Martha Marcy May Marlene (2011), Similarity Rating: 0.18/1.00
# Movie: Toy Story 3 (2010), Similarity Rating: 0.18/1.00
# Movie: Charlie and the Chocolate Factory (2005), Similarity Rating: 0.18/1.00
# Movie: Brazil (1985), Similarity Rating: 0.17/1.00
# Movie: Die Hard (1988), Similarity Rating: 0.17/1.00
# Movie: Dogtooth (Kynodontas) (2009), Similarity Rating: 0.17/1.00
# Movie: Thank You for Smoking (2006), Similarity Rating: 0.17/1.00
# Movie: 12 Years a Slave (2013), Similarity Rating: 0.17/1.00
# Movie: High Fidelity (2000), Similarity Rating: 0.17/1.00
# Movie: Hunt for Red October, The (1990), Similarity Rating: 0.17/1.00
# Movie: Little Women (2019), Similarity Rating: 0.17/1.00
# Movie: I Saw the Devil (Akmareul boatda) (2010), Similarity Rating: 0.17/1.00
# Movie: Annihilation (2018), Similarity Rating: 0.17/1.00
# Movie: Sin City (2005), Similarity Rating: 0.17/1.00
# Movie: Great Beauty, The (Grande Bellezza, La) (2013), Similarity Rating: 0.17/1.00
# Movie: Psycho (1960), Similarity Rating: 0.17/1.00
# Movie: Collateral (2004), Similarity Rating: 0.17/1.00
# Movie: Ocean's Eleven (2001), Similarity Rating: 0.17/1.00
# Movie: Manchester by the Sea (2016), Similarity Rating: 0.17/1.00
# Movie: Apollo 13 (1995), Similarity Rating: 0.16/1.00
# Movie: I Am Legend (2007), Similarity Rating: 0.16/1.00
# Movie: Sleeping Beauty (1959), Similarity Rating: 0.16/1.00
# Movie: Looper (2012), Similarity Rating: 0.16/1.00
# Movie: Argo (2012), Similarity Rating: 0.16/1.00
# Movie: Incredibles 2 (2018), Similarity Rating: 0.16/1.00
# Movie: Searching (2018), Similarity Rating: 0.16/1.00
# Movie: Hitchhiker's Guide to the Galaxy, The (2005), Similarity Rating: 0.16/1.00
# Movie: Donnie Darko (2001), Similarity Rating: 0.16/1.00
# Movie: Only Lovers Left Alive (2013), Similarity Rating: 0.16/1.00
# Movie: School of Rock (2003), Similarity Rating: 0.16/1.00
# Movie: Booksmart (2019), Similarity Rating: 0.16/1.00
# Movie: Song of the Sea (2014), Similarity Rating: 0.16/1.00
# Movie: Spider-Man: Far from Home (2019), Similarity Rating: 0.16/1.00
# Movie: Blue Ruin (2013), Similarity Rating: 0.16/1.00
# Movie: Primer (2004), Similarity Rating: 0.15/1.00
# Movie: Frozen (2013), Similarity Rating: 0.15/1.00
# Movie: Mr. & Mrs. Smith (2005), Similarity Rating: 0.15/1.00
# Movie: Juno (2007), Similarity Rating: 0.15/1.00
# Movie: Before Midnight (2013), Similarity Rating: 0.15/1.00
# Movie: Shoplifters (2018), Similarity Rating: 0.15/1.00
# Movie: Whisper of the Heart (Mimi wo sumaseba) (1995), Similarity Rating: 0.15/1.00
# Movie: Iron Man (2008), Similarity Rating: 0.15/1.00
# Movie: Garden State (2004), Similarity Rating: 0.15/1.00
# Movie: The Martian (2015), Similarity Rating: 0.15/1.00
# Movie: Winter's Bone (2010), Similarity Rating: 0.15/1.00
# Movie: Minority Report (2002), Similarity Rating: 0.15/1.00
# Movie: Edward Scissorhands (1990), Similarity Rating: 0.15/1.00
# Movie: We're the Millers (2013), Similarity Rating: 0.15/1.00
# Movie: Thoroughbreds (2018), Similarity Rating: 0.15/1.00
# Movie: Edge of Tomorrow (2014), Similarity Rating: 0.15/1.00
# Movie: Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966), Similarity Rating: 0.15/1.00
# Movie: Palm Springs (2020), Similarity Rating: 0.15/1.00
# Movie: Bohemian Rhapsody (2018), Similarity Rating: 0.15/1.00
# Movie: Patriot, The (2000), Similarity Rating: 0.15/1.00
# Movie: I'm Thinking of Ending Things, Similarity Rating: 0.15/1.00
# Movie: 40-Year-Old Virgin, The (2005), Similarity Rating: 0.15/1.00
# Movie: The Farewell (2019), Similarity Rating: 0.15/1.00
# Movie: Love Actually (2003), Similarity Rating: 0.15/1.00
# Movie: Untitled Spider-Man Reboot (2017), Similarity Rating: 0.15/1.00
# Movie: Inside Man (2006), Similarity Rating: 0.14/1.00
# Movie: Ready Player One, Similarity Rating: 0.14/1.00
# Movie: Million Dollar Baby (2004), Similarity Rating: 0.14/1.00
# Movie: Help, The (2011), Similarity Rating: 0.14/1.00
# Movie: Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000), Similarity Rating: 0.14/1.00
# Movie: Wolf Children (Okami kodomo no ame to yuki) (2012), Similarity Rating: 0.14/1.00
# Movie: Jackie Brown (1997), Similarity Rating: 0.14/1.00
# Movie: Boondock Saints, The (2000), Similarity Rating: 0.14/1.00
# Movie: X-Men (2000), Similarity Rating: 0.14/1.00
# Movie: Logan (2017), Similarity Rating: 0.14/1.00
# Movie: It Comes at Night (2017), Similarity Rating: 0.14/1.00
# Movie: Ocean's Thirteen (2007), Similarity Rating: 0.14/1.00
# Movie: Pirates of the Caribbean: On Stranger Tides (2011), Similarity Rating: 0.14/1.00
# Movie: A Simple Favor (2018), Similarity Rating: 0.14/1.00
# Movie: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964), Similarity Rating: 0.14/1.00
# Movie: Cat Returns, The (Neko no ongaeshi) (2002), Similarity Rating: 0.14/1.00
# Movie: Possession (1981), Similarity Rating: 0.14/1.00
# Movie: Mommy (2014), Similarity Rating: 0.14/1.00
# Movie: Carol (2015), Similarity Rating: 0.14/1.00
# Movie: 13th Warrior, The (1999), Similarity Rating: 0.14/1.00
# Movie: Perks of Being a Wallflower, The (2012), Similarity Rating: 0.14/1.00
# Movie: American Werewolf in London, An (1981), Similarity Rating: 0.13/1.00
# Movie: Zoolander (2001), Similarity Rating: 0.13/1.00
# Movie: Brawl in Cell Block 99 (2017), Similarity Rating: 0.13/1.00
# Movie: Frances Ha (2012), Similarity Rating: 0.13/1.00
# Movie: Devil Wears Prada, The (2006), Similarity Rating: 0.13/1.00
# Movie: Synecdoche, New York (2008), Similarity Rating: 0.13/1.00
